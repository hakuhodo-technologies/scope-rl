# %% [markdown]
# # Quickstart Example of Off-Policy Evaluation with Various Estimators (Discrete)
# This notebook provides an example of conducting **Off-policy Evaluation (OPE)** with a synthetic Real-Time Bidding (RTB) dataset and various OPE estimators (e.g., model-based vs importance sampling-based, marginal importance sampling, and double reinforcement learning).
#
# This example consists of the following 3 steps:
# 1. Setup, Synthetic Data Generation, and Offline Policy Learning
# 2. Off-Policy Evaluation (OPE) with various estimators
#
# \* This library uses [d3rlpy](https://github.com/takuseno/d3rlpy)'s algorithm implementations of offline rl policies and model-based evaluation.
# \* Also, our implementations of OPE are highly inspired by [Open Bandit Pipeline](https://github.com/st-tech/zr-obp).

# %%
# delete later
# %load_ext autoreload
# %autoreload 2

# %%
# delete later
import warnings
warnings.simplefilter('ignore')

# %%
# delete later
import sys
sys.path.append('../')
sys.path.append('../../')

# %%
# import OFRL modules
import ofrl
from rtbgym import RTBEnv, CustomizedRTBEnv
from ofrl.dataset import SyntheticDataset
from ofrl.policy import OnlineHead
from ofrl.policy import DiscreteEpsilonGreedyHead as EpsilonGreedyHead
from ofrl.policy import DiscreteSoftmaxHead as SoftmaxHead
from ofrl.ope.online import (
    calc_on_policy_policy_value,
    visualize_on_policy_policy_value,
)
from ofrl.utils import MinMaxScaler

# import d3rlpy algorithms
from d3rlpy.algos import DiscreteRandomPolicy as RandomPolicy
from d3rlpy.preprocessing import MinMaxScaler

# import from other libraries
import gym
import torch
from sklearn.model_selection import train_test_split

# %%
import pickle
from glob import glob
from tqdm import tqdm

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# version
print(ofrl.__version__)
# Out:
# 0.0.0

# %%
# set random state
random_state = 12345

# %%
# log directory
from pathlib import Path
Path("logs/").mkdir(exist_ok=True)

# %% [markdown]
# ## 1. Setup, Synthetic Data Generation, and Offline Policy Learning
# To begin with, we briefly describe how the RTB environment works.
#
# #### RL setup for RTB
# In RTB, the objective of the RL agent is to maximize some KPIs (number of clicks or conversions) within an episode under given budget constraints.
#
# We often try to achieve this by adjusting bidding price function parameter $\alpha$. By using $\alpha$, we can adjust the bid price as follows.
# $bid_{t,i} = \alpha \cdot r^{\ast}$,
# where $r^{\ast}$ denotes a predicted or expected reward (KPIs).
#
# We often formulate this RTB problem as the following Constrained Markov Decision Process (CMDP):
# - `timestep`: One episode (a day or a week) consists of several timesteps (24 hours or seven days, for instance).
# - `state`: We observe some feedback from the environment at each timestep, which includes the following.
#   - timestep
#   - remaining budget
#   - impression level features (budget consumption rate, cost per mille of impressions, auction winning rate, reward) at the previous timestep
#   - adjust rate (RL agent's decision making) at the previous timestep
# - `action`: Agent chooses adjust rate parameter $\alpha$ to maximize KPIs.
# - `reward`: Total number of clicks or conversions obtained during the timestep.
# - `constraints`: The pre-determined episodic budget should not be exceeded.
#
# For more about the environmental configuration and its customization, please refer to [examples/quickstart/rtb_synthetic_customize_env.ipynb](https://github.com/negocia-inc/rtb_reinforcement_learing/blob/ope/examples/quickstart/rtb_synthetic_customize_env.ipynb).

# %%
# standardized environment for discrete action
env = gym.make("RTBEnv-discrete-v0")

# %%
# for api compatibility to d3rlpy
from ofrl.utils import OldGymAPIWrapper
env_ = OldGymAPIWrapper(env)

# %% [markdown]
# #### Synthetic Data Generation
# Next, we collect logged data with the uniform random agent.
#
# `SyntheticDataset` has the following arguments:
# - `env`: RTB environment for RL defined in the previous section.
# - `behavior_policy`: RL agent (or algorithm) used for the data collection.
# - `maximum_step_per_episode`: Maximum number of timesteps in an episode.
# - `action_meaning`: Dictionary which maps discrete action index into specific actions.
# - `action_keys`: Name of the action variable at each dimension.
# - `state_keys`: Name of the state variable at each dimension.
# - `info_keys`: Dictionary containing of key and the type of info components.
# - `random_state`: Random state.
#
# For more about the data collection and visualization, please refer to [examples/quickstart/rtb_synthetic_data_collection.ipynb](https://github.com/negocia-inc/rtb_reinforcement_learing/blob/ope/examples/quickstart/rtb_synthetic_data_collection.ipynb).

# %%
# behavior policy
from d3rlpy.algos import DoubleDQN
from d3rlpy.models.encoders import VectorEncoderFactory
from d3rlpy.models.q_functions import MeanQFunctionFactory
from d3rlpy.online.buffers import ReplayBuffer
from d3rlpy.online.explorers import LinearDecayEpsilonGreedy

# model
ddqn = DoubleDQN(
    encoder_factory=VectorEncoderFactory(hidden_units=[30, 30]),
    q_func_factory=MeanQFunctionFactory(),
    target_update_interval=100,
    use_gpu=torch.cuda.is_available(),
)
# replay buffer
buffer = ReplayBuffer(
    maxlen=10000,
    env=env_,
)
# explorers
explorer = LinearDecayEpsilonGreedy(
    start_epsilon=1.0,
    end_epsilon=0.1,
    duration=1000,
)

# %%
# start training
# skip if there is a pre-trained model
ddqn.fit_online(
    env_,
    buffer,
    explorer=explorer,
    eval_env=env_,
    n_steps=100000,
    n_steps_per_epoch=1000,
    update_start_step=1000,
)
# Out:
# 2022-12-03 13:57.43 [info     ] Directory is created at d3rlpy_logs/DoubleDQN_online_20221203135743
# 2022-12-03 13:57.43 [debug    ] Building model...
# 2022-12-03 13:57.43 [debug    ] Model has been built.
# 2022-12-03 13:57.44 [info     ] Parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/params.json params={'action_scaler': None, 'batch_size': 32, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 0.99, 'generated_maxlen': 100000, 'learning_rate': 6.25e-05, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': None, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'DoubleDQN', 'observation_shape': (7,), 'action_size': 10}
#   0%|          | 0/100000 [00:00<?, ?it/s]
# 2022-12-03 13:57.46 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_1000.pt
# 2022-12-03 13:57.46 [info     ] DoubleDQN_online_20221203135743: epoch=1 step=1000 epoch=1 metrics={'time_inference': 0.0006497440338134766, 'time_environment_step': 0.0012680521011352538, 'time_step': 0.0019861850738525392, 'rollout_return': 10.47887323943662, 'evaluation': 11.6} step=1000
# 2022-12-03 13:58.08 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_2000.pt
# 2022-12-03 13:58.08 [info     ] DoubleDQN_online_20221203135743: epoch=2 step=2000 epoch=2 metrics={'time_inference': 0.0006359632015228271, 'time_environment_step': 0.0011641364097595215, 'time_sample_batch': 0.00011694121360778809, 'time_algorithm_update': 0.01982594919204712, 'loss': 47.2127366771698, 'time_step': 0.021863140344619753, 'rollout_return': 2.880281690140845, 'evaluation': 0.3} step=2000
# 2022-12-03 13:58.28 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_3000.pt
# 2022-12-03 13:58.28 [info     ] DoubleDQN_online_20221203135743: epoch=3 step=3000 epoch=3 metrics={'time_inference': 0.0005456216335296631, 'time_environment_step': 0.0010932540893554687, 'time_sample_batch': 0.00015882587432861328, 'time_algorithm_update': 0.017876347303390504, 'loss': 26.310031145095824, 'time_step': 0.019772937774658203, 'rollout_return': 2.26056338028169, 'evaluation': 0.0} step=3000
# 2022-12-03 13:58.49 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_4000.pt
# 2022-12-03 13:58.49 [info     ] DoubleDQN_online_20221203135743: epoch=4 step=4000 epoch=4 metrics={'time_inference': 0.0005328032970428467, 'time_environment_step': 0.0010894198417663575, 'time_sample_batch': 0.00012761592864990234, 'time_algorithm_update': 0.018386427879333495, 'loss': 21.371396664857865, 'time_step': 0.020222843885421754, 'rollout_return': 2.1690140845070425, 'evaluation': 0.0} step=4000
# 2022-12-03 13:59.10 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_5000.pt
# 2022-12-03 13:59.10 [info     ] DoubleDQN_online_20221203135743: epoch=5 step=5000 epoch=5 metrics={'time_inference': 0.000523761510848999, 'time_environment_step': 0.0011312575340270995, 'time_sample_batch': 0.00017151594161987304, 'time_algorithm_update': 0.018547494888305663, 'loss': 17.537997898101807, 'time_step': 0.02047631335258484, 'rollout_return': 2.1690140845070425, 'evaluation': 0.0} step=5000
# 2022-12-03 13:59.29 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_6000.pt
# 2022-12-03 13:59.29 [info     ] DoubleDQN_online_20221203135743: epoch=6 step=6000 epoch=6 metrics={'time_inference': 0.0005870180130004883, 'time_environment_step': 0.0012244477272033692, 'time_sample_batch': 0.00014687323570251464, 'time_algorithm_update': 0.016803038358688356, 'loss': 13.882774187922477, 'time_step': 0.01886590838432312, 'rollout_return': 2.3380281690140845, 'evaluation': 0.0} step=6000
# 2022-12-03 13:59.44 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_7000.pt
# 2022-12-03 13:59.44 [info     ] DoubleDQN_online_20221203135743: epoch=7 step=7000 epoch=7 metrics={'time_inference': 0.0004882762432098389, 'time_environment_step': 0.001048452377319336, 'time_sample_batch': 0.00014304566383361816, 'time_algorithm_update': 0.01290486764907837, 'loss': 9.882585637807846, 'time_step': 0.014690790176391601, 'rollout_return': 3.859154929577465, 'evaluation': 2.4} step=7000
# 2022-12-03 14:00.06 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_8000.pt
# 2022-12-03 14:00.06 [info     ] DoubleDQN_online_20221203135743: epoch=8 step=8000 epoch=8 metrics={'time_inference': 0.0006361746788024902, 'time_environment_step': 0.0011907227039337157, 'time_sample_batch': 0.00013394832611083986, 'time_algorithm_update': 0.019914119482040405, 'loss': 7.4068307482004165, 'time_step': 0.021990173101425172, 'rollout_return': 4.457746478873239, 'evaluation': 9.5} step=8000
# 2022-12-03 14:00.28 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_9000.pt
# 2022-12-03 14:00.28 [info     ] DoubleDQN_online_20221203135743: epoch=9 step=9000 epoch=9 metrics={'time_inference': 0.0006112143993377686, 'time_environment_step': 0.0012682616710662843, 'time_sample_batch': 0.00012157583236694336, 'time_algorithm_update': 0.018686956167221068, 'loss': 4.893276903748513, 'time_step': 0.020823081731796266, 'rollout_return': 8.887323943661972, 'evaluation': 14.6} step=9000
# 2022-12-03 14:00.49 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_10000.pt
# 2022-12-03 14:00.49 [info     ] DoubleDQN_online_20221203135743: epoch=10 step=10000 epoch=10 metrics={'time_inference': 0.0005622479915618897, 'time_environment_step': 0.0010714268684387208, 'time_sample_batch': 0.00012522363662719727, 'time_algorithm_update': 0.019228681564331055, 'loss': 3.329903755068779, 'time_step': 0.02106977725028992, 'rollout_return': 11.753521126760564, 'evaluation': 18.6} step=10000
# 2022-12-03 14:01.02 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_11000.pt
# 2022-12-03 14:01.02 [info     ] DoubleDQN_online_20221203135743: epoch=11 step=11000 epoch=11 metrics={'time_inference': 0.0004921445846557618, 'time_environment_step': 0.0009629206657409668, 'time_sample_batch': 0.0001651163101196289, 'time_algorithm_update': 0.010765725374221801, 'loss': 2.7998537080287935, 'time_step': 0.012481643915176392, 'rollout_return': 13.71830985915493, 'evaluation': 14.5} step=11000
# 2022-12-03 14:01.06 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_12000.pt
# 2022-12-03 14:01.06 [info     ] DoubleDQN_online_20221203135743: epoch=12 step=12000 epoch=12 metrics={'time_inference': 0.000468360424041748, 'time_environment_step': 0.0009740362167358398, 'time_sample_batch': 0.00011687564849853515, 'time_algorithm_update': 0.002388333320617676, 'loss': 2.73180625885725, 'time_step': 0.004032403469085693, 'rollout_return': 13.32394366197183, 'evaluation': 0.0} step=12000
# 2022-12-03 14:01.10 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_13000.pt
# 2022-12-03 14:01.10 [info     ] DoubleDQN_online_20221203135743: epoch=13 step=13000 epoch=13 metrics={'time_inference': 0.0004811680316925049, 'time_environment_step': 0.0009810447692871094, 'time_sample_batch': 0.00011850357055664063, 'time_algorithm_update': 0.0023475704193115236, 'loss': 2.2387574243545534, 'time_step': 0.004014707565307617, 'rollout_return': 14.45774647887324, 'evaluation': 15.6} step=13000
# 2022-12-03 14:01.16 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_14000.pt
# 2022-12-03 14:01.16 [info     ] DoubleDQN_online_20221203135743: epoch=14 step=14000 epoch=14 metrics={'time_inference': 0.0005463624000549317, 'time_environment_step': 0.0011126337051391602, 'time_sample_batch': 0.00014472270011901855, 'time_algorithm_update': 0.0032568888664245605, 'loss': 2.069347602009773, 'time_step': 0.005158446311950684, 'rollout_return': 14.711267605633802, 'evaluation': 0.0} step=14000
# 2022-12-03 14:01.21 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_15000.pt
# 2022-12-03 14:01.21 [info     ] DoubleDQN_online_20221203135743: epoch=15 step=15000 epoch=15 metrics={'time_inference': 0.0005678303241729736, 'time_environment_step': 0.0011512444019317627, 'time_sample_batch': 0.0001373598575592041, 'time_algorithm_update': 0.0034122955799102783, 'loss': 1.9664706978201867, 'time_step': 0.005375614881515503, 'rollout_return': 13.02112676056338, 'evaluation': 10.9} step=15000
# 2022-12-03 14:01.25 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_16000.pt
# 2022-12-03 14:01.26 [info     ] DoubleDQN_online_20221203135743: epoch=16 step=16000 epoch=16 metrics={'time_inference': 0.0004521503448486328, 'time_environment_step': 0.0009338152408599853, 'time_sample_batch': 0.00011258625984191895, 'time_algorithm_update': 0.0024500222206115725, 'loss': 1.669927763491869, 'time_step': 0.004030817031860352, 'rollout_return': 14.32394366197183, 'evaluation': 15.2} step=16000
# 2022-12-03 14:01.30 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_17000.pt
# 2022-12-03 14:01.30 [info     ] DoubleDQN_online_20221203135743: epoch=17 step=17000 epoch=17 metrics={'time_inference': 0.00046433138847351075, 'time_environment_step': 0.0009432783126831055, 'time_sample_batch': 0.00011844849586486817, 'time_algorithm_update': 0.0024942615032196047, 'loss': 1.4415444832742215, 'time_step': 0.004106707096099853, 'rollout_return': 14.338028169014084, 'evaluation': 15.9} step=17000
# 2022-12-03 14:01.34 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_18000.pt
# 2022-12-03 14:01.34 [info     ] DoubleDQN_online_20221203135743: epoch=18 step=18000 epoch=18 metrics={'time_inference': 0.0004978713989257813, 'time_environment_step': 0.001002802610397339, 'time_sample_batch': 0.0001297171115875244, 'time_algorithm_update': 0.0026376454830169677, 'loss': 1.2461864431798457, 'time_step': 0.004378027200698852, 'rollout_return': 13.908450704225352, 'evaluation': 14.6} step=18000
# 2022-12-03 14:01.38 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_19000.pt
# 2022-12-03 14:01.38 [info     ] DoubleDQN_online_20221203135743: epoch=19 step=19000 epoch=19 metrics={'time_inference': 0.0004545774459838867, 'time_environment_step': 0.0009040262699127197, 'time_sample_batch': 0.00011727690696716308, 'time_algorithm_update': 0.0021607804298400877, 'loss': 1.0821974020600318, 'time_step': 0.003720482587814331, 'rollout_return': 15.788732394366198, 'evaluation': 16.1} step=19000
# 2022-12-03 14:01.42 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_20000.pt
# 2022-12-03 14:01.42 [info     ] DoubleDQN_online_20221203135743: epoch=20 step=20000 epoch=20 metrics={'time_inference': 0.0004539377689361572, 'time_environment_step': 0.0009254117012023926, 'time_sample_batch': 0.0001251363754272461, 'time_algorithm_update': 0.002325520753860474, 'loss': 0.9890913976728917, 'time_step': 0.003915996074676514, 'rollout_return': 14.21830985915493, 'evaluation': 13.1} step=20000
# 2022-12-03 14:02.03 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_21000.pt
# 2022-12-03 14:02.03 [info     ] DoubleDQN_online_20221203135743: epoch=21 step=21000 epoch=21 metrics={'time_inference': 0.0007025058269500733, 'time_environment_step': 0.0012301580905914307, 'time_sample_batch': 0.00012416529655456544, 'time_algorithm_update': 0.01764860725402832, 'loss': 1.0233016096949576, 'time_step': 0.019811517477035523, 'rollout_return': 13.732394366197184, 'evaluation': 16.8} step=21000
# 2022-12-03 14:02.25 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_22000.pt
# 2022-12-03 14:02.25 [info     ] DoubleDQN_online_20221203135743: epoch=22 step=22000 epoch=22 metrics={'time_inference': 0.0006269283294677734, 'time_environment_step': 0.0010139284133911133, 'time_sample_batch': 0.00013227462768554686, 'time_algorithm_update': 0.019676878929138185, 'loss': 1.0346979552209377, 'time_step': 0.0215343496799469, 'rollout_return': 14.32394366197183, 'evaluation': 16.5} step=22000
# 2022-12-03 14:02.47 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_23000.pt
# 2022-12-03 14:02.47 [info     ] DoubleDQN_online_20221203135743: epoch=23 step=23000 epoch=23 metrics={'time_inference': 0.0005931742191314697, 'time_environment_step': 0.0012268130779266358, 'time_sample_batch': 0.0001241014003753662, 'time_algorithm_update': 0.020124444484710693, 'loss': 1.0724797537326813, 'time_step': 0.022166970252990723, 'rollout_return': 13.507042253521126, 'evaluation': 14.9} step=23000
# 2022-12-03 14:03.14 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_24000.pt
# 2022-12-03 14:03.14 [info     ] DoubleDQN_online_20221203135743: epoch=24 step=24000 epoch=24 metrics={'time_inference': 0.0007227790355682373, 'time_environment_step': 0.0012619767189025878, 'time_sample_batch': 0.00018607783317565918, 'time_algorithm_update': 0.023596174955368043, 'loss': 1.0704053875207902, 'time_step': 0.02586825394630432, 'rollout_return': 14.394366197183098, 'evaluation': 16.8} step=24000
# 2022-12-03 14:03.37 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_25000.pt
# 2022-12-03 14:03.37 [info     ] DoubleDQN_online_20221203135743: epoch=25 step=25000 epoch=25 metrics={'time_inference': 0.0008002521991729737, 'time_environment_step': 0.0012740707397460938, 'time_sample_batch': 0.0001496577262878418, 'time_algorithm_update': 0.020489367246627806, 'loss': 1.0547673656344414, 'time_step': 0.022835562467575073, 'rollout_return': 14.5, 'evaluation': 15.0} step=25000
# 2022-12-03 14:03.58 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_26000.pt
# 2022-12-03 14:03.58 [info     ] DoubleDQN_online_20221203135743: epoch=26 step=26000 epoch=26 metrics={'time_inference': 0.0005984117984771728, 'time_environment_step': 0.0011794636249542237, 'time_sample_batch': 0.00013625526428222656, 'time_algorithm_update': 0.018628259658813477, 'loss': 1.1392845824360847, 'time_step': 0.020666024684906005, 'rollout_return': 14.056338028169014, 'evaluation': 16.0} step=26000
# 2022-12-03 14:04.21 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_27000.pt
# 2022-12-03 14:04.21 [info     ] DoubleDQN_online_20221203135743: epoch=27 step=27000 epoch=27 metrics={'time_inference': 0.000559863805770874, 'time_environment_step': 0.001174584150314331, 'time_sample_batch': 0.00013655591011047362, 'time_algorithm_update': 0.021016107559204102, 'loss': 1.0334417403042317, 'time_step': 0.022977632999420166, 'rollout_return': 15.070422535211268, 'evaluation': 15.9} step=27000
# 2022-12-03 14:04.41 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_28000.pt
# 2022-12-03 14:04.41 [info     ] DoubleDQN_online_20221203135743: epoch=28 step=28000 epoch=28 metrics={'time_inference': 0.0006613121032714844, 'time_environment_step': 0.0011991243362426758, 'time_sample_batch': 0.00011279129981994629, 'time_algorithm_update': 0.01697898554801941, 'loss': 1.041049880221486, 'time_step': 0.019051480770111085, 'rollout_return': 13.746478873239436, 'evaluation': 3.2} step=28000
# 2022-12-03 14:05.05 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_29000.pt
# 2022-12-03 14:05.05 [info     ] DoubleDQN_online_20221203135743: epoch=29 step=29000 epoch=29 metrics={'time_inference': 0.0006629352569580078, 'time_environment_step': 0.0013058989048004151, 'time_sample_batch': 0.0001512589454650879, 'time_algorithm_update': 0.02157468891143799, 'loss': 1.0148691041171551, 'time_step': 0.02379814028739929, 'rollout_return': 15.73943661971831, 'evaluation': 15.7} step=29000
# 2022-12-03 14:05.27 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_30000.pt
# 2022-12-03 14:05.28 [info     ] DoubleDQN_online_20221203135743: epoch=30 step=30000 epoch=30 metrics={'time_inference': 0.000677844762802124, 'time_environment_step': 0.0011378414630889894, 'time_sample_batch': 0.00017373108863830567, 'time_algorithm_update': 0.019957611322402955, 'loss': 0.9834662842750549, 'time_step': 0.022052741289138793, 'rollout_return': 14.922535211267606, 'evaluation': 16.5} step=30000
# 2022-12-03 14:05.52 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_31000.pt
# 2022-12-03 14:05.53 [info     ] DoubleDQN_online_20221203135743: epoch=31 step=31000 epoch=31 metrics={'time_inference': 0.0006323330402374268, 'time_environment_step': 0.001260640859603882, 'time_sample_batch': 0.0001482391357421875, 'time_algorithm_update': 0.021920575618743898, 'loss': 0.9379102164655924, 'time_step': 0.02410309100151062, 'rollout_return': 15.47887323943662, 'evaluation': 14.2} step=31000
# 2022-12-03 14:06.16 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_32000.pt
# 2022-12-03 14:06.16 [info     ] DoubleDQN_online_20221203135743: epoch=32 step=32000 epoch=32 metrics={'time_inference': 0.0007259740829467774, 'time_environment_step': 0.0012630081176757812, 'time_sample_batch': 0.00013514113426208496, 'time_algorithm_update': 0.02048886013031006, 'loss': 0.9123132690638304, 'time_step': 0.02271088981628418, 'rollout_return': 14.78169014084507, 'evaluation': 14.6} step=32000
# 2022-12-03 14:06.37 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_33000.pt
# 2022-12-03 14:06.38 [info     ] DoubleDQN_online_20221203135743: epoch=33 step=33000 epoch=33 metrics={'time_inference': 0.0006347873210906982, 'time_environment_step': 0.0011418869495391846, 'time_sample_batch': 0.00014342260360717773, 'time_algorithm_update': 0.019211040496826173, 'loss': 0.905371645539999, 'time_step': 0.02126547312736511, 'rollout_return': 15.098591549295774, 'evaluation': 14.3} step=33000
# 2022-12-03 14:07.02 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_34000.pt
# 2022-12-03 14:07.02 [info     ] DoubleDQN_online_20221203135743: epoch=34 step=34000 epoch=34 metrics={'time_inference': 0.0006446077823638916, 'time_environment_step': 0.0011987078189849853, 'time_sample_batch': 0.00013199520111083985, 'time_algorithm_update': 0.021551936626434325, 'loss': 0.9025298906564713, 'time_step': 0.023619208335876465, 'rollout_return': 15.28169014084507, 'evaluation': 12.0} step=34000
# 2022-12-03 14:07.08 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_35000.pt
# 2022-12-03 14:07.08 [info     ] DoubleDQN_online_20221203135743: epoch=35 step=35000 epoch=35 metrics={'time_inference': 0.0005054662227630616, 'time_environment_step': 0.0009961676597595214, 'time_sample_batch': 0.00014104723930358887, 'time_algorithm_update': 0.00438791561126709, 'loss': 0.8638453578054905, 'time_step': 0.006123483896255493, 'rollout_return': 15.316901408450704, 'evaluation': 14.5} step=35000
# 2022-12-03 14:07.12 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_36000.pt
# 2022-12-03 14:07.12 [info     ] DoubleDQN_online_20221203135743: epoch=36 step=36000 epoch=36 metrics={'time_inference': 0.00044543123245239255, 'time_environment_step': 0.0009247615337371827, 'time_sample_batch': 0.00012175297737121582, 'time_algorithm_update': 0.0023633008003234863, 'loss': 0.8127269303053617, 'time_step': 0.003936858892440796, 'rollout_return': 15.070422535211268, 'evaluation': 16.8} step=36000
# 2022-12-03 14:07.16 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_37000.pt
# 2022-12-03 14:07.16 [info     ] DoubleDQN_online_20221203135743: epoch=37 step=37000 epoch=37 metrics={'time_inference': 0.00046515774726867674, 'time_environment_step': 0.0009565250873565674, 'time_sample_batch': 0.00011812400817871093, 'time_algorithm_update': 0.002300294876098633, 'loss': 0.8081723880022764, 'time_step': 0.003927066564559937, 'rollout_return': 14.880281690140846, 'evaluation': 14.3} step=37000
# 2022-12-03 14:07.20 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_38000.pt
# 2022-12-03 14:07.21 [info     ] DoubleDQN_online_20221203135743: epoch=38 step=38000 epoch=38 metrics={'time_inference': 0.0004789280891418457, 'time_environment_step': 0.0009766476154327393, 'time_sample_batch': 0.00012288260459899903, 'time_algorithm_update': 0.002488344430923462, 'loss': 0.8570233559012413, 'time_step': 0.0041529273986816405, 'rollout_return': 13.704225352112676, 'evaluation': 13.6} step=38000
# 2022-12-03 14:07.25 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_39000.pt
# 2022-12-03 14:07.25 [info     ] DoubleDQN_online_20221203135743: epoch=39 step=39000 epoch=39 metrics={'time_inference': 0.00047290444374084475, 'time_environment_step': 0.000976956605911255, 'time_sample_batch': 0.0001204218864440918, 'time_algorithm_update': 0.0022896852493286134, 'loss': 0.830306076362729, 'time_step': 0.003947814226150512, 'rollout_return': 14.549295774647888, 'evaluation': 16.2} step=39000
# 2022-12-03 14:07.28 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_40000.pt
# 2022-12-03 14:07.28 [info     ] DoubleDQN_online_20221203135743: epoch=40 step=40000 epoch=40 metrics={'time_inference': 0.00044243335723876954, 'time_environment_step': 0.0008980197906494141, 'time_sample_batch': 0.00011181569099426269, 'time_algorithm_update': 0.002073573112487793, 'loss': 0.8531491012573242, 'time_step': 0.0036062426567077636, 'rollout_return': 15.373239436619718, 'evaluation': 16.5} step=40000
# 2022-12-03 14:07.32 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_41000.pt
# 2022-12-03 14:07.32 [info     ] DoubleDQN_online_20221203135743: epoch=41 step=41000 epoch=41 metrics={'time_inference': 0.00041657161712646486, 'time_environment_step': 0.0008605785369873046, 'time_sample_batch': 0.00010730648040771485, 'time_algorithm_update': 0.001960308313369751, 'loss': 0.8155228536576032, 'time_step': 0.003423046112060547, 'rollout_return': 15.190140845070422, 'evaluation': 14.5} step=41000
# 2022-12-03 14:07.36 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_42000.pt
# 2022-12-03 14:07.36 [info     ] DoubleDQN_online_20221203135743: epoch=42 step=42000 epoch=42 metrics={'time_inference': 0.0004958007335662842, 'time_environment_step': 0.0009532146453857422, 'time_sample_batch': 0.00011767315864562989, 'time_algorithm_update': 0.0024281747341156007, 'loss': 0.9350776007324457, 'time_step': 0.004080313920974732, 'rollout_return': 14.894366197183098, 'evaluation': 12.8} step=42000
# 2022-12-03 14:07.41 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_43000.pt
# 2022-12-03 14:07.41 [info     ] DoubleDQN_online_20221203135743: epoch=43 step=43000 epoch=43 metrics={'time_inference': 0.0004628033638000488, 'time_environment_step': 0.0009487488269805908, 'time_sample_batch': 0.00011771726608276368, 'time_algorithm_update': 0.002738779306411743, 'loss': 0.8123657580912114, 'time_step': 0.004367815256118774, 'rollout_return': 14.887323943661972, 'evaluation': 17.2} step=43000
# 2022-12-03 14:07.46 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_44000.pt
# 2022-12-03 14:07.46 [info     ] DoubleDQN_online_20221203135743: epoch=44 step=44000 epoch=44 metrics={'time_inference': 0.0005427229404449462, 'time_environment_step': 0.001051924467086792, 'time_sample_batch': 0.0001321566104888916, 'time_algorithm_update': 0.003353217124938965, 'loss': 0.861064628303051, 'time_step': 0.005177094697952271, 'rollout_return': 14.915492957746478, 'evaluation': 15.9} step=44000
# 2022-12-03 14:07.51 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_45000.pt
# 2022-12-03 14:07.51 [info     ] DoubleDQN_online_20221203135743: epoch=45 step=45000 epoch=45 metrics={'time_inference': 0.0004711146354675293, 'time_environment_step': 0.0010159997940063477, 'time_sample_batch': 0.0001219325065612793, 'time_algorithm_update': 0.002674858570098877, 'loss': 0.8413710850328207, 'time_step': 0.004370044469833374, 'rollout_return': 14.56338028169014, 'evaluation': 14.4} step=45000
# 2022-12-03 14:07.55 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_46000.pt
# 2022-12-03 14:07.55 [info     ] DoubleDQN_online_20221203135743: epoch=46 step=46000 epoch=46 metrics={'time_inference': 0.0004858722686767578, 'time_environment_step': 0.0009601571559906005, 'time_sample_batch': 0.00013835763931274413, 'time_algorithm_update': 0.0025294551849365235, 'loss': 0.8550421274006367, 'time_step': 0.0042021584510803225, 'rollout_return': 15.084507042253522, 'evaluation': 15.8} step=46000
# 2022-12-03 14:07.59 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_47000.pt
# 2022-12-03 14:08.00 [info     ] DoubleDQN_online_20221203135743: epoch=47 step=47000 epoch=47 metrics={'time_inference': 0.00047498488426208496, 'time_environment_step': 0.0009693644046783448, 'time_sample_batch': 0.00011788368225097656, 'time_algorithm_update': 0.0023278779983520507, 'loss': 0.8607678637057543, 'time_step': 0.003979093790054321, 'rollout_return': 15.394366197183098, 'evaluation': 15.5} step=47000
# 2022-12-03 14:08.04 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_48000.pt
# 2022-12-03 14:08.04 [info     ] DoubleDQN_online_20221203135743: epoch=48 step=48000 epoch=48 metrics={'time_inference': 0.0004934029579162598, 'time_environment_step': 0.0009238128662109375, 'time_sample_batch': 0.00011478734016418456, 'time_algorithm_update': 0.0022403931617736815, 'loss': 0.8485032236278057, 'time_step': 0.003861335277557373, 'rollout_return': 15.161971830985916, 'evaluation': 16.8} step=48000
# 2022-12-03 14:08.07 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_49000.pt
# 2022-12-03 14:08.07 [info     ] DoubleDQN_online_20221203135743: epoch=49 step=49000 epoch=49 metrics={'time_inference': 0.0004069397449493408, 'time_environment_step': 0.0008514847755432129, 'time_sample_batch': 0.00010936355590820313, 'time_algorithm_update': 0.001990983009338379, 'loss': 0.7838924681991338, 'time_step': 0.0034398088455200194, 'rollout_return': 14.795774647887324, 'evaluation': 15.8} step=49000
# 2022-12-03 14:08.12 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_50000.pt
# 2022-12-03 14:08.12 [info     ] DoubleDQN_online_20221203135743: epoch=50 step=50000 epoch=50 metrics={'time_inference': 0.00048277592658996585, 'time_environment_step': 0.0009680407047271729, 'time_sample_batch': 0.00012442350387573242, 'time_algorithm_update': 0.00270754337310791, 'loss': 0.7872152620404959, 'time_step': 0.004369049787521362, 'rollout_return': 15.352112676056338, 'evaluation': 15.7} step=50000
# 2022-12-03 14:08.18 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_51000.pt
# 2022-12-03 14:08.18 [info     ] DoubleDQN_online_20221203135743: epoch=51 step=51000 epoch=51 metrics={'time_inference': 0.0005559208393096924, 'time_environment_step': 0.001180797815322876, 'time_sample_batch': 0.000164536714553833, 'time_algorithm_update': 0.0042773597240447995, 'loss': 0.8105298908501863, 'time_step': 0.006283758640289306, 'rollout_return': 14.985915492957746, 'evaluation': 15.4} step=51000
# 2022-12-03 14:08.24 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_52000.pt
# 2022-12-03 14:08.24 [info     ] DoubleDQN_online_20221203135743: epoch=52 step=52000 epoch=52 metrics={'time_inference': 0.0005173385143280029, 'time_environment_step': 0.0010459105968475342, 'time_sample_batch': 0.0001356184482574463, 'time_algorithm_update': 0.003385934114456177, 'loss': 0.7814102409631014, 'time_step': 0.005184590578079224, 'rollout_return': 14.830985915492958, 'evaluation': 16.6} step=52000
# 2022-12-03 14:08.28 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_53000.pt
# 2022-12-03 14:08.28 [info     ] DoubleDQN_online_20221203135743: epoch=53 step=53000 epoch=53 metrics={'time_inference': 0.0004937932491302491, 'time_environment_step': 0.0009486281871795654, 'time_sample_batch': 0.00011927175521850586, 'time_algorithm_update': 0.0025233829021453855, 'loss': 0.8237738446295262, 'time_step': 0.0041724972724914555, 'rollout_return': 14.908450704225352, 'evaluation': 18.1} step=53000
# 2022-12-03 14:08.32 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_54000.pt
# 2022-12-03 14:08.32 [info     ] DoubleDQN_online_20221203135743: epoch=54 step=54000 epoch=54 metrics={'time_inference': 0.0004539246559143066, 'time_environment_step': 0.0009276573657989502, 'time_sample_batch': 0.00011283230781555175, 'time_algorithm_update': 0.0021648037433624266, 'loss': 0.8352410076707601, 'time_step': 0.003741797924041748, 'rollout_return': 14.598591549295774, 'evaluation': 16.0} step=54000
# 2022-12-03 14:08.37 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_55000.pt
# 2022-12-03 14:08.37 [info     ] DoubleDQN_online_20221203135743: epoch=55 step=55000 epoch=55 metrics={'time_inference': 0.0005279924869537354, 'time_environment_step': 0.0010280957221984863, 'time_sample_batch': 0.0001279749870300293, 'time_algorithm_update': 0.003076057195663452, 'loss': 0.7841347644478083, 'time_step': 0.004875257730484008, 'rollout_return': 15.73943661971831, 'evaluation': 12.6} step=55000
# 2022-12-03 14:08.42 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_56000.pt
# 2022-12-03 14:08.42 [info     ] DoubleDQN_online_20221203135743: epoch=56 step=56000 epoch=56 metrics={'time_inference': 0.0005264744758605957, 'time_environment_step': 0.0009903292655944825, 'time_sample_batch': 0.0001294856071472168, 'time_algorithm_update': 0.002813046216964722, 'loss': 0.7856864117980004, 'time_step': 0.004549988746643066, 'rollout_return': 15.211267605633802, 'evaluation': 17.3} step=56000
# 2022-12-03 14:08.46 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_57000.pt
# 2022-12-03 14:08.47 [info     ] DoubleDQN_online_20221203135743: epoch=57 step=57000 epoch=57 metrics={'time_inference': 0.0005056381225585938, 'time_environment_step': 0.0010067768096923828, 'time_sample_batch': 0.0001227447986602783, 'time_algorithm_update': 0.002593308925628662, 'loss': 0.7894196799695492, 'time_step': 0.004315475225448609, 'rollout_return': 15.394366197183098, 'evaluation': 16.1} step=57000
# 2022-12-03 14:08.51 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_58000.pt
# 2022-12-03 14:08.51 [info     ] DoubleDQN_online_20221203135743: epoch=58 step=58000 epoch=58 metrics={'time_inference': 0.0004995720386505127, 'time_environment_step': 0.00101962947845459, 'time_sample_batch': 0.00012457561492919923, 'time_algorithm_update': 0.0026858866214752196, 'loss': 0.7997383523285388, 'time_step': 0.004416940689086914, 'rollout_return': 15.32394366197183, 'evaluation': 15.3} step=58000
# 2022-12-03 14:08.55 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_59000.pt
# 2022-12-03 14:08.55 [info     ] DoubleDQN_online_20221203135743: epoch=59 step=59000 epoch=59 metrics={'time_inference': 0.0004472780227661133, 'time_environment_step': 0.0009127166271209716, 'time_sample_batch': 0.00011231613159179688, 'time_algorithm_update': 0.0021972434520721434, 'loss': 0.8012019672840833, 'time_step': 0.0037548017501831056, 'rollout_return': 15.514084507042254, 'evaluation': 15.6} step=59000
# 2022-12-03 14:08.59 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_60000.pt
# 2022-12-03 14:08.59 [info     ] DoubleDQN_online_20221203135743: epoch=60 step=60000 epoch=60 metrics={'time_inference': 0.0004915294647216796, 'time_environment_step': 0.0009745869636535644, 'time_sample_batch': 0.00012182116508483886, 'time_algorithm_update': 0.0023400232791900635, 'loss': 0.7925955598801374, 'time_step': 0.004015564918518066, 'rollout_return': 15.795774647887324, 'evaluation': 17.9} step=60000
# 2022-12-03 14:09.04 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_61000.pt
# 2022-12-03 14:09.04 [info     ] DoubleDQN_online_20221203135743: epoch=61 step=61000 epoch=61 metrics={'time_inference': 0.0004788212776184082, 'time_environment_step': 0.0009500689506530762, 'time_sample_batch': 0.00012035465240478515, 'time_algorithm_update': 0.0024045276641845702, 'loss': 0.7848547240495681, 'time_step': 0.0040447101593017575, 'rollout_return': 15.098591549295774, 'evaluation': 17.5} step=61000
# 2022-12-03 14:09.08 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_62000.pt
# 2022-12-03 14:09.08 [info     ] DoubleDQN_online_20221203135743: epoch=62 step=62000 epoch=62 metrics={'time_inference': 0.0005034558773040771, 'time_environment_step': 0.0010066897869110108, 'time_sample_batch': 0.00012569761276245119, 'time_algorithm_update': 0.00248728084564209, 'loss': 0.825435461461544, 'time_step': 0.00422344183921814, 'rollout_return': 14.929577464788732, 'evaluation': 14.4} step=62000
# 2022-12-03 14:09.12 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_63000.pt
# 2022-12-03 14:09.12 [info     ] DoubleDQN_online_20221203135743: epoch=63 step=63000 epoch=63 metrics={'time_inference': 0.0004478118419647217, 'time_environment_step': 0.0009177389144897461, 'time_sample_batch': 0.00011393141746520996, 'time_algorithm_update': 0.0022156572341918944, 'loss': 0.7872940733134747, 'time_step': 0.003779534339904785, 'rollout_return': 15.295774647887324, 'evaluation': 14.8} step=63000
# 2022-12-03 14:09.16 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_64000.pt
# 2022-12-03 14:09.16 [info     ] DoubleDQN_online_20221203135743: epoch=64 step=64000 epoch=64 metrics={'time_inference': 0.0004171299934387207, 'time_environment_step': 0.0008680694103240967, 'time_sample_batch': 0.00011017608642578126, 'time_algorithm_update': 0.0019738709926605223, 'loss': 0.7993271413743496, 'time_step': 0.0034476115703582764, 'rollout_return': 15.049295774647888, 'evaluation': 15.4} step=64000
# 2022-12-03 14:09.20 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_65000.pt
# 2022-12-03 14:09.20 [info     ] DoubleDQN_online_20221203135743: epoch=65 step=65000 epoch=65 metrics={'time_inference': 0.0004949972629547119, 'time_environment_step': 0.0009992539882659913, 'time_sample_batch': 0.00012504529953002929, 'time_algorithm_update': 0.0024026970863342285, 'loss': 0.7687748047113419, 'time_step': 0.0041129469871521, 'rollout_return': 15.23943661971831, 'evaluation': 15.7} step=65000
# 2022-12-03 14:09.24 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_66000.pt
# 2022-12-03 14:09.24 [info     ] DoubleDQN_online_20221203135743: epoch=66 step=66000 epoch=66 metrics={'time_inference': 0.0004426453113555908, 'time_environment_step': 0.0009038512706756592, 'time_sample_batch': 0.00011287426948547363, 'time_algorithm_update': 0.0021694703102111816, 'loss': 0.7711143779158592, 'time_step': 0.0037107195854187013, 'rollout_return': 14.809859154929578, 'evaluation': 13.9} step=66000
# 2022-12-03 14:09.28 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_67000.pt
# 2022-12-03 14:09.28 [info     ] DoubleDQN_online_20221203135743: epoch=67 step=67000 epoch=67 metrics={'time_inference': 0.00045976948738098145, 'time_environment_step': 0.0009521443843841553, 'time_sample_batch': 0.00011494231224060059, 'time_algorithm_update': 0.0023226466178894044, 'loss': 0.7356762990355492, 'time_step': 0.003934539556503296, 'rollout_return': 15.669014084507042, 'evaluation': 16.7} step=67000
# 2022-12-03 14:09.33 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_68000.pt
# 2022-12-03 14:09.33 [info     ] DoubleDQN_online_20221203135743: epoch=68 step=68000 epoch=68 metrics={'time_inference': 0.0004728071689605713, 'time_environment_step': 0.0010588483810424804, 'time_sample_batch': 0.00014209270477294922, 'time_algorithm_update': 0.0028691301345825197, 'loss': 0.7769373402446509, 'time_step': 0.004641075849533081, 'rollout_return': 15.373239436619718, 'evaluation': 17.2} step=68000
# 2022-12-03 14:09.38 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_69000.pt
# 2022-12-03 14:09.38 [info     ] DoubleDQN_online_20221203135743: epoch=69 step=69000 epoch=69 metrics={'time_inference': 0.0005298004150390624, 'time_environment_step': 0.0010656161308288574, 'time_sample_batch': 0.00013040709495544433, 'time_algorithm_update': 0.0027197043895721435, 'loss': 0.756149893283844, 'time_step': 0.004541164875030518, 'rollout_return': 14.915492957746478, 'evaluation': 13.2} step=69000
# 2022-12-03 14:09.42 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_70000.pt
# 2022-12-03 14:09.42 [info     ] DoubleDQN_online_20221203135743: epoch=70 step=70000 epoch=70 metrics={'time_inference': 0.00045856070518493654, 'time_environment_step': 0.0009379022121429444, 'time_sample_batch': 0.00011516141891479492, 'time_algorithm_update': 0.0023331115245819093, 'loss': 0.7625186603069305, 'time_step': 0.003928821325302124, 'rollout_return': 15.366197183098592, 'evaluation': 15.7} step=70000
# 2022-12-03 14:09.46 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_71000.pt
# 2022-12-03 14:09.46 [info     ] DoubleDQN_online_20221203135743: epoch=71 step=71000 epoch=71 metrics={'time_inference': 0.0004639759063720703, 'time_environment_step': 0.0009144642353057862, 'time_sample_batch': 0.00011451125144958496, 'time_algorithm_update': 0.002374332666397095, 'loss': 0.7556077403277158, 'time_step': 0.0039505350589752195, 'rollout_return': 14.880281690140846, 'evaluation': 17.9} step=71000
# 2022-12-03 14:09.50 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_72000.pt
# 2022-12-03 14:09.50 [info     ] DoubleDQN_online_20221203135743: epoch=72 step=72000 epoch=72 metrics={'time_inference': 0.0004496541023254395, 'time_environment_step': 0.0009045953750610352, 'time_sample_batch': 0.00011416840553283692, 'time_algorithm_update': 0.0022759106159210207, 'loss': 0.7625816041231155, 'time_step': 0.00382835054397583, 'rollout_return': 15.570422535211268, 'evaluation': 18.6} step=72000
# 2022-12-03 14:09.54 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_73000.pt
# 2022-12-03 14:09.55 [info     ] DoubleDQN_online_20221203135743: epoch=73 step=73000 epoch=73 metrics={'time_inference': 0.0005017907619476318, 'time_environment_step': 0.0009982268810272217, 'time_sample_batch': 0.0001222202777862549, 'time_algorithm_update': 0.0027817628383636473, 'loss': 0.7737213885784149, 'time_step': 0.00449054479598999, 'rollout_return': 14.985915492957746, 'evaluation': 16.7} step=73000
# 2022-12-03 14:09.59 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_74000.pt
# 2022-12-03 14:09.59 [info     ] DoubleDQN_online_20221203135743: epoch=74 step=74000 epoch=74 metrics={'time_inference': 0.0005270395278930664, 'time_environment_step': 0.001035700798034668, 'time_sample_batch': 0.00012315797805786133, 'time_algorithm_update': 0.002968095302581787, 'loss': 0.7395016732662916, 'time_step': 0.004751445531845093, 'rollout_return': 15.0, 'evaluation': 16.8} step=74000
# 2022-12-03 14:10.04 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_75000.pt
# 2022-12-03 14:10.04 [info     ] DoubleDQN_online_20221203135743: epoch=75 step=75000 epoch=75 metrics={'time_inference': 0.0005007627010345459, 'time_environment_step': 0.0010290217399597167, 'time_sample_batch': 0.00012853336334228514, 'time_algorithm_update': 0.002577971935272217, 'loss': 0.7758531236648559, 'time_step': 0.00432846999168396, 'rollout_return': 15.661971830985916, 'evaluation': 15.7} step=75000
# 2022-12-03 14:10.09 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_76000.pt
# 2022-12-03 14:10.09 [info     ] DoubleDQN_online_20221203135743: epoch=76 step=76000 epoch=76 metrics={'time_inference': 0.0005053677558898926, 'time_environment_step': 0.0010426480770111084, 'time_sample_batch': 0.00013727450370788573, 'time_algorithm_update': 0.003248487949371338, 'loss': 0.7559213467687368, 'time_step': 0.005040898323059082, 'rollout_return': 15.485915492957746, 'evaluation': 15.9} step=76000
# 2022-12-03 14:10.14 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_77000.pt
# 2022-12-03 14:10.14 [info     ] DoubleDQN_online_20221203135743: epoch=77 step=77000 epoch=77 metrics={'time_inference': 0.00047868084907531737, 'time_environment_step': 0.000943662166595459, 'time_sample_batch': 0.0001284196376800537, 'time_algorithm_update': 0.0024521410465240478, 'loss': 0.7706125984042883, 'time_step': 0.004100123643875122, 'rollout_return': 15.845070422535212, 'evaluation': 15.5} step=77000
# 2022-12-03 14:10.18 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_78000.pt
# 2022-12-03 14:10.18 [info     ] DoubleDQN_online_20221203135743: epoch=78 step=78000 epoch=78 metrics={'time_inference': 0.0005164103507995605, 'time_environment_step': 0.0010221505165100098, 'time_sample_batch': 0.00013237953186035156, 'time_algorithm_update': 0.0026396453380584718, 'loss': 0.735633262783289, 'time_step': 0.004402414321899414, 'rollout_return': 14.880281690140846, 'evaluation': 13.7} step=78000
# 2022-12-03 14:10.23 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_79000.pt
# 2022-12-03 14:10.23 [info     ] DoubleDQN_online_20221203135743: epoch=79 step=79000 epoch=79 metrics={'time_inference': 0.00046112656593322754, 'time_environment_step': 0.000960822343826294, 'time_sample_batch': 0.00011588001251220703, 'time_algorithm_update': 0.00268195104598999, 'loss': 0.7317335034012794, 'time_step': 0.004311186552047729, 'rollout_return': 15.704225352112676, 'evaluation': 16.3} step=79000
# 2022-12-03 14:10.27 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_80000.pt
# 2022-12-03 14:10.27 [info     ] DoubleDQN_online_20221203135743: epoch=80 step=80000 epoch=80 metrics={'time_inference': 0.0004630241394042969, 'time_environment_step': 0.0009537477493286133, 'time_sample_batch': 0.00011909818649291992, 'time_algorithm_update': 0.0022783634662628172, 'loss': 0.7357639475166797, 'time_step': 0.00391363787651062, 'rollout_return': 15.69718309859155, 'evaluation': 18.6} step=80000
# 2022-12-03 14:10.31 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_81000.pt
# 2022-12-03 14:10.31 [info     ] DoubleDQN_online_20221203135743: epoch=81 step=81000 epoch=81 metrics={'time_inference': 0.0004625086784362793, 'time_environment_step': 0.0009188885688781738, 'time_sample_batch': 0.00011544036865234375, 'time_algorithm_update': 0.002159088134765625, 'loss': 0.7659048834443092, 'time_step': 0.003741084098815918, 'rollout_return': 15.373239436619718, 'evaluation': 15.3} step=81000
# 2022-12-03 14:10.35 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_82000.pt
# 2022-12-03 14:10.35 [info     ] DoubleDQN_online_20221203135743: epoch=82 step=82000 epoch=82 metrics={'time_inference': 0.0004904463291168213, 'time_environment_step': 0.0009952294826507569, 'time_sample_batch': 0.0001284775733947754, 'time_algorithm_update': 0.0024147665500640868, 'loss': 0.7370519784390926, 'time_step': 0.004122672319412232, 'rollout_return': 14.788732394366198, 'evaluation': 14.3} step=82000
# 2022-12-03 14:10.41 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_83000.pt
# 2022-12-03 14:10.41 [info     ] DoubleDQN_online_20221203135743: epoch=83 step=83000 epoch=83 metrics={'time_inference': 0.0005450620651245117, 'time_environment_step': 0.0011573548316955566, 'time_sample_batch': 0.00014126205444335937, 'time_algorithm_update': 0.0041503655910491944, 'loss': 0.738026187479496, 'time_step': 0.006094233274459839, 'rollout_return': 15.830985915492958, 'evaluation': 14.1} step=83000
# 2022-12-03 14:10.46 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_84000.pt
# 2022-12-03 14:10.46 [info     ] DoubleDQN_online_20221203135743: epoch=84 step=84000 epoch=84 metrics={'time_inference': 0.0004717245101928711, 'time_environment_step': 0.0009435732364654541, 'time_sample_batch': 0.00011592674255371094, 'time_algorithm_update': 0.0023016738891601563, 'loss': 0.737798055127263, 'time_step': 0.003919785261154175, 'rollout_return': 15.190140845070422, 'evaluation': 17.2} step=84000
# 2022-12-03 14:10.50 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_85000.pt
# 2022-12-03 14:10.50 [info     ] DoubleDQN_online_20221203135743: epoch=85 step=85000 epoch=85 metrics={'time_inference': 0.0004719686508178711, 'time_environment_step': 0.0009830002784729005, 'time_sample_batch': 0.00012000894546508789, 'time_algorithm_update': 0.002551255702972412, 'loss': 0.7364532014429569, 'time_step': 0.004215175867080688, 'rollout_return': 15.612676056338028, 'evaluation': 15.4} step=85000
# 2022-12-03 14:10.55 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_86000.pt
# 2022-12-03 14:10.55 [info     ] DoubleDQN_online_20221203135743: epoch=86 step=86000 epoch=86 metrics={'time_inference': 0.000490915060043335, 'time_environment_step': 0.0010146465301513672, 'time_sample_batch': 0.00012236547470092775, 'time_algorithm_update': 0.002642677545547485, 'loss': 0.7650715055465698, 'time_step': 0.00436430025100708, 'rollout_return': 15.408450704225352, 'evaluation': 15.6} step=86000
# 2022-12-03 14:10.59 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_87000.pt
# 2022-12-03 14:10.59 [info     ] DoubleDQN_online_20221203135743: epoch=87 step=87000 epoch=87 metrics={'time_inference': 0.0004930660724639892, 'time_environment_step': 0.0010366482734680176, 'time_sample_batch': 0.00012224411964416505, 'time_algorithm_update': 0.002780806303024292, 'loss': 0.7563179624974727, 'time_step': 0.004534302473068237, 'rollout_return': 15.098591549295774, 'evaluation': 18.3} step=87000
# 2022-12-03 14:11.04 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_88000.pt
# 2022-12-03 14:11.04 [info     ] DoubleDQN_online_20221203135743: epoch=88 step=88000 epoch=88 metrics={'time_inference': 0.0004690816402435303, 'time_environment_step': 0.0009353833198547364, 'time_sample_batch': 0.0001258237361907959, 'time_algorithm_update': 0.0025771682262420654, 'loss': 0.7484776829928159, 'time_step': 0.004194612979888916, 'rollout_return': 15.119718309859154, 'evaluation': 15.3} step=88000
# 2022-12-03 14:11.09 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_89000.pt
# 2022-12-03 14:11.09 [info     ] DoubleDQN_online_20221203135743: epoch=89 step=89000 epoch=89 metrics={'time_inference': 0.0004948809146881104, 'time_environment_step': 0.0009782116413116456, 'time_sample_batch': 0.00012210512161254882, 'time_algorithm_update': 0.002792203426361084, 'loss': 0.7327150093019008, 'time_step': 0.004475348949432373, 'rollout_return': 15.084507042253522, 'evaluation': 16.5} step=89000
# 2022-12-03 14:11.13 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_90000.pt
# 2022-12-03 14:11.13 [info     ] DoubleDQN_online_20221203135743: epoch=90 step=90000 epoch=90 metrics={'time_inference': 0.0005121326446533203, 'time_environment_step': 0.0010443718433380126, 'time_sample_batch': 0.00014725279808044435, 'time_algorithm_update': 0.002881420135498047, 'loss': 0.7238167409598827, 'time_step': 0.004677741765975952, 'rollout_return': 14.859154929577464, 'evaluation': 12.5} step=90000
# 2022-12-03 14:11.18 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_91000.pt
# 2022-12-03 14:11.18 [info     ] DoubleDQN_online_20221203135743: epoch=91 step=91000 epoch=91 metrics={'time_inference': 0.00048614072799682616, 'time_environment_step': 0.000996504545211792, 'time_sample_batch': 0.00011476492881774902, 'time_algorithm_update': 0.002662697792053223, 'loss': 0.725936520844698, 'time_step': 0.004352704048156738, 'rollout_return': 14.985915492957746, 'evaluation': 17.1} step=91000
# 2022-12-03 14:11.25 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_92000.pt
# 2022-12-03 14:11.25 [info     ] DoubleDQN_online_20221203135743: epoch=92 step=92000 epoch=92 metrics={'time_inference': 0.0005227587223052978, 'time_environment_step': 0.0010945472717285155, 'time_sample_batch': 0.00013523411750793456, 'time_algorithm_update': 0.0047522010803222655, 'loss': 0.7442273970246315, 'time_step': 0.0066034247875213625, 'rollout_return': 14.866197183098592, 'evaluation': 15.8} step=92000
# 2022-12-03 14:11.30 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_93000.pt
# 2022-12-03 14:11.30 [info     ] DoubleDQN_online_20221203135743: epoch=93 step=93000 epoch=93 metrics={'time_inference': 0.0005352144241333007, 'time_environment_step': 0.0010678949356079102, 'time_sample_batch': 0.0001381227970123291, 'time_algorithm_update': 0.002767419338226318, 'loss': 0.7381678713262081, 'time_step': 0.004601503372192383, 'rollout_return': 15.47887323943662, 'evaluation': 11.8} step=93000
# 2022-12-03 14:11.36 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_94000.pt
# 2022-12-03 14:11.36 [info     ] DoubleDQN_online_20221203135743: epoch=94 step=94000 epoch=94 metrics={'time_inference': 0.0005255260467529297, 'time_environment_step': 0.0010161180496215821, 'time_sample_batch': 0.00013085126876831056, 'time_algorithm_update': 0.003943410634994507, 'loss': 0.7616234687715768, 'time_step': 0.005711894273757934, 'rollout_return': 15.746478873239436, 'evaluation': 16.2} step=94000
# 2022-12-03 14:11.42 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_95000.pt
# 2022-12-03 14:11.42 [info     ] DoubleDQN_online_20221203135743: epoch=95 step=95000 epoch=95 metrics={'time_inference': 0.0005895705223083497, 'time_environment_step': 0.0010875194072723388, 'time_sample_batch': 0.00012616848945617675, 'time_algorithm_update': 0.004510163307189941, 'loss': 0.7344462653845548, 'time_step': 0.0064059624671936035, 'rollout_return': 15.535211267605634, 'evaluation': 14.2} step=95000
# 2022-12-03 14:11.47 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_96000.pt
# 2022-12-03 14:11.47 [info     ] DoubleDQN_online_20221203135743: epoch=96 step=96000 epoch=96 metrics={'time_inference': 0.0004579575061798096, 'time_environment_step': 0.0009492099285125733, 'time_sample_batch': 0.00011172723770141601, 'time_algorithm_update': 0.0025971646308898927, 'loss': 0.7272604991793632, 'time_step': 0.004200193166732788, 'rollout_return': 15.133802816901408, 'evaluation': 15.7} step=96000
# 2022-12-03 14:11.51 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_97000.pt
# 2022-12-03 14:11.51 [info     ] DoubleDQN_online_20221203135743: epoch=97 step=97000 epoch=97 metrics={'time_inference': 0.00046726107597351075, 'time_environment_step': 0.0009127211570739746, 'time_sample_batch': 0.00011267352104187011, 'time_algorithm_update': 0.002221202850341797, 'loss': 0.7285609217584134, 'time_step': 0.0037958889007568357, 'rollout_return': 14.56338028169014, 'evaluation': 14.8} step=97000
# 2022-12-03 14:11.55 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_98000.pt
# 2022-12-03 14:11.55 [info     ] DoubleDQN_online_20221203135743: epoch=98 step=98000 epoch=98 metrics={'time_inference': 0.0004530754089355469, 'time_environment_step': 0.0009381675720214844, 'time_sample_batch': 0.00011314582824707031, 'time_algorithm_update': 0.002277233600616455, 'loss': 0.7521305444836617, 'time_step': 0.003866351366043091, 'rollout_return': 15.471830985915492, 'evaluation': 15.6} step=98000
# 2022-12-03 14:12.00 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_99000.pt
# 2022-12-03 14:12.00 [info     ] DoubleDQN_online_20221203135743: epoch=99 step=99000 epoch=99 metrics={'time_inference': 0.0005379748344421386, 'time_environment_step': 0.001147071361541748, 'time_sample_batch': 0.00013949847221374513, 'time_algorithm_update': 0.003350032091140747, 'loss': 0.7493825725615024, 'time_step': 0.0052746119499206545, 'rollout_return': 15.049295774647888, 'evaluation': 13.1} step=99000
# 2022-12-03 14:12.06 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203135743/model_100000.pt
# 2022-12-03 14:12.06 [info     ] DoubleDQN_online_20221203135743: epoch=100 step=100000 epoch=100 metrics={'time_inference': 0.0005539991855621338, 'time_environment_step': 0.0010728204250335693, 'time_sample_batch': 0.00014672636985778808, 'time_algorithm_update': 0.0034189460277557373, 'loss': 0.8142453399002552, 'time_step': 0.0052967541217803955, 'rollout_return': 15.23943661971831, 'evaluation': 14.9} step=100000

# %%
# save model
ddqn.save_model("d3rlpy_logs/ddqn.pt")

# %%
# reload model
ddqn.build_with_env(env)
ddqn.load_model("d3rlpy_logs/ddqn.pt")

# %%
behavior_policy = EpsilonGreedyHead(
    ddqn, 
    n_actions=env.action_space.n,
    epsilon=0.3,
    name="ddqn_epsilon_0.3",
    random_state=random_state,
)

# %%
# initialize dataset class
dataset = SyntheticDataset(
    env=env,
    behavior_policy=behavior_policy,
    action_meaning=env.action_meaning,
    state_keys=env.obs_keys,
    max_episode_steps=env.step_per_episode,
    info_keys={
        "search_volume": int,
        "impression": int,
        "click": int,
        "conversion": int,
        "average_bid_price": float,
    },
    random_state=random_state,
)

# %%
# collect logged data by a behavior policy
# skip if there is a preserved logged dataset
logged_dataset = dataset.obtain_episodes(n_trajectories=10000, obtain_info=True)
# Out:
# [obtain_trajectories]:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
with open("logs/dataset_discrete_ddpn.pkl", "wb") as f:
    pickle.dump(logged_dataset, f)

# %%
with open("logs/dataset_discrete_ddpn.pkl", "rb") as f:
    logged_dataset = pickle.load(f)

# %% [markdown]
# #### Offline Policy Learning
# Here, we learn several "candidate" policies to be evaluated and selected using [d3rlpy](https://github.com/takuseno/d3rlpy)'s algorithm implementation.
#
# For more about the offline RL procedure, please refer to [examples/quickstart/rtb_synthetic_discrete_basic.ipynb](https://github.com/negocia-inc/rtb_reinforcement_learing/blob/ope/examples/quickstart/rtb_synthetic_discrete_basic.ipynb).

# %%
# import modules from d3rlpy
from d3rlpy.dataset import MDPDataset
from d3rlpy.algos import DiscreteCQL as CQL
# transform offline dataset for d3rlpy
offlinerl_dataset = MDPDataset(
    observations=logged_dataset["state"],
    actions=logged_dataset["action"],
    rewards=logged_dataset["reward"],
    terminals=logged_dataset["done"],
    episode_terminals=logged_dataset["done"],
    discrete_action=True,
)
train_episodes, test_episodes = train_test_split(offlinerl_dataset, test_size=0.2, random_state=random_state)

# %%
# Use Conservative Q-Learning policy
cql = CQL(
    encoder_factory=VectorEncoderFactory(hidden_units=[30, 30]),
    q_func_factory=MeanQFunctionFactory(),
    use_gpu=torch.cuda.is_available(),
)

# %%
cql.fit(
    train_episodes,
    eval_episodes=test_episodes,
    n_steps=10000,
    scorers={},
)
# Out:
# 2022-11-24 04:49.20 [debug    ] RandomIterator is selected.
# 2022-11-24 04:49.20 [info     ] Directory is created at d3rlpy_logs/DiscreteCQL_20221124044920
# 2022-11-24 04:49.20 [debug    ] Building models...
# 2022-11-24 04:49.20 [debug    ] Models have been built.
# 2022-11-24 04:49.20 [info     ] Parameters are saved to d3rlpy_logs/DiscreteCQL_20221124044920/params.json params={'action_scaler': None, 'alpha': 1.0, 'batch_size': 32, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 0.99, 'generated_maxlen': 100000, 'learning_rate': 6.25e-05, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': None, 'target_update_interval': 8000, 'use_gpu': None, 'algorithm': 'DiscreteCQL', 'observation_shape': (7,), 'action_size': 10}
# Epoch 1/1:   0%|          | 0/10000 [00:00<?, ?it/s]
# 2022-11-24 04:56.13 [info     ] DiscreteCQL_20221124044920: epoch=1 step=10000 epoch=1 metrics={'time_sample_batch': 0.00039889097213745116, 'time_algorithm_update': 0.04027746403217316, 'loss': 77.3925471253395, 'time_step': 0.04094007489681244} step=10000
# 2022-11-24 04:56.13 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteCQL_20221124044920/model_10000.pt
# [(1,
#   {'time_sample_batch': 0.00039889097213745116,
#    'time_algorithm_update': 0.04027746403217316,
#    'loss': 77.3925471253395,
#    'time_step': 0.04094007489681244})]

# %%
# save model
cql.save_model("d3rlpy_logs/cql_discrete.pt")

# %%
# reload model
cql.build_with_env(env_)
cql.load_model("d3rlpy_logs/cql_discrete.pt")

# %% [markdown]
# ## 2. Off-Policy Evaluation
# In this section, we aim at evaluating the various performance statistics of policies in an offline manner using (basic) model-based and importance sampling-based estimators.
#
# #### Estimation Target
#
# The goal to estimate the estimators' average policy performance, the *policy value*.
#
# $$ V(\pi) := \mathbb{E}\left[\sum_{t=1}^T \gamma^{t-1} r_t \mid \pi \right] $$

# %%
# import ope modules from OFRL
from ofrl.ope import CreateOPEInput
from ofrl.ope import OffPolicyEvaluation as OPE
# basic estimators
from ofrl.ope import DiscreteDirectMethod as DM
from ofrl.ope import DiscreteTrajectoryWiseImportanceSampling as TIS
from ofrl.ope import DiscretePerDecisionImportanceSampling as PDIS
from ofrl.ope import DiscreteDoublyRobust as DR
# self normalized estimators
from ofrl.ope import DiscreteSelfNormalizedTrajectoryWiseImportanceSampling as SNTIS
from ofrl.ope import DiscreteSelfNormalizedPerDecisionImportanceSampling as SNPDIS
from ofrl.ope import DiscreteSelfNormalizedDoublyRobust as SNDR
# marginal estimators
from ofrl.ope import DiscreteStateActionMarginalImportanceSampling as SAMIS
from ofrl.ope import DiscreteStateActionMarginalDoublyRobust as SAMDR
from ofrl.ope import DiscreteStateMarginalImportanceSampling as SMIS
from ofrl.ope import DiscreteStateMarginalDoublyRobust as SMDR
from ofrl.ope import DiscreteStateActionMarginalSelfNormalizedImportanceSampling as SAMSNIS
from ofrl.ope import DiscreteStateActionMarginalSelfNormalizedDoublyRobust as SAMSNDR
from ofrl.ope import DiscreteStateMarginalSelfNormalizedImportanceSampling as SMSNIS
from ofrl.ope import DiscreteStateMarginalSelfNormalizedDoublyRobust as SMSNDR
# double reinforcement learning estimators
from ofrl.ope import DiscreteDoubleReinforcementLearning as DRL

# %%
from d3rlpy.algos import DiscreteRandomPolicy
random = DiscreteRandomPolicy()
random.build_with_env(env_)

# %%
# define evaluation policies
cql_ = EpsilonGreedyHead(base_policy=cql, n_actions=env.action_space.n, name="cql", epsilon=0.0, random_state=random_state)
ddqn_ = EpsilonGreedyHead(base_policy=ddqn, n_actions=env.action_space.n, name="ddqn", epsilon=0.0, random_state=random_state)
random_ = EpsilonGreedyHead(base_policy=random, n_actions=env.action_space.n, name="random", epsilon=1.0, random_state=random_state)
evaluation_policies = [cql_, ddqn_, random_]

# %%
# first, prepare OPE inputs
prep = CreateOPEInput(
    env=env,
    logged_dataset=logged_dataset,
    model_args={
        "fqe": {
            "encoder_factory": VectorEncoderFactory(hidden_units=[30, 30]),
            "q_func_factory": MeanQFunctionFactory(),
            "learning_rate": 1e-4,
            "use_gpu": torch.cuda.is_available(),
        },
    },
    state_scaler=MinMaxScaler(
        minimum=logged_dataset["state"].min(axis=0),
        maximum=logged_dataset["state"].max(axis=0),
    ),
    sigma=0.1,
    gamma=0.95,
    device="cuda:0" if torch.cuda.is_available() else "cpu",
)

# %%
# takes time
input_dict = prep.obtain_whole_inputs(
    evaluation_policies=evaluation_policies,
    require_value_prediction=True,
    require_weight_prediction=True,
    n_trajectories_on_policy_evaluation=100,
    random_state=random_state,
)
# Out:
# [fit FQE model]:   0%|          | 0/3 [00:00<?, ?it/s]
# 2022-12-04 06:47.17 [debug    ] RoundIterator is selected.
# 2022-12-04 06:47.17 [info     ] Directory is created at d3rlpy_logs/DiscreteFQE_20221204064717
# 2022-12-04 06:47.17 [debug    ] Fitting scaler...              scaler=min_max
# 2022-12-04 06:47.17 [debug    ] Building models...
# 2022-12-04 06:47.17 [debug    ] Models have been built.
# 2022-12-04 06:47.17 [info     ] Parameters are saved to d3rlpy_logs/DiscreteFQE_20221204064717/params.json params={'action_scaler': None, 'batch_size': 100, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 0.95, 'generated_maxlen': 100000, 'learning_rate': 0.0001, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': {'type': 'min_max', 'params': {'maximum': array([6.00000000e+00, 3.00000000e+03, 9.99995065e-01, 5.90000000e+04,
#        1.00000000e+00, 2.10000000e+01, 1.00000000e+01]), 'minimum': array([0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 2.4455093e-05])}}, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'DiscreteFQE', 'observation_shape': (7,), 'action_size': 10}
# Epoch 1/1:   0%|          | 0/700 [00:00<?, ?it/s]
# 2022-12-04 06:47.23 [info     ] DiscreteFQE_20221204064717: epoch=1 step=700 epoch=1 metrics={'time_sample_batch': 0.00022631236485072545, 'time_algorithm_update': 0.007175087928771973, 'loss': 1.7370723927021026, 'time_step': 0.0074873321396963935} step=700
# 2022-12-04 06:47.23 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteFQE_20221204064717/model_700.pt
# 2022-12-04 06:47.23 [debug    ] RoundIterator is selected.
# 2022-12-04 06:47.23 [info     ] Directory is created at d3rlpy_logs/DiscreteFQE_20221204064723
# 2022-12-04 06:47.23 [debug    ] Fitting scaler...              scaler=min_max
# 2022-12-04 06:47.23 [debug    ] Building models...
# 2022-12-04 06:47.23 [debug    ] Models have been built.
# 2022-12-04 06:47.23 [info     ] Parameters are saved to d3rlpy_logs/DiscreteFQE_20221204064723/params.json params={'action_scaler': None, 'batch_size': 100, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 0.95, 'generated_maxlen': 100000, 'learning_rate': 0.0001, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': {'type': 'min_max', 'params': {'maximum': array([6.00000000e+00, 3.00000000e+03, 9.99995065e-01, 5.90000000e+04,
#        1.00000000e+00, 2.10000000e+01, 1.00000000e+01]), 'minimum': array([0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 2.4455093e-05])}}, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'DiscreteFQE', 'observation_shape': (7,), 'action_size': 10}
# Epoch 1/1:   0%|          | 0/700 [00:00<?, ?it/s]
# 2022-12-04 06:47.30 [info     ] DiscreteFQE_20221204064723: epoch=1 step=700 epoch=1 metrics={'time_sample_batch': 0.0002725870268685477, 'time_algorithm_update': 0.009161967890603202, 'loss': 1.7539822702748435, 'time_step': 0.009534916537148611} step=700
# 2022-12-04 06:47.30 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteFQE_20221204064723/model_700.pt
# 2022-12-04 06:47.30 [debug    ] RoundIterator is selected.
# 2022-12-04 06:47.30 [info     ] Directory is created at d3rlpy_logs/DiscreteFQE_20221204064730
# 2022-12-04 06:47.30 [debug    ] Fitting scaler...              scaler=min_max
# 2022-12-04 06:47.30 [debug    ] Building models...
# 2022-12-04 06:47.30 [debug    ] Models have been built.
# 2022-12-04 06:47.30 [info     ] Parameters are saved to d3rlpy_logs/DiscreteFQE_20221204064730/params.json params={'action_scaler': None, 'batch_size': 100, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 0.95, 'generated_maxlen': 100000, 'learning_rate': 0.0001, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': {'type': 'min_max', 'params': {'maximum': array([6.00000000e+00, 3.00000000e+03, 9.99995065e-01, 5.90000000e+04,
#        1.00000000e+00, 2.10000000e+01, 1.00000000e+01]), 'minimum': array([0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 2.4455093e-05])}}, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'DiscreteFQE', 'observation_shape': (7,), 'action_size': 10}
# Epoch 1/1:   0%|          | 0/700 [00:00<?, ?it/s]
# 2022-12-04 06:47.42 [info     ] DiscreteFQE_20221204064730: epoch=1 step=700 epoch=1 metrics={'time_sample_batch': 0.00024359839303152902, 'time_algorithm_update': 0.016814965179988317, 'loss': 1.7570793559721538, 'time_step': 0.017147119045257567} step=700
# 2022-12-04 06:47.42 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteFQE_20221204064730/model_700.pt
# [fit MWL model]:   0%|          | 0/3 [00:00<?, ?it/s]
# [fitting_weight_function]:   0%|          | 0/100 [00:00<?, ?it/s]
# [fitting_weight_function]:   0%|          | 0/100 [00:00<?, ?it/s]
# [fitting_weight_function]:   0%|          | 0/100 [00:00<?, ?it/s]
# [fitting_weight_function]:   0%|          | 0/100 [00:00<?, ?it/s]
# [fitting_weight_function]:   0%|          | 0/100 [00:00<?, ?it/s]
# [fitting_weight_function]:   0%|          | 0/100 [00:00<?, ?it/s]
# [collect input data]:   0%|          | 0/3 [00:00<?, ?it/s]
# [calculate on-policy policy value]:   0%|          | 0/100 [00:00<?, ?it/s]
# [calculate on-policy policy value]:   0%|          | 0/100 [00:00<?, ?it/s]
# [calculate on-policy policy value]:   0%|          | 0/100 [00:00<?, ?it/s]

# %%
with open("logs/ope_input_dict_discrete_zoo.pkl", "wb") as f:
    pickle.dump(input_dict, f)

# %%
with open("logs/ope_input_dict_discrete_zoo.pkl", "rb") as f:
    input_dict = pickle.load(f)

# %%
basic_estimators = [DM(), TIS(), PDIS(), DR(), SNTIS(), SNPDIS(), SNDR()]
state_marginal_estimators = [SMIS(), SMDR(), SMSNIS(), SMSNDR()]
state_action_marginal_estimators = [SAMIS(), SAMDR(), SAMSNIS(), SAMSNDR()]
drl_estimators = [DRL()]
all_estimators = basic_estimators + state_marginal_estimators + state_action_marginal_estimators + drl_estimators

# %%
basic_estimators_name = ["dm", "tis", "pdis", "dr", "sntis", "snpdis", "sndr"]
state_marginal_estimators_name = ["sm_is", "sm_dr", "sm_snis", "sm_sndr"]
state_action_marginal_estimators_name = ["sam_is", "sam_dr", "sam_snis", "sam_sndr"]
drl_estimators_name = ["drl"]

# %%
ope = OPE(
    logged_dataset=logged_dataset,
    ope_estimators=all_estimators,
)

# %%
# policy value estimation by ope
policy_value_df_dict, policy_value_interval_df_dict = ope.summarize_off_policy_estimates(
    input_dict, 
    random_state=random_state,
)
# dictionary of the estimation
policy_value_df_dict
# Out:
# {'cql':            policy_value  relative_policy_value
#  on_policy     14.408129               1.000000
#  dm             2.128820               0.147751
#  tis            0.921820               0.063979
#  pdis          14.948645               1.037515
#  dr            16.104931               1.117767
#  sntis         12.572488               0.872597
#  snpdis        15.030980               1.043229
#  sndr          15.263293               1.059353
#  sm_is               NaN                    NaN
#  sm_dr               NaN                    NaN
#  sm_snis             NaN                    NaN
#  sm_sndr             NaN                    NaN
#  sam_is              NaN                    NaN
#  sam_dr              NaN                    NaN
#  sam_snis            NaN                    NaN
#  sam_sndr            NaN                    NaN
#  drl            2.128848               0.147753,
#  'ddqn':            policy_value  relative_policy_value
#  on_policy     14.252056               1.000000
#  dm             1.935830               0.135828
#  tis           13.715250               0.962335
#  pdis          14.129104               0.991373
#  dr            14.473729               1.015554
#  sntis         17.248425               1.210241
#  snpdis        13.840196               0.971102
#  sndr          14.033133               0.984639
#  sm_is               NaN                    NaN
#  sm_dr               NaN                    NaN
#  sm_snis             NaN                    NaN
#  sm_sndr             NaN                    NaN
#  sam_is              NaN                    NaN
#  sam_dr              NaN                    NaN
#  sam_snis            NaN                    NaN
#  sam_sndr            NaN                    NaN
#  drl            1.936114               0.135848,
#  'random':            policy_value  relative_policy_value
#  on_policy     10.837735               1.000000
#  dm             1.295873               0.119570
#  tis           13.603061               1.255157
#  pdis          11.268438               1.039741
#  dr            11.067244               1.021177
#  sntis         12.999940               1.199507
#  snpdis        10.896643               1.005435
#  sndr          10.809119               0.997360
#  sm_is          0.000016               0.000001
#  sm_dr          1.295887               0.119572
#  sm_snis        3.276030               0.302280
#  sm_sndr        3.637175               0.335603
#  sam_is         0.000018               0.000002
#  sam_dr         1.295887               0.119572
#  sam_snis      13.794388               1.272811
#  sam_sndr      12.109019               1.117302
#  drl            1.296021               0.119584}

# %%
# visualize and compare the result
ope.visualize_off_policy_estimates(
    input_dict, 
    compared_estimators=basic_estimators_name,
    random_state=random_state, 
    sharey=False,
)
# relative policy value to the behavior policy
# ope.visualize_off_policy_estimates(input_dict, random_state=random_state, is_relative=True, sharey=False)

# %%
# visualize and compare the result
ope.visualize_off_policy_estimates(
    input_dict, 
    compared_estimators=state_marginal_estimators_name,
    random_state=random_state, 
    sharey=False,
)

# %%
# visualize and compare the result
ope.visualize_off_policy_estimates(
    input_dict, 
    compared_estimators=state_action_marginal_estimators_name,
    random_state=random_state, 
    sharey=False,
)

# %%
# visualize and compare the result
ope.visualize_off_policy_estimates(
    input_dict, 
    compared_estimators=["dm", "pdis", "dr", "sm_is", "sm_dr", "sam_is", "sam_dr", "drl"],
    random_state=random_state, 
    sharey=False,
)

# %%
ope.visualize_off_policy_estimates(
    input_dict, 
    compared_estimators=["dm", "snpdis", "sndr", "sm_snis", "sm_sndr", "sam_snis", "sam_sndr"],
    random_state=random_state, 
    sharey=False,
)

# %% [markdown]
# For more advanced topics in OPE (e.g., cumulative distribution function estimation) and OPS, please refer to [examples/quickstart/rtb_synthetic_discrete_advanced.ipynb](https://github.com/negocia-inc/rtb_reinforcement_learing/blob/ope/examples/quickstart/rtb_synthetic_discrete_advanced.ipynb).
#
# For the examples in the continuous action space, please refer to [examples/quickstart/rtb_synthetic_continuous_zoo.ipynb](https://github.com/negocia-inc/rtb_reinforcement_learing/blob/ope/examples/quickstart/rtb_synthetic_continuous_zoo.ipynb).

# %% [markdown]
# ## Reference
#
# - Yuta Saito, Shunsuke Aihara, Megumi Matsutani, and Yusuke Narita. \
# "Open Bandit Dataset and Pipeline: Towards Realistic and Reproducible Off-Policy Evaluation.", 2021.
#
# - Takuma Seno and Michita Imai. \
# "d3rlpy: An Offline Deep Reinforcement Library.", 2021.
#
# - Christina J. Yuan, Yash Chandak, Stephen Giguere, Philip S. Thomas, and Scott Niekum. \
# "SOPE: Spectrum of Off-Policy Estimators.", 2021.
#
# - Nathan Kallus and Masatoshi Uehara. \
# "Double Reinforcement Learning for Efficient Off-Policy Evaluation in Markov Decision Processes.", 2020.
#
# - Masatoshi Uehara, Jiawei Huang, and Nan Jiang. \
# "Minimax Weight and Q-Function Learning for Off-Policy Evaluation.", 2020.
#
# - Mengjiao Yang, Ofir Nachum, Bo Dai, Lihong Li, and Dale Schuurmans. \
# "Off-Policy Evaluation via the Regularized Lagrangian.", 2020.
#
# - Sergey Levine, Aviral Kumar, George Tucker, and Justin Fu. \
# "Offline Reinforcement Learning: Tutorial, Review, and Perspectives on Open Problems." 2020.
#
# - Aviral Kumar, Aurick Zhou, George Tucker, and Sergey Levine. \
# "Conservative Q-Learning for Offline Reinforcement Learning.", 2020.
#
# - Nathan Kallus and Masatoshi Uehara. \
# "Intrinsically Efficient, Stable, and Bounded Off-Policy Evaluation for Reinforcement Learning.", 2019.
#
# - Hoang Le, Cameron Voloshin, and Yisong Yue. \
# "Batch Policy Learning under Constraints.", 2019.
#
# - Qiang Liu, Lihong Li, Ziyang Tang, and Dengyong Zhou. \
# "Breaking the Curse of Horizon: Infinite-Horizon Off-Policy Estimation.", 2018
#
# - Di Wu, Xiujun Chen, Xun Yang, Hao Wang, Qing Tan, Xiaoxun Zhang, Jian Xu, and Kun Gai. \
# "Budget Constrained Bidding by Model-free Reinforcement Learning in Display Advertising.", 2018.
#
# - Jun Zhao, Guang Qiu, Ziyu Guan, Wei Zhao, and Xiaofei He. \
# "Deep Reinforcement Learning for Sponsored Search Real-time Bidding.", 2018.
#
# - Josiah P. Hanna, Peter Stone, and Scott Niekum. \
# "Bootstrapping with Models: Confidence Intervals for Off-Policy Evaluation.", 2017.
#
# - Nan Jiang and Lihong Li. \
# "Doubly Robust Off-policy Value Evaluation for Reinforcement Learning.", 2016.
#
# - Philip S. Thomas and Emma Brunskill. \
# "Data-Efficient Off-Policy Policy Evaluation for Reinforcement Learning.", 2016.
#
# - Greg Brockman, Vicki Cheung, Ludwig Pettersson, Jonas Schneider, John Schulman, Jie Tang, and Wojciech Zaremba. \
# "OpenAI Gym.", 2016.
#
# - Philip S. Thomas, Georgios Theocharous, and Mohammad Ghavamzadeh. \
# "High Confidence Policy Improvement.", 2015.
#
# - Philip S. Thomas, Georgios Theocharous, and Mohammad Ghavamzadeh. \
# "High Confidence Off-Policy Evaluation.", 2015.
#
# - Adith Swaminathan and Thorsten Joachims. \
# "The Self-Normalized Estimator for Counterfactual Learning.", 2015.
#
# - Hado van Hasselt, Arthur Guez, and David Silver. \
# "Deep Reinforcement Learning with Double Q-learning.", 2015.
#
# - Miroslav Dudík, Dumitru Erhan, John Langford, and Lihong Li. \
# "Doubly Robust Policy Evaluation and Optimization.", 2014.
#
# - Alex Strehl, John Langford, Sham Kakade, and Lihong Li. \
# "Learning from Logged Implicit Exploration Data.", 2010.
#
# - Alina Beygelzimer and John Langford. \
# "The Offset Tree for Learning with Partial Labels.", 2009.
#
# - Doina Precup, Richard S. Sutton, and Satinder P. Singh. \
# "Eligibility Traces for Off-Policy Policy Evaluation.", 2000.
