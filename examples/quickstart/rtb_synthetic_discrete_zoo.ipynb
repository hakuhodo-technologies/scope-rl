# %% [markdown]
# # Quickstart Example of Off-Policy Evaluation with Various Estimators (Discrete)
# This notebook provides an example of conducting **Off-policy Evaluation (OPE)** with a synthetic Real-Time Bidding (RTB) dataset and various OPE estimators (e.g., model-based vs importance sampling-based, marginal importance sampling, and double reinforcement learning).
#
# This example consists of the following 3 steps:
# 1. Setup, Synthetic Data Generation, and Offline Policy Learning
# 2. Off-Policy Evaluation (OPE) with various estimators
#
# \* This library uses [d3rlpy](https://github.com/takuseno/d3rlpy)'s algorithm implementations of offline rl policies and model-based evaluation.
# \* Also, our implementations of OPE are highly inspired by [Open Bandit Pipeline](https://github.com/st-tech/zr-obp).

# %%
# delete later
# %load_ext autoreload
# %autoreload 2

# %%
# delete later
import warnings
warnings.simplefilter('ignore')

# %%
# delete later
import sys
sys.path.append('../')
sys.path.append('../../')

# %%
# import OFRL modules
import ofrl
from rtbgym import RTBEnv, CustomizedRTBEnv
from ofrl.dataset import SyntheticDataset
from ofrl.policy import OnlineHead
from ofrl.policy import DiscreteEpsilonGreedyHead as EpsilonGreedyHead
from ofrl.policy import DiscreteSoftmaxHead as SoftmaxHead
from ofrl.ope.online import (
    calc_on_policy_policy_value,
    visualize_on_policy_policy_value,
)
from ofrl.utils import MinMaxScaler

# import d3rlpy algorithms
from d3rlpy.algos import DiscreteRandomPolicy as RandomPolicy
from d3rlpy.preprocessing import MinMaxScaler

# import from other libraries
import gym
import torch
from sklearn.model_selection import train_test_split

# %%
import pickle
from glob import glob
from tqdm import tqdm

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# version
print(ofrl.__version__)
# Out:
# 0.0.0

# %%
# set random state
random_state = 12345

# %%
# log directory
from pathlib import Path
Path("logs/").mkdir(exist_ok=True)

# %% [markdown]
# ## 1. Setup, Synthetic Data Generation, and Offline Policy Learning
# To begin with, we briefly describe how the RTB environment works.
#
# #### RL setup for RTB
# In RTB, the objective of the RL agent is to maximize some KPIs (number of clicks or conversions) within an episode under given budget constraints.
#
# We often try to achieve this by adjusting bidding price function parameter $\alpha$. By using $\alpha$, we can adjust the bid price as follows.
# $bid_{t,i} = \alpha \cdot r^{\ast}$,
# where $r^{\ast}$ denotes a predicted or expected reward (KPIs).
#
# We often formulate this RTB problem as the following Constrained Markov Decision Process (CMDP):
# - `timestep`: One episode (a day or a week) consists of several timesteps (24 hours or seven days, for instance).
# - `state`: We observe some feedback from the environment at each timestep, which includes the following.
#   - timestep
#   - remaining budget
#   - impression level features (budget consumption rate, cost per mille of impressions, auction winning rate, reward) at the previous timestep
#   - adjust rate (RL agent's decision making) at the previous timestep
# - `action`: Agent chooses adjust rate parameter $\alpha$ to maximize KPIs.
# - `reward`: Total number of clicks or conversions obtained during the timestep.
# - `constraints`: The pre-determined episodic budget should not be exceeded.
#
# For more about the environmental configuration and its customization, please refer to [examples/quickstart/rtb_synthetic_customize_env.ipynb](https://github.com/negocia-inc/rtb_reinforcement_learing/blob/ope/examples/quickstart/rtb_synthetic_customize_env.ipynb).

# %%
# standardized environment for discrete action
env = gym.make("RTBEnv-discrete-v0")

# %%
# for api compatibility to d3rlpy
from ofrl.utils import OldGymAPIWrapper
env_ = OldGymAPIWrapper(env)

# %% [markdown]
# #### Synthetic Data Generation
# Next, we collect logged data with the uniform random agent.
#
# `SyntheticDataset` has the following arguments:
# - `env`: RTB environment for RL defined in the previous section.
# - `behavior_policy`: RL agent (or algorithm) used for the data collection.
# - `maximum_step_per_episode`: Maximum number of timesteps in an episode.
# - `action_meaning`: Dictionary which maps discrete action index into specific actions.
# - `action_keys`: Name of the action variable at each dimension.
# - `state_keys`: Name of the state variable at each dimension.
# - `info_keys`: Dictionary containing of key and the type of info components.
# - `random_state`: Random state.
#
# For more about the data collection and visualization, please refer to [examples/quickstart/rtb_synthetic_data_collection.ipynb](https://github.com/negocia-inc/rtb_reinforcement_learing/blob/ope/examples/quickstart/rtb_synthetic_data_collection.ipynb).

# %%
# behavior policy
from d3rlpy.algos import DoubleDQN
from d3rlpy.models.encoders import VectorEncoderFactory
from d3rlpy.models.q_functions import MeanQFunctionFactory
from d3rlpy.online.buffers import ReplayBuffer
from d3rlpy.online.explorers import LinearDecayEpsilonGreedy

# model
ddqn = DoubleDQN(
    encoder_factory=VectorEncoderFactory(hidden_units=[30, 30]),
    q_func_factory=MeanQFunctionFactory(),
    target_update_interval=100,
    use_gpu=torch.cuda.is_available(),
)
# replay buffer
buffer = ReplayBuffer(
    maxlen=10000,
    env=env_,
)
# explorers
explorer = LinearDecayEpsilonGreedy(
    start_epsilon=1.0,
    end_epsilon=0.1,
    duration=1000,
)

# %%
# start training
# skip if there is a pre-trained model
ddqn.fit_online(
    env_,
    buffer,
    explorer=explorer,
    eval_env=env_,
    n_steps=100000,
    n_steps_per_epoch=1000,
    update_start_step=1000,
)
# Out:
# 2022-12-03 11:15.01 [info     ] Directory is created at d3rlpy_logs/DoubleDQN_online_20221203111501
# 2022-12-03 11:15.01 [debug    ] Building model...
# 2022-12-03 11:15.01 [debug    ] Model has been built.
# 2022-12-03 11:15.01 [info     ] Parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/params.json params={'action_scaler': None, 'batch_size': 32, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 0.99, 'generated_maxlen': 100000, 'learning_rate': 6.25e-05, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': None, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'DoubleDQN', 'observation_shape': (7,), 'action_size': 10}
# /home/haa/.local/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
#   0%|          | 0/100000 [00:00<?, ?it/s]
# 2022-12-03 11:15.03 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_1000.pt
# 2022-12-03 11:15.03 [info     ] DoubleDQN_online_20221203111501: epoch=1 step=1000 epoch=1 metrics={'time_inference': 0.0005516684055328369, 'time_environment_step': 0.000990365982055664, 'time_step': 0.001606921434402466, 'rollout_return': 14.232394366197184, 'evaluation': 16.7} step=1000
# 2022-12-03 11:15.10 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_2000.pt
# 2022-12-03 11:15.10 [info     ] DoubleDQN_online_20221203111501: epoch=2 step=2000 epoch=2 metrics={'time_inference': 0.0005590941905975342, 'time_environment_step': 0.0010946035385131837, 'time_sample_batch': 0.0001288473606109619, 'time_algorithm_update': 0.00491914701461792, 'loss': 41.332989449501035, 'time_step': 0.006799020290374756, 'rollout_return': 11.140845070422536, 'evaluation': 0.0} step=2000
# 2022-12-03 11:15.14 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_3000.pt
# 2022-12-03 11:15.14 [info     ] DoubleDQN_online_20221203111501: epoch=3 step=3000 epoch=3 metrics={'time_inference': 0.0005136117935180664, 'time_environment_step': 0.0010362024307250977, 'time_sample_batch': 0.00013077521324157714, 'time_algorithm_update': 0.002845743179321289, 'loss': 14.777350785493852, 'time_step': 0.00462293529510498, 'rollout_return': 1.9647887323943662, 'evaluation': 0.0} step=3000
# 2022-12-03 11:15.19 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_4000.pt
# 2022-12-03 11:15.19 [info     ] DoubleDQN_online_20221203111501: epoch=4 step=4000 epoch=4 metrics={'time_inference': 0.0004620189666748047, 'time_environment_step': 0.000943427562713623, 'time_sample_batch': 0.00012948226928710937, 'time_algorithm_update': 0.002913468837738037, 'loss': 16.027421439647675, 'time_step': 0.004533993005752563, 'rollout_return': 2.859154929577465, 'evaluation': 5.9} step=4000
# 2022-12-03 11:15.24 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_5000.pt
# 2022-12-03 11:15.24 [info     ] DoubleDQN_online_20221203111501: epoch=5 step=5000 epoch=5 metrics={'time_inference': 0.00048529052734375, 'time_environment_step': 0.0009912140369415284, 'time_sample_batch': 0.00012244749069213867, 'time_algorithm_update': 0.0032636544704437256, 'loss': 14.590841921806335, 'time_step': 0.004952908277511597, 'rollout_return': 2.1338028169014085, 'evaluation': 0.0} step=5000
# 2022-12-03 11:15.29 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_6000.pt
# 2022-12-03 11:15.29 [info     ] DoubleDQN_online_20221203111501: epoch=6 step=6000 epoch=6 metrics={'time_inference': 0.0004691436290740967, 'time_environment_step': 0.0009484038352966308, 'time_sample_batch': 0.0001117706298828125, 'time_algorithm_update': 0.002384066104888916, 'loss': 13.110981290578842, 'time_step': 0.003997548818588257, 'rollout_return': 2.816901408450704, 'evaluation': 6.0} step=6000
# 2022-12-03 11:15.33 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_7000.pt
# 2022-12-03 11:15.33 [info     ] DoubleDQN_online_20221203111501: epoch=7 step=7000 epoch=7 metrics={'time_inference': 0.0004625520706176758, 'time_environment_step': 0.0009775998592376708, 'time_sample_batch': 0.00011104536056518554, 'time_algorithm_update': 0.0026366620063781737, 'loss': 9.83526736485958, 'time_step': 0.004268702507019043, 'rollout_return': 4.295774647887324, 'evaluation': 0.0} step=7000
# 2022-12-03 11:15.38 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_8000.pt
# 2022-12-03 11:15.38 [info     ] DoubleDQN_online_20221203111501: epoch=8 step=8000 epoch=8 metrics={'time_inference': 0.0005149643421173096, 'time_environment_step': 0.0010340545177459717, 'time_sample_batch': 0.00012526965141296386, 'time_algorithm_update': 0.0027696290016174315, 'loss': 7.539488996386528, 'time_step': 0.004529734134674072, 'rollout_return': 4.633802816901408, 'evaluation': 6.2} step=8000
# 2022-12-03 11:15.42 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_9000.pt
# 2022-12-03 11:15.42 [info     ] DoubleDQN_online_20221203111501: epoch=9 step=9000 epoch=9 metrics={'time_inference': 0.0005011224746704102, 'time_environment_step': 0.001002225399017334, 'time_sample_batch': 0.00012174630165100098, 'time_algorithm_update': 0.002720017433166504, 'loss': 4.890406783223153, 'time_step': 0.004429046630859375, 'rollout_return': 7.514084507042254, 'evaluation': 7.0} step=9000
# 2022-12-03 11:15.47 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_10000.pt
# 2022-12-03 11:15.47 [info     ] DoubleDQN_online_20221203111501: epoch=10 step=10000 epoch=10 metrics={'time_inference': 0.00048646950721740724, 'time_environment_step': 0.0010348129272460937, 'time_sample_batch': 0.00013786697387695312, 'time_algorithm_update': 0.0025739624500274658, 'loss': 3.6416286895275114, 'time_step': 0.004321572065353394, 'rollout_return': 8.950704225352112, 'evaluation': 14.7} step=10000
# 2022-12-03 11:15.51 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_11000.pt
# 2022-12-03 11:15.52 [info     ] DoubleDQN_online_20221203111501: epoch=11 step=11000 epoch=11 metrics={'time_inference': 0.0004743742942810059, 'time_environment_step': 0.00098211669921875, 'time_sample_batch': 0.00011808991432189942, 'time_algorithm_update': 0.002650599241256714, 'loss': 2.9427012710571288, 'time_step': 0.004311208724975586, 'rollout_return': 10.45774647887324, 'evaluation': 3.8} step=11000
# 2022-12-03 11:15.56 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_12000.pt
# 2022-12-03 11:15.56 [info     ] DoubleDQN_online_20221203111501: epoch=12 step=12000 epoch=12 metrics={'time_inference': 0.00048701000213623044, 'time_environment_step': 0.0009793176651000976, 'time_sample_batch': 0.00013904333114624025, 'time_algorithm_update': 0.0025893120765686033, 'loss': 2.3608502726852896, 'time_step': 0.004282532215118408, 'rollout_return': 12.54225352112676, 'evaluation': 13.1} step=12000
# 2022-12-03 11:16.00 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_13000.pt
# 2022-12-03 11:16.00 [info     ] DoubleDQN_online_20221203111501: epoch=13 step=13000 epoch=13 metrics={'time_inference': 0.00047867751121521, 'time_environment_step': 0.0008945531845092773, 'time_sample_batch': 0.00011514735221862794, 'time_algorithm_update': 0.002444983959197998, 'loss': 2.091033407688141, 'time_step': 0.004018179655075073, 'rollout_return': 13.204225352112676, 'evaluation': 13.4} step=13000
# 2022-12-03 11:16.05 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_14000.pt
# 2022-12-03 11:16.05 [info     ] DoubleDQN_online_20221203111501: epoch=14 step=14000 epoch=14 metrics={'time_inference': 0.0004812881946563721, 'time_environment_step': 0.0009790351390838623, 'time_sample_batch': 0.0001232461929321289, 'time_algorithm_update': 0.0026169674396514893, 'loss': 2.0625337743759156, 'time_step': 0.004306507110595703, 'rollout_return': 13.23943661971831, 'evaluation': 13.7} step=14000
# 2022-12-03 11:16.09 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_15000.pt
# 2022-12-03 11:16.10 [info     ] DoubleDQN_online_20221203111501: epoch=15 step=15000 epoch=15 metrics={'time_inference': 0.0004857609272003174, 'time_environment_step': 0.0010644023418426513, 'time_sample_batch': 0.00012035870552062989, 'time_algorithm_update': 0.002717588424682617, 'loss': 1.7656896835565568, 'time_step': 0.004484096050262451, 'rollout_return': 13.795774647887324, 'evaluation': 11.5} step=15000
# 2022-12-03 11:16.14 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_16000.pt
# 2022-12-03 11:16.14 [info     ] DoubleDQN_online_20221203111501: epoch=16 step=16000 epoch=16 metrics={'time_inference': 0.0004515104293823242, 'time_environment_step': 0.0009631567001342773, 'time_sample_batch': 0.0001288149356842041, 'time_algorithm_update': 0.002366589069366455, 'loss': 1.5973151468336582, 'time_step': 0.003998542070388794, 'rollout_return': 13.352112676056338, 'evaluation': 15.1} step=16000
# 2022-12-03 11:16.18 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_17000.pt
# 2022-12-03 11:16.18 [info     ] DoubleDQN_online_20221203111501: epoch=17 step=17000 epoch=17 metrics={'time_inference': 0.0004520707130432129, 'time_environment_step': 0.0009784440994262695, 'time_sample_batch': 0.00011693000793457031, 'time_algorithm_update': 0.002559039115905762, 'loss': 1.4708173546493053, 'time_step': 0.004193584680557251, 'rollout_return': 13.605633802816902, 'evaluation': 13.7} step=17000
# 2022-12-03 11:16.23 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_18000.pt
# 2022-12-03 11:16.23 [info     ] DoubleDQN_online_20221203111501: epoch=18 step=18000 epoch=18 metrics={'time_inference': 0.00048480796813964844, 'time_environment_step': 0.0010066697597503663, 'time_sample_batch': 0.00012191486358642578, 'time_algorithm_update': 0.0025184152126312255, 'loss': 1.2885290595889092, 'time_step': 0.004224649667739868, 'rollout_return': 14.154929577464788, 'evaluation': 11.6} step=18000
# 2022-12-03 11:16.27 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_19000.pt
# 2022-12-03 11:16.27 [info     ] DoubleDQN_online_20221203111501: epoch=19 step=19000 epoch=19 metrics={'time_inference': 0.0004970219135284424, 'time_environment_step': 0.0009483253955841065, 'time_sample_batch': 0.00011462545394897461, 'time_algorithm_update': 0.0026379990577697753, 'loss': 1.1262838286459447, 'time_step': 0.0042837302684783935, 'rollout_return': 15.211267605633802, 'evaluation': 14.9} step=19000
# 2022-12-03 11:16.31 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_20000.pt
# 2022-12-03 11:16.31 [info     ] DoubleDQN_online_20221203111501: epoch=20 step=20000 epoch=20 metrics={'time_inference': 0.0004648311138153076, 'time_environment_step': 0.0009698567390441894, 'time_sample_batch': 0.0001147606372833252, 'time_algorithm_update': 0.0024019718170166016, 'loss': 1.0591643363237382, 'time_step': 0.004045375347137451, 'rollout_return': 14.901408450704226, 'evaluation': 8.0} step=20000
# 2022-12-03 11:16.36 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_21000.pt
# 2022-12-03 11:16.36 [info     ] DoubleDQN_online_20221203111501: epoch=21 step=21000 epoch=21 metrics={'time_inference': 0.00046880221366882324, 'time_environment_step': 0.0009901714324951172, 'time_sample_batch': 0.00012278723716735839, 'time_algorithm_update': 0.0024939279556274413, 'loss': 1.004553144454956, 'time_step': 0.0041681983470916745, 'rollout_return': 14.288732394366198, 'evaluation': 9.5} step=21000
# 2022-12-03 11:16.40 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_22000.pt
# 2022-12-03 11:16.40 [info     ] DoubleDQN_online_20221203111501: epoch=22 step=22000 epoch=22 metrics={'time_inference': 0.00047747302055358885, 'time_environment_step': 0.0009828257560729982, 'time_sample_batch': 0.00012387323379516602, 'time_algorithm_update': 0.002610386848449707, 'loss': 0.9476354798376561, 'time_step': 0.004281281471252441, 'rollout_return': 13.422535211267606, 'evaluation': 15.4} step=22000
# 2022-12-03 11:16.45 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_23000.pt
# 2022-12-03 11:16.45 [info     ] DoubleDQN_online_20221203111501: epoch=23 step=23000 epoch=23 metrics={'time_inference': 0.0004662995338439941, 'time_environment_step': 0.0009442951679229736, 'time_sample_batch': 0.00012148642539978027, 'time_algorithm_update': 0.002428850173950195, 'loss': 0.9284539340436458, 'time_step': 0.004049752235412598, 'rollout_return': 14.112676056338028, 'evaluation': 16.0} step=23000
# 2022-12-03 11:16.49 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_24000.pt
# 2022-12-03 11:16.49 [info     ] DoubleDQN_online_20221203111501: epoch=24 step=24000 epoch=24 metrics={'time_inference': 0.0005045361518859863, 'time_environment_step': 0.000984992504119873, 'time_sample_batch': 0.0001294107437133789, 'time_algorithm_update': 0.00262524938583374, 'loss': 0.903735237300396, 'time_step': 0.004338678121566773, 'rollout_return': 15.507042253521126, 'evaluation': 17.5} step=24000
# 2022-12-03 11:16.53 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_25000.pt
# 2022-12-03 11:16.53 [info     ] DoubleDQN_online_20221203111501: epoch=25 step=25000 epoch=25 metrics={'time_inference': 0.00044611024856567385, 'time_environment_step': 0.0009265592098236084, 'time_sample_batch': 0.0001179964542388916, 'time_algorithm_update': 0.002301672697067261, 'loss': 0.8772457257658243, 'time_step': 0.0038802874088287352, 'rollout_return': 15.091549295774648, 'evaluation': 13.0} step=25000
# 2022-12-03 11:16.58 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_26000.pt
# 2022-12-03 11:16.58 [info     ] DoubleDQN_online_20221203111501: epoch=26 step=26000 epoch=26 metrics={'time_inference': 0.0005006916522979736, 'time_environment_step': 0.001027839183807373, 'time_sample_batch': 0.00012113189697265626, 'time_algorithm_update': 0.0027093198299407957, 'loss': 0.8663341920375824, 'time_step': 0.004450574398040772, 'rollout_return': 14.95774647887324, 'evaluation': 14.5} step=26000
# 2022-12-03 11:17.03 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_27000.pt
# 2022-12-03 11:17.03 [info     ] DoubleDQN_online_20221203111501: epoch=27 step=27000 epoch=27 metrics={'time_inference': 0.0005269641876220703, 'time_environment_step': 0.0009946069717407227, 'time_sample_batch': 0.00011781764030456543, 'time_algorithm_update': 0.0028101294040679932, 'loss': 0.8389585270285607, 'time_step': 0.004548445463180542, 'rollout_return': 15.584507042253522, 'evaluation': 16.8} step=27000
# 2022-12-03 11:17.07 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_28000.pt
# 2022-12-03 11:17.07 [info     ] DoubleDQN_online_20221203111501: epoch=28 step=28000 epoch=28 metrics={'time_inference': 0.00047377729415893553, 'time_environment_step': 0.0009884600639343262, 'time_sample_batch': 0.0001226959228515625, 'time_algorithm_update': 0.0026369352340698243, 'loss': 0.8288788186311722, 'time_step': 0.004309531688690186, 'rollout_return': 15.309859154929578, 'evaluation': 17.4} step=28000
# 2022-12-03 11:17.12 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_29000.pt
# 2022-12-03 11:17.12 [info     ] DoubleDQN_online_20221203111501: epoch=29 step=29000 epoch=29 metrics={'time_inference': 0.0005118491649627686, 'time_environment_step': 0.0010616121292114258, 'time_sample_batch': 0.00014781618118286133, 'time_algorithm_update': 0.002974802017211914, 'loss': 0.856206168949604, 'time_step': 0.004798843860626221, 'rollout_return': 15.267605633802816, 'evaluation': 16.6} step=29000
# 2022-12-03 11:17.17 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_30000.pt
# 2022-12-03 11:17.17 [info     ] DoubleDQN_online_20221203111501: epoch=30 step=30000 epoch=30 metrics={'time_inference': 0.0004653987884521484, 'time_environment_step': 0.0009700593948364258, 'time_sample_batch': 0.00011925530433654785, 'time_algorithm_update': 0.0025639626979827882, 'loss': 0.8015994575619697, 'time_step': 0.0042081806659698484, 'rollout_return': 15.591549295774648, 'evaluation': 15.7} step=30000
# 2022-12-03 11:17.22 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_31000.pt
# 2022-12-03 11:17.22 [info     ] DoubleDQN_online_20221203111501: epoch=31 step=31000 epoch=31 metrics={'time_inference': 0.0005373296737670899, 'time_environment_step': 0.0010759758949279786, 'time_sample_batch': 0.0001499357223510742, 'time_algorithm_update': 0.0037951650619506834, 'loss': 0.8238139083981514, 'time_step': 0.005660393238067627, 'rollout_return': 16.014084507042252, 'evaluation': 15.3} step=31000
# 2022-12-03 11:17.26 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_32000.pt
# 2022-12-03 11:17.26 [info     ] DoubleDQN_online_20221203111501: epoch=32 step=32000 epoch=32 metrics={'time_inference': 0.0004438467025756836, 'time_environment_step': 0.000936311960220337, 'time_sample_batch': 0.0001370851993560791, 'time_algorithm_update': 0.0022005171775817873, 'loss': 0.7558571645468474, 'time_step': 0.003801842451095581, 'rollout_return': 15.190140845070422, 'evaluation': 15.1} step=32000
# 2022-12-03 11:17.31 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_33000.pt
# 2022-12-03 11:17.31 [info     ] DoubleDQN_online_20221203111501: epoch=33 step=33000 epoch=33 metrics={'time_inference': 0.0005166330337524414, 'time_environment_step': 0.000994525671005249, 'time_sample_batch': 0.00012428665161132814, 'time_algorithm_update': 0.0030535755157470703, 'loss': 0.7387865745425224, 'time_step': 0.0047927343845367435, 'rollout_return': 15.06338028169014, 'evaluation': 14.4} step=33000
# 2022-12-03 11:17.38 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_34000.pt
# 2022-12-03 11:17.38 [info     ] DoubleDQN_online_20221203111501: epoch=34 step=34000 epoch=34 metrics={'time_inference': 0.0005640773773193359, 'time_environment_step': 0.0010600526332855225, 'time_sample_batch': 0.00012271475791931152, 'time_algorithm_update': 0.004636348247528076, 'loss': 0.7321604148447514, 'time_step': 0.006476733684539795, 'rollout_return': 15.345070422535212, 'evaluation': 13.0} step=34000
# 2022-12-03 11:17.46 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_35000.pt
# 2022-12-03 11:17.46 [info     ] DoubleDQN_online_20221203111501: epoch=35 step=35000 epoch=35 metrics={'time_inference': 0.0005573456287384034, 'time_environment_step': 0.0011577932834625243, 'time_sample_batch': 0.0001607487201690674, 'time_algorithm_update': 0.005477475643157959, 'loss': 0.7286828189641237, 'time_step': 0.00747638201713562, 'rollout_return': 15.112676056338028, 'evaluation': 13.0} step=35000
# 2022-12-03 11:17.53 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_36000.pt
# 2022-12-03 11:17.53 [info     ] DoubleDQN_online_20221203111501: epoch=36 step=36000 epoch=36 metrics={'time_inference': 0.000527909517288208, 'time_environment_step': 0.0011265225410461426, 'time_sample_batch': 0.00016828012466430664, 'time_algorithm_update': 0.0045926222801208495, 'loss': 0.7109182679951191, 'time_step': 0.006520641803741455, 'rollout_return': 15.873239436619718, 'evaluation': 16.7} step=36000
# 2022-12-03 11:17.59 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_37000.pt
# 2022-12-03 11:17.59 [info     ] DoubleDQN_online_20221203111501: epoch=37 step=37000 epoch=37 metrics={'time_inference': 0.0005534377098083496, 'time_environment_step': 0.0010228517055511474, 'time_sample_batch': 0.00012420034408569335, 'time_algorithm_update': 0.0041540608406066895, 'loss': 0.7162346058487892, 'time_step': 0.0059638071060180665, 'rollout_return': 15.47887323943662, 'evaluation': 17.4} step=37000
# 2022-12-03 11:18.03 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_38000.pt
# 2022-12-03 11:18.03 [info     ] DoubleDQN_online_20221203111501: epoch=38 step=38000 epoch=38 metrics={'time_inference': 0.0004613337516784668, 'time_environment_step': 0.0009553303718566894, 'time_sample_batch': 0.0001244783401489258, 'time_algorithm_update': 0.002461266756057739, 'loss': 0.6970788097530604, 'time_step': 0.0040912432670593265, 'rollout_return': 14.711267605633802, 'evaluation': 15.5} step=38000
# 2022-12-03 11:18.08 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_39000.pt
# 2022-12-03 11:18.08 [info     ] DoubleDQN_online_20221203111501: epoch=39 step=39000 epoch=39 metrics={'time_inference': 0.00048700976371765135, 'time_environment_step': 0.0010146148204803467, 'time_sample_batch': 0.0001186225414276123, 'time_algorithm_update': 0.002992289066314697, 'loss': 0.6986186704933643, 'time_step': 0.004706991910934448, 'rollout_return': 14.943661971830986, 'evaluation': 14.5} step=39000
# 2022-12-03 11:18.13 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_40000.pt
# 2022-12-03 11:18.13 [info     ] DoubleDQN_online_20221203111501: epoch=40 step=40000 epoch=40 metrics={'time_inference': 0.0005296518802642823, 'time_environment_step': 0.0010522832870483397, 'time_sample_batch': 0.0001450634002685547, 'time_algorithm_update': 0.00273806095123291, 'loss': 0.6973607938885689, 'time_step': 0.004560430288314819, 'rollout_return': 15.330985915492958, 'evaluation': 15.6} step=40000
# 2022-12-03 11:18.18 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_41000.pt
# 2022-12-03 11:18.18 [info     ] DoubleDQN_online_20221203111501: epoch=41 step=41000 epoch=41 metrics={'time_inference': 0.0005390613079071045, 'time_environment_step': 0.0011567535400390625, 'time_sample_batch': 0.00014474153518676759, 'time_algorithm_update': 0.0033230161666870117, 'loss': 0.7111304909288884, 'time_step': 0.0052661759853363035, 'rollout_return': 15.492957746478874, 'evaluation': 15.3} step=41000
# 2022-12-03 11:18.23 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_42000.pt
# 2022-12-03 11:18.23 [info     ] DoubleDQN_online_20221203111501: epoch=42 step=42000 epoch=42 metrics={'time_inference': 0.0005263910293579102, 'time_environment_step': 0.0010198564529418945, 'time_sample_batch': 0.00014536190032958985, 'time_algorithm_update': 0.0028722617626190184, 'loss': 0.6986904642730951, 'time_step': 0.004659841775894165, 'rollout_return': 15.204225352112676, 'evaluation': 16.6} step=42000
# 2022-12-03 11:18.27 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_43000.pt
# 2022-12-03 11:18.27 [info     ] DoubleDQN_online_20221203111501: epoch=43 step=43000 epoch=43 metrics={'time_inference': 0.00046370506286621095, 'time_environment_step': 0.0009136288166046142, 'time_sample_batch': 0.00011652469635009766, 'time_algorithm_update': 0.0022009308338165282, 'loss': 0.7018055550009012, 'time_step': 0.0037798991203308106, 'rollout_return': 15.640845070422536, 'evaluation': 17.5} step=43000
# 2022-12-03 11:18.31 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_44000.pt
# 2022-12-03 11:18.31 [info     ] DoubleDQN_online_20221203111501: epoch=44 step=44000 epoch=44 metrics={'time_inference': 0.0004553055763244629, 'time_environment_step': 0.0009585857391357422, 'time_sample_batch': 0.00011428141593933106, 'time_algorithm_update': 0.0022351341247558595, 'loss': 0.723048509657383, 'time_step': 0.0038490538597106935, 'rollout_return': 15.816901408450704, 'evaluation': 15.8} step=44000
# 2022-12-03 11:18.36 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_45000.pt
# 2022-12-03 11:18.36 [info     ] DoubleDQN_online_20221203111501: epoch=45 step=45000 epoch=45 metrics={'time_inference': 0.00047762131690979004, 'time_environment_step': 0.0009467849731445312, 'time_sample_batch': 0.000135911226272583, 'time_algorithm_update': 0.0025872554779052736, 'loss': 0.7133985159397125, 'time_step': 0.00423633599281311, 'rollout_return': 15.669014084507042, 'evaluation': 14.3} step=45000
# 2022-12-03 11:18.40 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_46000.pt
# 2022-12-03 11:18.40 [info     ] DoubleDQN_online_20221203111501: epoch=46 step=46000 epoch=46 metrics={'time_inference': 0.0005224220752716065, 'time_environment_step': 0.0010608105659484863, 'time_sample_batch': 0.00013451170921325683, 'time_algorithm_update': 0.0026073739528656007, 'loss': 0.6894497815668583, 'time_step': 0.004420798540115356, 'rollout_return': 15.97887323943662, 'evaluation': 14.2} step=46000
# 2022-12-03 11:18.45 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_47000.pt
# 2022-12-03 11:18.45 [info     ] DoubleDQN_online_20221203111501: epoch=47 step=47000 epoch=47 metrics={'time_inference': 0.0004658870697021484, 'time_environment_step': 0.0009782953262329102, 'time_sample_batch': 0.0001162557601928711, 'time_algorithm_update': 0.0022530343532562256, 'loss': 0.7027528499364852, 'time_step': 0.00390654468536377, 'rollout_return': 15.5, 'evaluation': 14.6} step=47000
# 2022-12-03 11:18.49 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_48000.pt
# 2022-12-03 11:18.49 [info     ] DoubleDQN_online_20221203111501: epoch=48 step=48000 epoch=48 metrics={'time_inference': 0.0004978516101837158, 'time_environment_step': 0.0009952497482299805, 'time_sample_batch': 0.00012253594398498535, 'time_algorithm_update': 0.002382666349411011, 'loss': 0.6993410596251488, 'time_step': 0.004095173358917236, 'rollout_return': 14.605633802816902, 'evaluation': 17.2} step=48000
# 2022-12-03 11:18.53 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_49000.pt
# 2022-12-03 11:18.53 [info     ] DoubleDQN_online_20221203111501: epoch=49 step=49000 epoch=49 metrics={'time_inference': 0.0004355878829956055, 'time_environment_step': 0.0009083333015441895, 'time_sample_batch': 0.00011787700653076171, 'time_algorithm_update': 0.0020714709758758547, 'loss': 0.7102090625613928, 'time_step': 0.0036156678199768064, 'rollout_return': 15.070422535211268, 'evaluation': 13.4} step=49000
# 2022-12-03 11:18.57 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_50000.pt
# 2022-12-03 11:18.57 [info     ] DoubleDQN_online_20221203111501: epoch=50 step=50000 epoch=50 metrics={'time_inference': 0.0004538359642028809, 'time_environment_step': 0.0009502887725830079, 'time_sample_batch': 0.00011894726753234864, 'time_algorithm_update': 0.002276238679885864, 'loss': 0.708265726044774, 'time_step': 0.003886418581008911, 'rollout_return': 15.640845070422536, 'evaluation': 17.2} step=50000
# 2022-12-03 11:19.01 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_51000.pt
# 2022-12-03 11:19.01 [info     ] DoubleDQN_online_20221203111501: epoch=51 step=51000 epoch=51 metrics={'time_inference': 0.00046707749366760255, 'time_environment_step': 0.0009215590953826904, 'time_sample_batch': 0.00011266875267028809, 'time_algorithm_update': 0.0022516567707061767, 'loss': 0.7258961725234986, 'time_step': 0.003838467359542847, 'rollout_return': 14.992957746478874, 'evaluation': 15.2} step=51000
# 2022-12-03 11:19.05 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_52000.pt
# 2022-12-03 11:19.05 [info     ] DoubleDQN_online_20221203111501: epoch=52 step=52000 epoch=52 metrics={'time_inference': 0.00044907593727111815, 'time_environment_step': 0.0009137387275695801, 'time_sample_batch': 0.00010988783836364747, 'time_algorithm_update': 0.002145653009414673, 'loss': 0.7258743511736393, 'time_step': 0.00370755410194397, 'rollout_return': 14.929577464788732, 'evaluation': 15.7} step=52000
# 2022-12-03 11:19.09 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_53000.pt
# 2022-12-03 11:19.09 [info     ] DoubleDQN_online_20221203111501: epoch=53 step=53000 epoch=53 metrics={'time_inference': 0.00045583343505859375, 'time_environment_step': 0.00095682692527771, 'time_sample_batch': 0.00011992597579956054, 'time_algorithm_update': 0.002410975456237793, 'loss': 0.742886907979846, 'time_step': 0.0040284512042999265, 'rollout_return': 15.901408450704226, 'evaluation': 16.5} step=53000
# 2022-12-03 11:19.13 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_54000.pt
# 2022-12-03 11:19.13 [info     ] DoubleDQN_online_20221203111501: epoch=54 step=54000 epoch=54 metrics={'time_inference': 0.0004500529766082764, 'time_environment_step': 0.0009476428031921387, 'time_sample_batch': 0.00012039709091186524, 'time_algorithm_update': 0.0022848267555236816, 'loss': 0.7777961824536324, 'time_step': 0.0038930146694183348, 'rollout_return': 15.183098591549296, 'evaluation': 15.1} step=54000
# 2022-12-03 11:19.17 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_55000.pt
# 2022-12-03 11:19.17 [info     ] DoubleDQN_online_20221203111501: epoch=55 step=55000 epoch=55 metrics={'time_inference': 0.0004651820659637451, 'time_environment_step': 0.0009568562507629395, 'time_sample_batch': 0.00013079047203063966, 'time_algorithm_update': 0.0023473193645477293, 'loss': 0.7263947973400354, 'time_step': 0.003990790367126465, 'rollout_return': 15.605633802816902, 'evaluation': 11.6} step=55000
# 2022-12-03 11:19.22 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_56000.pt
# 2022-12-03 11:19.22 [info     ] DoubleDQN_online_20221203111501: epoch=56 step=56000 epoch=56 metrics={'time_inference': 0.0005142798423767089, 'time_environment_step': 0.0010433928966522216, 'time_sample_batch': 0.00013666534423828125, 'time_algorithm_update': 0.002577240467071533, 'loss': 0.7251541134566069, 'time_step': 0.0043719465732574465, 'rollout_return': 15.76056338028169, 'evaluation': 16.0} step=56000
# 2022-12-03 11:19.27 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_57000.pt
# 2022-12-03 11:19.27 [info     ] DoubleDQN_online_20221203111501: epoch=57 step=57000 epoch=57 metrics={'time_inference': 0.0004943361282348633, 'time_environment_step': 0.0010101971626281737, 'time_sample_batch': 0.00011627364158630371, 'time_algorithm_update': 0.0028721261024475097, 'loss': 0.729920778542757, 'time_step': 0.004579949140548706, 'rollout_return': 15.464788732394366, 'evaluation': 15.6} step=57000
# 2022-12-03 11:19.31 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_58000.pt
# 2022-12-03 11:19.31 [info     ] DoubleDQN_online_20221203111501: epoch=58 step=58000 epoch=58 metrics={'time_inference': 0.0005036697387695312, 'time_environment_step': 0.0010846040248870849, 'time_sample_batch': 0.0001358182430267334, 'time_algorithm_update': 0.002804046869277954, 'loss': 0.7178011549264193, 'time_step': 0.00463379168510437, 'rollout_return': 15.30281690140845, 'evaluation': 15.6} step=58000
# 2022-12-03 11:19.36 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_59000.pt
# 2022-12-03 11:19.36 [info     ] DoubleDQN_online_20221203111501: epoch=59 step=59000 epoch=59 metrics={'time_inference': 0.00047861599922180176, 'time_environment_step': 0.001004746437072754, 'time_sample_batch': 0.00011809468269348144, 'time_algorithm_update': 0.002325477361679077, 'loss': 0.7497206893265247, 'time_step': 0.004027941465377808, 'rollout_return': 15.78169014084507, 'evaluation': 15.0} step=59000
# 2022-12-03 11:19.40 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_60000.pt
# 2022-12-03 11:19.40 [info     ] DoubleDQN_online_20221203111501: epoch=60 step=60000 epoch=60 metrics={'time_inference': 0.0004792954921722412, 'time_environment_step': 0.0009753334522247314, 'time_sample_batch': 0.00011452531814575195, 'time_algorithm_update': 0.0022727518081665037, 'loss': 0.7371416822075844, 'time_step': 0.003928416967391967, 'rollout_return': 15.598591549295774, 'evaluation': 18.0} step=60000
# 2022-12-03 11:19.44 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_61000.pt
# 2022-12-03 11:19.44 [info     ] DoubleDQN_online_20221203111501: epoch=61 step=61000 epoch=61 metrics={'time_inference': 0.00048305416107177735, 'time_environment_step': 0.0009666435718536377, 'time_sample_batch': 0.00011849141120910644, 'time_algorithm_update': 0.0025323116779327392, 'loss': 0.7298229283988475, 'time_step': 0.004191343545913696, 'rollout_return': 15.26056338028169, 'evaluation': 17.4} step=61000
# 2022-12-03 11:19.51 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_62000.pt
# 2022-12-03 11:19.51 [info     ] DoubleDQN_online_20221203111501: epoch=62 step=62000 epoch=62 metrics={'time_inference': 0.0005268118381500244, 'time_environment_step': 0.0011048333644866942, 'time_sample_batch': 0.00013627004623413086, 'time_algorithm_update': 0.004776071548461914, 'loss': 0.7498253819644451, 'time_step': 0.006640559196472168, 'rollout_return': 15.091549295774648, 'evaluation': 15.2} step=62000
# 2022-12-03 11:19.57 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_63000.pt
# 2022-12-03 11:19.57 [info     ] DoubleDQN_online_20221203111501: epoch=63 step=63000 epoch=63 metrics={'time_inference': 0.0005519003868103028, 'time_environment_step': 0.0011121015548706055, 'time_sample_batch': 0.0001264946460723877, 'time_algorithm_update': 0.0036692056655883787, 'loss': 0.7066115356385708, 'time_step': 0.0055537445545196535, 'rollout_return': 15.816901408450704, 'evaluation': 15.4} step=63000
# 2022-12-03 11:20.04 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_64000.pt
# 2022-12-03 11:20.05 [info     ] DoubleDQN_online_20221203111501: epoch=64 step=64000 epoch=64 metrics={'time_inference': 0.0005811383724212646, 'time_environment_step': 0.0010661256313323974, 'time_sample_batch': 0.00013275980949401856, 'time_algorithm_update': 0.005552757024765015, 'loss': 0.7003746520727873, 'time_step': 0.007428991079330444, 'rollout_return': 15.591549295774648, 'evaluation': 16.6} step=64000
# 2022-12-03 11:20.10 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_65000.pt
# 2022-12-03 11:20.10 [info     ] DoubleDQN_online_20221203111501: epoch=65 step=65000 epoch=65 metrics={'time_inference': 0.000509777545928955, 'time_environment_step': 0.0010900373458862305, 'time_sample_batch': 0.00013959383964538575, 'time_algorithm_update': 0.002997563362121582, 'loss': 0.6991438234746457, 'time_step': 0.004839002847671509, 'rollout_return': 15.683098591549296, 'evaluation': 15.8} step=65000
# 2022-12-03 11:20.16 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_66000.pt
# 2022-12-03 11:20.16 [info     ] DoubleDQN_online_20221203111501: epoch=66 step=66000 epoch=66 metrics={'time_inference': 0.0005045340061187744, 'time_environment_step': 0.001133127450942993, 'time_sample_batch': 0.00012008118629455566, 'time_algorithm_update': 0.004293386220932007, 'loss': 0.7193598199635745, 'time_step': 0.006144238471984863, 'rollout_return': 15.091549295774648, 'evaluation': 17.2} step=66000
# 2022-12-03 11:20.22 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_67000.pt
# 2022-12-03 11:20.22 [info     ] DoubleDQN_online_20221203111501: epoch=67 step=67000 epoch=67 metrics={'time_inference': 0.00048164939880371093, 'time_environment_step': 0.0010126125812530517, 'time_sample_batch': 0.00012327003479003907, 'time_algorithm_update': 0.0038158981800079346, 'loss': 0.6760976343005896, 'time_step': 0.005528412818908692, 'rollout_return': 15.908450704225352, 'evaluation': 18.7} step=67000
# 2022-12-03 11:20.29 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_68000.pt
# 2022-12-03 11:20.29 [info     ] DoubleDQN_online_20221203111501: epoch=68 step=68000 epoch=68 metrics={'time_inference': 0.0006140213012695312, 'time_environment_step': 0.0010835633277893066, 'time_sample_batch': 0.00015057849884033203, 'time_algorithm_update': 0.004784454822540283, 'loss': 0.7331063700318337, 'time_step': 0.006742487668991089, 'rollout_return': 15.901408450704226, 'evaluation': 15.6} step=68000
# 2022-12-03 11:20.36 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_69000.pt
# 2022-12-03 11:20.36 [info     ] DoubleDQN_online_20221203111501: epoch=69 step=69000 epoch=69 metrics={'time_inference': 0.0005494959354400635, 'time_environment_step': 0.0010996625423431397, 'time_sample_batch': 0.00013127851486206054, 'time_algorithm_update': 0.00473221755027771, 'loss': 0.7368041766732931, 'time_step': 0.006605772256851196, 'rollout_return': 15.514084507042254, 'evaluation': 14.2} step=69000
# 2022-12-03 11:20.41 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_70000.pt
# 2022-12-03 11:20.41 [info     ] DoubleDQN_online_20221203111501: epoch=70 step=70000 epoch=70 metrics={'time_inference': 0.0005227878093719483, 'time_environment_step': 0.0010331230163574219, 'time_sample_batch': 0.00014266085624694826, 'time_algorithm_update': 0.00319738507270813, 'loss': 0.7197445274293423, 'time_step': 0.00499112057685852, 'rollout_return': 15.352112676056338, 'evaluation': 14.4} step=70000
# 2022-12-03 11:20.45 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_71000.pt
# 2022-12-03 11:20.45 [info     ] DoubleDQN_online_20221203111501: epoch=71 step=71000 epoch=71 metrics={'time_inference': 0.00047352075576782225, 'time_environment_step': 0.001004636287689209, 'time_sample_batch': 0.00012596392631530762, 'time_algorithm_update': 0.0024063479900360107, 'loss': 0.7259797503054142, 'time_step': 0.00409932279586792, 'rollout_return': 15.19718309859155, 'evaluation': 16.8} step=71000
# 2022-12-03 11:20.50 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_72000.pt
# 2022-12-03 11:20.50 [info     ] DoubleDQN_online_20221203111501: epoch=72 step=72000 epoch=72 metrics={'time_inference': 0.00047612977027893064, 'time_environment_step': 0.0009582431316375732, 'time_sample_batch': 0.00012323451042175294, 'time_algorithm_update': 0.002567683219909668, 'loss': 0.7403044623732566, 'time_step': 0.004209581613540649, 'rollout_return': 15.894366197183098, 'evaluation': 14.4} step=72000
# 2022-12-03 11:20.53 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_73000.pt
# 2022-12-03 11:20.53 [info     ] DoubleDQN_online_20221203111501: epoch=73 step=73000 epoch=73 metrics={'time_inference': 0.00043631649017333987, 'time_environment_step': 0.0008938453197479249, 'time_sample_batch': 0.00010767531394958496, 'time_algorithm_update': 0.002091296672821045, 'loss': 0.7344100881516934, 'time_step': 0.0036124954223632814, 'rollout_return': 15.309859154929578, 'evaluation': 17.1} step=73000
# 2022-12-03 11:20.57 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_74000.pt
# 2022-12-03 11:20.57 [info     ] DoubleDQN_online_20221203111501: epoch=74 step=74000 epoch=74 metrics={'time_inference': 0.00041426014900207517, 'time_environment_step': 0.0008587582111358643, 'time_sample_batch': 0.00011831307411193847, 'time_algorithm_update': 0.0020857696533203127, 'loss': 0.7747734618186951, 'time_step': 0.0035568718910217287, 'rollout_return': 15.28169014084507, 'evaluation': 17.0} step=74000
# 2022-12-03 11:21.01 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_75000.pt
# 2022-12-03 11:21.02 [info     ] DoubleDQN_online_20221203111501: epoch=75 step=75000 epoch=75 metrics={'time_inference': 0.0004821763038635254, 'time_environment_step': 0.0009714927673339843, 'time_sample_batch': 0.00011541271209716797, 'time_algorithm_update': 0.002474574089050293, 'loss': 0.7146642490923405, 'time_step': 0.004146429061889648, 'rollout_return': 15.690140845070422, 'evaluation': 14.5} step=75000
# 2022-12-03 11:21.06 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_76000.pt
# 2022-12-03 11:21.06 [info     ] DoubleDQN_online_20221203111501: epoch=76 step=76000 epoch=76 metrics={'time_inference': 0.0004929404258728027, 'time_environment_step': 0.0010165746212005616, 'time_sample_batch': 0.00012784457206726075, 'time_algorithm_update': 0.002544301748275757, 'loss': 0.7509797350168228, 'time_step': 0.004272822380065918, 'rollout_return': 15.415492957746478, 'evaluation': 16.5} step=76000
# 2022-12-03 11:21.10 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_77000.pt
# 2022-12-03 11:21.10 [info     ] DoubleDQN_online_20221203111501: epoch=77 step=77000 epoch=77 metrics={'time_inference': 0.00042027997970581053, 'time_environment_step': 0.0009102523326873779, 'time_sample_batch': 0.0001086738109588623, 'time_algorithm_update': 0.002145617961883545, 'loss': 0.7447004611045123, 'time_step': 0.0036684350967407225, 'rollout_return': 16.12676056338028, 'evaluation': 16.4} step=77000
# 2022-12-03 11:21.15 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_78000.pt
# 2022-12-03 11:21.15 [info     ] DoubleDQN_online_20221203111501: epoch=78 step=78000 epoch=78 metrics={'time_inference': 0.0005110800266265869, 'time_environment_step': 0.0010896584987640382, 'time_sample_batch': 0.0001372668743133545, 'time_algorithm_update': 0.003303797960281372, 'loss': 0.7670536522865296, 'time_step': 0.005138813734054565, 'rollout_return': 15.056338028169014, 'evaluation': 15.8} step=78000
# 2022-12-03 11:21.21 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_79000.pt
# 2022-12-03 11:21.21 [info     ] DoubleDQN_online_20221203111501: epoch=79 step=79000 epoch=79 metrics={'time_inference': 0.0005277204513549805, 'time_environment_step': 0.0011059513092041015, 'time_sample_batch': 0.00013460183143615724, 'time_algorithm_update': 0.003656265020370483, 'loss': 0.7447476849257946, 'time_step': 0.005525444030761719, 'rollout_return': 15.288732394366198, 'evaluation': 15.1} step=79000
# 2022-12-03 11:21.25 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_80000.pt
# 2022-12-03 11:21.25 [info     ] DoubleDQN_online_20221203111501: epoch=80 step=80000 epoch=80 metrics={'time_inference': 0.00044035601615905764, 'time_environment_step': 0.000932966947555542, 'time_sample_batch': 0.00011169672012329102, 'time_algorithm_update': 0.002509428977966309, 'loss': 0.7811459861844778, 'time_step': 0.004077401399612427, 'rollout_return': 15.295774647887324, 'evaluation': 19.2} step=80000
# 2022-12-03 11:21.30 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_81000.pt
# 2022-12-03 11:21.30 [info     ] DoubleDQN_online_20221203111501: epoch=81 step=81000 epoch=81 metrics={'time_inference': 0.0005153539180755615, 'time_environment_step': 0.0010672595500946045, 'time_sample_batch': 0.00012441229820251464, 'time_algorithm_update': 0.002761202335357666, 'loss': 0.7766378638148308, 'time_step': 0.004566797971725464, 'rollout_return': 15.619718309859154, 'evaluation': 14.7} step=81000
# 2022-12-03 11:21.37 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_82000.pt
# 2022-12-03 11:21.37 [info     ] DoubleDQN_online_20221203111501: epoch=82 step=82000 epoch=82 metrics={'time_inference': 0.0005304422378540039, 'time_environment_step': 0.0010676157474517822, 'time_sample_batch': 0.0001421358585357666, 'time_algorithm_update': 0.004785065889358521, 'loss': 0.8075129863619804, 'time_step': 0.006625141143798828, 'rollout_return': 15.007042253521126, 'evaluation': 14.4} step=82000
# 2022-12-03 11:21.42 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_83000.pt
# 2022-12-03 11:21.42 [info     ] DoubleDQN_online_20221203111501: epoch=83 step=83000 epoch=83 metrics={'time_inference': 0.0005175185203552246, 'time_environment_step': 0.0010313935279846192, 'time_sample_batch': 0.0001241612434387207, 'time_algorithm_update': 0.0031674876213073733, 'loss': 0.7669320404827594, 'time_step': 0.004932004690170288, 'rollout_return': 16.06338028169014, 'evaluation': 15.0} step=83000
# 2022-12-03 11:21.57 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_84000.pt
# 2022-12-03 11:21.57 [info     ] DoubleDQN_online_20221203111501: epoch=84 step=84000 epoch=84 metrics={'time_inference': 0.0006151878833770752, 'time_environment_step': 0.001164278745651245, 'time_sample_batch': 0.00015645480155944825, 'time_algorithm_update': 0.012910169124603271, 'loss': 0.800312889918685, 'time_step': 0.014941775560379029, 'rollout_return': 15.80281690140845, 'evaluation': 16.8} step=84000
# 2022-12-03 11:22.20 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_85000.pt
# 2022-12-03 11:22.20 [info     ] DoubleDQN_online_20221203111501: epoch=85 step=85000 epoch=85 metrics={'time_inference': 0.0006530780792236328, 'time_environment_step': 0.0012040224075317383, 'time_sample_batch': 0.00014703083038330078, 'time_algorithm_update': 0.020312689542770386, 'loss': 0.7696364217549563, 'time_step': 0.02244394874572754, 'rollout_return': 15.528169014084508, 'evaluation': 15.3} step=85000
# 2022-12-03 11:22.34 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_86000.pt
# 2022-12-03 11:22.34 [info     ] DoubleDQN_online_20221203111501: epoch=86 step=86000 epoch=86 metrics={'time_inference': 0.0007177679538726806, 'time_environment_step': 0.0012892391681671143, 'time_sample_batch': 0.00015780115127563476, 'time_algorithm_update': 0.01106185746192932, 'loss': 0.7576078561544418, 'time_step': 0.01334730887413025, 'rollout_return': 15.549295774647888, 'evaluation': 16.0} step=86000
# 2022-12-03 11:22.39 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_87000.pt
# 2022-12-03 11:22.39 [info     ] DoubleDQN_online_20221203111501: epoch=87 step=87000 epoch=87 metrics={'time_inference': 0.0005030531883239746, 'time_environment_step': 0.0010358076095581055, 'time_sample_batch': 0.00013625311851501464, 'time_algorithm_update': 0.002735881805419922, 'loss': 0.7437402805089951, 'time_step': 0.004504873514175415, 'rollout_return': 15.492957746478874, 'evaluation': 18.5} step=87000
# 2022-12-03 11:22.43 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_88000.pt
# 2022-12-03 11:22.43 [info     ] DoubleDQN_online_20221203111501: epoch=88 step=88000 epoch=88 metrics={'time_inference': 0.0005004096031188965, 'time_environment_step': 0.0010283231735229493, 'time_sample_batch': 0.00012479043006896972, 'time_algorithm_update': 0.00255104660987854, 'loss': 0.7376475044190883, 'time_step': 0.0042969970703125, 'rollout_return': 14.95774647887324, 'evaluation': 16.7} step=88000
# 2022-12-03 11:22.48 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_89000.pt
# 2022-12-03 11:22.48 [info     ] DoubleDQN_online_20221203111501: epoch=89 step=89000 epoch=89 metrics={'time_inference': 0.00048734402656555175, 'time_environment_step': 0.0009846458435058595, 'time_sample_batch': 0.00012700152397155762, 'time_algorithm_update': 0.0030853638648986816, 'loss': 0.7442140153646469, 'time_step': 0.004777176380157471, 'rollout_return': 15.183098591549296, 'evaluation': 17.6} step=89000
# 2022-12-03 11:22.54 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_90000.pt
# 2022-12-03 11:22.54 [info     ] DoubleDQN_online_20221203111501: epoch=90 step=90000 epoch=90 metrics={'time_inference': 0.0005131621360778809, 'time_environment_step': 0.001036376953125, 'time_sample_batch': 0.00011672091484069824, 'time_algorithm_update': 0.003546786546707153, 'loss': 0.7259418800026178, 'time_step': 0.005318801879882812, 'rollout_return': 15.23943661971831, 'evaluation': 15.6} step=90000
# 2022-12-03 11:22.59 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_91000.pt
# 2022-12-03 11:22.59 [info     ] DoubleDQN_online_20221203111501: epoch=91 step=91000 epoch=91 metrics={'time_inference': 0.0005197770595550537, 'time_environment_step': 0.0010507075786590576, 'time_sample_batch': 0.0001251349449157715, 'time_algorithm_update': 0.003017455816268921, 'loss': 0.7207903894484043, 'time_step': 0.004804306745529175, 'rollout_return': 15.070422535211268, 'evaluation': 17.4} step=91000
# 2022-12-03 11:23.03 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_92000.pt
# 2022-12-03 11:23.03 [info     ] DoubleDQN_online_20221203111501: epoch=92 step=92000 epoch=92 metrics={'time_inference': 0.000498945951461792, 'time_environment_step': 0.0009874191284179688, 'time_sample_batch': 0.00012428903579711915, 'time_algorithm_update': 0.002781684398651123, 'loss': 0.7194583518803119, 'time_step': 0.004493086338043213, 'rollout_return': 15.669014084507042, 'evaluation': 15.7} step=92000
# 2022-12-03 11:23.07 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_93000.pt
# 2022-12-03 11:23.08 [info     ] DoubleDQN_online_20221203111501: epoch=93 step=93000 epoch=93 metrics={'time_inference': 0.00046518898010253906, 'time_environment_step': 0.0009467432498931885, 'time_sample_batch': 0.00011394858360290527, 'time_algorithm_update': 0.0023990666866302492, 'loss': 0.7444570993632078, 'time_step': 0.004009776115417481, 'rollout_return': 15.211267605633802, 'evaluation': 15.6} step=93000
# 2022-12-03 11:23.12 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_94000.pt
# 2022-12-03 11:23.12 [info     ] DoubleDQN_online_20221203111501: epoch=94 step=94000 epoch=94 metrics={'time_inference': 0.0005003843307495117, 'time_environment_step': 0.0010534334182739258, 'time_sample_batch': 0.00012479376792907715, 'time_algorithm_update': 0.002774796724319458, 'loss': 0.7290114849805832, 'time_step': 0.004551177501678467, 'rollout_return': 15.535211267605634, 'evaluation': 16.2} step=94000
# 2022-12-03 11:23.17 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_95000.pt
# 2022-12-03 11:23.17 [info     ] DoubleDQN_online_20221203111501: epoch=95 step=95000 epoch=95 metrics={'time_inference': 0.0004890484809875488, 'time_environment_step': 0.0010316569805145263, 'time_sample_batch': 0.00011816167831420898, 'time_algorithm_update': 0.0026453404426574705, 'loss': 0.7220961852371692, 'time_step': 0.004379113435745239, 'rollout_return': 15.69718309859155, 'evaluation': 15.6} step=95000
# 2022-12-03 11:23.22 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_96000.pt
# 2022-12-03 11:23.22 [info     ] DoubleDQN_online_20221203111501: epoch=96 step=96000 epoch=96 metrics={'time_inference': 0.0005014684200286866, 'time_environment_step': 0.0010189251899719238, 'time_sample_batch': 0.00012736988067626952, 'time_algorithm_update': 0.0028196477890014646, 'loss': 0.7632156173586846, 'time_step': 0.004572202205657959, 'rollout_return': 15.077464788732394, 'evaluation': 16.5} step=96000
# 2022-12-03 11:23.36 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_97000.pt
# 2022-12-03 11:23.36 [info     ] DoubleDQN_online_20221203111501: epoch=97 step=97000 epoch=97 metrics={'time_inference': 0.0005327930450439453, 'time_environment_step': 0.0011292123794555665, 'time_sample_batch': 0.00014120078086853028, 'time_algorithm_update': 0.012275442838668823, 'loss': 0.7726627477854491, 'time_step': 0.014216754913330078, 'rollout_return': 15.119718309859154, 'evaluation': 14.8} step=97000
# 2022-12-03 11:23.59 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_98000.pt
# 2022-12-03 11:23.59 [info     ] DoubleDQN_online_20221203111501: epoch=98 step=98000 epoch=98 metrics={'time_inference': 0.0006924054622650147, 'time_environment_step': 0.0012305481433868407, 'time_sample_batch': 0.00013725018501281738, 'time_algorithm_update': 0.019884137153625487, 'loss': 0.7626202102303505, 'time_step': 0.022054404020309448, 'rollout_return': 15.82394366197183, 'evaluation': 15.0} step=98000
# 2022-12-03 11:24.24 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_99000.pt
# 2022-12-03 11:24.24 [info     ] DoubleDQN_online_20221203111501: epoch=99 step=99000 epoch=99 metrics={'time_inference': 0.000644622802734375, 'time_environment_step': 0.0012832911014556885, 'time_sample_batch': 0.00013814353942871095, 'time_algorithm_update': 0.022156720399856566, 'loss': 0.7728916337490082, 'time_step': 0.024368768215179443, 'rollout_return': 15.471830985915492, 'evaluation': 14.8} step=99000
# 2022-12-03 11:24.48 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20221203111501/model_100000.pt
# 2022-12-03 11:24.48 [info     ] DoubleDQN_online_20221203111501: epoch=100 step=100000 epoch=100 metrics={'time_inference': 0.0006845977306365967, 'time_environment_step': 0.001138540506362915, 'time_sample_batch': 0.0001735401153564453, 'time_algorithm_update': 0.02139772582054138, 'loss': 0.7644820635914803, 'time_step': 0.02351876711845398, 'rollout_return': 15.591549295774648, 'evaluation': 15.5} step=100000

# %%
# save model
ddqn.save_model("d3rlpy_logs/ddqn.pt")

# %%
# reload model
ddqn.build_with_env(env)
ddqn.load_model("d3rlpy_logs/ddqn.pt")

# %%
behavior_policy = EpsilonGreedyHead(
    ddqn, 
    n_actions=env.action_space.n,
    epsilon=0.3,
    name="ddqn_epsilon_0.3",
    random_state=random_state,
)

# %%
# initialize dataset class
dataset = SyntheticDataset(
    env=env,
    behavior_policy=behavior_policy,
    action_meaning=env.action_meaning,
    state_keys=env.obs_keys,
    max_episode_steps=env.step_per_episode,
    info_keys={
        "search_volume": int,
        "impression": int,
        "click": int,
        "conversion": int,
        "average_bid_price": float,
    },
    random_state=random_state,
)

# %%
# collect logged data by a behavior policy
# skip if there is a preserved logged dataset
logged_dataset = dataset.obtain_episodes(n_trajectories=10000, obtain_info=True)
# Out:
# [obtain_trajectories]:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
with open("logs/dataset_discrete_ddpn.pkl", "wb") as f:
    pickle.dump(logged_dataset, f)

# %%
with open("logs/dataset_discrete_ddpn.pkl", "rb") as f:
    logged_dataset = pickle.load(f)

# %% [markdown]
# #### Offline Policy Learning
# Here, we learn several "candidate" policies to be evaluated and selected using [d3rlpy](https://github.com/takuseno/d3rlpy)'s algorithm implementation.
#
# For more about the offline RL procedure, please refer to [examples/quickstart/rtb_synthetic_discrete_basic.ipynb](https://github.com/negocia-inc/rtb_reinforcement_learing/blob/ope/examples/quickstart/rtb_synthetic_discrete_basic.ipynb).

# %%
# import modules from d3rlpy
from d3rlpy.dataset import MDPDataset
from d3rlpy.algos import DiscreteCQL as CQL
# transform offline dataset for d3rlpy
offlinerl_dataset = MDPDataset(
    observations=logged_dataset["state"],
    actions=logged_dataset["action"],
    rewards=logged_dataset["reward"],
    terminals=logged_dataset["done"],
    episode_terminals=logged_dataset["done"],
    discrete_action=True,
)
train_episodes, test_episodes = train_test_split(offlinerl_dataset, test_size=0.2, random_state=random_state)

# %%
# Use Conservative Q-Learning policy
cql = CQL(
    encoder_factory=VectorEncoderFactory(hidden_units=[30, 30]),
    q_func_factory=MeanQFunctionFactory(),
    use_gpu=torch.cuda.is_available(),
)

# %%
cql.fit(
    train_episodes,
    eval_episodes=test_episodes,
    n_steps=10000,
    scorers={},
)
# Out:
# 2022-11-24 04:49.20 [debug    ] RandomIterator is selected.
# 2022-11-24 04:49.20 [info     ] Directory is created at d3rlpy_logs/DiscreteCQL_20221124044920
# 2022-11-24 04:49.20 [debug    ] Building models...
# 2022-11-24 04:49.20 [debug    ] Models have been built.
# 2022-11-24 04:49.20 [info     ] Parameters are saved to d3rlpy_logs/DiscreteCQL_20221124044920/params.json params={'action_scaler': None, 'alpha': 1.0, 'batch_size': 32, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 0.99, 'generated_maxlen': 100000, 'learning_rate': 6.25e-05, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': None, 'target_update_interval': 8000, 'use_gpu': None, 'algorithm': 'DiscreteCQL', 'observation_shape': (7,), 'action_size': 10}
# Epoch 1/1:   0%|          | 0/10000 [00:00<?, ?it/s]
# 2022-11-24 04:56.13 [info     ] DiscreteCQL_20221124044920: epoch=1 step=10000 epoch=1 metrics={'time_sample_batch': 0.00039889097213745116, 'time_algorithm_update': 0.04027746403217316, 'loss': 77.3925471253395, 'time_step': 0.04094007489681244} step=10000
# 2022-11-24 04:56.13 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteCQL_20221124044920/model_10000.pt
# [(1,
#   {'time_sample_batch': 0.00039889097213745116,
#    'time_algorithm_update': 0.04027746403217316,
#    'loss': 77.3925471253395,
#    'time_step': 0.04094007489681244})]

# %%
# save model
cql.save_model("d3rlpy_logs/cql_discrete.pt")

# %%
# reload model
cql.build_with_env(env_)
cql.load_model("d3rlpy_logs/cql_discrete.pt")

# %% [markdown]
# ## 2. Off-Policy Evaluation
# In this section, we aim at evaluating the various performance statistics of policies in an offline manner using (basic) model-based and importance sampling-based estimators.
#
# #### Estimation Target
#
# The goal to estimate the estimators' average policy performance, the *policy value*.
#
# $$ V(\pi) := \mathbb{E}\left[\sum_{t=1}^T \gamma^{t-1} r_t \mid \pi \right] $$

# %%
# import ope modules from OFRL
from ofrl.ope import CreateOPEInput
from ofrl.ope import OffPolicyEvaluation as OPE
# basic estimators
from ofrl.ope import DiscreteDirectMethod as DM
from ofrl.ope import DiscreteTrajectoryWiseImportanceSampling as TIS
from ofrl.ope import DiscretePerDecisionImportanceSampling as PDIS
from ofrl.ope import DiscreteDoublyRobust as DR
# self normalized estimators
from ofrl.ope import DiscreteSelfNormalizedTrajectoryWiseImportanceSampling as SNTIS
from ofrl.ope import DiscreteSelfNormalizedPerDecisionImportanceSampling as SNPDIS
from ofrl.ope import DiscreteSelfNormalizedDoublyRobust as SNDR
# marginal estimators
from ofrl.ope import DiscreteStateActionMarginalImportanceSampling as SAMIS
from ofrl.ope import DiscreteStateActionMarginalDoublyRobust as SAMDR
from ofrl.ope import DiscreteStateMarginalImportanceSampling as SMIS
from ofrl.ope import DiscreteStateMarginalDoublyRobust as SMDR
from ofrl.ope import DiscreteStateActionMarginalSelfNormalizedImportanceSampling as SAMSNIS
from ofrl.ope import DiscreteStateActionMarginalSelfNormalizedDoublyRobust as SAMSNDR
from ofrl.ope import DiscreteStateMarginalSelfNormalizedImportanceSampling as SMSNIS
from ofrl.ope import DiscreteStateMarginalSelfNormalizedDoublyRobust as SMSNDR
# double reinforcement learning estimators
from ofrl.ope import DiscreteDoubleReinforcementLearning as DRL

# %%
from d3rlpy.algos import DiscreteRandomPolicy
random = DiscreteRandomPolicy()
random.build_with_env(env_)

# %%
# define evaluation policies
cql_ = EpsilonGreedyHead(base_policy=cql, n_actions=env.action_space.n, name="cql", epsilon=0.0, random_state=random_state)
ddqn_ = EpsilonGreedyHead(base_policy=ddqn, n_actions=env.action_space.n, name="ddqn", epsilon=0.0, random_state=random_state)
random_ = EpsilonGreedyHead(base_policy=random, n_actions=env.action_space.n, name="random", epsilon=1.0, random_state=random_state)
evaluation_policies = [cql_, ddqn_, random_]

# %%
# first, prepare OPE inputs
prep = CreateOPEInput(
    env=env,
    logged_dataset=logged_dataset,
    model_args={
        "fqe": {
            "encoder_factory": VectorEncoderFactory(hidden_units=[30, 30]),
            "q_func_factory": MeanQFunctionFactory(),
            "learning_rate": 1e-4,
            "use_gpu": torch.cuda.is_available(),
        },
    },
    state_scaler=MinMaxScaler(
        minimum=logged_dataset["state"].min(axis=0),
        maximum=logged_dataset["state"].max(axis=0),
    ),
    sigma=0.1,
    gamma=0.95,
    device="cuda:0" if torch.cuda.is_available() else "cpu",
)

# %%
# takes time
input_dict = prep.obtain_whole_inputs(
    evaluation_policies=evaluation_policies,
    require_value_prediction=True,
    require_weight_prediction=True,
    n_trajectories_on_policy_evaluation=100,
    random_state=random_state,
)
# Out:
# [fit FQE model]:   0%|          | 0/3 [00:00<?, ?it/s]
# 2022-12-03 12:09.21 [debug    ] RoundIterator is selected.
# 2022-12-03 12:09.21 [info     ] Directory is created at d3rlpy_logs/DiscreteFQE_20221203120921
# 2022-12-03 12:09.21 [debug    ] Fitting scaler...              scaler=min_max
# 2022-12-03 12:09.21 [debug    ] Building models...
# 2022-12-03 12:09.21 [debug    ] Models have been built.
# 2022-12-03 12:09.21 [info     ] Parameters are saved to d3rlpy_logs/DiscreteFQE_20221203120921/params.json params={'action_scaler': None, 'batch_size': 100, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 0.95, 'generated_maxlen': 100000, 'learning_rate': 0.0001, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': {'type': 'min_max', 'params': {'maximum': array([6.00000000e+00, 3.00000000e+03, 9.99993399e-01, 7.00000000e+04,
#        1.00000000e+00, 2.00000000e+01, 1.04034167e+01]), 'minimum': array([0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.38960797e-04])}}, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'DiscreteFQE', 'observation_shape': (7,), 'action_size': 10}
# Epoch 1/1:   0%|          | 0/700 [00:00<?, ?it/s]
# 2022-12-03 12:09.26 [info     ] DiscreteFQE_20221203120921: epoch=1 step=700 epoch=1 metrics={'time_sample_batch': 0.0002432734625680106, 'time_algorithm_update': 0.006265948159354074, 'loss': 1.6798482384000506, 'time_step': 0.006614545754023961} step=700
# 2022-12-03 12:09.26 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteFQE_20221203120921/model_700.pt
# 2022-12-03 12:09.26 [debug    ] RoundIterator is selected.
# 2022-12-03 12:09.26 [info     ] Directory is created at d3rlpy_logs/DiscreteFQE_20221203120926
# 2022-12-03 12:09.26 [debug    ] Fitting scaler...              scaler=min_max
# 2022-12-03 12:09.26 [debug    ] Building models...
# 2022-12-03 12:09.26 [debug    ] Models have been built.
# 2022-12-03 12:09.26 [info     ] Parameters are saved to d3rlpy_logs/DiscreteFQE_20221203120926/params.json params={'action_scaler': None, 'batch_size': 100, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 0.95, 'generated_maxlen': 100000, 'learning_rate': 0.0001, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': {'type': 'min_max', 'params': {'maximum': array([6.00000000e+00, 3.00000000e+03, 9.99993399e-01, 7.00000000e+04,
#        1.00000000e+00, 2.00000000e+01, 1.04034167e+01]), 'minimum': array([0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.38960797e-04])}}, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'DiscreteFQE', 'observation_shape': (7,), 'action_size': 10}
# Epoch 1/1:   0%|          | 0/700 [00:00<?, ?it/s]
# 2022-12-03 12:09.31 [info     ] DiscreteFQE_20221203120926: epoch=1 step=700 epoch=1 metrics={'time_sample_batch': 0.00030666589736938477, 'time_algorithm_update': 0.007131538050515311, 'loss': 1.7687852048873902, 'time_step': 0.007523338454110282} step=700
# 2022-12-03 12:09.31 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteFQE_20221203120926/model_700.pt
# 2022-12-03 12:09.31 [debug    ] RoundIterator is selected.
# 2022-12-03 12:09.31 [info     ] Directory is created at d3rlpy_logs/DiscreteFQE_20221203120931
# 2022-12-03 12:09.31 [debug    ] Fitting scaler...              scaler=min_max
# 2022-12-03 12:09.31 [debug    ] Building models...
# 2022-12-03 12:09.31 [debug    ] Models have been built.
# 2022-12-03 12:09.31 [info     ] Parameters are saved to d3rlpy_logs/DiscreteFQE_20221203120931/params.json params={'action_scaler': None, 'batch_size': 100, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 0.95, 'generated_maxlen': 100000, 'learning_rate': 0.0001, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': {'type': 'min_max', 'params': {'maximum': array([6.00000000e+00, 3.00000000e+03, 9.99993399e-01, 7.00000000e+04,
#        1.00000000e+00, 2.00000000e+01, 1.04034167e+01]), 'minimum': array([0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.38960797e-04])}}, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'DiscreteFQE', 'observation_shape': (7,), 'action_size': 10}
# Epoch 1/1:   0%|          | 0/700 [00:00<?, ?it/s]
# 2022-12-03 12:09.38 [info     ] DiscreteFQE_20221203120931: epoch=1 step=700 epoch=1 metrics={'time_sample_batch': 0.00032706941877092634, 'time_algorithm_update': 0.008497515746525356, 'loss': 1.7417070238930838, 'time_step': 0.008953704152788435} step=700
# 2022-12-03 12:09.38 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteFQE_20221203120931/model_700.pt
# [fit MWL model]:   0%|          | 0/3 [00:00<?, ?it/s]
# [fitting_weight_function]:   0%|          | 0/100 [00:00<?, ?it/s]
# [fitting_weight_function]:   0%|          | 0/100 [00:00<?, ?it/s]
# [fitting_weight_function]:   0%|          | 0/100 [00:00<?, ?it/s]
# [fitting_weight_function]:   0%|          | 0/100 [00:00<?, ?it/s]
# [fitting_weight_function]:   0%|          | 0/100 [00:00<?, ?it/s]
# [fitting_weight_function]:   0%|          | 0/100 [00:00<?, ?it/s]
# [collect input data]:   0%|          | 0/3 [00:00<?, ?it/s]
# [calculate on-policy policy value]:   0%|          | 0/100 [00:00<?, ?it/s]
# [calculate on-policy policy value]:   0%|          | 0/100 [00:00<?, ?it/s]
# [calculate on-policy policy value]:   0%|          | 0/100 [00:00<?, ?it/s]

# %%
with open("logs/ope_input_dict_discrete_zoo.pkl", "wb") as f:
    pickle.dump(input_dict, f)

# %%
with open("logs/ope_input_dict_discrete_zoo.pkl", "rb") as f:
    input_dict = pickle.load(f)

# %%
basic_estimators = [DM(), TIS(), PDIS(), DR(), SNTIS(), SNPDIS(), SNDR()]
state_marginal_estimators = [SMIS(), SMDR(), SMSNIS(), SMSNDR()]
state_action_marginal_estimators = [SAMIS(), SAMDR(), SAMSNIS(), SAMSNDR()]
drl_estimators = [DRL()]
all_estimators = basic_estimators + state_marginal_estimators + state_action_marginal_estimators + drl_estimators

# %%
basic_estimators_name = ["dm", "tis", "pdis", "dr", "sntis", "snpdis", "sndr"]
state_marginal_estimators_name = ["sm_is", "sm_dr", "sm_snis", "sm_sndr"]
state_action_marginal_estimators_name = ["sam_is", "sam_dr", "sam_snis", "sam_sndr"]
drl_estimators_name = ["drl"]

# %%
ope = OPE(
    logged_dataset=logged_dataset,
    ope_estimators=all_estimators,
)

# %%
# policy value estimation by ope
policy_value_df_dict, policy_value_interval_df_dict = ope.summarize_off_policy_estimates(
    input_dict, 
    random_state=random_state,
)
# dictionary of the estimation
policy_value_df_dict
# Out:
# {'cql':            policy_value  relative_policy_value
#  on_policy     14.408129               1.000000
#  dm             3.860479               0.267938
#  tis           11.523358               0.799782
#  pdis          14.753083               1.023942
#  dr            14.938996               1.036845
#  sntis         13.104520               0.909523
#  snpdis        15.425639               1.070621
#  sndr          15.492974               1.075294
#  sm_is               NaN                    NaN
#  sm_dr               NaN                    NaN
#  sm_snis             NaN                    NaN
#  sm_sndr             NaN                    NaN
#  sam_is              NaN                    NaN
#  sam_dr              NaN                    NaN
#  sam_snis            NaN                    NaN
#  sam_sndr            NaN                    NaN
#  drl            3.860416               0.267933,
#  'ddqn':            policy_value  relative_policy_value
#  on_policy     14.252056               1.000000
#  dm             1.456458               0.102193
#  tis           15.103882               1.059769
#  pdis          15.041581               1.055397
#  dr            15.038854               1.055206
#  sntis         15.032307               1.054746
#  snpdis        14.944377               1.048577
#  sndr          14.946887               1.048753
#  sm_is               NaN                    NaN
#  sm_dr               NaN                    NaN
#  sm_snis             NaN                    NaN
#  sm_sndr             NaN                    NaN
#  sam_is              NaN                    NaN
#  sam_dr              NaN                    NaN
#  sam_snis            NaN                    NaN
#  sam_sndr            NaN                    NaN
#  drl            1.456651               0.102206,
#  'random':            policy_value  relative_policy_value
#  on_policy  1.120516e+01           1.000000e+00
#  dm         1.063308e+00           9.489446e-02
#  tis        5.679955e+00           5.069051e-01
#  pdis       1.071245e+01           9.560276e-01
#  dr         1.101819e+01           9.833131e-01
#  sntis      1.133762e+01           1.011821e+00
#  snpdis     1.212190e+01           1.081813e+00
#  sndr       1.205157e+01           1.075537e+00
#  sm_is      3.783836e-07           3.376868e-08
#  sm_dr      1.063309e+00           9.489457e-02
#  sm_snis    1.991976e-01           1.777731e-02
#  sm_sndr    8.657038e-01           7.725936e-02
#  sam_is     1.334365e-05           1.190848e-06
#  sam_dr     1.063320e+00           9.489550e-02
#  sam_snis   9.700994e+00           8.657609e-01
#  sam_sndr   9.621134e+00           8.586339e-01
#  drl        1.063426e+00           9.490501e-02}

# %%
# visualize and compare the result
ope.visualize_off_policy_estimates(
    input_dict, 
    compared_estimators=basic_estimators_name,
    random_state=random_state, 
    sharey=False,
)
# relative policy value to the behavior policy
# ope.visualize_off_policy_estimates(input_dict, random_state=random_state, is_relative=True, sharey=False)

# %%
# visualize and compare the result
ope.visualize_off_policy_estimates(
    input_dict, 
    compared_estimators=state_marginal_estimators_name,
    random_state=random_state, 
    sharey=False,
)

# %%
# visualize and compare the result
ope.visualize_off_policy_estimates(
    input_dict, 
    compared_estimators=state_action_marginal_estimators_name,
    random_state=random_state, 
    sharey=False,
)

# %%
# visualize and compare the result
ope.visualize_off_policy_estimates(
    input_dict, 
    compared_estimators=["dm", "pdis", "dr", "sm_is", "sm_dr", "sam_is", "sam_dr", "drl"],
    random_state=random_state, 
    sharey=False,
)

# %%
ope.visualize_off_policy_estimates(
    input_dict, 
    compared_estimators=["dm", "snpdis", "sndr", "sm_snis", "sm_sndr", "sam_snis", "sam_sndr"],
    random_state=random_state, 
    sharey=False,
)

# %% [markdown]
# For more advanced topics in OPE (e.g., cumulative distribution function estimation) and OPS, please refer to [examples/quickstart/rtb_synthetic_discrete_advanced.ipynb](https://github.com/negocia-inc/rtb_reinforcement_learing/blob/ope/examples/quickstart/rtb_synthetic_discrete_advanced.ipynb).
#
# For the examples in the continuous action space, please refer to [examples/quickstart/rtb_synthetic_continuous_zoo.ipynb](https://github.com/negocia-inc/rtb_reinforcement_learing/blob/ope/examples/quickstart/rtb_synthetic_continuous_zoo.ipynb).

# %% [markdown]
# ## Reference
#
# - Yuta Saito, Shunsuke Aihara, Megumi Matsutani, and Yusuke Narita. \
# "Open Bandit Dataset and Pipeline: Towards Realistic and Reproducible Off-Policy Evaluation.", 2021.
#
# - Takuma Seno and Michita Imai. \
# "d3rlpy: An Offline Deep Reinforcement Library.", 2021.
#
# - Christina J. Yuan, Yash Chandak, Stephen Giguere, Philip S. Thomas, and Scott Niekum. \
# "SOPE: Spectrum of Off-Policy Estimators.", 2021.
#
# - Nathan Kallus and Masatoshi Uehara. \
# "Double Reinforcement Learning for Efficient Off-Policy Evaluation in Markov Decision Processes.", 2020.
#
# - Masatoshi Uehara, Jiawei Huang, and Nan Jiang. \
# "Minimax Weight and Q-Function Learning for Off-Policy Evaluation.", 2020.
#
# - Mengjiao Yang, Ofir Nachum, Bo Dai, Lihong Li, and Dale Schuurmans. \
# "Off-Policy Evaluation via the Regularized Lagrangian.", 2020.
#
# - Sergey Levine, Aviral Kumar, George Tucker, and Justin Fu. \
# "Offline Reinforcement Learning: Tutorial, Review, and Perspectives on Open Problems." 2020.
#
# - Aviral Kumar, Aurick Zhou, George Tucker, and Sergey Levine. \
# "Conservative Q-Learning for Offline Reinforcement Learning.", 2020.
#
# - Nathan Kallus and Masatoshi Uehara. \
# "Intrinsically Efficient, Stable, and Bounded Off-Policy Evaluation for Reinforcement Learning.", 2019.
#
# - Hoang Le, Cameron Voloshin, and Yisong Yue. \
# "Batch Policy Learning under Constraints.", 2019.
#
# - Qiang Liu, Lihong Li, Ziyang Tang, and Dengyong Zhou. \
# "Breaking the Curse of Horizon: Infinite-Horizon Off-Policy Estimation.", 2018
#
# - Di Wu, Xiujun Chen, Xun Yang, Hao Wang, Qing Tan, Xiaoxun Zhang, Jian Xu, and Kun Gai. \
# "Budget Constrained Bidding by Model-free Reinforcement Learning in Display Advertising.", 2018.
#
# - Jun Zhao, Guang Qiu, Ziyu Guan, Wei Zhao, and Xiaofei He. \
# "Deep Reinforcement Learning for Sponsored Search Real-time Bidding.", 2018.
#
# - Josiah P. Hanna, Peter Stone, and Scott Niekum. \
# "Bootstrapping with Models: Confidence Intervals for Off-Policy Evaluation.", 2017.
#
# - Nan Jiang and Lihong Li. \
# "Doubly Robust Off-policy Value Evaluation for Reinforcement Learning.", 2016.
#
# - Philip S. Thomas and Emma Brunskill. \
# "Data-Efficient Off-Policy Policy Evaluation for Reinforcement Learning.", 2016.
#
# - Greg Brockman, Vicki Cheung, Ludwig Pettersson, Jonas Schneider, John Schulman, Jie Tang, and Wojciech Zaremba. \
# "OpenAI Gym.", 2016.
#
# - Philip S. Thomas, Georgios Theocharous, and Mohammad Ghavamzadeh. \
# "High Confidence Policy Improvement.", 2015.
#
# - Philip S. Thomas, Georgios Theocharous, and Mohammad Ghavamzadeh. \
# "High Confidence Off-Policy Evaluation.", 2015.
#
# - Adith Swaminathan and Thorsten Joachims. \
# "The Self-Normalized Estimator for Counterfactual Learning.", 2015.
#
# - Hado van Hasselt, Arthur Guez, and David Silver. \
# "Deep Reinforcement Learning with Double Q-learning.", 2015.
#
# - Miroslav Dudík, Dumitru Erhan, John Langford, and Lihong Li. \
# "Doubly Robust Policy Evaluation and Optimization.", 2014.
#
# - Alex Strehl, John Langford, Sham Kakade, and Lihong Li. \
# "Learning from Logged Implicit Exploration Data.", 2010.
#
# - Alina Beygelzimer and John Langford. \
# "The Offset Tree for Learning with Partial Labels.", 2009.
#
# - Doina Precup, Richard S. Sutton, and Satinder P. Singh. \
# "Eligibility Traces for Off-Policy Policy Evaluation.", 2000.
