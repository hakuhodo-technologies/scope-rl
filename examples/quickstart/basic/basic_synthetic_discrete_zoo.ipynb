# %% [markdown]
# # Quickstart Example of Off-Policy Evaluation with Various Estimators (Discrete)
# This notebook provides an example of conducting **Off-policy Evaluation (OPE)** with a basic synthetic dataset and various OPE estimators (e.g., model-based vs importance sampling-based, marginal importance sampling, and double reinforcement learning).
#
# This example consists of the following 3 steps:
# 1. Setup, Synthetic Data Generation, and Offline Policy Learning
# 2. Off-Policy Evaluation (OPE) with various estimators
#
# \* This library uses [d3rlpy](https://github.com/takuseno/d3rlpy)'s algorithm implementations of offline rl policies and model-based evaluation.
# \* Also, our implementations of OPE are highly inspired by [Open Bandit Pipeline](https://github.com/st-tech/zr-obp).

# %%
# delete later
# %load_ext autoreload
# %autoreload 2

# %%
# delete later
import warnings
warnings.simplefilter('ignore')

# %%
# delete later
import sys
sys.path.append('../../')
sys.path.append('../../../')

# %%
# import OFRL modules
import ofrl
from basicgym import BasicEnv
from ofrl.dataset import SyntheticDataset
from ofrl.policy import OnlineHead
from ofrl.policy import DiscreteEpsilonGreedyHead as EpsilonGreedyHead
from ofrl.policy import DiscreteSoftmaxHead as SoftmaxHead
from ofrl.ope.online import (
    calc_on_policy_policy_value,
    visualize_on_policy_policy_value,
)
from ofrl.utils import MinMaxScaler

# import d3rlpy algorithms
from d3rlpy.algos import DiscreteRandomPolicy as RandomPolicy
# from d3rlpy.preprocessing import MinMaxScaler
from ofrl.utils import MinMaxScaler

# import from other libraries
import gym
import torch
from sklearn.model_selection import train_test_split

# %%
import pickle
from glob import glob
from tqdm import tqdm

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# version
print(ofrl.__version__)
# Out:
# 0.0.0

# %%
# set random state
random_state = 12345

# %%
# log directory
from pathlib import Path
Path("logs/").mkdir(exist_ok=True)

# %% [markdown]
# ## 1. Setup, Synthetic Data Generation, and Offline Policy Learning
# To begin with, we briefly describe the basic usage of the environment.
#
# #### RL setup for Basic Synthetic
# In Basic Synthetic, the objective of the RL agent is to maximize reward.
#
# We often formulate this synthetic  problem as the following (Partially Observable) Markov Decision Process ((PO)MDP):
# - `state`: State observation, which may be noisy in POMDPs.
# - `action`:  Indicating the action to presented by the RL agent.
# - `reward`: Reward observation.
#
# For more about the environmental configuration and its customization, please refer to [examples/quickstart/basic/basic_synthetic_customize_env.ipynb](https://github.com/negocia-inc/ofrl/blob/ope/examples/quickstart/basic/asic_synthetic_customize_env.ipynb).

# %%
# standardized environment for discrete action
env = gym.make("BasicEnv-discrete-v0")

# %%
# for api compatibility to d3rlpy
from ofrl.utils import OldGymAPIWrapper
env_ = OldGymAPIWrapper(env)

# %% [markdown]
# #### Synthetic Data Generation
# Next, we collect logged data with a behavior policy $\pi_0$:
#
# $$\mathcal{D}_0 := \{ \{ s_t, a_t, s_{t+1}, r_t \}_{t=1}^T \}_{i=1}^n \sim \prod_{i=1}^n d_{s_0}(s_0) \prod_{t=1}^T \pi_0(a_t | s_t) p(s_{t+1} | s_t, a_t) p(r_t | s_t, a_t),$$
#
# where $s_t \in \mathcal{S}$ is the state observed at timestep $t$, $a_t$ is the action chosen by the behavior policy $\pi_0$, and $r_t$ is the reward.
#
# `SyntheticDataset` has the following arguments:
# - `env`: basic environment for RL defined in the previous section.
# - `max_episode_steps`: Maximum number of timesteps in an episode.
#
# For more about the data collection and visualization, please refer to [examples/quickstart/basic/basic_synthetic_data_collection.ipynb](https://github.com/negocia-inc/ofrl/blob/ope/examples/quickstart/basic/basic_synthetic_data_collection.ipynb).

# %%
# behavior policy
from d3rlpy.algos import DoubleDQN
from d3rlpy.models.encoders import VectorEncoderFactory
from d3rlpy.models.q_functions import MeanQFunctionFactory
from d3rlpy.online.buffers import ReplayBuffer
from d3rlpy.online.explorers import LinearDecayEpsilonGreedy

# model
ddqn = DoubleDQN(
    encoder_factory=VectorEncoderFactory(hidden_units=[30, 30]),
    q_func_factory=MeanQFunctionFactory(),
    target_update_interval=100,
    use_gpu=torch.cuda.is_available(),
)
# replay buffer
buffer = ReplayBuffer(
    maxlen=10000,
    env=env_,
)
# explorers
explorer = LinearDecayEpsilonGreedy(
    start_epsilon=1.0,
    end_epsilon=0.1,
    duration=1000,
)

# %%
# start training
# skip if there is a pre-trained model
ddqn.fit_online(
    env_,
    buffer,
    explorer=explorer,
    eval_env=env_,
    n_steps=100000,
    n_steps_per_epoch=1000,
    update_start_step=1000,
)
# Out:
# 2023-03-28 17:35.32 [info     ] Directory is created at d3rlpy_logs/DoubleDQN_online_20230328173532
# 2023-03-28 17:35.32 [debug    ] Building model...
# 2023-03-28 17:35.32 [debug    ] Model has been built.
# 2023-03-28 17:35.32 [info     ] Parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/params.json params={'action_scaler': None, 'batch_size': 32, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 0.99, 'generated_maxlen': 100000, 'learning_rate': 6.25e-05, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': None, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'DoubleDQN', 'observation_shape': (5,), 'action_size': 10}
#   0%|          | 0/100000 [00:00<?, ?it/s]
# 2023-03-28 17:35.33 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_1000.pt
# 2023-03-28 17:35.33 [info     ] DoubleDQN_online_20230328173532: epoch=1 step=1000 epoch=1 metrics={'time_inference': 0.00012371349334716798, 'time_environment_step': 2.6752710342407227e-05, 'time_step': 0.00015959930419921875, 'rollout_return': -0.2987598555915555, 'evaluation': -2.5508190775280934} step=1000
# 2023-03-28 17:35.33 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_2000.pt
# 2023-03-28 17:35.33 [info     ] DoubleDQN_online_20230328173532: epoch=2 step=2000 epoch=2 metrics={'time_inference': 0.00013561558723449707, 'time_environment_step': 3.353118896484375e-05, 'time_sample_batch': 3.042936325073242e-05, 'time_algorithm_update': 0.0006973865032196045, 'loss': 0.07138407574687153, 'time_step': 0.0009139432907104493, 'rollout_return': 2.3416759668619744, 'evaluation': 3.149380663072439} step=2000
# 2023-03-28 17:35.34 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_3000.pt
# 2023-03-28 17:35.34 [info     ] DoubleDQN_online_20230328173532: epoch=3 step=3000 epoch=3 metrics={'time_inference': 0.00013040447235107422, 'time_environment_step': 3.277945518493652e-05, 'time_sample_batch': 2.977132797241211e-05, 'time_algorithm_update': 0.0006360836029052734, 'loss': 0.20800853661447763, 'time_step': 0.0008453145027160644, 'rollout_return': 2.830790411714547, 'evaluation': 3.063044353729168} step=3000
# 2023-03-28 17:35.35 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_4000.pt
# 2023-03-28 17:35.35 [info     ] DoubleDQN_online_20230328173532: epoch=4 step=4000 epoch=4 metrics={'time_inference': 0.00012885856628417968, 'time_environment_step': 3.128647804260254e-05, 'time_sample_batch': 2.916383743286133e-05, 'time_algorithm_update': 0.0006241147518157959, 'loss': 0.40159699876606464, 'time_step': 0.0008290138244628906, 'rollout_return': 2.8863265073893682, 'evaluation': 3.0653681170491596} step=4000
# 2023-03-28 17:35.36 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_5000.pt
# 2023-03-28 17:35.36 [info     ] DoubleDQN_online_20230328173532: epoch=5 step=5000 epoch=5 metrics={'time_inference': 0.00013136935234069825, 'time_environment_step': 3.235316276550293e-05, 'time_sample_batch': 3.097105026245117e-05, 'time_algorithm_update': 0.0006414351463317871, 'loss': 0.5424282206594944, 'time_step': 0.0008521878719329834, 'rollout_return': 3.4833256222319187, 'evaluation': 3.6203994722364263} step=5000
# 2023-03-28 17:35.37 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_6000.pt
# 2023-03-28 17:35.37 [info     ] DoubleDQN_online_20230328173532: epoch=6 step=6000 epoch=6 metrics={'time_inference': 0.0001295042037963867, 'time_environment_step': 3.2286882400512693e-05, 'time_sample_batch': 3.0943632125854494e-05, 'time_algorithm_update': 0.0006401891708374024, 'loss': 0.8292096751332283, 'time_step': 0.0008487725257873536, 'rollout_return': 3.5687084950618106, 'evaluation': 4.4245576913028595} step=6000
# 2023-03-28 17:35.38 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_7000.pt
# 2023-03-28 17:35.38 [info     ] DoubleDQN_online_20230328173532: epoch=7 step=7000 epoch=7 metrics={'time_inference': 0.00013631033897399902, 'time_environment_step': 3.3716440200805664e-05, 'time_sample_batch': 3.2856225967407226e-05, 'time_algorithm_update': 0.0006549293994903564, 'loss': 1.175019842609763, 'time_step': 0.0008748173713684082, 'rollout_return': 5.480486173342381, 'evaluation': 7.171011167741982} step=7000
# 2023-03-28 17:35.39 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_8000.pt
# 2023-03-28 17:35.39 [info     ] DoubleDQN_online_20230328173532: epoch=8 step=8000 epoch=8 metrics={'time_inference': 0.0001317915916442871, 'time_environment_step': 3.266024589538574e-05, 'time_sample_batch': 3.248524665832519e-05, 'time_algorithm_update': 0.0006418867111206055, 'loss': 1.7210948056727648, 'time_step': 0.0008552880287170411, 'rollout_return': 6.5556958560522025, 'evaluation': 7.05943227717964} step=8000
# 2023-03-28 17:35.40 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_9000.pt
# 2023-03-28 17:35.40 [info     ] DoubleDQN_online_20230328173532: epoch=9 step=9000 epoch=9 metrics={'time_inference': 0.000143754243850708, 'time_environment_step': 3.605937957763672e-05, 'time_sample_batch': 3.535008430480957e-05, 'time_algorithm_update': 0.0007094142436981201, 'loss': 2.4110626650452613, 'time_step': 0.0009430069923400878, 'rollout_return': 6.469582313958184, 'evaluation': 7.062182755708269} step=9000
# 2023-03-28 17:35.41 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_10000.pt
# 2023-03-28 17:35.41 [info     ] DoubleDQN_online_20230328173532: epoch=10 step=10000 epoch=10 metrics={'time_inference': 0.00014023900032043458, 'time_environment_step': 3.629326820373535e-05, 'time_sample_batch': 3.428030014038086e-05, 'time_algorithm_update': 0.0007407240867614746, 'loss': 3.1053642657101155, 'time_step': 0.0009692566394805908, 'rollout_return': 6.5174700412147475, 'evaluation': 7.1491077622143155} step=10000
# 2023-03-28 17:35.42 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_11000.pt
# 2023-03-28 17:35.42 [info     ] DoubleDQN_online_20230328173532: epoch=11 step=11000 epoch=11 metrics={'time_inference': 0.0001500992774963379, 'time_environment_step': 3.827691078186035e-05, 'time_sample_batch': 3.732800483703613e-05, 'time_algorithm_update': 0.0007501850128173828, 'loss': 3.7182482561022043, 'time_step': 0.0009960083961486816, 'rollout_return': 6.433883215893441, 'evaluation': 7.210979605283834} step=11000
# 2023-03-28 17:35.43 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_12000.pt
# 2023-03-28 17:35.43 [info     ] DoubleDQN_online_20230328173532: epoch=12 step=12000 epoch=12 metrics={'time_inference': 0.00014742398262023926, 'time_environment_step': 3.714895248413086e-05, 'time_sample_batch': 3.797721862792969e-05, 'time_algorithm_update': 0.0007271549701690674, 'loss': 4.2784856643080715, 'time_step': 0.0009700217247009277, 'rollout_return': 6.543566781251989, 'evaluation': 7.013423111283862} step=12000
# 2023-03-28 17:35.44 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_13000.pt
# 2023-03-28 17:35.44 [info     ] DoubleDQN_online_20230328173532: epoch=13 step=13000 epoch=13 metrics={'time_inference': 0.0001427595615386963, 'time_environment_step': 3.5928964614868165e-05, 'time_sample_batch': 3.638005256652832e-05, 'time_algorithm_update': 0.0006815235614776611, 'loss': 4.728544688843191, 'time_step': 0.0009157273769378662, 'rollout_return': 6.441877639959983, 'evaluation': 6.965537398494634} step=13000
# 2023-03-28 17:35.45 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_14000.pt
# 2023-03-28 17:35.45 [info     ] DoubleDQN_online_20230328173532: epoch=14 step=14000 epoch=14 metrics={'time_inference': 0.0001381049156188965, 'time_environment_step': 3.436374664306641e-05, 'time_sample_batch': 3.423476219177246e-05, 'time_algorithm_update': 0.0006728277206420898, 'loss': 5.219794816583395, 'time_step': 0.0008972387313842773, 'rollout_return': 6.279545633840421, 'evaluation': 6.889382236857726} step=14000
# 2023-03-28 17:35.46 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_15000.pt
# 2023-03-28 17:35.46 [info     ] DoubleDQN_online_20230328173532: epoch=15 step=15000 epoch=15 metrics={'time_inference': 0.00013987255096435547, 'time_environment_step': 3.4987688064575194e-05, 'time_sample_batch': 3.4205436706542966e-05, 'time_algorithm_update': 0.0007423062324523926, 'loss': 5.548974691689015, 'time_step': 0.0009695320129394532, 'rollout_return': 6.763006544386371, 'evaluation': 7.206783436754579} step=15000
# 2023-03-28 17:35.46 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_16000.pt
# 2023-03-28 17:35.46 [info     ] DoubleDQN_online_20230328173532: epoch=16 step=16000 epoch=16 metrics={'time_inference': 0.00013075113296508788, 'time_environment_step': 3.222203254699707e-05, 'time_sample_batch': 3.161454200744629e-05, 'time_algorithm_update': 0.0006332705020904541, 'loss': 5.820035478413105, 'time_step': 0.0008443100452423096, 'rollout_return': 7.216645522162938, 'evaluation': 7.785391524527968} step=16000
# 2023-03-28 17:35.47 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_17000.pt
# 2023-03-28 17:35.47 [info     ] DoubleDQN_online_20230328173532: epoch=17 step=17000 epoch=17 metrics={'time_inference': 0.0001277616024017334, 'time_environment_step': 3.104329109191895e-05, 'time_sample_batch': 3.075385093688965e-05, 'time_algorithm_update': 0.0006182012557983398, 'loss': 6.032901748623699, 'time_step': 0.0008237679004669189, 'rollout_return': 7.401005250038028, 'evaluation': 4.701222544794386} step=17000
# 2023-03-28 17:35.48 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_18000.pt
# 2023-03-28 17:35.48 [info     ] DoubleDQN_online_20230328173532: epoch=18 step=18000 epoch=18 metrics={'time_inference': 0.0001273972988128662, 'time_environment_step': 3.113007545471191e-05, 'time_sample_batch': 3.08535099029541e-05, 'time_algorithm_update': 0.0006205587387084961, 'loss': 6.312567441821098, 'time_step': 0.0008259601593017578, 'rollout_return': 7.156105284373509, 'evaluation': 8.755909026266647} step=18000
# 2023-03-28 17:35.49 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_19000.pt
# 2023-03-28 17:35.49 [info     ] DoubleDQN_online_20230328173532: epoch=19 step=19000 epoch=19 metrics={'time_inference': 0.00013170361518859863, 'time_environment_step': 3.2888412475585935e-05, 'time_sample_batch': 3.305387496948242e-05, 'time_algorithm_update': 0.0006518287658691406, 'loss': 6.716749626398086, 'time_step': 0.0008664624691009521, 'rollout_return': 8.018247918258773, 'evaluation': 9.039239135515526} step=19000
# 2023-03-28 17:35.50 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_20000.pt
# 2023-03-28 17:35.50 [info     ] DoubleDQN_online_20230328173532: epoch=20 step=20000 epoch=20 metrics={'time_inference': 0.00013515186309814454, 'time_environment_step': 3.4687042236328125e-05, 'time_sample_batch': 3.418564796447754e-05, 'time_algorithm_update': 0.0006677780151367188, 'loss': 7.175595072533936, 'time_step': 0.0008898417949676513, 'rollout_return': 8.035999298838329, 'evaluation': 9.151781236414099} step=20000
# 2023-03-28 17:35.51 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_21000.pt
# 2023-03-28 17:35.51 [info     ] DoubleDQN_online_20230328173532: epoch=21 step=21000 epoch=21 metrics={'time_inference': 0.0001344316005706787, 'time_environment_step': 3.343963623046875e-05, 'time_sample_batch': 3.374648094177246e-05, 'time_algorithm_update': 0.0006532704830169677, 'loss': 7.652836294293404, 'time_step': 0.0008726437091827392, 'rollout_return': 7.799529777927693, 'evaluation': 9.335253212627249} step=21000
# 2023-03-28 17:35.52 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_22000.pt
# 2023-03-28 17:35.52 [info     ] DoubleDQN_online_20230328173532: epoch=22 step=22000 epoch=22 metrics={'time_inference': 0.00013709640502929688, 'time_environment_step': 3.416633605957031e-05, 'time_sample_batch': 3.4176111221313476e-05, 'time_algorithm_update': 0.0006693663597106933, 'loss': 7.877124297380448, 'time_step': 0.0008926630020141601, 'rollout_return': 7.477384602891117, 'evaluation': 7.594230167975065} step=22000
# 2023-03-28 17:35.53 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_23000.pt
# 2023-03-28 17:35.53 [info     ] DoubleDQN_online_20230328173532: epoch=23 step=23000 epoch=23 metrics={'time_inference': 0.00013108015060424804, 'time_environment_step': 3.304123878479004e-05, 'time_sample_batch': 3.3068656921386716e-05, 'time_algorithm_update': 0.0006512563228607178, 'loss': 8.10859125994146, 'time_step': 0.0008656914234161377, 'rollout_return': 7.482841735539143, 'evaluation': 8.386910624358478} step=23000
# 2023-03-28 17:35.54 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_24000.pt
# 2023-03-28 17:35.54 [info     ] DoubleDQN_online_20230328173532: epoch=24 step=24000 epoch=24 metrics={'time_inference': 0.00012804174423217775, 'time_environment_step': 3.132462501525879e-05, 'time_sample_batch': 3.116106986999512e-05, 'time_algorithm_update': 0.0006201729774475098, 'loss': 8.105084946274758, 'time_step': 0.0008269085884094238, 'rollout_return': 7.2309057940215755, 'evaluation': 7.771761599627149} step=24000
# 2023-03-28 17:35.54 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_25000.pt
# 2023-03-28 17:35.54 [info     ] DoubleDQN_online_20230328173532: epoch=25 step=25000 epoch=25 metrics={'time_inference': 0.00012825679779052734, 'time_environment_step': 3.1543731689453125e-05, 'time_sample_batch': 3.121781349182129e-05, 'time_algorithm_update': 0.0006387529373168945, 'loss': 8.599782010726631, 'time_step': 0.0008460752964019776, 'rollout_return': 7.311793093870157, 'evaluation': 7.603609526657131} step=25000
# 2023-03-28 17:35.55 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_26000.pt
# 2023-03-28 17:35.55 [info     ] DoubleDQN_online_20230328173532: epoch=26 step=26000 epoch=26 metrics={'time_inference': 0.00012906599044799804, 'time_environment_step': 3.1674623489379885e-05, 'time_sample_batch': 3.153300285339355e-05, 'time_algorithm_update': 0.0006474266052246094, 'loss': 8.654772369876504, 'time_step': 0.0008562560081481934, 'rollout_return': 7.146473867256431, 'evaluation': 7.6917691532484325} step=26000
# 2023-03-28 17:35.56 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_27000.pt
# 2023-03-28 17:35.56 [info     ] DoubleDQN_online_20230328173532: epoch=27 step=27000 epoch=27 metrics={'time_inference': 0.00013463902473449707, 'time_environment_step': 3.3899545669555665e-05, 'time_sample_batch': 3.355789184570313e-05, 'time_algorithm_update': 0.0006797263622283935, 'loss': 8.849207523971796, 'time_step': 0.0008995037078857422, 'rollout_return': 7.107575755980375, 'evaluation': 8.009980493005243} step=27000
# 2023-03-28 17:35.57 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_28000.pt
# 2023-03-28 17:35.57 [info     ] DoubleDQN_online_20230328173532: epoch=28 step=28000 epoch=28 metrics={'time_inference': 0.00014236116409301758, 'time_environment_step': 3.613018989562988e-05, 'time_sample_batch': 3.5062074661254884e-05, 'time_algorithm_update': 0.0007364284992218017, 'loss': 8.810188942432404, 'time_step': 0.0009686288833618164, 'rollout_return': 7.173888106482836, 'evaluation': 7.355403879158568} step=28000
# 2023-03-28 17:35.58 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_29000.pt
# 2023-03-28 17:35.58 [info     ] DoubleDQN_online_20230328173532: epoch=29 step=29000 epoch=29 metrics={'time_inference': 0.00014076662063598633, 'time_environment_step': 3.545665740966797e-05, 'time_sample_batch': 3.4214973449707034e-05, 'time_algorithm_update': 0.0006796870231628418, 'loss': 9.119747987195849, 'time_step': 0.0009084000587463379, 'rollout_return': 7.071727565097527, 'evaluation': 8.386863578608692} step=29000
# 2023-03-28 17:35.59 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_30000.pt
# 2023-03-28 17:35.59 [info     ] DoubleDQN_online_20230328173532: epoch=30 step=30000 epoch=30 metrics={'time_inference': 0.0001352260112762451, 'time_environment_step': 3.408885002136231e-05, 'time_sample_batch': 3.3153295516967775e-05, 'time_algorithm_update': 0.0007216496467590333, 'loss': 9.239858304828406, 'time_step': 0.0009417636394500733, 'rollout_return': 7.360096931022766, 'evaluation': 7.99719985607607} step=30000
# 2023-03-28 17:36.00 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_31000.pt
# 2023-03-28 17:36.00 [info     ] DoubleDQN_online_20230328173532: epoch=31 step=31000 epoch=31 metrics={'time_inference': 0.0001325383186340332, 'time_environment_step': 3.278827667236328e-05, 'time_sample_batch': 3.3114194869995115e-05, 'time_algorithm_update': 0.0006414799690246582, 'loss': 9.253777698859572, 'time_step': 0.0008570926189422608, 'rollout_return': 7.227108450310429, 'evaluation': 7.955158921402793} step=31000
# 2023-03-28 17:36.01 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_32000.pt
# 2023-03-28 17:36.01 [info     ] DoubleDQN_online_20230328173532: epoch=32 step=32000 epoch=32 metrics={'time_inference': 0.0001317291259765625, 'time_environment_step': 3.204751014709473e-05, 'time_sample_batch': 3.179192543029785e-05, 'time_algorithm_update': 0.0006288449764251709, 'loss': 9.172223427206278, 'time_step': 0.0008410794734954834, 'rollout_return': 7.5217008844725886, 'evaluation': 8.151741062532174} step=32000
# 2023-03-28 17:36.02 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_33000.pt
# 2023-03-28 17:36.02 [info     ] DoubleDQN_online_20230328173532: epoch=33 step=33000 epoch=33 metrics={'time_inference': 0.00013096833229064942, 'time_environment_step': 3.2176017761230466e-05, 'time_sample_batch': 3.178834915161133e-05, 'time_algorithm_update': 0.0006288907527923584, 'loss': 9.451137878339738, 'time_step': 0.0008404617309570313, 'rollout_return': 7.5528291768546, 'evaluation': 8.353608577770123} step=33000
# 2023-03-28 17:36.03 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_34000.pt
# 2023-03-28 17:36.03 [info     ] DoubleDQN_online_20230328173532: epoch=34 step=34000 epoch=34 metrics={'time_inference': 0.00013176918029785155, 'time_environment_step': 3.240299224853515e-05, 'time_sample_batch': 3.2549381256103514e-05, 'time_algorithm_update': 0.0006370205879211426, 'loss': 9.405603723168372, 'time_step': 0.0008506765365600586, 'rollout_return': 7.631597011635994, 'evaluation': 7.762382976308382} step=34000
# 2023-03-28 17:36.03 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_35000.pt
# 2023-03-28 17:36.03 [info     ] DoubleDQN_online_20230328173532: epoch=35 step=35000 epoch=35 metrics={'time_inference': 0.00013137269020080568, 'time_environment_step': 3.255462646484375e-05, 'time_sample_batch': 3.271174430847168e-05, 'time_algorithm_update': 0.0006474366188049316, 'loss': 9.505924876451493, 'time_step': 0.0008610408306121826, 'rollout_return': 7.525955447258585, 'evaluation': 7.954595307134419} step=35000
# 2023-03-28 17:36.04 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_36000.pt
# 2023-03-28 17:36.04 [info     ] DoubleDQN_online_20230328173532: epoch=36 step=36000 epoch=36 metrics={'time_inference': 0.0001368420124053955, 'time_environment_step': 3.396749496459961e-05, 'time_sample_batch': 3.3948659896850584e-05, 'time_algorithm_update': 0.0006914734840393066, 'loss': 9.73541541531682, 'time_step': 0.0009139432907104493, 'rollout_return': 7.302514002878008, 'evaluation': 7.985457204713354} step=36000
# 2023-03-28 17:36.05 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_37000.pt
# 2023-03-28 17:36.05 [info     ] DoubleDQN_online_20230328173532: epoch=37 step=37000 epoch=37 metrics={'time_inference': 0.00014268016815185546, 'time_environment_step': 3.4998655319213864e-05, 'time_sample_batch': 3.453373908996582e-05, 'time_algorithm_update': 0.0007107725143432617, 'loss': 9.687089905008675, 'time_step': 0.0009413337707519531, 'rollout_return': 7.621043843450742, 'evaluation': 7.880001528532766} step=37000
# 2023-03-28 17:36.06 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_38000.pt
# 2023-03-28 17:36.06 [info     ] DoubleDQN_online_20230328173532: epoch=38 step=38000 epoch=38 metrics={'time_inference': 0.00012967824935913085, 'time_environment_step': 3.1793594360351563e-05, 'time_sample_batch': 3.234529495239258e-05, 'time_algorithm_update': 0.0006277189254760742, 'loss': 9.718906254887582, 'time_step': 0.0008381841182708741, 'rollout_return': 7.723289011437072, 'evaluation': 7.899413534068114} step=38000
# 2023-03-28 17:36.07 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_39000.pt
# 2023-03-28 17:36.07 [info     ] DoubleDQN_online_20230328173532: epoch=39 step=39000 epoch=39 metrics={'time_inference': 0.00013184356689453124, 'time_environment_step': 3.353166580200195e-05, 'time_sample_batch': 3.32033634185791e-05, 'time_algorithm_update': 0.0006419060230255127, 'loss': 9.813900840759278, 'time_step': 0.000857816219329834, 'rollout_return': 7.703818502156476, 'evaluation': 7.734895462851457} step=39000
# 2023-03-28 17:36.08 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_40000.pt
# 2023-03-28 17:36.08 [info     ] DoubleDQN_online_20230328173532: epoch=40 step=40000 epoch=40 metrics={'time_inference': 0.0001335911750793457, 'time_environment_step': 3.3682823181152346e-05, 'time_sample_batch': 3.2626867294311525e-05, 'time_algorithm_update': 0.0006758112907409668, 'loss': 9.723366773843765, 'time_step': 0.0008928406238555908, 'rollout_return': 7.473475234975532, 'evaluation': 7.800774485079122} step=40000
# 2023-03-28 17:36.09 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_41000.pt
# 2023-03-28 17:36.09 [info     ] DoubleDQN_online_20230328173532: epoch=41 step=41000 epoch=41 metrics={'time_inference': 0.00013422250747680665, 'time_environment_step': 3.326773643493652e-05, 'time_sample_batch': 3.278756141662597e-05, 'time_algorithm_update': 0.0006835036277770996, 'loss': 9.62287092256546, 'time_step': 0.0009012465476989746, 'rollout_return': 7.437727420813479, 'evaluation': 7.726797046923769} step=41000
# 2023-03-28 17:36.10 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_42000.pt
# 2023-03-28 17:36.10 [info     ] DoubleDQN_online_20230328173532: epoch=42 step=42000 epoch=42 metrics={'time_inference': 0.00013479351997375488, 'time_environment_step': 3.3487796783447265e-05, 'time_sample_batch': 3.273797035217285e-05, 'time_algorithm_update': 0.000676222562789917, 'loss': 9.797545144446195, 'time_step': 0.0008946108818054199, 'rollout_return': 7.360159248892162, 'evaluation': 8.524374496603567} step=42000
# 2023-03-28 17:36.11 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_43000.pt
# 2023-03-28 17:36.11 [info     ] DoubleDQN_online_20230328173532: epoch=43 step=43000 epoch=43 metrics={'time_inference': 0.00012970805168151855, 'time_environment_step': 3.1861305236816405e-05, 'time_sample_batch': 3.184032440185547e-05, 'time_algorithm_update': 0.0006423332691192627, 'loss': 10.041710358519108, 'time_step': 0.0008523499965667724, 'rollout_return': 7.253347770303412, 'evaluation': 7.190213003165094} step=43000
# 2023-03-28 17:36.12 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_44000.pt
# 2023-03-28 17:36.12 [info     ] DoubleDQN_online_20230328173532: epoch=44 step=44000 epoch=44 metrics={'time_inference': 0.00013366746902465822, 'time_environment_step': 3.283143043518067e-05, 'time_sample_batch': 3.265953063964844e-05, 'time_algorithm_update': 0.0006481266021728516, 'loss': 9.802273876409977, 'time_step': 0.0008642377853393555, 'rollout_return': 7.428503386778119, 'evaluation': 7.777263078841858} step=44000
# 2023-03-28 17:36.13 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_45000.pt
# 2023-03-28 17:36.13 [info     ] DoubleDQN_online_20230328173532: epoch=45 step=45000 epoch=45 metrics={'time_inference': 0.00013445496559143068, 'time_environment_step': 3.326821327209473e-05, 'time_sample_batch': 3.3638477325439454e-05, 'time_algorithm_update': 0.0006764674186706543, 'loss': 9.789131244763732, 'time_step': 0.0008951339721679687, 'rollout_return': 7.308826050002547, 'evaluation': 7.5734219333016854} step=45000
# 2023-03-28 17:36.13 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_46000.pt
# 2023-03-28 17:36.13 [info     ] DoubleDQN_online_20230328173532: epoch=46 step=46000 epoch=46 metrics={'time_inference': 0.0001351785659790039, 'time_environment_step': 3.353166580200195e-05, 'time_sample_batch': 3.3773183822631836e-05, 'time_algorithm_update': 0.0006517324447631836, 'loss': 9.78606808412075, 'time_step': 0.0008718762397766114, 'rollout_return': 7.346385356104969, 'evaluation': 8.409410630392536} step=46000
# 2023-03-28 17:36.14 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_47000.pt
# 2023-03-28 17:36.14 [info     ] DoubleDQN_online_20230328173532: epoch=47 step=47000 epoch=47 metrics={'time_inference': 0.00013771796226501464, 'time_environment_step': 3.55682373046875e-05, 'time_sample_batch': 3.4973859786987305e-05, 'time_algorithm_update': 0.0006810851097106933, 'loss': 9.876600236058236, 'time_step': 0.0009080901145935059, 'rollout_return': 7.513508149036218, 'evaluation': 7.014730779931128} step=47000
# 2023-03-28 17:36.15 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_48000.pt
# 2023-03-28 17:36.15 [info     ] DoubleDQN_online_20230328173532: epoch=48 step=48000 epoch=48 metrics={'time_inference': 0.00015001583099365234, 'time_environment_step': 3.893375396728516e-05, 'time_sample_batch': 3.7805557250976565e-05, 'time_algorithm_update': 0.0007251074314117431, 'loss': 10.021321289539337, 'time_step': 0.0009733285903930664, 'rollout_return': 7.258532603921959, 'evaluation': 7.784662678514678} step=48000
# 2023-03-28 17:36.17 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_49000.pt
# 2023-03-28 17:36.17 [info     ] DoubleDQN_online_20230328173532: epoch=49 step=49000 epoch=49 metrics={'time_inference': 0.00018665075302124024, 'time_environment_step': 4.741501808166504e-05, 'time_sample_batch': 4.593372344970703e-05, 'time_algorithm_update': 0.0009818344116210938, 'loss': 9.924589955925942, 'time_step': 0.0012867989540100097, 'rollout_return': 7.403707093434642, 'evaluation': 9.198249182301037} step=49000
# 2023-03-28 17:36.18 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_50000.pt
# 2023-03-28 17:36.18 [info     ] DoubleDQN_online_20230328173532: epoch=50 step=50000 epoch=50 metrics={'time_inference': 0.0001886742115020752, 'time_environment_step': 4.371452331542969e-05, 'time_sample_batch': 3.967905044555664e-05, 'time_algorithm_update': 0.0008194842338562012, 'loss': 9.742496835939587, 'time_step': 0.0011173574924468995, 'rollout_return': 7.150775946715899, 'evaluation': 8.018521761226836} step=50000
# 2023-03-28 17:36.19 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_51000.pt
# 2023-03-28 17:36.19 [info     ] DoubleDQN_online_20230328173532: epoch=51 step=51000 epoch=51 metrics={'time_inference': 0.00013801383972167968, 'time_environment_step': 3.3948659896850584e-05, 'time_sample_batch': 3.37221622467041e-05, 'time_algorithm_update': 0.000667036771774292, 'loss': 9.710577919483185, 'time_step': 0.0008909268379211426, 'rollout_return': 7.535364790037394, 'evaluation': 8.25759159627864} step=51000
# 2023-03-28 17:36.20 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_52000.pt
# 2023-03-28 17:36.20 [info     ] DoubleDQN_online_20230328173532: epoch=52 step=52000 epoch=52 metrics={'time_inference': 0.00014355134963989257, 'time_environment_step': 3.618955612182617e-05, 'time_sample_batch': 3.5880327224731444e-05, 'time_algorithm_update': 0.0006944572925567627, 'loss': 9.85957141172886, 'time_step': 0.0009289143085479736, 'rollout_return': 7.308250549472563, 'evaluation': 7.722889751878178} step=52000
# 2023-03-28 17:36.21 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_53000.pt
# 2023-03-28 17:36.21 [info     ] DoubleDQN_online_20230328173532: epoch=53 step=53000 epoch=53 metrics={'time_inference': 0.00014254593849182128, 'time_environment_step': 3.645515441894531e-05, 'time_sample_batch': 3.5242795944213864e-05, 'time_algorithm_update': 0.0006964273452758789, 'loss': 9.877380548693239, 'time_step': 0.0009297752380371094, 'rollout_return': 7.3768017551891205, 'evaluation': 7.790121715392911} step=53000
# 2023-03-28 17:36.22 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_54000.pt
# 2023-03-28 17:36.22 [info     ] DoubleDQN_online_20230328173532: epoch=54 step=54000 epoch=54 metrics={'time_inference': 0.00013809037208557129, 'time_environment_step': 3.5794973373413084e-05, 'time_sample_batch': 3.477787971496582e-05, 'time_algorithm_update': 0.0006725482940673828, 'loss': 9.91881223000586, 'time_step': 0.0009001128673553467, 'rollout_return': 7.436918763405035, 'evaluation': 8.923723608192907} step=54000
# 2023-03-28 17:36.23 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_55000.pt
# 2023-03-28 17:36.23 [info     ] DoubleDQN_online_20230328173532: epoch=55 step=55000 epoch=55 metrics={'time_inference': 0.00014437627792358398, 'time_environment_step': 3.746652603149414e-05, 'time_sample_batch': 3.6275863647460934e-05, 'time_algorithm_update': 0.0007391157150268555, 'loss': 9.812783033810556, 'time_step': 0.0009764585494995117, 'rollout_return': 7.550441908767726, 'evaluation': 5.364685630999821} step=55000
# 2023-03-28 17:36.24 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_56000.pt
# 2023-03-28 17:36.24 [info     ] DoubleDQN_online_20230328173532: epoch=56 step=56000 epoch=56 metrics={'time_inference': 0.00014535093307495116, 'time_environment_step': 3.593087196350098e-05, 'time_sample_batch': 4.048085212707519e-05, 'time_algorithm_update': 0.0008063278198242187, 'loss': 9.934533174250275, 'time_step': 0.0010483765602111816, 'rollout_return': 7.569182745657932, 'evaluation': 7.674385918975763} step=56000
# 2023-03-28 17:36.25 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_57000.pt
# 2023-03-28 17:36.25 [info     ] DoubleDQN_online_20230328173532: epoch=57 step=57000 epoch=57 metrics={'time_inference': 0.0001322059631347656, 'time_environment_step': 3.3037185668945315e-05, 'time_sample_batch': 3.293466567993164e-05, 'time_algorithm_update': 0.0006390023231506348, 'loss': 9.903966042686253, 'time_step': 0.0008544120788574219, 'rollout_return': 7.380062108708836, 'evaluation': 7.887066710868956} step=57000
# 2023-03-28 17:36.25 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_58000.pt
# 2023-03-28 17:36.25 [info     ] DoubleDQN_online_20230328173532: epoch=58 step=58000 epoch=58 metrics={'time_inference': 0.00012961554527282716, 'time_environment_step': 3.1753063201904294e-05, 'time_sample_batch': 3.2259225845336916e-05, 'time_algorithm_update': 0.0006401433944702149, 'loss': 9.794674677658826, 'time_step': 0.0008502023220062256, 'rollout_return': 7.854931115877683, 'evaluation': 8.277988059537208} step=58000
# 2023-03-28 17:36.26 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_59000.pt
# 2023-03-28 17:36.26 [info     ] DoubleDQN_online_20230328173532: epoch=59 step=59000 epoch=59 metrics={'time_inference': 0.00013635063171386718, 'time_environment_step': 3.480720520019531e-05, 'time_sample_batch': 3.5001039505004884e-05, 'time_algorithm_update': 0.0007162461280822754, 'loss': 9.868178143262863, 'time_step': 0.0009406952857971191, 'rollout_return': 7.684382865779378, 'evaluation': 7.871739588908251} step=59000
# 2023-03-28 17:36.27 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_60000.pt
# 2023-03-28 17:36.27 [info     ] DoubleDQN_online_20230328173532: epoch=60 step=60000 epoch=60 metrics={'time_inference': 0.00013535237312316893, 'time_environment_step': 3.412222862243652e-05, 'time_sample_batch': 3.4109115600585936e-05, 'time_algorithm_update': 0.0006826860904693604, 'loss': 9.888078753504901, 'time_step': 0.0009038419723510742, 'rollout_return': 7.6350740323028985, 'evaluation': 8.352867221754924} step=60000
# 2023-03-28 17:36.28 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_61000.pt
# 2023-03-28 17:36.28 [info     ] DoubleDQN_online_20230328173532: epoch=61 step=61000 epoch=61 metrics={'time_inference': 0.0001412489414215088, 'time_environment_step': 3.539323806762695e-05, 'time_sample_batch': 3.482627868652344e-05, 'time_algorithm_update': 0.0007374985218048096, 'loss': 9.853638346672058, 'time_step': 0.0009673752784729004, 'rollout_return': 7.588091315089473, 'evaluation': 8.355064553189631} step=61000
# 2023-03-28 17:36.29 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_62000.pt
# 2023-03-28 17:36.29 [info     ] DoubleDQN_online_20230328173532: epoch=62 step=62000 epoch=62 metrics={'time_inference': 0.0001430196762084961, 'time_environment_step': 3.730511665344238e-05, 'time_sample_batch': 3.552079200744629e-05, 'time_algorithm_update': 0.0007343573570251465, 'loss': 9.861969243764877, 'time_step': 0.0009695568084716797, 'rollout_return': 7.718895761389047, 'evaluation': 9.302022876019425} step=62000
# 2023-03-28 17:36.30 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_63000.pt
# 2023-03-28 17:36.30 [info     ] DoubleDQN_online_20230328173532: epoch=63 step=63000 epoch=63 metrics={'time_inference': 0.00016002750396728514, 'time_environment_step': 3.9640665054321286e-05, 'time_sample_batch': 3.783321380615234e-05, 'time_algorithm_update': 0.0007628586292266846, 'loss': 9.857969551801682, 'time_step': 0.0010210652351379395, 'rollout_return': 7.833615415880039, 'evaluation': 9.323625600312903} step=63000
# 2023-03-28 17:36.31 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_64000.pt
# 2023-03-28 17:36.32 [info     ] DoubleDQN_online_20230328173532: epoch=64 step=64000 epoch=64 metrics={'time_inference': 0.00016352009773254393, 'time_environment_step': 4.137134552001953e-05, 'time_sample_batch': 3.9716482162475586e-05, 'time_algorithm_update': 0.0007620911598205566, 'loss': 10.051805201437324, 'time_step': 0.0010283925533294677, 'rollout_return': 7.8795546084353285, 'evaluation': 7.630159586956784} step=64000
# 2023-03-28 17:36.33 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_65000.pt
# 2023-03-28 17:36.33 [info     ] DoubleDQN_online_20230328173532: epoch=65 step=65000 epoch=65 metrics={'time_inference': 0.0001729617118835449, 'time_environment_step': 4.29999828338623e-05, 'time_sample_batch': 4.111528396606445e-05, 'time_algorithm_update': 0.0007962696552276611, 'loss': 9.898705664731562, 'time_step': 0.0010752835273742675, 'rollout_return': 7.614566557770974, 'evaluation': 8.104917336355314} step=65000
# 2023-03-28 17:36.34 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_66000.pt
# 2023-03-28 17:36.34 [info     ] DoubleDQN_online_20230328173532: epoch=66 step=66000 epoch=66 metrics={'time_inference': 0.00016994333267211914, 'time_environment_step': 4.289913177490234e-05, 'time_sample_batch': 4.055500030517578e-05, 'time_algorithm_update': 0.0007761063575744629, 'loss': 10.052385017879308, 'time_step': 0.001051880121231079, 'rollout_return': 7.414223397494052, 'evaluation': 7.161204056440171} step=66000
# 2023-03-28 17:36.35 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_67000.pt
# 2023-03-28 17:36.35 [info     ] DoubleDQN_online_20230328173532: epoch=67 step=67000 epoch=67 metrics={'time_inference': 0.0001937549114227295, 'time_environment_step': 5.1634073257446286e-05, 'time_sample_batch': 4.488801956176758e-05, 'time_algorithm_update': 0.0009277606010437012, 'loss': 9.886519093155862, 'time_step': 0.0012443473339080811, 'rollout_return': 7.541206268904538, 'evaluation': 8.891965672841355} step=67000
# 2023-03-28 17:36.36 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_68000.pt
# 2023-03-28 17:36.36 [info     ] DoubleDQN_online_20230328173532: epoch=68 step=68000 epoch=68 metrics={'time_inference': 0.00020284891128540038, 'time_environment_step': 4.887509346008301e-05, 'time_sample_batch': 4.5856714248657224e-05, 'time_algorithm_update': 0.0009336760044097901, 'loss': 9.921210208281874, 'time_step': 0.0012566897869110108, 'rollout_return': 7.688631076748973, 'evaluation': 9.198654951615} step=68000
# 2023-03-28 17:36.38 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_69000.pt
# 2023-03-28 17:36.38 [info     ] DoubleDQN_online_20230328173532: epoch=69 step=69000 epoch=69 metrics={'time_inference': 0.0002123889923095703, 'time_environment_step': 5.3004741668701175e-05, 'time_sample_batch': 4.90717887878418e-05, 'time_algorithm_update': 0.0009602432250976563, 'loss': 9.90635790489614, 'time_step': 0.0013030786514282226, 'rollout_return': 7.631211066016294, 'evaluation': 8.049812613602318} step=69000
# 2023-03-28 17:36.39 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_70000.pt
# 2023-03-28 17:36.39 [info     ] DoubleDQN_online_20230328173532: epoch=70 step=70000 epoch=70 metrics={'time_inference': 0.00021686148643493652, 'time_environment_step': 5.475497245788574e-05, 'time_sample_batch': 4.9052476882934574e-05, 'time_algorithm_update': 0.0009795715808868408, 'loss': 9.90624261051789, 'time_step': 0.0013285479545593261, 'rollout_return': 7.341571005415749, 'evaluation': 7.83926148379804} step=70000
# 2023-03-28 17:36.41 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_71000.pt
# 2023-03-28 17:36.41 [info     ] DoubleDQN_online_20230328173532: epoch=71 step=71000 epoch=71 metrics={'time_inference': 0.00023504924774169923, 'time_environment_step': 6.053948402404785e-05, 'time_sample_batch': 5.360007286071777e-05, 'time_algorithm_update': 0.0011224913597106933, 'loss': 9.87135446858406, 'time_step': 0.001503941774368286, 'rollout_return': 7.4577749108718185, 'evaluation': 8.61355844991598} step=71000
# 2023-03-28 17:36.42 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_72000.pt
# 2023-03-28 17:36.42 [info     ] DoubleDQN_online_20230328173532: epoch=72 step=72000 epoch=72 metrics={'time_inference': 0.00023920607566833496, 'time_environment_step': 6.0828208923339845e-05, 'time_sample_batch': 5.460476875305176e-05, 'time_algorithm_update': 0.0010761866569519044, 'loss': 9.985909253120422, 'time_step': 0.0014628562927246093, 'rollout_return': 7.505961245064586, 'evaluation': 7.987506213631181} step=72000
# 2023-03-28 17:36.45 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_73000.pt
# 2023-03-28 17:36.45 [info     ] DoubleDQN_online_20230328173532: epoch=73 step=73000 epoch=73 metrics={'time_inference': 0.00032770895957946777, 'time_environment_step': 8.117818832397461e-05, 'time_sample_batch': 6.910133361816406e-05, 'time_algorithm_update': 0.001841266393661499, 'loss': 9.944639417141676, 'time_step': 0.002365617275238037, 'rollout_return': 7.464384296049209, 'evaluation': 8.527627529046653} step=73000
# 2023-03-28 17:36.46 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_74000.pt
# 2023-03-28 17:36.46 [info     ] DoubleDQN_online_20230328173532: epoch=74 step=74000 epoch=74 metrics={'time_inference': 0.00026709961891174317, 'time_environment_step': 6.652164459228516e-05, 'time_sample_batch': 5.8628082275390624e-05, 'time_algorithm_update': 0.0011179394721984863, 'loss': 10.02220135974884, 'time_step': 0.0015446360111236572, 'rollout_return': 7.5461932983575215, 'evaluation': 7.964790469345365} step=74000
# 2023-03-28 17:36.48 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_75000.pt
# 2023-03-28 17:36.48 [info     ] DoubleDQN_online_20230328173532: epoch=75 step=75000 epoch=75 metrics={'time_inference': 0.00026849722862243655, 'time_environment_step': 6.661057472229004e-05, 'time_sample_batch': 5.783224105834961e-05, 'time_algorithm_update': 0.0011626861095428466, 'loss': 10.095172991633415, 'time_step': 0.001590106964111328, 'rollout_return': 7.626546008106458, 'evaluation': 8.270756002395002} step=75000
# 2023-03-28 17:36.50 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_76000.pt
# 2023-03-28 17:36.50 [info     ] DoubleDQN_online_20230328173532: epoch=76 step=76000 epoch=76 metrics={'time_inference': 0.00029578375816345214, 'time_environment_step': 7.698774337768555e-05, 'time_sample_batch': 6.354594230651856e-05, 'time_algorithm_update': 0.0012452752590179444, 'loss': 9.921944863200189, 'time_step': 0.0017206313610076903, 'rollout_return': 7.78936076800124, 'evaluation': 7.363045006154503} step=76000
# 2023-03-28 17:36.51 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_77000.pt
# 2023-03-28 17:36.51 [info     ] DoubleDQN_online_20230328173532: epoch=77 step=77000 epoch=77 metrics={'time_inference': 0.00028736400604248045, 'time_environment_step': 7.43880271911621e-05, 'time_sample_batch': 6.393146514892579e-05, 'time_algorithm_update': 0.0012212281227111817, 'loss': 9.780392560265959, 'time_step': 0.0016851363182067871, 'rollout_return': 7.461711298676815, 'evaluation': 8.603069793598028} step=77000
# 2023-03-28 17:36.53 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_78000.pt
# 2023-03-28 17:36.53 [info     ] DoubleDQN_online_20230328173532: epoch=78 step=78000 epoch=78 metrics={'time_inference': 0.0002756617069244385, 'time_environment_step': 7.130813598632813e-05, 'time_sample_batch': 6.025958061218262e-05, 'time_algorithm_update': 0.0011906688213348389, 'loss': 10.031500247478485, 'time_step': 0.0016335604190826417, 'rollout_return': 7.651744638539348, 'evaluation': 8.655740502914126} step=78000
# 2023-03-28 17:36.55 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_79000.pt
# 2023-03-28 17:36.55 [info     ] DoubleDQN_online_20230328173532: epoch=79 step=79000 epoch=79 metrics={'time_inference': 0.0003079812526702881, 'time_environment_step': 8.20767879486084e-05, 'time_sample_batch': 6.77788257598877e-05, 'time_algorithm_update': 0.0013867073059082031, 'loss': 9.832767447814346, 'time_step': 0.0018855738639831543, 'rollout_return': 7.813418207812979, 'evaluation': 8.536014621328258} step=79000
# 2023-03-28 17:36.57 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_80000.pt
# 2023-03-28 17:36.57 [info     ] DoubleDQN_online_20230328173532: epoch=80 step=80000 epoch=80 metrics={'time_inference': 0.00030177855491638183, 'time_environment_step': 7.621169090270995e-05, 'time_sample_batch': 6.593513488769532e-05, 'time_algorithm_update': 0.0012787292003631592, 'loss': 9.729195766091348, 'time_step': 0.001762125015258789, 'rollout_return': 7.796030946566862, 'evaluation': 8.357976602913302} step=80000
# 2023-03-28 17:36.59 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_81000.pt
# 2023-03-28 17:36.59 [info     ] DoubleDQN_online_20230328173532: epoch=81 step=81000 epoch=81 metrics={'time_inference': 0.0002799623012542725, 'time_environment_step': 6.987476348876954e-05, 'time_sample_batch': 6.156063079833985e-05, 'time_algorithm_update': 0.001244908094406128, 'loss': 9.990556954655796, 'time_step': 0.001694913387298584, 'rollout_return': 7.845012587512076, 'evaluation': 9.20065151156275} step=81000
# 2023-03-28 17:37.00 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_82000.pt
# 2023-03-28 17:37.00 [info     ] DoubleDQN_online_20230328173532: epoch=82 step=82000 epoch=82 metrics={'time_inference': 0.0002548544406890869, 'time_environment_step': 6.298089027404785e-05, 'time_sample_batch': 5.5722475051879886e-05, 'time_algorithm_update': 0.001083479642868042, 'loss': 9.886059997081757, 'time_step': 0.0014894094467163086, 'rollout_return': 7.7494708193162944, 'evaluation': 9.39529422833007} step=82000
# 2023-03-28 17:37.02 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_83000.pt
# 2023-03-28 17:37.02 [info     ] DoubleDQN_online_20230328173532: epoch=83 step=83000 epoch=83 metrics={'time_inference': 0.0002597510814666748, 'time_environment_step': 6.405067443847657e-05, 'time_sample_batch': 5.8492183685302735e-05, 'time_algorithm_update': 0.0011513729095458983, 'loss': 9.88572540380247, 'time_step': 0.001567070245742798, 'rollout_return': 7.817248349848724, 'evaluation': 7.5943709916942534} step=83000
# 2023-03-28 17:37.03 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_84000.pt
# 2023-03-28 17:37.03 [info     ] DoubleDQN_online_20230328173532: epoch=84 step=84000 epoch=84 metrics={'time_inference': 0.00027213191986083984, 'time_environment_step': 6.686782836914062e-05, 'time_sample_batch': 5.901885032653809e-05, 'time_algorithm_update': 0.0011740708351135254, 'loss': 9.96969460940361, 'time_step': 0.0016065027713775635, 'rollout_return': 7.549535637577728, 'evaluation': 7.575298848380008} step=84000
# 2023-03-28 17:37.05 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_85000.pt
# 2023-03-28 17:37.05 [info     ] DoubleDQN_online_20230328173532: epoch=85 step=85000 epoch=85 metrics={'time_inference': 0.00026160216331481934, 'time_environment_step': 6.543779373168946e-05, 'time_sample_batch': 5.776071548461914e-05, 'time_algorithm_update': 0.0011076209545135497, 'loss': 9.781479359030724, 'time_step': 0.0015268175601959228, 'rollout_return': 7.490221446565084, 'evaluation': 8.787973759769727} step=85000
# 2023-03-28 17:37.07 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_86000.pt
# 2023-03-28 17:37.07 [info     ] DoubleDQN_online_20230328173532: epoch=86 step=86000 epoch=86 metrics={'time_inference': 0.00025690007209777833, 'time_environment_step': 6.561064720153808e-05, 'time_sample_batch': 5.5495262145996096e-05, 'time_algorithm_update': 0.0011463882923126222, 'loss': 10.003485213123263, 'time_step': 0.001558983564376831, 'rollout_return': 7.5110953767862325, 'evaluation': 8.66594750421017} step=86000
# 2023-03-28 17:37.08 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_87000.pt
# 2023-03-28 17:37.08 [info     ] DoubleDQN_online_20230328173532: epoch=87 step=87000 epoch=87 metrics={'time_inference': 0.00024347877502441407, 'time_environment_step': 6.116867065429688e-05, 'time_sample_batch': 5.3700923919677734e-05, 'time_algorithm_update': 0.0010487823486328126, 'loss': 9.946036745429039, 'time_step': 0.0014391751289367675, 'rollout_return': 7.412222442767484, 'evaluation': 7.875551175846221} step=87000
# 2023-03-28 17:37.10 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_88000.pt
# 2023-03-28 17:37.10 [info     ] DoubleDQN_online_20230328173532: epoch=88 step=88000 epoch=88 metrics={'time_inference': 0.0002470564842224121, 'time_environment_step': 6.165409088134766e-05, 'time_sample_batch': 5.418300628662109e-05, 'time_algorithm_update': 0.0010810356140136719, 'loss': 9.772678491804749, 'time_step': 0.0014755325317382813, 'rollout_return': 7.400601484795228, 'evaluation': 5.1071564067054345} step=88000
# 2023-03-28 17:37.11 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_89000.pt
# 2023-03-28 17:37.11 [info     ] DoubleDQN_online_20230328173532: epoch=89 step=89000 epoch=89 metrics={'time_inference': 0.00022782063484191894, 'time_environment_step': 5.6365489959716794e-05, 'time_sample_batch': 5.090665817260742e-05, 'time_algorithm_update': 0.000978531837463379, 'loss': 9.742545786242932, 'time_step': 0.0013424944877624512, 'rollout_return': 7.372548373548536, 'evaluation': 7.542569787826345} step=89000
# 2023-03-28 17:37.12 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_90000.pt
# 2023-03-28 17:37.12 [info     ] DoubleDQN_online_20230328173532: epoch=90 step=90000 epoch=90 metrics={'time_inference': 0.00021782851219177246, 'time_environment_step': 5.394935607910156e-05, 'time_sample_batch': 4.8541545867919925e-05, 'time_algorithm_update': 0.0009333744049072266, 'loss': 9.747662794828415, 'time_step': 0.0012812647819519043, 'rollout_return': 7.601975094918677, 'evaluation': 7.870271200910905} step=90000
# 2023-03-28 17:37.14 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_91000.pt
# 2023-03-28 17:37.14 [info     ] DoubleDQN_online_20230328173532: epoch=91 step=91000 epoch=91 metrics={'time_inference': 0.00021843814849853516, 'time_environment_step': 5.384635925292969e-05, 'time_sample_batch': 4.829859733581543e-05, 'time_algorithm_update': 0.000921809196472168, 'loss': 9.78405112195015, 'time_step': 0.001269946575164795, 'rollout_return': 7.609328677346864, 'evaluation': 8.09381731460279} step=91000
# 2023-03-28 17:37.15 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_92000.pt
# 2023-03-28 17:37.15 [info     ] DoubleDQN_online_20230328173532: epoch=92 step=92000 epoch=92 metrics={'time_inference': 0.000238936185836792, 'time_environment_step': 5.9700965881347655e-05, 'time_sample_batch': 5.347251892089844e-05, 'time_algorithm_update': 0.0010498147010803223, 'loss': 9.79035782249272, 'time_step': 0.001438981294631958, 'rollout_return': 7.5816261449778, 'evaluation': 7.828683170483617} step=92000
# 2023-03-28 17:37.17 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_93000.pt
# 2023-03-28 17:37.17 [info     ] DoubleDQN_online_20230328173532: epoch=93 step=93000 epoch=93 metrics={'time_inference': 0.00023862671852111818, 'time_environment_step': 5.9050321578979495e-05, 'time_sample_batch': 5.262279510498047e-05, 'time_algorithm_update': 0.0010418131351470946, 'loss': 9.814005644440652, 'time_step': 0.0014226441383361817, 'rollout_return': 7.4948226618317735, 'evaluation': 8.611417941197335} step=93000
# 2023-03-28 17:37.18 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_94000.pt
# 2023-03-28 17:37.18 [info     ] DoubleDQN_online_20230328173532: epoch=94 step=94000 epoch=94 metrics={'time_inference': 0.00021289753913879394, 'time_environment_step': 5.2866458892822266e-05, 'time_sample_batch': 4.770827293395996e-05, 'time_algorithm_update': 0.0009148612022399903, 'loss': 9.798679851174354, 'time_step': 0.0012553305625915528, 'rollout_return': 7.481367959462331, 'evaluation': 7.410430214372449} step=94000
# 2023-03-28 17:37.19 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_95000.pt
# 2023-03-28 17:37.19 [info     ] DoubleDQN_online_20230328173532: epoch=95 step=95000 epoch=95 metrics={'time_inference': 0.0002225322723388672, 'time_environment_step': 5.48396110534668e-05, 'time_sample_batch': 4.9863338470458983e-05, 'time_algorithm_update': 0.0009735815525054931, 'loss': 9.738265957649798, 'time_step': 0.001329249382019043, 'rollout_return': 7.584481470110037, 'evaluation': 7.455757221851561} step=95000
# 2023-03-28 17:37.21 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_96000.pt
# 2023-03-28 17:37.21 [info     ] DoubleDQN_online_20230328173532: epoch=96 step=96000 epoch=96 metrics={'time_inference': 0.0002309250831604004, 'time_environment_step': 5.756664276123047e-05, 'time_sample_batch': 5.143880844116211e-05, 'time_algorithm_update': 0.0010096075534820556, 'loss': 9.598178440332413, 'time_step': 0.001379284143447876, 'rollout_return': 7.618669103840052, 'evaluation': 8.749809224677822} step=96000
# 2023-03-28 17:37.22 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_97000.pt
# 2023-03-28 17:37.22 [info     ] DoubleDQN_online_20230328173532: epoch=97 step=97000 epoch=97 metrics={'time_inference': 0.0002189662456512451, 'time_environment_step': 5.3902387619018554e-05, 'time_sample_batch': 4.863953590393066e-05, 'time_algorithm_update': 0.0009398581981658935, 'loss': 9.596539952516556, 'time_step': 0.0012891082763671876, 'rollout_return': 7.403901465177293, 'evaluation': 8.011370508916695} step=97000
# 2023-03-28 17:37.23 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_98000.pt
# 2023-03-28 17:37.23 [info     ] DoubleDQN_online_20230328173532: epoch=98 step=98000 epoch=98 metrics={'time_inference': 0.00021555924415588378, 'time_environment_step': 5.35130500793457e-05, 'time_sample_batch': 4.89804744720459e-05, 'time_algorithm_update': 0.0009359078407287598, 'loss': 9.724302197098732, 'time_step': 0.0012818341255187988, 'rollout_return': 7.60675830569902, 'evaluation': 7.859058955224742} step=98000
# 2023-03-28 17:37.25 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_99000.pt
# 2023-03-28 17:37.25 [info     ] DoubleDQN_online_20230328173532: epoch=99 step=99000 epoch=99 metrics={'time_inference': 0.00021153020858764648, 'time_environment_step': 5.33301830291748e-05, 'time_sample_batch': 4.869174957275391e-05, 'time_algorithm_update': 0.0009202380180358886, 'loss': 9.811555383563041, 'time_step': 0.001261228084564209, 'rollout_return': 7.5867951769622355, 'evaluation': 7.9825214763485} step=99000
# 2023-03-28 17:37.26 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230328173532/model_100000.pt
# 2023-03-28 17:37.26 [info     ] DoubleDQN_online_20230328173532: epoch=100 step=100000 epoch=100 metrics={'time_inference': 0.00021459650993347167, 'time_environment_step': 5.3519248962402344e-05, 'time_sample_batch': 4.834604263305664e-05, 'time_algorithm_update': 0.0009238216876983643, 'loss': 9.646312903523445, 'time_step': 0.0012677109241485596, 'rollout_return': 7.44538959451089, 'evaluation': 8.966670405503761} step=100000

# %%
# save model
ddqn.save_model("d3rlpy_logs/ddqn.pt")

# %%
# reload model
ddqn.build_with_env(env)
ddqn.load_model("d3rlpy_logs/ddqn.pt")
# Out:
# 2023-03-28 17:37.26 [warning  ] Parameters will be reinitialized.

# %%
behavior_policy = EpsilonGreedyHead(
    ddqn, 
    n_actions=env.action_space.n,
    epsilon=0.3,
    name="ddqn_epsilon_0.3",
    random_state=random_state,
)

# %%
# initialize dataset class
dataset = SyntheticDataset(
    env=env,
    max_episode_steps=env.step_per_episode,
)

# %%
# collect logged data by a behavior policy
# skip if there is a preserved logged dataset
train_logged_dataset = dataset.obtain_episodes(
    behavior_policies=behavior_policy,
    n_trajectories=10000, 
    obtain_info=False,
    random_state=random_state,
)
test_logged_dataset = dataset.obtain_episodes(
    behavior_policies=behavior_policy,
    n_trajectories=10000, 
    obtain_info=False,
    random_state=random_state,
)
# Out:
# [obtain_trajectories]:   0%|          | 0/10000 [00:00<?, ?it/s]
# [obtain_trajectories]:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
with open("logs/train_dataset_discrete_ddpn.pkl", "wb") as f:
    pickle.dump(train_logged_dataset, f)
with open("logs/test_dataset_discrete_ddpn.pkl", "wb") as f:
    pickle.dump(test_logged_dataset, f)

# %%
with open("logs/train_dataset_discrete_ddpn.pkl", "rb") as f:
    train_logged_dataset = pickle.load(f)
with open("logs/test_dataset_discrete_ddpn.pkl", "rb") as f:
    test_logged_dataset = pickle.load(f)

# %% [markdown]
# #### Offline Policy Learning
# Here, we learn several "candidate" policies to be evaluated and selected using [d3rlpy](https://github.com/takuseno/d3rlpy)'s algorithm implementation.
#
# For more about the offline RL procedure, please refer to [examples/quickstart/basic/basic_synthetic_discrete_basic.ipynb](https://github.com/negocia-inc/ofrl/blob/ope/examples/quickstart/basic/basic_synthetic_discrete_basic.ipynb).

# %%
# import modules from d3rlpy
from d3rlpy.dataset import MDPDataset
from d3rlpy.algos import DiscreteCQL as CQL
# transform offline dataset for d3rlpy
offlinerl_dataset = MDPDataset(
    observations=train_logged_dataset["state"],
    actions=train_logged_dataset["action"],
    rewards=train_logged_dataset["reward"],
    terminals=train_logged_dataset["done"],
    episode_terminals=train_logged_dataset["done"],
    discrete_action=True,
)
train_episodes, test_episodes = train_test_split(offlinerl_dataset, test_size=0.2, random_state=random_state)

# %%
# Use Conservative Q-Learning policy
cql = CQL(
    encoder_factory=VectorEncoderFactory(hidden_units=[30, 30]),
    q_func_factory=MeanQFunctionFactory(),
    use_gpu=torch.cuda.is_available(),
)

# %%
cql.fit(
    train_episodes,
    eval_episodes=test_episodes,
    n_steps=10000,
    scorers={},
)
# Out:
# 2023-03-28 17:38.41 [debug    ] RandomIterator is selected.
# 2023-03-28 17:38.41 [info     ] Directory is created at d3rlpy_logs/DiscreteCQL_20230328173841
# 2023-03-28 17:38.41 [debug    ] Building models...
# 2023-03-28 17:38.41 [debug    ] Models have been built.
# 2023-03-28 17:38.41 [info     ] Parameters are saved to d3rlpy_logs/DiscreteCQL_20230328173841/params.json params={'action_scaler': None, 'alpha': 1.0, 'batch_size': 32, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 0.99, 'generated_maxlen': 100000, 'learning_rate': 6.25e-05, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': None, 'target_update_interval': 8000, 'use_gpu': None, 'algorithm': 'DiscreteCQL', 'observation_shape': (5,), 'action_size': 10}
# Epoch 1/1:   0%|          | 0/10000 [00:00<?, ?it/s]
# 2023-03-28 17:38.57 [info     ] DiscreteCQL_20230328173841: epoch=1 step=10000 epoch=1 metrics={'time_sample_batch': 0.00010821139812469483, 'time_algorithm_update': 0.0013384353876113892, 'loss': 1.7593222920000553, 'time_step': 0.0015497016668319702} step=10000
# 2023-03-28 17:38.57 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteCQL_20230328173841/model_10000.pt
# [(1,
#   {'time_sample_batch': 0.00010821139812469483,
#    'time_algorithm_update': 0.0013384353876113892,
#    'loss': 1.7593222920000553,
#    'time_step': 0.0015497016668319702})]

# %%
# save model
cql.save_model("d3rlpy_logs/cql_discrete.pt")

# %%
# reload model
cql.build_with_env(env_)
cql.load_model("d3rlpy_logs/cql_discrete.pt")
# Out:
# 2023-03-28 17:38.57 [warning  ] Parameters will be reinitialized.

# %% [markdown]
# ## 2. Off-Policy Evaluation
# In this section, we aim at evaluating the various performance statistics of policies in an offline manner using (basic) model-based and importance sampling-based estimators.
#
# #### Estimation Target
#
# The goal to estimate the estimators' average policy performance, the *policy value*.
#
# $$ V(\pi) := \mathbb{E}\left[\sum_{t=1}^T \gamma^{t-1} r_t \mid \pi \right] $$

# %%
# import ope modules from OFRL
from ofrl.ope import CreateOPEInput
from ofrl.ope import OffPolicyEvaluation as OPE
# basic estimators
from ofrl.ope import DiscreteDirectMethod as DM
from ofrl.ope import DiscreteTrajectoryWiseImportanceSampling as TIS
from ofrl.ope import DiscretePerDecisionImportanceSampling as PDIS
from ofrl.ope import DiscreteDoublyRobust as DR
# self normalized estimators
from ofrl.ope import DiscreteSelfNormalizedTrajectoryWiseImportanceSampling as SNTIS
from ofrl.ope import DiscreteSelfNormalizedPerDecisionImportanceSampling as SNPDIS
from ofrl.ope import DiscreteSelfNormalizedDoublyRobust as SNDR
# marginal estimators
from ofrl.ope import DiscreteStateActionMarginalImportanceSampling as SAMIS
from ofrl.ope import DiscreteStateActionMarginalDoublyRobust as SAMDR
from ofrl.ope import DiscreteStateMarginalImportanceSampling as SMIS
from ofrl.ope import DiscreteStateMarginalDoublyRobust as SMDR
from ofrl.ope import DiscreteStateActionMarginalSelfNormalizedImportanceSampling as SAMSNIS
from ofrl.ope import DiscreteStateActionMarginalSelfNormalizedDoublyRobust as SAMSNDR
from ofrl.ope import DiscreteStateMarginalSelfNormalizedImportanceSampling as SMSNIS
from ofrl.ope import DiscreteStateMarginalSelfNormalizedDoublyRobust as SMSNDR
# double reinforcement learning estimators
from ofrl.ope import DiscreteDoubleReinforcementLearning as DRL

# %%
from d3rlpy.algos import DiscreteRandomPolicy
random = DiscreteRandomPolicy()
random.build_with_env(env_)

# %%
# define evaluation policies
cql_ = EpsilonGreedyHead(base_policy=cql, n_actions=env.action_space.n, name="cql", epsilon=0.0, random_state=random_state)
ddqn_ = EpsilonGreedyHead(base_policy=ddqn, n_actions=env.action_space.n, name="ddqn", epsilon=0.0, random_state=random_state)
random_ = EpsilonGreedyHead(base_policy=random, n_actions=env.action_space.n, name="random", epsilon=1.0, random_state=random_state)
evaluation_policies = [cql_, ddqn_, random_]

# %%
# first, prepare OPE inputs
prep = CreateOPEInput(
    env=env,
    model_args={
        "fqe": {
            "encoder_factory": VectorEncoderFactory(hidden_units=[30, 30]),
            "q_func_factory": MeanQFunctionFactory(),
            "learning_rate": 1e-4,
            "use_gpu": torch.cuda.is_available(),
        },
    },
    state_scaler=MinMaxScaler(
        minimum=test_logged_dataset["state"].min(axis=0),
        maximum=test_logged_dataset["state"].max(axis=0),
    ),
    sigma=0.1,
    gamma=0.95,
    device="cuda:0" if torch.cuda.is_available() else "cpu",
)

# %%
# takes time
input_dict = prep.obtain_whole_inputs(
    logged_dataset=test_logged_dataset,
    evaluation_policies=evaluation_policies,
    require_value_prediction=True,
    require_weight_prediction=True,
    n_trajectories_on_policy_evaluation=100,
    random_state=random_state,
)
# Out:
# [fit FQE model]:   0%|          | 0/3 [00:00<?, ?it/s]
# 2023-03-28 17:38.58 [debug    ] RoundIterator is selected.
# 2023-03-28 17:38.58 [info     ] Directory is created at d3rlpy_logs/DiscreteFQE_20230328173858
# 2023-03-28 17:38.58 [debug    ] Fitting scaler...              scaler=min_max
# 2023-03-28 17:38.58 [debug    ] Building models...
# 2023-03-28 17:38.58 [debug    ] Models have been built.
# 2023-03-28 17:38.58 [info     ] Parameters are saved to d3rlpy_logs/DiscreteFQE_20230328173858/params.json params={'action_scaler': None, 'batch_size': 100, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 0.95, 'generated_maxlen': 100000, 'learning_rate': 0.0001, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': {'type': 'min_max', 'params': {'maximum': array([0.98859931, 0.98694758, 0.99240934, 0.98863837, 0.99247112]), 'minimum': array([-0.99265486, -0.99068671, -0.99643228, -0.99825981, -0.99242592])}}, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'DiscreteFQE', 'observation_shape': (5,), 'action_size': 10}
# Epoch 1/1:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2023-03-28 17:38.59 [info     ] DiscreteFQE_20230328173858: epoch=1 step=1000 epoch=1 metrics={'time_sample_batch': 0.00010669374465942382, 'time_algorithm_update': 0.0009835116863250732, 'loss': 0.24187277864664794, 'time_step': 0.0011396644115447998} step=1000
# 2023-03-28 17:38.59 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteFQE_20230328173858/model_1000.pt
# 2023-03-28 17:38.59 [debug    ] RoundIterator is selected.
# 2023-03-28 17:38.59 [info     ] Directory is created at d3rlpy_logs/DiscreteFQE_20230328173859
# 2023-03-28 17:38.59 [debug    ] Fitting scaler...              scaler=min_max
# 2023-03-28 17:38.59 [debug    ] Building models...
# 2023-03-28 17:38.59 [debug    ] Models have been built.
# 2023-03-28 17:38.59 [info     ] Parameters are saved to d3rlpy_logs/DiscreteFQE_20230328173859/params.json params={'action_scaler': None, 'batch_size': 100, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 0.95, 'generated_maxlen': 100000, 'learning_rate': 0.0001, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': {'type': 'min_max', 'params': {'maximum': array([0.98859931, 0.98694758, 0.99240934, 0.98863837, 0.99247112]), 'minimum': array([-0.99265486, -0.99068671, -0.99643228, -0.99825981, -0.99242592])}}, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'DiscreteFQE', 'observation_shape': (5,), 'action_size': 10}
# Epoch 1/1:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2023-03-28 17:39.00 [info     ] DiscreteFQE_20230328173859: epoch=1 step=1000 epoch=1 metrics={'time_sample_batch': 0.0001116783618927002, 'time_algorithm_update': 0.0010884296894073486, 'loss': 0.22470349299162626, 'time_step': 0.0012567903995513916} step=1000
# 2023-03-28 17:39.00 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteFQE_20230328173859/model_1000.pt
# 2023-03-28 17:39.00 [debug    ] RoundIterator is selected.
# 2023-03-28 17:39.00 [info     ] Directory is created at d3rlpy_logs/DiscreteFQE_20230328173900
# 2023-03-28 17:39.00 [debug    ] Fitting scaler...              scaler=min_max
# 2023-03-28 17:39.00 [debug    ] Building models...
# 2023-03-28 17:39.00 [debug    ] Models have been built.
# 2023-03-28 17:39.00 [info     ] Parameters are saved to d3rlpy_logs/DiscreteFQE_20230328173900/params.json params={'action_scaler': None, 'batch_size': 100, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 0.95, 'generated_maxlen': 100000, 'learning_rate': 0.0001, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': {'type': 'min_max', 'params': {'maximum': array([0.98859931, 0.98694758, 0.99240934, 0.98863837, 0.99247112]), 'minimum': array([-0.99265486, -0.99068671, -0.99643228, -0.99825981, -0.99242592])}}, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'DiscreteFQE', 'observation_shape': (5,), 'action_size': 10}
# Epoch 1/1:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2023-03-28 17:39.02 [info     ] DiscreteFQE_20230328173900: epoch=1 step=1000 epoch=1 metrics={'time_sample_batch': 0.00011214709281921387, 'time_algorithm_update': 0.0009103848934173584, 'loss': 0.10921166695281863, 'time_step': 0.0010756196975708007} step=1000
# 2023-03-28 17:39.02 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteFQE_20230328173900/model_1000.pt
# [fit MWL model]:   0%|          | 0/3 [00:00<?, ?it/s]
# [fitting_weight_function]:   0%|          | 0/100 [00:00<?, ?it/s]
# [fitting_weight_function]:   0%|          | 0/100 [00:00<?, ?it/s]
# [fitting_weight_function]:   0%|          | 0/100 [00:00<?, ?it/s]
# [fitting_weight_function]:   0%|          | 0/100 [00:00<?, ?it/s]
# [fitting_weight_function]:   0%|          | 0/100 [00:00<?, ?it/s]
# [fitting_weight_function]:   0%|          | 0/100 [00:00<?, ?it/s]
# [collect input data: eval_policy]:   0%|          | 0/3 [00:00<?, ?it/s]
# [calculate on-policy policy value]:   0%|          | 0/100 [00:00<?, ?it/s]
# [calculate on-policy policy value]:   0%|          | 0/100 [00:00<?, ?it/s]
# [calculate on-policy policy value]:   0%|          | 0/100 [00:00<?, ?it/s]

# %%
with open("logs/ope_input_dict_discrete_zoo.pkl", "wb") as f:
    pickle.dump(input_dict, f)

# %%
with open("logs/ope_input_dict_discrete_zoo.pkl", "rb") as f:
    input_dict = pickle.load(f)

# %%
basic_estimators = [DM(), TIS(), PDIS(), DR(), SNTIS(), SNPDIS(), SNDR()]
state_marginal_estimators = [SMIS(), SMDR(), SMSNIS(), SMSNDR()]
state_action_marginal_estimators = [SAMIS(), SAMDR(), SAMSNIS(), SAMSNDR()]
drl_estimators = [DRL()]
all_estimators = basic_estimators + state_marginal_estimators + state_action_marginal_estimators + drl_estimators

# %%
basic_estimators_name = ["dm", "tis", "pdis", "dr", "sntis", "snpdis", "sndr"]
state_marginal_estimators_name = ["sm_is", "sm_dr", "sm_snis", "sm_sndr"]
state_action_marginal_estimators_name = ["sam_is", "sam_dr", "sam_snis", "sam_sndr"]
drl_estimators_name = ["drl"]

# %%
ope = OPE(
    logged_dataset=test_logged_dataset,
    ope_estimators=all_estimators,
)

# %%
# policy value estimation by ope
policy_value_df_dict, policy_value_interval_df_dict = ope.summarize_off_policy_estimates(
    input_dict, 
    random_state=random_state,
)
# dictionary of the estimation
policy_value_df_dict
# Out:
# {'cql':            policy_value  relative_policy_value
#  on_policy      7.069015               1.000000
#  dm             2.967973               0.419857
#  tis            7.311214               1.034262
#  pdis           7.104918               1.005079
#  dr             7.171755               1.014534
#  sntis          7.404760               1.047495
#  snpdis         7.407588               1.047895
#  sndr           7.400136               1.046841
#  sm_is               NaN                    NaN
#  sm_dr               NaN                    NaN
#  sm_snis             NaN                    NaN
#  sm_sndr             NaN                    NaN
#  sam_is              NaN                    NaN
#  sam_dr              NaN                    NaN
#  sam_snis            NaN                    NaN
#  sam_sndr            NaN                    NaN
#  drl            2.968003               0.419861,
#  'ddqn':            policy_value  relative_policy_value
#  on_policy      6.727275               1.000000
#  dm             2.907167               0.432146
#  tis            7.087684               1.053574
#  pdis           7.136514               1.060833
#  dr             7.119546               1.058310
#  sntis          7.083771               1.052993
#  snpdis         7.057009               1.049015
#  sndr           7.053462               1.048487
#  sm_is               NaN                    NaN
#  sm_dr               NaN                    NaN
#  sm_snis             NaN                    NaN
#  sm_sndr             NaN                    NaN
#  sam_is              NaN                    NaN
#  sam_dr              NaN                    NaN
#  sam_snis            NaN                    NaN
#  sam_sndr            NaN                    NaN
#  drl            2.907309               0.432167,
#  'random':            policy_value  relative_policy_value
#  on_policy  1.304105e+00           1.000000e+00
#  dm         9.151156e-01           7.017194e-01
#  tis        3.159851e+00           2.423003e+00
#  pdis       2.944018e+00           2.257501e+00
#  dr         1.151251e+00           8.827905e-01
#  sntis      1.951266e+00           1.496250e+00
#  snpdis     1.520817e+00           1.166177e+00
#  sndr       1.182152e+00           9.064852e-01
#  sm_is      0.000000e+00           0.000000e+00
#  sm_dr      9.151156e-01           7.017194e-01
#  sm_snis    0.000000e+00           0.000000e+00
#  sm_sndr    9.132080e-01           7.002566e-01
#  sam_is     7.731830e-08           5.928841e-08
#  sam_dr     9.151160e-01           7.017197e-01
#  sam_snis   7.086518e-01           5.434010e-01
#  sam_sndr   1.933612e+00           1.482712e+00
#  drl        9.151215e-01           7.017239e-01}

# %%
# visualize and compare the result
ope.visualize_off_policy_estimates(
    input_dict, 
    compared_estimators=basic_estimators_name,
    random_state=random_state, 
    sharey=False,
)
# relative policy value to the behavior policy
# ope.visualize_off_policy_estimates(input_dict, random_state=random_state, is_relative=True, sharey=False)

# %%
# visualize and compare the result
ope.visualize_off_policy_estimates(
    input_dict, 
    compared_estimators=state_marginal_estimators_name,
    random_state=random_state, 
    sharey=False,
)

# %%
# visualize and compare the result
ope.visualize_off_policy_estimates(
    input_dict, 
    compared_estimators=state_action_marginal_estimators_name,
    random_state=random_state, 
    sharey=False,
)

# %%
# visualize and compare the result
ope.visualize_off_policy_estimates(
    input_dict, 
    compared_estimators=["dm", "pdis", "dr", "sm_is", "sm_dr", "sam_is", "sam_dr", "drl"],
    random_state=random_state, 
    sharey=False,
)

# %%
ope.visualize_off_policy_estimates(
    input_dict, 
    compared_estimators=["dm", "snpdis", "sndr", "sm_snis", "sm_sndr", "sam_snis", "sam_sndr"],
    random_state=random_state, 
    sharey=False,
)

# %% [markdown]
# For more advanced topics in OPE (e.g., cumulative distribution function estimation) and OPS, please refer to [examples/quickstart/basic/basic_synthetic_discrete_advanced.ipynb](https://github.com/negocia-inc/ofrl/blob/ope/examples/quickstart/basic/basic_synthetic_discrete_advanced.ipynb).
#
# For the examples in the continuous action space, please refer to [examples/quickstart/basic/basic_synthetic_continuous_zoo.ipynb](https://github.com/negocia-inc/ofrl/blob/ope/examples/quickstart/basic/basic_synthetic_continuous_zoo.ipynb).

# %% [markdown]
# ## Reference
#
# - Yuta Saito, Shunsuke Aihara, Megumi Matsutani, and Yusuke Narita. \
# "Open Bandit Dataset and Pipeline: Towards Realistic and Reproducible Off-Policy Evaluation.", 2021.
#
# - Takuma Seno and Michita Imai. \
# "d3rlpy: An Offline Deep Reinforcement Library.", 2021.
#
# - Christina J. Yuan, Yash Chandak, Stephen Giguere, Philip S. Thomas, and Scott Niekum. \
# "SOPE: Spectrum of Off-Policy Estimators.", 2021.
#
# - Nathan Kallus and Masatoshi Uehara. \
# "Double Reinforcement Learning for Efficient Off-Policy Evaluation in Markov Decision Processes.", 2020.
#
# - Masatoshi Uehara, Jiawei Huang, and Nan Jiang. \
# "Minimax Weight and Q-Function Learning for Off-Policy Evaluation.", 2020.
#
# - Mengjiao Yang, Ofir Nachum, Bo Dai, Lihong Li, and Dale Schuurmans. \
# "Off-Policy Evaluation via the Regularized Lagrangian.", 2020.
#
# - Sergey Levine, Aviral Kumar, George Tucker, and Justin Fu. \
# "Offline Reinforcement Learning: Tutorial, Review, and Perspectives on Open Problems." 2020.
#
# - Aviral Kumar, Aurick Zhou, George Tucker, and Sergey Levine. \
# "Conservative Q-Learning for Offline Reinforcement Learning.", 2020.
#
# - Nathan Kallus and Masatoshi Uehara. \
# "Intrinsically Efficient, Stable, and Bounded Off-Policy Evaluation for Reinforcement Learning.", 2019.
#
# - Hoang Le, Cameron Voloshin, and Yisong Yue. \
# "Batch Policy Learning under Constraints.", 2019.
#
# - Qiang Liu, Lihong Li, Ziyang Tang, and Dengyong Zhou. \
# "Breaking the Curse of Horizon: Infinite-Horizon Off-Policy Estimation.", 2018
#
# - Di Wu, Xiujun Chen, Xun Yang, Hao Wang, Qing Tan, Xiaoxun Zhang, Jian Xu, and Kun Gai. \
# "Budget Constrained Bidding by Model-free Reinforcement Learning in Display Advertising.", 2018.
#
# - Jun Zhao, Guang Qiu, Ziyu Guan, Wei Zhao, and Xiaofei He. \
# "Deep Reinforcement Learning for Sponsored Search Real-time Bidding.", 2018.
#
# - Josiah P. Hanna, Peter Stone, and Scott Niekum. \
# "Bootstrapping with Models: Confidence Intervals for Off-Policy Evaluation.", 2017.
#
# - Nan Jiang and Lihong Li. \
# "Doubly Robust Off-policy Value Evaluation for Reinforcement Learning.", 2016.
#
# - Philip S. Thomas and Emma Brunskill. \
# "Data-Efficient Off-Policy Policy Evaluation for Reinforcement Learning.", 2016.
#
# - Greg Brockman, Vicki Cheung, Ludwig Pettersson, Jonas Schneider, John Schulman, Jie Tang, and Wojciech Zaremba. \
# "OpenAI Gym.", 2016.
#
# - Philip S. Thomas, Georgios Theocharous, and Mohammad Ghavamzadeh. \
# "High Confidence Policy Improvement.", 2015.
#
# - Philip S. Thomas, Georgios Theocharous, and Mohammad Ghavamzadeh. \
# "High Confidence Off-Policy Evaluation.", 2015.
#
# - Adith Swaminathan and Thorsten Joachims. \
# "The Self-Normalized Estimator for Counterfactual Learning.", 2015.
#
# - Hado van Hasselt, Arthur Guez, and David Silver. \
# "Deep Reinforcement Learning with Double Q-learning.", 2015.
#
# - Miroslav Dudík, Dumitru Erhan, John Langford, and Lihong Li. \
# "Doubly Robust Policy Evaluation and Optimization.", 2014.
#
# - Alex Strehl, John Langford, Sham Kakade, and Lihong Li. \
# "Learning from Logged Implicit Exploration Data.", 2010.
#
# - Alina Beygelzimer and John Langford. \
# "The Offset Tree for Learning with Partial Labels.", 2009.
#
# - Doina Precup, Richard S. Sutton, and Satinder P. Singh. \
# "Eligibility Traces for Off-Policy Policy Evaluation.", 2000.
