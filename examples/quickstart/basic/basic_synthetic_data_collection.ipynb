# %% [markdown]
# # Quickstart Example with Basic Synthetic Simulation and Dataset (Data Collection)
# This notebook provides an example of visualizing the logged dataset collected on an basic environment.
#
# This example on consists of the following 3 cases:
# 1. Discrete Action Case
# 2. Continuous Action Case
# 3. Collecting Logged Datasets with Multiple Behavior Policies and Random Seeds
#
# \* This library uses [d3rlpy](https://github.com/takuseno/d3rlpy)'s algorithm implementations.
# \* Also, our data collection module is highly inspired by [Open Bandit Pipeline](https://github.com/st-tech/zr-obp).

# %%
# delete later
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# delete later
import warnings
warnings.simplefilter('ignore')

# %%
# delete later
import sys
sys.path.append('../../')
sys.path.append('../../../')

# %%
# import OFRL modules
import ofrl
from basicgym import BasicEnv
from ofrl.dataset import SyntheticDataset
from ofrl.policy import OnlineHead
from ofrl.ope.online import (
    calc_on_policy_policy_value,
    visualize_on_policy_policy_value,
)

# import d3rlpy algorithms
from d3rlpy.algos import DiscreteRandomPolicy
from d3rlpy.algos import RandomPolicy as ContinuousRandomPolicy
from d3rlpy.preprocessing import MinMaxActionScaler

# import from other libraries
import gym
import torch
from sklearn.model_selection import train_test_split
from sklearn.utils import check_random_state

# %%
import pickle
from dataclasses import dataclass
from typing import Tuple, Union, Optional
from glob import glob
from tqdm import tqdm

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# version
print(ofrl.__version__)
# Out:
# 0.0.0

# %%
# set random state
random_state = 12345
random_ = check_random_state(random_state)

# %% [markdown]
# ## 0. Description of Synthetic Basic Simulation Environment
# To begin with, we briefly describe the basic usage of the environment.
#
# #### RL setup for Synthetic
# In Synthetic , the objective of the RL agent is to maximize reward
#
# We often formulate this synthetic  problem as the following (Partially Observable) Markov Decision Process ((PO)MDP):
# - `state`: State observation, which may be noisy in POMDPs.
# - `action`:  Indicating the action to presented by the RL agent.
# - `reward`: Reward observation.
#
# Let's see how it works!

# %%
# setup environment
env = BasicEnv(random_state=random_state)

# %%
# define a random agent
agent = OnlineHead(
    ContinuousRandomPolicy(
        action_scaler=MinMaxActionScaler(
            minimum=env.action_space.low,  # minimum value that policy can take
            maximum=env.action_space.high,  # maximum value that policy can take
        )
    ),
    name="random",
)

# %%
# interact agent with the environment
# only 6 lines are needed for RL interaction
for episode in range(10):
    obs, info = env.reset()
    done = False

    while not done:
        action = agent.predict_online(obs)
        obs, reward, done, truncated, info = env.step(action)

# %%
# state 
print(obs.shape)
print(obs)
# Out:
# (5,)
# [-0.37164978 -0.49943402  0.36963097 -0.28399277 -0.62862005]

# %%
# let's visualize the transition of the reward
# our goal is to obtain a policy (or an agent) that maximizes the reward
obs, info = env.reset()
done = False
reward_list = []

while not done:
    action = agent.sample_action_online(obs)
    obs, reward, done, truncated, info = env.step(action)
    reward_list.append(reward)

# plot
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(reward_list[:-1], label='reward', color='tab:orange')
ax1.set_xlabel('timestep')
ax1.set_ylabel('reward')
ax1.legend(loc='upper left')
plt.show()

# %% [markdown]
# For more about the environmental configuration , please refer to [examples/quickstart/basic/basic_synthetic_customize_env.ipynb](https://github.com/negocia-inc/ofrl/blob/ope/examples/quickstart/basic/basic_synthetic_customize_env.ipynb).

# %% [markdown]
# ## 1. Discrete Action Case
# Here, we present how to collect logged data by a behavior policy in the case of discrete action.
#
# The procedure requires two steps:
#
# 1. Learn a base deterministic policy
# 2. Convert the deterministic policy into a stochastic policy.
#
# Below, we first learn a deterministic policy using [d3rlpy](https://github.com/takuseno/d3rlpy).

# %%
# standardized environment for discrete action
env = gym.make("BasicEnv-discrete-v0")

# %%
# for api compatibility to d3rlpy
from ofrl.utils import OldGymAPIWrapper
env_ = OldGymAPIWrapper(env)

# %%
# learn a base deterministic policy for data collection
from d3rlpy.algos import DoubleDQN
from d3rlpy.models.encoders import VectorEncoderFactory
from d3rlpy.models.q_functions import MeanQFunctionFactory
from d3rlpy.online.buffers import ReplayBuffer
from d3rlpy.online.explorers import LinearDecayEpsilonGreedy

# model
ddqn = DoubleDQN(
    encoder_factory=VectorEncoderFactory(hidden_units=[30, 30]),
    q_func_factory=MeanQFunctionFactory(),
    target_update_interval=100,
    use_gpu=torch.cuda.is_available(),
)
# replay buffer
buffer = ReplayBuffer(
    maxlen=10000,
    env=env_,
)
# explorers
explorer = LinearDecayEpsilonGreedy(
    start_epsilon=1.0,
    end_epsilon=0.1,
    duration=1000,
)

# %%
# start training
# skip if there is a pre-trained model
ddqn.fit_online(
    env_,
    buffer,
    explorer=explorer,
    eval_env=env_,
    n_steps=100000,
    n_steps_per_epoch=1000,
    update_start_step=1000,
)
# Out:
# 2023-03-19 16:54.02 [info     ] Directory is created at d3rlpy_logs/DoubleDQN_online_20230319165402
# 2023-03-19 16:54.02 [debug    ] Building model...
# 2023-03-19 16:54.02 [debug    ] Model has been built.
# 2023-03-19 16:54.02 [info     ] Parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/params.json params={'action_scaler': None, 'batch_size': 32, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 0.99, 'generated_maxlen': 100000, 'learning_rate': 6.25e-05, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': None, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'DoubleDQN', 'observation_shape': (5,), 'action_size': 10}
#   0%|          | 0/100000 [00:00<?, ?it/s]
# 2023-03-19 16:54.02 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_1000.pt
# 2023-03-19 16:54.02 [info     ] DoubleDQN_online_20230319165402: epoch=1 step=1000 epoch=1 metrics={'time_inference': 0.00012751936912536622, 'time_environment_step': 2.6270151138305665e-05, 'time_step': 0.00016262412071228028, 'rollout_return': 0.5442806503607356, 'evaluation': -0.6666262082826482} step=1000
# 2023-03-19 16:54.03 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_2000.pt
# 2023-03-19 16:54.03 [info     ] DoubleDQN_online_20230319165402: epoch=2 step=2000 epoch=2 metrics={'time_inference': 0.00012253713607788085, 'time_environment_step': 3.1208276748657225e-05, 'time_sample_batch': 2.670431137084961e-05, 'time_algorithm_update': 0.0006041865348815918, 'loss': 0.05947500136680901, 'time_step': 0.0008000679016113281, 'rollout_return': 2.458872074736453, 'evaluation': 3.109116563801435} step=2000
# 2023-03-19 16:54.04 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_3000.pt
# 2023-03-19 16:54.04 [info     ] DoubleDQN_online_20230319165402: epoch=3 step=3000 epoch=3 metrics={'time_inference': 0.00012330889701843263, 'time_environment_step': 3.197264671325684e-05, 'time_sample_batch': 2.8085708618164062e-05, 'time_algorithm_update': 0.0005760746002197266, 'loss': 0.11833454709127546, 'time_step': 0.0007754096984863281, 'rollout_return': 2.932570673354649, 'evaluation': 3.09723972978714} step=3000
# 2023-03-19 16:54.04 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_4000.pt
# 2023-03-19 16:54.04 [info     ] DoubleDQN_online_20230319165402: epoch=4 step=4000 epoch=4 metrics={'time_inference': 0.00011931586265563965, 'time_environment_step': 3.0212640762329102e-05, 'time_sample_batch': 2.5680303573608398e-05, 'time_algorithm_update': 0.0005519356727600097, 'loss': 0.18527212234959006, 'time_step': 0.0007421624660491943, 'rollout_return': 5.259439299309062, 'evaluation': 9.321744934078568} step=4000
# 2023-03-19 16:54.05 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_5000.pt
# 2023-03-19 16:54.05 [info     ] DoubleDQN_online_20230319165402: epoch=5 step=5000 epoch=5 metrics={'time_inference': 0.00011829543113708495, 'time_environment_step': 2.994084358215332e-05, 'time_sample_batch': 2.6192665100097656e-05, 'time_algorithm_update': 0.0005505738258361816, 'loss': 1.0142320854365825, 'time_step': 0.000739835262298584, 'rollout_return': 8.548417913135342, 'evaluation': 9.526111418860078} step=5000
# 2023-03-19 16:54.06 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_6000.pt
# 2023-03-19 16:54.06 [info     ] DoubleDQN_online_20230319165402: epoch=6 step=6000 epoch=6 metrics={'time_inference': 0.00012064266204833984, 'time_environment_step': 3.0561208724975584e-05, 'time_sample_batch': 2.7534961700439452e-05, 'time_algorithm_update': 0.0005582633018493652, 'loss': 2.5616779254376887, 'time_step': 0.0007520279884338379, 'rollout_return': 8.476847803339481, 'evaluation': 9.391682952774518} step=6000
# 2023-03-19 16:54.07 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_7000.pt
# 2023-03-19 16:54.07 [info     ] DoubleDQN_online_20230319165402: epoch=7 step=7000 epoch=7 metrics={'time_inference': 0.00011598420143127442, 'time_environment_step': 2.897787094116211e-05, 'time_sample_batch': 2.440953254699707e-05, 'time_algorithm_update': 0.000538823127746582, 'loss': 3.915296990275383, 'time_step': 0.0007223248481750488, 'rollout_return': 8.493373213582249, 'evaluation': 9.416914254916525} step=7000
# 2023-03-19 16:54.07 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_8000.pt
# 2023-03-19 16:54.07 [info     ] DoubleDQN_online_20230319165402: epoch=8 step=8000 epoch=8 metrics={'time_inference': 0.00011959218978881836, 'time_environment_step': 3.0119895935058592e-05, 'time_sample_batch': 2.7369022369384765e-05, 'time_algorithm_update': 0.0005534796714782715, 'loss': 5.058712070316076, 'time_step': 0.0007453765869140624, 'rollout_return': 8.620231837349948, 'evaluation': 9.440372051181503} step=8000
# 2023-03-19 16:54.08 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_9000.pt
# 2023-03-19 16:54.08 [info     ] DoubleDQN_online_20230319165402: epoch=9 step=9000 epoch=9 metrics={'time_inference': 0.00012034201622009277, 'time_environment_step': 3.055953979492187e-05, 'time_sample_batch': 2.8630733489990234e-05, 'time_algorithm_update': 0.0005599167346954345, 'loss': 6.080259581089019, 'time_step': 0.0007545943260192871, 'rollout_return': 8.56712579245517, 'evaluation': 9.346987899687312} step=9000
# 2023-03-19 16:54.09 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_10000.pt
# 2023-03-19 16:54.09 [info     ] DoubleDQN_online_20230319165402: epoch=10 step=10000 epoch=10 metrics={'time_inference': 0.0001224215030670166, 'time_environment_step': 3.1172990798950194e-05, 'time_sample_batch': 2.9514312744140625e-05, 'time_algorithm_update': 0.0005649101734161377, 'loss': 6.623519055604935, 'time_step': 0.0007634899616241456, 'rollout_return': 8.199527863629358, 'evaluation': 9.375364587689408} step=10000
# 2023-03-19 16:54.10 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_11000.pt
# 2023-03-19 16:54.10 [info     ] DoubleDQN_online_20230319165402: epoch=11 step=11000 epoch=11 metrics={'time_inference': 0.000123002290725708, 'time_environment_step': 3.143095970153808e-05, 'time_sample_batch': 2.9653787612915038e-05, 'time_algorithm_update': 0.0005778331756591797, 'loss': 7.127128561615944, 'time_step': 0.0007778675556182861, 'rollout_return': 7.773483317604266, 'evaluation': 6.597182247702577} step=11000
# 2023-03-19 16:54.11 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_12000.pt
# 2023-03-19 16:54.11 [info     ] DoubleDQN_online_20230319165402: epoch=12 step=12000 epoch=12 metrics={'time_inference': 0.00012033057212829589, 'time_environment_step': 3.020763397216797e-05, 'time_sample_batch': 2.8401851654052736e-05, 'time_algorithm_update': 0.0005607631206512451, 'loss': 7.296982374668121, 'time_step': 0.0007550604343414307, 'rollout_return': 7.198424438641894, 'evaluation': 6.959320206315178} step=12000
# 2023-03-19 16:54.11 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_13000.pt
# 2023-03-19 16:54.11 [info     ] DoubleDQN_online_20230319165402: epoch=13 step=13000 epoch=13 metrics={'time_inference': 0.00011901950836181641, 'time_environment_step': 2.9993534088134767e-05, 'time_sample_batch': 2.8264760971069336e-05, 'time_algorithm_update': 0.0005538733005523681, 'loss': 7.510267426133156, 'time_step': 0.0007464797496795655, 'rollout_return': 6.53145869196091, 'evaluation': 8.861269398875471} step=13000
# 2023-03-19 16:54.12 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_14000.pt
# 2023-03-19 16:54.12 [info     ] DoubleDQN_online_20230319165402: epoch=14 step=14000 epoch=14 metrics={'time_inference': 0.00011843299865722657, 'time_environment_step': 2.9794216156005858e-05, 'time_sample_batch': 2.7843236923217774e-05, 'time_algorithm_update': 0.0005512869358062744, 'loss': 7.879038535416126, 'time_step': 0.0007424514293670654, 'rollout_return': 7.604186084007966, 'evaluation': 7.3672917151390305} step=14000
# 2023-03-19 16:54.13 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_15000.pt
# 2023-03-19 16:54.13 [info     ] DoubleDQN_online_20230319165402: epoch=15 step=15000 epoch=15 metrics={'time_inference': 0.00012320876121520996, 'time_environment_step': 3.146696090698242e-05, 'time_sample_batch': 3.0464887619018554e-05, 'time_algorithm_update': 0.000573535680770874, 'loss': 7.975976383924484, 'time_step': 0.0007748816013336182, 'rollout_return': 7.836739560635715, 'evaluation': 8.432328960290132} step=15000
# 2023-03-19 16:54.14 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_16000.pt
# 2023-03-19 16:54.14 [info     ] DoubleDQN_online_20230319165402: epoch=16 step=16000 epoch=16 metrics={'time_inference': 0.00011890792846679687, 'time_environment_step': 3.012704849243164e-05, 'time_sample_batch': 2.8836727142333985e-05, 'time_algorithm_update': 0.0005566401481628418, 'loss': 8.390653490982949, 'time_step': 0.0007501263618469238, 'rollout_return': 7.268544765417861, 'evaluation': 7.444717799553908} step=16000
# 2023-03-19 16:54.14 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_17000.pt
# 2023-03-19 16:54.14 [info     ] DoubleDQN_online_20230319165402: epoch=17 step=17000 epoch=17 metrics={'time_inference': 0.00011653566360473633, 'time_environment_step': 2.9083728790283204e-05, 'time_sample_batch': 2.600860595703125e-05, 'time_algorithm_update': 0.000548102855682373, 'loss': 8.311446744710207, 'time_step': 0.00073445725440979, 'rollout_return': 6.886102850855516, 'evaluation': 7.804067663357614} step=17000
# 2023-03-19 16:54.15 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_18000.pt
# 2023-03-19 16:54.15 [info     ] DoubleDQN_online_20230319165402: epoch=18 step=18000 epoch=18 metrics={'time_inference': 0.00011592507362365723, 'time_environment_step': 2.895069122314453e-05, 'time_sample_batch': 2.5823354721069338e-05, 'time_algorithm_update': 0.0005378279685974121, 'loss': 8.42482455702871, 'time_step': 0.0007232069969177246, 'rollout_return': 6.76771722138357, 'evaluation': 7.4799292548945955} step=18000
# 2023-03-19 16:54.16 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_19000.pt
# 2023-03-19 16:54.16 [info     ] DoubleDQN_online_20230319165402: epoch=19 step=19000 epoch=19 metrics={'time_inference': 0.00011532950401306152, 'time_environment_step': 2.8820037841796874e-05, 'time_sample_batch': 2.5771617889404295e-05, 'time_algorithm_update': 0.000535308837890625, 'loss': 8.532919896960259, 'time_step': 0.0007197055816650391, 'rollout_return': 6.9564570685755704, 'evaluation': 7.665765436753207} step=19000
# 2023-03-19 16:54.17 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_20000.pt
# 2023-03-19 16:54.17 [info     ] DoubleDQN_online_20230319165402: epoch=20 step=20000 epoch=20 metrics={'time_inference': 0.00011532878875732422, 'time_environment_step': 2.885723114013672e-05, 'time_sample_batch': 2.5787830352783205e-05, 'time_algorithm_update': 0.0005347847938537598, 'loss': 8.64170327758789, 'time_step': 0.0007192795276641846, 'rollout_return': 7.147850770807375, 'evaluation': 8.039217099459808} step=20000
# 2023-03-19 16:54.17 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_21000.pt
# 2023-03-19 16:54.17 [info     ] DoubleDQN_online_20230319165402: epoch=21 step=21000 epoch=21 metrics={'time_inference': 0.00011573886871337891, 'time_environment_step': 2.9002666473388672e-05, 'time_sample_batch': 2.5757074356079102e-05, 'time_algorithm_update': 0.0005360360145568847, 'loss': 8.636604731932282, 'time_step': 0.0007211508750915528, 'rollout_return': 7.069622288638439, 'evaluation': 7.725989106944391} step=21000
# 2023-03-19 16:54.18 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_22000.pt
# 2023-03-19 16:54.18 [info     ] DoubleDQN_online_20230319165402: epoch=22 step=22000 epoch=22 metrics={'time_inference': 0.00011534857749938965, 'time_environment_step': 2.8866291046142578e-05, 'time_sample_batch': 2.5763034820556642e-05, 'time_algorithm_update': 0.0005354712009429932, 'loss': 8.755086007118225, 'time_step': 0.0007202591896057129, 'rollout_return': 7.2018552721990385, 'evaluation': 7.4595175849628195} step=22000
# 2023-03-19 16:54.19 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_23000.pt
# 2023-03-19 16:54.19 [info     ] DoubleDQN_online_20230319165402: epoch=23 step=23000 epoch=23 metrics={'time_inference': 0.00011570644378662109, 'time_environment_step': 2.92050838470459e-05, 'time_sample_batch': 2.5818824768066407e-05, 'time_algorithm_update': 0.0005343565940856933, 'loss': 8.703169487655163, 'time_step': 0.0007197740077972412, 'rollout_return': 7.2141761174901315, 'evaluation': 7.635090738820298} step=23000
# 2023-03-19 16:54.20 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_24000.pt
# 2023-03-19 16:54.20 [info     ] DoubleDQN_online_20230319165402: epoch=24 step=24000 epoch=24 metrics={'time_inference': 0.00011546516418457031, 'time_environment_step': 2.883315086364746e-05, 'time_sample_batch': 2.5528669357299805e-05, 'time_algorithm_update': 0.0005356831550598145, 'loss': 9.018869826093317, 'time_step': 0.0007202577590942383, 'rollout_return': 6.9175578547838015, 'evaluation': 7.585562872933812} step=24000
# 2023-03-19 16:54.20 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_25000.pt
# 2023-03-19 16:54.20 [info     ] DoubleDQN_online_20230319165402: epoch=25 step=25000 epoch=25 metrics={'time_inference': 0.00011572694778442383, 'time_environment_step': 2.8943300247192384e-05, 'time_sample_batch': 2.585911750793457e-05, 'time_algorithm_update': 0.000535179615020752, 'loss': 8.972737449288369, 'time_step': 0.0007204205989837647, 'rollout_return': 7.0349275878026205, 'evaluation': 7.983846307915731} step=25000
# 2023-03-19 16:54.21 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_26000.pt
# 2023-03-19 16:54.21 [info     ] DoubleDQN_online_20230319165402: epoch=26 step=26000 epoch=26 metrics={'time_inference': 0.00011491012573242188, 'time_environment_step': 2.895545959472656e-05, 'time_sample_batch': 2.5977611541748046e-05, 'time_algorithm_update': 0.0005348474979400635, 'loss': 9.142330569967628, 'time_step': 0.0007192778587341308, 'rollout_return': 6.971520394162252, 'evaluation': 7.86787358145928} step=26000
# 2023-03-19 16:54.22 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_27000.pt
# 2023-03-19 16:54.22 [info     ] DoubleDQN_online_20230319165402: epoch=27 step=27000 epoch=27 metrics={'time_inference': 0.00011655569076538086, 'time_environment_step': 2.9143333435058595e-05, 'time_sample_batch': 2.601766586303711e-05, 'time_algorithm_update': 0.000537391185760498, 'loss': 8.912611418873071, 'time_step': 0.0007239432334899903, 'rollout_return': 7.374088232279302, 'evaluation': 7.934789721018315} step=27000
# 2023-03-19 16:54.23 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_28000.pt
# 2023-03-19 16:54.23 [info     ] DoubleDQN_online_20230319165402: epoch=28 step=28000 epoch=28 metrics={'time_inference': 0.00011575698852539062, 'time_environment_step': 2.911686897277832e-05, 'time_sample_batch': 2.572321891784668e-05, 'time_algorithm_update': 0.0005353724956512451, 'loss': 8.962222306579351, 'time_step': 0.0007205824851989746, 'rollout_return': 7.566119421668085, 'evaluation': 8.428704616041873} step=28000
# 2023-03-19 16:54.23 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_29000.pt
# 2023-03-19 16:54.23 [info     ] DoubleDQN_online_20230319165402: epoch=29 step=29000 epoch=29 metrics={'time_inference': 0.00011552190780639648, 'time_environment_step': 2.9022216796875e-05, 'time_sample_batch': 2.5616168975830076e-05, 'time_algorithm_update': 0.0005337162017822266, 'loss': 9.025289743304253, 'time_step': 0.0007185153961181641, 'rollout_return': 7.881191504367447, 'evaluation': 8.334699904292815} step=29000
# 2023-03-19 16:54.24 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_30000.pt
# 2023-03-19 16:54.24 [info     ] DoubleDQN_online_20230319165402: epoch=30 step=30000 epoch=30 metrics={'time_inference': 0.00011541390419006348, 'time_environment_step': 2.916383743286133e-05, 'time_sample_batch': 2.5645256042480467e-05, 'time_algorithm_update': 0.0005342054367065429, 'loss': 9.057061051167548, 'time_step': 0.0007190158367156983, 'rollout_return': 7.622747337397733, 'evaluation': 8.345607315472865} step=30000
# 2023-03-19 16:54.25 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_31000.pt
# 2023-03-19 16:54.25 [info     ] DoubleDQN_online_20230319165402: epoch=31 step=31000 epoch=31 metrics={'time_inference': 0.00011564779281616211, 'time_environment_step': 2.9107332229614256e-05, 'time_sample_batch': 2.5768518447875977e-05, 'time_algorithm_update': 0.0005352697372436523, 'loss': 9.153193986445665, 'time_step': 0.0007204573154449463, 'rollout_return': 7.968171000916808, 'evaluation': 7.280506289269067} step=31000
# 2023-03-19 16:54.26 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_32000.pt
# 2023-03-19 16:54.26 [info     ] DoubleDQN_online_20230319165402: epoch=32 step=32000 epoch=32 metrics={'time_inference': 0.00011526679992675781, 'time_environment_step': 2.9048681259155273e-05, 'time_sample_batch': 2.564072608947754e-05, 'time_algorithm_update': 0.0005345146656036377, 'loss': 9.167530139558018, 'time_step': 0.0007190155982971191, 'rollout_return': 7.861195317977302, 'evaluation': 7.776355482978188} step=32000
# 2023-03-19 16:54.26 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_33000.pt
# 2023-03-19 16:54.26 [info     ] DoubleDQN_online_20230319165402: epoch=33 step=33000 epoch=33 metrics={'time_inference': 0.00011536169052124024, 'time_environment_step': 2.8995752334594728e-05, 'time_sample_batch': 2.578568458557129e-05, 'time_algorithm_update': 0.0005342130661010742, 'loss': 9.169451398544014, 'time_step': 0.0007189531326293945, 'rollout_return': 7.7402398432128665, 'evaluation': 9.388753806248491} step=33000
# 2023-03-19 16:54.27 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_34000.pt
# 2023-03-19 16:54.27 [info     ] DoubleDQN_online_20230319165402: epoch=34 step=34000 epoch=34 metrics={'time_inference': 0.00011611270904541016, 'time_environment_step': 2.924656867980957e-05, 'time_sample_batch': 2.6147127151489257e-05, 'time_algorithm_update': 0.0005450377464294434, 'loss': 9.18995184777677, 'time_step': 0.0007315080165863037, 'rollout_return': 8.096057240872504, 'evaluation': 8.400043554676753} step=34000
# 2023-03-19 16:54.28 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_35000.pt
# 2023-03-19 16:54.28 [info     ] DoubleDQN_online_20230319165402: epoch=35 step=35000 epoch=35 metrics={'time_inference': 0.00011540555953979492, 'time_environment_step': 2.8904438018798827e-05, 'time_sample_batch': 2.5542736053466797e-05, 'time_algorithm_update': 0.000534395694732666, 'loss': 9.249663495369255, 'time_step': 0.0007188701629638672, 'rollout_return': 7.855017321212634, 'evaluation': 7.790851741495952} step=35000
# 2023-03-19 16:54.29 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_36000.pt
# 2023-03-19 16:54.29 [info     ] DoubleDQN_online_20230319165402: epoch=36 step=36000 epoch=36 metrics={'time_inference': 0.0001157689094543457, 'time_environment_step': 2.8875112533569337e-05, 'time_sample_batch': 2.545428276062012e-05, 'time_algorithm_update': 0.0005335288047790528, 'loss': 9.570630775608123, 'time_step': 0.0007182865142822266, 'rollout_return': 7.588021257446029, 'evaluation': 8.01454735368748} step=36000
# 2023-03-19 16:54.29 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_37000.pt
# 2023-03-19 16:54.29 [info     ] DoubleDQN_online_20230319165402: epoch=37 step=37000 epoch=37 metrics={'time_inference': 0.00011597013473510742, 'time_environment_step': 2.9006242752075196e-05, 'time_sample_batch': 2.5450706481933595e-05, 'time_algorithm_update': 0.0005343124866485596, 'loss': 9.094523026265204, 'time_step': 0.0007193496227264404, 'rollout_return': 7.709552844936503, 'evaluation': 9.350529119399617} step=37000
# 2023-03-19 16:54.30 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_38000.pt
# 2023-03-19 16:54.30 [info     ] DoubleDQN_online_20230319165402: epoch=38 step=38000 epoch=38 metrics={'time_inference': 0.0001154470443725586, 'time_environment_step': 2.8996467590332032e-05, 'time_sample_batch': 2.5751590728759767e-05, 'time_algorithm_update': 0.0005331332683563233, 'loss': 9.459672748144715, 'time_step': 0.000717909574508667, 'rollout_return': 7.596883834467181, 'evaluation': 7.876637933121145} step=38000
# 2023-03-19 16:54.31 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_39000.pt
# 2023-03-19 16:54.31 [info     ] DoubleDQN_online_20230319165402: epoch=39 step=39000 epoch=39 metrics={'time_inference': 0.000114898681640625, 'time_environment_step': 2.8923988342285157e-05, 'time_sample_batch': 2.5656938552856445e-05, 'time_algorithm_update': 0.0005338921546936035, 'loss': 9.592856149405241, 'time_step': 0.0007179422378540039, 'rollout_return': 7.665587119396434, 'evaluation': 9.490636134130828} step=39000
# 2023-03-19 16:54.31 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_40000.pt
# 2023-03-19 16:54.32 [info     ] DoubleDQN_online_20230319165402: epoch=40 step=40000 epoch=40 metrics={'time_inference': 0.00011500930786132813, 'time_environment_step': 2.8985023498535157e-05, 'time_sample_batch': 2.5535106658935548e-05, 'time_algorithm_update': 0.0005322728157043457, 'loss': 9.532089199662208, 'time_step': 0.0007164120674133301, 'rollout_return': 7.788614731051962, 'evaluation': 8.475013029021344} step=40000
# 2023-03-19 16:54.32 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_41000.pt
# 2023-03-19 16:54.32 [info     ] DoubleDQN_online_20230319165402: epoch=41 step=41000 epoch=41 metrics={'time_inference': 0.00011564517021179199, 'time_environment_step': 2.90374755859375e-05, 'time_sample_batch': 2.5570392608642578e-05, 'time_algorithm_update': 0.000534792423248291, 'loss': 9.970127077460289, 'time_step': 0.0007197296619415283, 'rollout_return': 8.182926890695255, 'evaluation': 9.096431088950855} step=41000
# 2023-03-19 16:54.33 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_42000.pt
# 2023-03-19 16:54.33 [info     ] DoubleDQN_online_20230319165402: epoch=42 step=42000 epoch=42 metrics={'time_inference': 0.00011558008193969727, 'time_environment_step': 2.8905630111694337e-05, 'time_sample_batch': 2.5619029998779295e-05, 'time_algorithm_update': 0.0005347235202789307, 'loss': 9.623542525891214, 'time_step': 0.0007194969654083252, 'rollout_return': 7.862560990581373, 'evaluation': 8.105408104177316} step=42000
# 2023-03-19 16:54.34 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_43000.pt
# 2023-03-19 16:54.34 [info     ] DoubleDQN_online_20230319165402: epoch=43 step=43000 epoch=43 metrics={'time_inference': 0.0001159381866455078, 'time_environment_step': 2.916240692138672e-05, 'time_sample_batch': 2.580404281616211e-05, 'time_algorithm_update': 0.0005366020202636719, 'loss': 9.786035180702806, 'time_step': 0.0007222552299499512, 'rollout_return': 8.02777222179114, 'evaluation': 9.237380184993887} step=43000
# 2023-03-19 16:54.34 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_44000.pt
# 2023-03-19 16:54.34 [info     ] DoubleDQN_online_20230319165402: epoch=44 step=44000 epoch=44 metrics={'time_inference': 0.00011586332321166992, 'time_environment_step': 2.8887510299682616e-05, 'time_sample_batch': 2.565956115722656e-05, 'time_algorithm_update': 0.0005334672927856445, 'loss': 10.04419548195228, 'time_step': 0.0007185614109039306, 'rollout_return': 7.829735232991246, 'evaluation': 7.5654565899992265} step=44000
# 2023-03-19 16:54.35 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_45000.pt
# 2023-03-19 16:54.35 [info     ] DoubleDQN_online_20230319165402: epoch=45 step=45000 epoch=45 metrics={'time_inference': 0.00011588096618652344, 'time_environment_step': 2.9352664947509767e-05, 'time_sample_batch': 2.595686912536621e-05, 'time_algorithm_update': 0.0005448615550994873, 'loss': 9.740049881577491, 'time_step': 0.0007309119701385498, 'rollout_return': 7.810885165856718, 'evaluation': 8.297780445944909} step=45000
# 2023-03-19 16:54.36 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_46000.pt
# 2023-03-19 16:54.36 [info     ] DoubleDQN_online_20230319165402: epoch=46 step=46000 epoch=46 metrics={'time_inference': 0.00011476230621337891, 'time_environment_step': 2.8934717178344728e-05, 'time_sample_batch': 2.5501966476440428e-05, 'time_algorithm_update': 0.0005327591896057129, 'loss': 9.817910590086132, 'time_step': 0.0007164723873138428, 'rollout_return': 7.838560192008609, 'evaluation': 7.842413144766006} step=46000
# 2023-03-19 16:54.37 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_47000.pt
# 2023-03-19 16:54.37 [info     ] DoubleDQN_online_20230319165402: epoch=47 step=47000 epoch=47 metrics={'time_inference': 0.0001147780418395996, 'time_environment_step': 2.8865575790405273e-05, 'time_sample_batch': 2.5350093841552733e-05, 'time_algorithm_update': 0.000532923936843872, 'loss': 9.619078487955035, 'time_step': 0.0007164895534515381, 'rollout_return': 7.583989483615069, 'evaluation': 7.779796449125866} step=47000
# 2023-03-19 16:54.37 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_48000.pt
# 2023-03-19 16:54.37 [info     ] DoubleDQN_online_20230319165402: epoch=48 step=48000 epoch=48 metrics={'time_inference': 0.00011569643020629883, 'time_environment_step': 2.9013872146606445e-05, 'time_sample_batch': 2.5604724884033204e-05, 'time_algorithm_update': 0.0005354859828948975, 'loss': 9.667446192502975, 'time_step': 0.0007203884124755859, 'rollout_return': 8.007697477221384, 'evaluation': 7.849543650057458} step=48000
# 2023-03-19 16:54.38 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_49000.pt
# 2023-03-19 16:54.38 [info     ] DoubleDQN_online_20230319165402: epoch=49 step=49000 epoch=49 metrics={'time_inference': 0.00011545348167419434, 'time_environment_step': 2.8928518295288084e-05, 'time_sample_batch': 2.5452136993408204e-05, 'time_algorithm_update': 0.0005333676338195801, 'loss': 9.99776393084228, 'time_step': 0.0007178022861480713, 'rollout_return': 7.577215161888322, 'evaluation': 7.782478770254597} step=49000
# 2023-03-19 16:54.39 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_50000.pt
# 2023-03-19 16:54.39 [info     ] DoubleDQN_online_20230319165402: epoch=50 step=50000 epoch=50 metrics={'time_inference': 0.00011565160751342773, 'time_environment_step': 2.896237373352051e-05, 'time_sample_batch': 2.553105354309082e-05, 'time_algorithm_update': 0.0005349555015563965, 'loss': 9.933536231253296, 'time_step': 0.0007197244167327881, 'rollout_return': 7.736293741176493, 'evaluation': 7.583380667716867} step=50000
# 2023-03-19 16:54.40 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_51000.pt
# 2023-03-19 16:54.40 [info     ] DoubleDQN_online_20230319165402: epoch=51 step=51000 epoch=51 metrics={'time_inference': 0.00011555600166320801, 'time_environment_step': 2.9230594635009767e-05, 'time_sample_batch': 2.5775671005249024e-05, 'time_algorithm_update': 0.0005344698429107666, 'loss': 9.78392766069621, 'time_step': 0.0007196948528289795, 'rollout_return': 7.772019321466567, 'evaluation': 7.9990984485265715} step=51000
# 2023-03-19 16:54.40 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_52000.pt
# 2023-03-19 16:54.40 [info     ] DoubleDQN_online_20230319165402: epoch=52 step=52000 epoch=52 metrics={'time_inference': 0.00011545467376708985, 'time_environment_step': 2.885627746582031e-05, 'time_sample_batch': 2.54976749420166e-05, 'time_algorithm_update': 0.0005344924926757813, 'loss': 9.969667878605426, 'time_step': 0.0007189640998840332, 'rollout_return': 7.650436889592973, 'evaluation': 7.30616189774202} step=52000
# 2023-03-19 16:54.41 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_53000.pt
# 2023-03-19 16:54.41 [info     ] DoubleDQN_online_20230319165402: epoch=53 step=53000 epoch=53 metrics={'time_inference': 0.00011542510986328125, 'time_environment_step': 2.8960466384887694e-05, 'time_sample_batch': 2.5517940521240235e-05, 'time_algorithm_update': 0.0005343761444091796, 'loss': 9.836965101718903, 'time_step': 0.0007189559936523437, 'rollout_return': 7.631770753884362, 'evaluation': 8.03131410942581} step=53000
# 2023-03-19 16:54.42 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_54000.pt
# 2023-03-19 16:54.42 [info     ] DoubleDQN_online_20230319165402: epoch=54 step=54000 epoch=54 metrics={'time_inference': 0.00011594104766845702, 'time_environment_step': 2.9123783111572265e-05, 'time_sample_batch': 2.5764942169189454e-05, 'time_algorithm_update': 0.0005349738597869873, 'loss': 9.989484395503998, 'time_step': 0.0007205376625061035, 'rollout_return': 7.696245318802687, 'evaluation': 9.406586299914853} step=54000
# 2023-03-19 16:54.43 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_55000.pt
# 2023-03-19 16:54.43 [info     ] DoubleDQN_online_20230319165402: epoch=55 step=55000 epoch=55 metrics={'time_inference': 0.00011650466918945313, 'time_environment_step': 2.9338836669921874e-05, 'time_sample_batch': 2.5996446609497072e-05, 'time_algorithm_update': 0.000543407917022705, 'loss': 10.022581315040588, 'time_step': 0.0007300293445587159, 'rollout_return': 7.794944777390347, 'evaluation': 7.938996032028219} step=55000
# 2023-03-19 16:54.43 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_56000.pt
# 2023-03-19 16:54.43 [info     ] DoubleDQN_online_20230319165402: epoch=56 step=56000 epoch=56 metrics={'time_inference': 0.00011527109146118165, 'time_environment_step': 2.90064811706543e-05, 'time_sample_batch': 2.579188346862793e-05, 'time_algorithm_update': 0.000532783031463623, 'loss': 9.672349161840975, 'time_step': 0.0007175590991973877, 'rollout_return': 8.22447647370791, 'evaluation': 9.215756335085718} step=56000
# 2023-03-19 16:54.44 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_57000.pt
# 2023-03-19 16:54.44 [info     ] DoubleDQN_online_20230319165402: epoch=57 step=57000 epoch=57 metrics={'time_inference': 0.00011531352996826172, 'time_environment_step': 2.8957128524780273e-05, 'time_sample_batch': 2.5687694549560548e-05, 'time_algorithm_update': 0.0005325417518615722, 'loss': 10.016761932373047, 'time_step': 0.0007171924114227295, 'rollout_return': 7.902821392273404, 'evaluation': 9.219665680174142} step=57000
# 2023-03-19 16:54.45 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_58000.pt
# 2023-03-19 16:54.45 [info     ] DoubleDQN_online_20230319165402: epoch=58 step=58000 epoch=58 metrics={'time_inference': 0.00011467528343200684, 'time_environment_step': 2.88999080657959e-05, 'time_sample_batch': 2.5531530380249024e-05, 'time_algorithm_update': 0.0005324280261993408, 'loss': 10.087923810962588, 'time_step': 0.0007161467075347901, 'rollout_return': 8.016664862576853, 'evaluation': 9.36395876489669} step=58000
# 2023-03-19 16:54.46 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_59000.pt
# 2023-03-19 16:54.46 [info     ] DoubleDQN_online_20230319165402: epoch=59 step=59000 epoch=59 metrics={'time_inference': 0.00011540675163269043, 'time_environment_step': 2.895212173461914e-05, 'time_sample_batch': 2.5559663772583007e-05, 'time_algorithm_update': 0.0005326249599456787, 'loss': 9.894816967397928, 'time_step': 0.0007171721458435059, 'rollout_return': 7.962465360281312, 'evaluation': 8.789129661492591} step=59000
# 2023-03-19 16:54.46 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_60000.pt
# 2023-03-19 16:54.46 [info     ] DoubleDQN_online_20230319165402: epoch=60 step=60000 epoch=60 metrics={'time_inference': 0.00011514973640441895, 'time_environment_step': 2.8944730758666994e-05, 'time_sample_batch': 2.5382280349731445e-05, 'time_algorithm_update': 0.000532789945602417, 'loss': 9.675359238982201, 'time_step': 0.0007169284820556641, 'rollout_return': 8.178124481299744, 'evaluation': 8.408668521132054} step=60000
# 2023-03-19 16:54.47 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_61000.pt
# 2023-03-19 16:54.47 [info     ] DoubleDQN_online_20230319165402: epoch=61 step=61000 epoch=61 metrics={'time_inference': 0.00011546707153320312, 'time_environment_step': 2.9023170471191406e-05, 'time_sample_batch': 2.5790929794311523e-05, 'time_algorithm_update': 0.0005854361057281494, 'loss': 9.93197762497142, 'time_step': 0.000770390510559082, 'rollout_return': 7.897562984493259, 'evaluation': 9.451713191254795} step=61000
# 2023-03-19 16:54.48 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_62000.pt
# 2023-03-19 16:54.48 [info     ] DoubleDQN_online_20230319165402: epoch=62 step=62000 epoch=62 metrics={'time_inference': 0.0001148838996887207, 'time_environment_step': 2.8963565826416015e-05, 'time_sample_batch': 2.559232711791992e-05, 'time_algorithm_update': 0.0005327060222625733, 'loss': 9.867112414360047, 'time_step': 0.0007167718410491943, 'rollout_return': 8.011421298696147, 'evaluation': 9.371944390401762} step=62000
# 2023-03-19 16:54.49 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_63000.pt
# 2023-03-19 16:54.49 [info     ] DoubleDQN_online_20230319165402: epoch=63 step=63000 epoch=63 metrics={'time_inference': 0.00011503362655639648, 'time_environment_step': 2.876710891723633e-05, 'time_sample_batch': 2.5476217269897462e-05, 'time_algorithm_update': 0.0005330460071563721, 'loss': 9.933407580375672, 'time_step': 0.0007169978618621826, 'rollout_return': 8.585144875580228, 'evaluation': 9.487444672257539} step=63000
# 2023-03-19 16:54.49 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_64000.pt
# 2023-03-19 16:54.49 [info     ] DoubleDQN_online_20230319165402: epoch=64 step=64000 epoch=64 metrics={'time_inference': 0.00011494994163513183, 'time_environment_step': 2.898693084716797e-05, 'time_sample_batch': 2.5467872619628905e-05, 'time_algorithm_update': 0.0005348334312438965, 'loss': 10.073238450162112, 'time_step': 0.000718944787979126, 'rollout_return': 8.199175458378544, 'evaluation': 7.650584631059995} step=64000
# 2023-03-19 16:54.50 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_65000.pt
# 2023-03-19 16:54.50 [info     ] DoubleDQN_online_20230319165402: epoch=65 step=65000 epoch=65 metrics={'time_inference': 0.00011697816848754883, 'time_environment_step': 2.9445886611938475e-05, 'time_sample_batch': 2.5891780853271484e-05, 'time_algorithm_update': 0.0005435402393341065, 'loss': 10.182657180391253, 'time_step': 0.0007307958602905273, 'rollout_return': 8.05716646285799, 'evaluation': 7.719700162552241} step=65000
# 2023-03-19 16:54.51 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_66000.pt
# 2023-03-19 16:54.51 [info     ] DoubleDQN_online_20230319165402: epoch=66 step=66000 epoch=66 metrics={'time_inference': 0.00011527395248413087, 'time_environment_step': 2.9013395309448243e-05, 'time_sample_batch': 2.5719404220581055e-05, 'time_algorithm_update': 0.000535881519317627, 'loss': 10.012285479664802, 'time_step': 0.0007205877304077149, 'rollout_return': 8.440563323292096, 'evaluation': 9.434374551307279} step=66000
# 2023-03-19 16:54.52 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_67000.pt
# 2023-03-19 16:54.52 [info     ] DoubleDQN_online_20230319165402: epoch=67 step=67000 epoch=67 metrics={'time_inference': 0.00011476922035217285, 'time_environment_step': 2.897334098815918e-05, 'time_sample_batch': 2.5745630264282226e-05, 'time_algorithm_update': 0.0005346500873565674, 'loss': 10.081646764159203, 'time_step': 0.0007188761234283447, 'rollout_return': 8.006148641812288, 'evaluation': 6.984067160318223} step=67000
# 2023-03-19 16:54.52 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_68000.pt
# 2023-03-19 16:54.52 [info     ] DoubleDQN_online_20230319165402: epoch=68 step=68000 epoch=68 metrics={'time_inference': 0.00011505603790283203, 'time_environment_step': 2.892279624938965e-05, 'time_sample_batch': 2.5762081146240235e-05, 'time_algorithm_update': 0.0005349218845367432, 'loss': 10.060388112723828, 'time_step': 0.000719331979751587, 'rollout_return': 7.754517893987246, 'evaluation': 9.469776100267687} step=68000
# 2023-03-19 16:54.53 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_69000.pt
# 2023-03-19 16:54.53 [info     ] DoubleDQN_online_20230319165402: epoch=69 step=69000 epoch=69 metrics={'time_inference': 0.00011488556861877442, 'time_environment_step': 2.884840965270996e-05, 'time_sample_batch': 2.5472879409790038e-05, 'time_algorithm_update': 0.0005341839790344239, 'loss': 10.148072521619499, 'time_step': 0.0007180490493774414, 'rollout_return': 8.071075220724289, 'evaluation': 9.448429176643128} step=69000
# 2023-03-19 16:54.54 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_70000.pt
# 2023-03-19 16:54.54 [info     ] DoubleDQN_online_20230319165402: epoch=70 step=70000 epoch=70 metrics={'time_inference': 0.00011721396446228027, 'time_environment_step': 2.9217004776000977e-05, 'time_sample_batch': 2.5917768478393553e-05, 'time_algorithm_update': 0.0005408601760864258, 'loss': 10.33794701552391, 'time_step': 0.0007280583381652832, 'rollout_return': 7.975489641145266, 'evaluation': 8.419541588874587} step=70000
# 2023-03-19 16:54.55 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_71000.pt
# 2023-03-19 16:54.55 [info     ] DoubleDQN_online_20230319165402: epoch=71 step=71000 epoch=71 metrics={'time_inference': 0.00011466240882873535, 'time_environment_step': 2.8823375701904298e-05, 'time_sample_batch': 2.5466442108154295e-05, 'time_algorithm_update': 0.0005335526466369629, 'loss': 10.425710135303438, 'time_step': 0.0007171540260314941, 'rollout_return': 8.022002940862357, 'evaluation': 9.42928480740654} step=71000
# 2023-03-19 16:54.55 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_72000.pt
# 2023-03-19 16:54.55 [info     ] DoubleDQN_online_20230319165402: epoch=72 step=72000 epoch=72 metrics={'time_inference': 0.00011554241180419922, 'time_environment_step': 2.8950929641723633e-05, 'time_sample_batch': 2.5714874267578124e-05, 'time_algorithm_update': 0.0005338904857635498, 'loss': 10.00406794822216, 'time_step': 0.0007188236713409424, 'rollout_return': 7.823674185652051, 'evaluation': 9.266835965667525} step=72000
# 2023-03-19 16:54.56 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_73000.pt
# 2023-03-19 16:54.56 [info     ] DoubleDQN_online_20230319165402: epoch=73 step=73000 epoch=73 metrics={'time_inference': 0.00011507129669189453, 'time_environment_step': 2.88393497467041e-05, 'time_sample_batch': 2.5596857070922853e-05, 'time_algorithm_update': 0.0005314242839813232, 'loss': 10.405238127984106, 'time_step': 0.0007156286239624023, 'rollout_return': 7.7519023792809545, 'evaluation': 8.41638301062741} step=73000
# 2023-03-19 16:54.57 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_74000.pt
# 2023-03-19 16:54.57 [info     ] DoubleDQN_online_20230319165402: epoch=74 step=74000 epoch=74 metrics={'time_inference': 0.00011546492576599121, 'time_environment_step': 2.8888463973999024e-05, 'time_sample_batch': 2.5543689727783204e-05, 'time_algorithm_update': 0.0005320155620574951, 'loss': 10.087866657793523, 'time_step': 0.0007166357040405273, 'rollout_return': 7.861864894899727, 'evaluation': 8.240611069287187} step=74000
# 2023-03-19 16:54.57 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_75000.pt
# 2023-03-19 16:54.57 [info     ] DoubleDQN_online_20230319165402: epoch=75 step=75000 epoch=75 metrics={'time_inference': 0.00011534500122070312, 'time_environment_step': 2.8930187225341797e-05, 'time_sample_batch': 2.5501012802124024e-05, 'time_algorithm_update': 0.0005350735187530518, 'loss': 10.057725729584694, 'time_step': 0.0007195382118225098, 'rollout_return': 7.839169636087909, 'evaluation': 7.85642271795624} step=75000
# 2023-03-19 16:54.58 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_76000.pt
# 2023-03-19 16:54.58 [info     ] DoubleDQN_online_20230319165402: epoch=76 step=76000 epoch=76 metrics={'time_inference': 0.00011573100090026856, 'time_environment_step': 2.9050111770629883e-05, 'time_sample_batch': 2.55892276763916e-05, 'time_algorithm_update': 0.0005332767963409424, 'loss': 10.140580778855831, 'time_step': 0.0007184126377105713, 'rollout_return': 7.869139258982174, 'evaluation': 7.928238775654053} step=76000
# 2023-03-19 16:54.59 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_77000.pt
# 2023-03-19 16:54.59 [info     ] DoubleDQN_online_20230319165402: epoch=77 step=77000 epoch=77 metrics={'time_inference': 0.00011567234992980958, 'time_environment_step': 2.9034852981567384e-05, 'time_sample_batch': 2.564406394958496e-05, 'time_algorithm_update': 0.0005343210697174072, 'loss': 10.016659377098083, 'time_step': 0.0007194211483001709, 'rollout_return': 7.824778860069382, 'evaluation': 9.555206337325677} step=77000
# 2023-03-19 16:55.00 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_78000.pt
# 2023-03-19 16:55.00 [info     ] DoubleDQN_online_20230319165402: epoch=78 step=78000 epoch=78 metrics={'time_inference': 0.00011687612533569336, 'time_environment_step': 2.919626235961914e-05, 'time_sample_batch': 2.601313591003418e-05, 'time_algorithm_update': 0.0005432462692260742, 'loss': 10.079049964427949, 'time_step': 0.0007302334308624267, 'rollout_return': 8.091931857444104, 'evaluation': 8.511124364099668} step=78000
# 2023-03-19 16:55.00 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_79000.pt
# 2023-03-19 16:55.00 [info     ] DoubleDQN_online_20230319165402: epoch=79 step=79000 epoch=79 metrics={'time_inference': 0.00011550951004028321, 'time_environment_step': 2.888298034667969e-05, 'time_sample_batch': 2.5711536407470703e-05, 'time_algorithm_update': 0.0005325059890747071, 'loss': 10.007315072081983, 'time_step': 0.0007172312736511231, 'rollout_return': 7.819832233866122, 'evaluation': 9.450922393667373} step=79000
# 2023-03-19 16:55.01 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_80000.pt
# 2023-03-19 16:55.01 [info     ] DoubleDQN_online_20230319165402: epoch=80 step=80000 epoch=80 metrics={'time_inference': 0.00011502885818481446, 'time_environment_step': 2.9122114181518556e-05, 'time_sample_batch': 2.535247802734375e-05, 'time_algorithm_update': 0.0005310213565826416, 'loss': 10.093233425755054, 'time_step': 0.0007151410579681396, 'rollout_return': 8.050750019455775, 'evaluation': 8.495127528109256} step=80000
# 2023-03-19 16:55.02 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_81000.pt
# 2023-03-19 16:55.02 [info     ] DoubleDQN_online_20230319165402: epoch=81 step=81000 epoch=81 metrics={'time_inference': 0.00011621880531311035, 'time_environment_step': 2.920389175415039e-05, 'time_sample_batch': 2.599811553955078e-05, 'time_algorithm_update': 0.0005394484996795654, 'loss': 9.937598862159998, 'time_step': 0.0007255580425262451, 'rollout_return': 8.235030990518258, 'evaluation': 9.342330487742764} step=81000
# 2023-03-19 16:55.03 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_82000.pt
# 2023-03-19 16:55.03 [info     ] DoubleDQN_online_20230319165402: epoch=82 step=82000 epoch=82 metrics={'time_inference': 0.00011522030830383301, 'time_environment_step': 2.8968095779418946e-05, 'time_sample_batch': 2.5827646255493163e-05, 'time_algorithm_update': 0.0005339148044586181, 'loss': 9.957786611504853, 'time_step': 0.0007186689376831054, 'rollout_return': 8.004117704044186, 'evaluation': 8.390848094455816} step=82000
# 2023-03-19 16:55.03 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_83000.pt
# 2023-03-19 16:55.03 [info     ] DoubleDQN_online_20230319165402: epoch=83 step=83000 epoch=83 metrics={'time_inference': 0.00011569833755493164, 'time_environment_step': 2.901768684387207e-05, 'time_sample_batch': 2.5548219680786132e-05, 'time_algorithm_update': 0.000535381555557251, 'loss': 10.086532166004181, 'time_step': 0.0007202861309051514, 'rollout_return': 7.803098129670004, 'evaluation': 7.855257989420762} step=83000
# 2023-03-19 16:55.04 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_84000.pt
# 2023-03-19 16:55.04 [info     ] DoubleDQN_online_20230319165402: epoch=84 step=84000 epoch=84 metrics={'time_inference': 0.00011492466926574707, 'time_environment_step': 2.897453308105469e-05, 'time_sample_batch': 2.5664567947387694e-05, 'time_algorithm_update': 0.0005332741737365723, 'loss': 9.94707105576992, 'time_step': 0.0007174601554870606, 'rollout_return': 8.117222680291581, 'evaluation': 9.289813607461378} step=84000
# 2023-03-19 16:55.05 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_85000.pt
# 2023-03-19 16:55.05 [info     ] DoubleDQN_online_20230319165402: epoch=85 step=85000 epoch=85 metrics={'time_inference': 0.00011671113967895508, 'time_environment_step': 2.9228448867797852e-05, 'time_sample_batch': 2.5954484939575196e-05, 'time_algorithm_update': 0.0005407044887542724, 'loss': 10.023983320355415, 'time_step': 0.000727393388748169, 'rollout_return': 7.9415993305046255, 'evaluation': 8.401154725185375} step=85000
# 2023-03-19 16:55.06 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_86000.pt
# 2023-03-19 16:55.06 [info     ] DoubleDQN_online_20230319165402: epoch=86 step=86000 epoch=86 metrics={'time_inference': 0.00011570453643798828, 'time_environment_step': 2.8965950012207032e-05, 'time_sample_batch': 2.5731563568115235e-05, 'time_algorithm_update': 0.0005325353145599365, 'loss': 10.029357593432069, 'time_step': 0.0007176058292388916, 'rollout_return': 8.065802758356664, 'evaluation': 8.349450706896793} step=86000
# 2023-03-19 16:55.06 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_87000.pt
# 2023-03-19 16:55.06 [info     ] DoubleDQN_online_20230319165402: epoch=87 step=87000 epoch=87 metrics={'time_inference': 0.00011504936218261719, 'time_environment_step': 2.89614200592041e-05, 'time_sample_batch': 2.5490283966064453e-05, 'time_algorithm_update': 0.0005325403213500976, 'loss': 9.997671395458282, 'time_step': 0.0007167162895202637, 'rollout_return': 7.72142575589787, 'evaluation': 9.288637743583147} step=87000
# 2023-03-19 16:55.07 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_88000.pt
# 2023-03-19 16:55.07 [info     ] DoubleDQN_online_20230319165402: epoch=88 step=88000 epoch=88 metrics={'time_inference': 0.0001155867576599121, 'time_environment_step': 2.9089927673339844e-05, 'time_sample_batch': 2.5502920150756836e-05, 'time_algorithm_update': 0.0005331454277038574, 'loss': 10.164688521385193, 'time_step': 0.0007180337905883789, 'rollout_return': 8.016843952792204, 'evaluation': 9.568205210598085} step=88000
# 2023-03-19 16:55.08 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_89000.pt
# 2023-03-19 16:55.08 [info     ] DoubleDQN_online_20230319165402: epoch=89 step=89000 epoch=89 metrics={'time_inference': 0.00011534595489501953, 'time_environment_step': 2.8895378112792968e-05, 'time_sample_batch': 2.5574207305908204e-05, 'time_algorithm_update': 0.0005328512191772461, 'loss': 10.037215395409614, 'time_step': 0.000717341661453247, 'rollout_return': 8.15069525192718, 'evaluation': 9.481275153476478} step=89000
# 2023-03-19 16:55.09 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_90000.pt
# 2023-03-19 16:55.09 [info     ] DoubleDQN_online_20230319165402: epoch=90 step=90000 epoch=90 metrics={'time_inference': 0.00011508989334106445, 'time_environment_step': 2.8942346572875977e-05, 'time_sample_batch': 2.550172805786133e-05, 'time_algorithm_update': 0.0005326423645019531, 'loss': 9.981072573065758, 'time_step': 0.0007168788909912109, 'rollout_return': 8.06926889861254, 'evaluation': 9.437555391116943} step=90000
# 2023-03-19 16:55.09 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_91000.pt
# 2023-03-19 16:55.09 [info     ] DoubleDQN_online_20230319165402: epoch=91 step=91000 epoch=91 metrics={'time_inference': 0.00011567306518554688, 'time_environment_step': 2.9038190841674805e-05, 'time_sample_batch': 2.5821447372436523e-05, 'time_algorithm_update': 0.000534419059753418, 'loss': 10.16205987393856, 'time_step': 0.000719771146774292, 'rollout_return': 8.134161388916366, 'evaluation': 8.237984471477908} step=91000
# 2023-03-19 16:55.10 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_92000.pt
# 2023-03-19 16:55.10 [info     ] DoubleDQN_online_20230319165402: epoch=92 step=92000 epoch=92 metrics={'time_inference': 0.00011662769317626954, 'time_environment_step': 2.9169797897338866e-05, 'time_sample_batch': 2.5845766067504883e-05, 'time_algorithm_update': 0.0005473325252532959, 'loss': 9.917072053670884, 'time_step': 0.0007338676452636718, 'rollout_return': 8.150475015377317, 'evaluation': 9.257299657222704} step=92000
# 2023-03-19 16:55.11 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_93000.pt
# 2023-03-19 16:55.11 [info     ] DoubleDQN_online_20230319165402: epoch=93 step=93000 epoch=93 metrics={'time_inference': 0.00011537718772888184, 'time_environment_step': 2.8939008712768556e-05, 'time_sample_batch': 2.5634765625e-05, 'time_algorithm_update': 0.0005355157852172852, 'loss': 10.031938158005476, 'time_step': 0.0007201526165008545, 'rollout_return': 8.058284038400123, 'evaluation': 9.374254449043963} step=93000
# 2023-03-19 16:55.12 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_94000.pt
# 2023-03-19 16:55.12 [info     ] DoubleDQN_online_20230319165402: epoch=94 step=94000 epoch=94 metrics={'time_inference': 0.0001156308650970459, 'time_environment_step': 2.925872802734375e-05, 'time_sample_batch': 2.578425407409668e-05, 'time_algorithm_update': 0.0005326638221740723, 'loss': 10.069043305441737, 'time_step': 0.0007181262969970703, 'rollout_return': 8.235663331665616, 'evaluation': 9.500876513858191} step=94000
# 2023-03-19 16:55.12 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_95000.pt
# 2023-03-19 16:55.12 [info     ] DoubleDQN_online_20230319165402: epoch=95 step=95000 epoch=95 metrics={'time_inference': 0.00011496996879577637, 'time_environment_step': 2.893710136413574e-05, 'time_sample_batch': 2.5394916534423827e-05, 'time_algorithm_update': 0.0005318765640258789, 'loss': 10.245079311609269, 'time_step': 0.0007159018516540527, 'rollout_return': 8.054095292704421, 'evaluation': 8.6136956742082} step=95000
# 2023-03-19 16:55.13 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_96000.pt
# 2023-03-19 16:55.13 [info     ] DoubleDQN_online_20230319165402: epoch=96 step=96000 epoch=96 metrics={'time_inference': 0.0001155564785003662, 'time_environment_step': 2.8882265090942384e-05, 'time_sample_batch': 2.5620222091674805e-05, 'time_algorithm_update': 0.0005324554443359375, 'loss': 9.91718260898441, 'time_step': 0.0007172148227691651, 'rollout_return': 7.9274813053255215, 'evaluation': 7.903342942381921} step=96000
# 2023-03-19 16:55.14 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_97000.pt
# 2023-03-19 16:55.14 [info     ] DoubleDQN_online_20230319165402: epoch=97 step=97000 epoch=97 metrics={'time_inference': 0.00011523890495300292, 'time_environment_step': 2.901506423950195e-05, 'time_sample_batch': 2.5670766830444337e-05, 'time_algorithm_update': 0.0005323874950408935, 'loss': 9.883279570817948, 'time_step': 0.0007170248031616211, 'rollout_return': 8.060859863024984, 'evaluation': 8.246783668258136} step=97000
# 2023-03-19 16:55.15 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_98000.pt
# 2023-03-19 16:55.15 [info     ] DoubleDQN_online_20230319165402: epoch=98 step=98000 epoch=98 metrics={'time_inference': 0.00011523675918579102, 'time_environment_step': 2.8846025466918946e-05, 'time_sample_batch': 2.5522470474243166e-05, 'time_algorithm_update': 0.0005303609371185302, 'loss': 10.115535644959659, 'time_step': 0.0007146956920623779, 'rollout_return': 8.15868575048081, 'evaluation': 8.137181055123346} step=98000
# 2023-03-19 16:55.15 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_99000.pt
# 2023-03-19 16:55.15 [info     ] DoubleDQN_online_20230319165402: epoch=99 step=99000 epoch=99 metrics={'time_inference': 0.0001282644271850586, 'time_environment_step': 3.295016288757324e-05, 'time_sample_batch': 3.0216455459594725e-05, 'time_algorithm_update': 0.000599689245223999, 'loss': 10.225755005285144, 'time_step': 0.0008078875541687011, 'rollout_return': 7.726318346323054, 'evaluation': 8.542602101945056} step=99000
# 2023-03-19 16:55.16 [info     ] Model parameters are saved to d3rlpy_logs/DoubleDQN_online_20230319165402/model_100000.pt
# 2023-03-19 16:55.16 [info     ] DoubleDQN_online_20230319165402: epoch=100 step=100000 epoch=100 metrics={'time_inference': 0.00012474513053894044, 'time_environment_step': 3.1851053237915037e-05, 'time_sample_batch': 2.9091835021972655e-05, 'time_algorithm_update': 0.0005989964008331299, 'loss': 10.008148767352104, 'time_step': 0.0008011083602905274, 'rollout_return': 7.4797866775522905, 'evaluation': 7.585868395357925} step=100000

# %%
# save model
ddqn.save_model("d3rlpy_logs/ddqn.pt")

# %%
# reload model
ddqn.build_with_env(env)
ddqn.load_model("d3rlpy_logs/ddqn.pt")
# Out:
# 2023-03-19 16:55.16 [warning  ] Parameters will be reinitialized.

# %% [markdown]
# ### 1.1. Epsilon-Greedy behavior policy
#
# Let's now convert the deterministic policy (i.e., ddqn policy) into a stochastic behavior policy.
#
# We use epsilon-greedy policy to collect logged data using `DiscreteEpsilonGreedyHead`, where the behavior policy greedily takes an action chosen by the deterministic policy with probability $1 - \epsilon$ and takes an action randomly with probability $\epsilon$ as follows.
#
# $$\pi(a | s) := (1 - \epsilon) * \pi_{\mathrm{det}}(a | s) + \epsilon / |\mathcal{A}|,$$
#
# where $a \in \mathcal{A}$ is an action, $s \in \mathcal{S}$ is a state, and $\pi$ is a stochastic policy defined with the (deterministic) behavior policy $\pi_{\mathrm{det}}$.
#
# `SyntheticDataset` has the following arguments:
# - `env`: Basic synthetic environment for RL defined in the previous section.
# - `max_episode_steps`: Maximum number of timesteps in an episode.

# %%
# convert the base ddqn policy into a stochastic data collection policy
from ofrl.policy import DiscreteEpsilonGreedyHead

behavior_policy = DiscreteEpsilonGreedyHead(
    ddqn, 
    n_actions=env.action_space.n,
    epsilon=0.3,  # probability of taking random action
    name="ddqn_epsilon_0.3",
    random_state=random_state,
)

# %%
# collect data
dataset = SyntheticDataset(
    env=env,
    max_episode_steps=env.step_per_episode,
)
logged_dataset = dataset.obtain_episodes(
    behavior_policies=behavior_policy,
    n_trajectories=10000, 
    obtain_info=False,
    random_state=random_state,
)
# Out:
# [obtain_trajectories]:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
logged_dataset
# Out:
# {'size': 100000,
#  'n_trajectories': 10000,
#  'step_per_trajectory': 10,
#  'action_type': 'discrete',
#  'n_actions': 10,
#  'action_dim': None,
#  'action_meaning': None,
#  'action_keys': None,
#  'state_dim': 5,
#  'state_keys': None,
#  'state': array([[ 0.46692103, -0.60091272,  0.12748286,  0.10612129,  0.62719618],
#         [ 0.00305434,  0.25886564,  0.94683458, -0.18441597, -0.04974207],
#         [ 0.09209668,  0.18060315, -0.96557628, -0.16297735,  0.00123719],
#         ...,
#         [-0.08604248, -0.06294277,  0.46005661, -0.31068976,  0.82489678],
#         [ 0.7231203 ,  0.3276454 ,  0.26169129, -0.20740293,  0.5081803 ],
#         [-0.13514496,  0.03110442,  0.26689395, -0.95193514,  0.0579264 ]]),
#  'action': array([6, 1, 5, ..., 8, 6, 5]),
#  'reward': array([ 0.85571015, -0.27916946,  0.43932507, ...,  0.09842358,
#          0.83497698,  0.65557526]),
#  'done': array([0., 0., 0., ..., 0., 0., 1.]),
#  'terminal': array([0., 0., 0., ..., 0., 0., 1.]),
#  'info': {},
#  'pscore': array([0.73, 0.03, 0.73, ..., 0.03, 0.73, 0.03]),
#  'behavior_policy': 'ddqn_epsilon_0.3',
#  'dataset_id': 0}

# %% [markdown]
# ### 1.2. Softmax behavior policy
# We can also use `DiscreteSoftmaxHead` to derive a stochastic behavior policy.
#
# This algorithm uses Q function of the original algorithm, which estimates the value of a given context and action pair (i.e., $(s, a)$) as $Q(s, a)$. \
# Specifically, the behavior policy chooses actions stochastically as:
#
# $$\pi(a \mid s) = \frac{\exp(Q(s, a) / \tau)}{\sum_{a' \in A} \exp(Q(s, a') / \tau)},$$
#
# where $A$ indicates the set discrete actions and $\tau$ is an inverse temperature parameter.

# %%
# convert base ddqn policy into a stochastic data collection policy
from ofrl.policy import DiscreteSoftmaxHead

behavior_policy = DiscreteSoftmaxHead(
    ddqn, 
    n_actions=env.action_space.n,
    tau=1.0,  # temperature parameter
    name="ddqn_softmax_tau_1.0",
    random_state=random_state,
)

# %%
# collect data
dataset = SyntheticDataset(
    env=env,
    max_episode_steps=env.step_per_episode,
)
logged_dataset = dataset.obtain_episodes(
    behavior_policies=behavior_policy, 
    n_trajectories=10000, 
    obtain_info=False,
    random_state=random_state,
)
# Out:
# [obtain_trajectories]:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
logged_dataset
# Out:
# {'size': 100000,
#  'n_trajectories': 10000,
#  'step_per_trajectory': 10,
#  'action_type': 'discrete',
#  'n_actions': 10,
#  'action_dim': None,
#  'action_meaning': None,
#  'action_keys': None,
#  'state_dim': 5,
#  'state_keys': None,
#  'state': array([[ 0.46692103, -0.60091272,  0.12748286,  0.10612129,  0.62719618],
#         [ 0.00305434,  0.25886564,  0.94683458, -0.18441597, -0.04974207],
#         [-0.04232595,  0.00530112, -0.23147397, -0.24222478,  0.94123715],
#         ...,
#         [ 0.33303925, -0.12147387, -0.53166742, -0.44979933,  0.62397057],
#         [-0.07047588, -0.45761772,  0.794374  , -0.38997429,  0.05009166],
#         [-0.10470584, -0.07035717,  0.43358778, -0.35178959,  0.8199587 ]]),
#  'action': array([6, 8, 6, ..., 5, 6, 2]),
#  'reward': array([ 0.85571015, -0.38244575,  0.92561678, ...,  0.59526105,
#          0.89869983,  0.53432782]),
#  'done': array([0., 0., 0., ..., 0., 0., 1.]),
#  'terminal': array([0., 0., 0., ..., 0., 0., 1.]),
#  'info': {},
#  'pscore': array([0.16227005, 0.09263128, 0.11330675, ..., 0.13710368, 0.15752947,
#         0.12084852]),
#  'behavior_policy': 'ddqn_softmax_tau_1.0',
#  'dataset_id': 0}

# %% [markdown]
# For offline RL and OPE procedures, please refer to [examples/quickstart/basic/basic_synthetic_discrete_basic.ipynb](https://github.com/negocia-inc/ofrl/blob/master/examples/quickstart/basic/basic_synthetic_discrete_basic.ipynb).
#
# For more advanced topic in OPE and OPS, please refer to [examples/quickstart/basic/basic_synthetic_discrete_advanced.ipynb](https://github.com/negocia-inc/ofrl/blob/ope/examples/quickstart/basic/basic_synthetic_discrete_advanced.ipynb).

# %% [markdown]
# ## 2. Continuous Action Space
# We also describe the case where a continuous behavior policy is used. \
# Here, we first learn a base deterministic policy in a similar manner with the discrete action case.

# %%
# standardized environment for continuous action
env = gym.make("BasicEnv-continuous-v0")

# %%
# for api compatibility to d3rlpy
env_ = OldGymAPIWrapper(env)

# %%
# learn base deterministic policy for data collection
from d3rlpy.algos import SAC
from d3rlpy.models.encoders import VectorEncoderFactory
from d3rlpy.models.q_functions import MeanQFunctionFactory
from d3rlpy.online.buffers import ReplayBuffer

# model
sac = SAC(
    actor_encoder_factory=VectorEncoderFactory(hidden_units=[30, 30]),
    critic_encoder_factory=VectorEncoderFactory(hidden_units=[30, 30]),
    q_func_factory=MeanQFunctionFactory(),
    use_gpu=torch.cuda.is_available(),
    action_scaler=MinMaxActionScaler(
        minimum=env.action_space.low,   # 0.1
        maximum=env.action_space.high,  # 10
    ),
)
# setup replay buffer
buffer = ReplayBuffer(
    maxlen=10000,
    env=env,
)

# %%
# start training
# skip if there is a pre-trained model
sac.fit_online(
    env_,
    buffer,
    eval_env=env_,
    n_steps=100000,
    n_steps_per_epoch=1000,
    update_start_step=1000,
)
# Out:
# 2023-03-19 16:55.58 [info     ] Directory is created at d3rlpy_logs/SAC_online_20230319165558
# 2023-03-19 16:55.58 [debug    ] Fitting action scaler...       action_scler=min_max
# 2023-03-19 16:55.58 [debug    ] Building model...
# 2023-03-19 16:55.58 [debug    ] Model has been built.
# 2023-03-19 16:55.58 [info     ] Parameters are saved to d3rlpy_logs/SAC_online_20230319165558/params.json params={'action_scaler': {'type': 'min_max', 'params': {'minimum': array([-1., -1., -1.]), 'maximum': array([1., 1., 1.])}}, 'actor_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'actor_learning_rate': 0.0003, 'actor_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'batch_size': 256, 'critic_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'critic_learning_rate': 0.0003, 'critic_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'gamma': 0.99, 'generated_maxlen': 100000, 'initial_temperature': 1.0, 'n_critics': 2, 'n_frames': 1, 'n_steps': 1, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': None, 'tau': 0.005, 'temp_learning_rate': 0.0003, 'temp_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'use_gpu': None, 'algorithm': 'SAC', 'observation_shape': (5,), 'action_size': 3}
#   0%|          | 0/100000 [00:00<?, ?it/s]
# 2023-03-19 16:55.58 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_1000.pt
# 2023-03-19 16:55.58 [info     ] SAC_online_20230319165558: epoch=1 step=1000 epoch=1 metrics={'time_inference': 0.0002364828586578369, 'time_environment_step': 2.7676105499267577e-05, 'time_step': 0.0002729175090789795, 'rollout_return': -0.033474539729213805, 'evaluation': -1.4932619145676216} step=1000
# 2023-03-19 16:56.01 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_2000.pt
# 2023-03-19 16:56.01 [info     ] SAC_online_20230319165558: epoch=2 step=2000 epoch=2 metrics={'time_inference': 0.00025159025192260744, 'time_environment_step': 3.67579460144043e-05, 'time_sample_batch': 7.600712776184083e-05, 'time_algorithm_update': 0.0026094188690185547, 'temp_loss': 4.349937979698181, 'temp': 0.8690366302132606, 'critic_loss': 3.8429091494083405, 'actor_loss': -3.8199393187761306, 'time_step': 0.002991351366043091, 'rollout_return': 0.5395211337982385, 'evaluation': 0.07746846449924055} step=2000
# 2023-03-19 16:56.05 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_3000.pt
# 2023-03-19 16:56.05 [info     ] SAC_online_20230319165558: epoch=3 step=3000 epoch=3 metrics={'time_inference': 0.0002931978702545166, 'time_environment_step': 4.767251014709473e-05, 'time_sample_batch': 0.00010831212997436523, 'time_algorithm_update': 0.0030187861919403077, 'temp_loss': 3.2758879806995393, 'temp': 0.6659549210071564, 'critic_loss': 8.319815588474274, 'actor_loss': -5.418126364231109, 'time_step': 0.0034906930923461915, 'rollout_return': 1.4334034101514879, 'evaluation': 1.9793521422483344} step=3000
# 2023-03-19 16:56.08 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_4000.pt
# 2023-03-19 16:56.08 [info     ] SAC_online_20230319165558: epoch=4 step=4000 epoch=4 metrics={'time_inference': 0.00026778864860534666, 'time_environment_step': 3.861689567565918e-05, 'time_sample_batch': 8.395934104919434e-05, 'time_algorithm_update': 0.0026601030826568606, 'temp_loss': 2.5106595010757444, 'temp': 0.5214695160388947, 'critic_loss': 8.660016809940338, 'actor_loss': -5.2709559783935545, 'time_step': 0.0030689206123352053, 'rollout_return': 1.9049896818960212, 'evaluation': 3.9697241392822074} step=4000
# 2023-03-19 16:56.11 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_5000.pt
# 2023-03-19 16:56.11 [info     ] SAC_online_20230319165558: epoch=5 step=5000 epoch=5 metrics={'time_inference': 0.0002587714195251465, 'time_environment_step': 3.714752197265625e-05, 'time_sample_batch': 8.710241317749024e-05, 'time_algorithm_update': 0.0026133131980895998, 'temp_loss': 1.9413523724079131, 'temp': 0.4136558654308319, 'critic_loss': 6.823398414134979, 'actor_loss': -4.6336660575866695, 'time_step': 0.003014329433441162, 'rollout_return': 2.6169990160052596, 'evaluation': 4.890475816353806} step=5000
# 2023-03-19 16:56.14 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_6000.pt
# 2023-03-19 16:56.14 [info     ] SAC_online_20230319165558: epoch=6 step=6000 epoch=6 metrics={'time_inference': 0.0002551875114440918, 'time_environment_step': 3.610849380493164e-05, 'time_sample_batch': 8.29770565032959e-05, 'time_algorithm_update': 0.0025803256034851074, 'temp_loss': 1.50416874730587, 'temp': 0.3307127809524536, 'critic_loss': 5.072455295801163, 'actor_loss': -3.948247960805893, 'time_step': 0.0029720399379730223, 'rollout_return': 3.036411222424247, 'evaluation': 5.315271204171974} step=6000
# 2023-03-19 16:56.17 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_7000.pt
# 2023-03-19 16:56.17 [info     ] SAC_online_20230319165558: epoch=7 step=7000 epoch=7 metrics={'time_inference': 0.0002563772201538086, 'time_environment_step': 3.6756277084350586e-05, 'time_sample_batch': 8.812689781188964e-05, 'time_algorithm_update': 0.0026069626808166504, 'temp_loss': 1.1585630031228065, 'temp': 0.2658219639360905, 'critic_loss': 3.7414027335643767, 'actor_loss': -3.4189618968963624, 'time_step': 0.0030059051513671876, 'rollout_return': 3.6151175041960553, 'evaluation': 5.835618692574801} step=7000
# 2023-03-19 16:56.20 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_8000.pt
# 2023-03-19 16:56.20 [info     ] SAC_online_20230319165558: epoch=8 step=8000 epoch=8 metrics={'time_inference': 0.00025414085388183593, 'time_environment_step': 3.5946607589721676e-05, 'time_sample_batch': 8.60755443572998e-05, 'time_algorithm_update': 0.0025724899768829346, 'temp_loss': 0.8758798477053642, 'temp': 0.21486417539417743, 'critic_loss': 2.95056850194931, 'actor_loss': -3.043611833572388, 'time_step': 0.0029660322666168215, 'rollout_return': 4.258256386373356, 'evaluation': 5.620535645182121} step=8000
# 2023-03-19 16:56.23 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_9000.pt
# 2023-03-19 16:56.23 [info     ] SAC_online_20230319165558: epoch=9 step=9000 epoch=9 metrics={'time_inference': 0.00025685715675354004, 'time_environment_step': 3.690433502197266e-05, 'time_sample_batch': 9.596133232116699e-05, 'time_algorithm_update': 0.002597384214401245, 'temp_loss': 0.6563228983283043, 'temp': 0.17468291364610194, 'critic_loss': 2.4658126628398893, 'actor_loss': -2.8052320244312288, 'time_step': 0.003004871606826782, 'rollout_return': 4.837835745520497, 'evaluation': 6.469144184720247} step=9000
# 2023-03-19 16:56.26 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_10000.pt
# 2023-03-19 16:56.26 [info     ] SAC_online_20230319165558: epoch=10 step=10000 epoch=10 metrics={'time_inference': 0.0002587766647338867, 'time_environment_step': 3.76734733581543e-05, 'time_sample_batch': 9.98389720916748e-05, 'time_algorithm_update': 0.002623204469680786, 'temp_loss': 0.4897686989307404, 'temp': 0.1426219771653414, 'critic_loss': 2.1872181668281554, 'actor_loss': -2.6376341166496275, 'time_step': 0.003037691593170166, 'rollout_return': 5.256155192677843, 'evaluation': 6.630274908334377} step=10000
# 2023-03-19 16:56.29 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_11000.pt
# 2023-03-19 16:56.29 [info     ] SAC_online_20230319165558: epoch=11 step=11000 epoch=11 metrics={'time_inference': 0.0002575185298919678, 'time_environment_step': 3.70182991027832e-05, 'time_sample_batch': 9.687376022338867e-05, 'time_algorithm_update': 0.0025937838554382325, 'temp_loss': 0.3610503003001213, 'temp': 0.11697762878984212, 'critic_loss': 2.0454670666456223, 'actor_loss': -2.571737075805664, 'time_step': 0.0030043163299560546, 'rollout_return': 5.677016118576476, 'evaluation': 7.224453337873575} step=11000
# 2023-03-19 16:56.32 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_12000.pt
# 2023-03-19 16:56.32 [info     ] SAC_online_20230319165558: epoch=12 step=12000 epoch=12 metrics={'time_inference': 0.0002605130672454834, 'time_environment_step': 3.7421464920043944e-05, 'time_sample_batch': 0.00010051250457763671, 'time_algorithm_update': 0.0026295137405395507, 'temp_loss': 0.25479915882647036, 'temp': 0.0966472784653306, 'critic_loss': 2.025826663017273, 'actor_loss': -2.5654361131191252, 'time_step': 0.0030474591255187987, 'rollout_return': 6.204826334193725, 'evaluation': 7.244836493163096} step=12000
# 2023-03-19 16:56.35 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_13000.pt
# 2023-03-19 16:56.35 [info     ] SAC_online_20230319165558: epoch=13 step=13000 epoch=13 metrics={'time_inference': 0.00025540542602539064, 'time_environment_step': 3.589487075805664e-05, 'time_sample_batch': 9.315013885498047e-05, 'time_algorithm_update': 0.0025793991088867187, 'temp_loss': 0.18138219468295574, 'temp': 0.08030450006574393, 'critic_loss': 2.0307436215877535, 'actor_loss': -2.5694077134132387, 'time_step': 0.0029825668334960936, 'rollout_return': 6.5257519372553086, 'evaluation': 7.538311930376727} step=13000
# 2023-03-19 16:56.38 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_14000.pt
# 2023-03-19 16:56.38 [info     ] SAC_online_20230319165558: epoch=14 step=14000 epoch=14 metrics={'time_inference': 0.0002582242488861084, 'time_environment_step': 3.69570255279541e-05, 'time_sample_batch': 9.77928638458252e-05, 'time_algorithm_update': 0.002599466562271118, 'temp_loss': 0.12980262688547373, 'temp': 0.06723217697441577, 'critic_loss': 2.0693507620096208, 'actor_loss': -2.611973912000656, 'time_step': 0.0030118105411529542, 'rollout_return': 6.666472170951109, 'evaluation': 7.328226435970374} step=14000
# 2023-03-19 16:56.41 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_15000.pt
# 2023-03-19 16:56.41 [info     ] SAC_online_20230319165558: epoch=15 step=15000 epoch=15 metrics={'time_inference': 0.00026228713989257814, 'time_environment_step': 3.8628816604614255e-05, 'time_sample_batch': 0.00010561251640319824, 'time_algorithm_update': 0.002646899938583374, 'temp_loss': 0.09133138486370444, 'temp': 0.05630031033977866, 'critic_loss': 2.1315223993062973, 'actor_loss': -2.661042872428894, 'time_step': 0.0030743248462677003, 'rollout_return': 6.85605908837347, 'evaluation': 7.433566569376988} step=15000
# 2023-03-19 16:56.44 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_16000.pt
# 2023-03-19 16:56.44 [info     ] SAC_online_20230319165558: epoch=16 step=16000 epoch=16 metrics={'time_inference': 0.0002570445537567139, 'time_environment_step': 3.6393642425537106e-05, 'time_sample_batch': 9.631681442260743e-05, 'time_algorithm_update': 0.0025810699462890624, 'temp_loss': 0.058532441614195706, 'temp': 0.04751945823058486, 'critic_loss': 2.1888485511541367, 'actor_loss': -2.7254249355793, 'time_step': 0.0029898884296417237, 'rollout_return': 7.048402333555631, 'evaluation': 7.6589398414053935} step=16000
# 2023-03-19 16:56.48 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_17000.pt
# 2023-03-19 16:56.48 [info     ] SAC_online_20230319165558: epoch=17 step=17000 epoch=17 metrics={'time_inference': 0.00026316070556640627, 'time_environment_step': 3.923583030700684e-05, 'time_sample_batch': 0.00010727858543395996, 'time_algorithm_update': 0.0026436972618103026, 'temp_loss': 0.04414460410922766, 'temp': 0.0404764241874218, 'critic_loss': 2.257765286564827, 'actor_loss': -2.766185502767563, 'time_step': 0.0030737760066986085, 'rollout_return': 7.093324866398242, 'evaluation': 7.797931075964402} step=17000
# 2023-03-19 16:56.51 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_18000.pt
# 2023-03-19 16:56.51 [info     ] SAC_online_20230319165558: epoch=18 step=18000 epoch=18 metrics={'time_inference': 0.00025830507278442385, 'time_environment_step': 3.6873102188110354e-05, 'time_sample_batch': 9.979462623596192e-05, 'time_algorithm_update': 0.0026016037464141844, 'temp_loss': 0.031281537672504786, 'temp': 0.03423547613620758, 'critic_loss': 2.2916624530553817, 'actor_loss': -2.801545613288879, 'time_step': 0.0030159430503845213, 'rollout_return': 7.0516538800297415, 'evaluation': 7.485526143215833} step=18000
# 2023-03-19 16:56.54 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_19000.pt
# 2023-03-19 16:56.54 [info     ] SAC_online_20230319165558: epoch=19 step=19000 epoch=19 metrics={'time_inference': 0.0002637779712677002, 'time_environment_step': 3.940200805664063e-05, 'time_sample_batch': 0.00010748791694641113, 'time_algorithm_update': 0.002703805685043335, 'temp_loss': 0.02166063235606998, 'temp': 0.02899813968874514, 'critic_loss': 2.3386635987758635, 'actor_loss': -2.857440170288086, 'time_step': 0.003134873151779175, 'rollout_return': 6.799870423949127, 'evaluation': 6.791491882242316} step=19000
# 2023-03-19 16:56.57 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_20000.pt
# 2023-03-19 16:56.57 [info     ] SAC_online_20230319165558: epoch=20 step=20000 epoch=20 metrics={'time_inference': 0.0002610485553741455, 'time_environment_step': 3.755927085876465e-05, 'time_sample_batch': 0.00010164809226989747, 'time_algorithm_update': 0.002625122308731079, 'temp_loss': 0.012951613399374765, 'temp': 0.024762007111683488, 'critic_loss': 2.4376871995925904, 'actor_loss': -2.9202920372486116, 'time_step': 0.003045119047164917, 'rollout_return': 6.215623734395515, 'evaluation': 7.495459405622716} step=20000
# 2023-03-19 16:57.00 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_21000.pt
# 2023-03-19 16:57.00 [info     ] SAC_online_20230319165558: epoch=21 step=21000 epoch=21 metrics={'time_inference': 0.0002553699016571045, 'time_environment_step': 3.5953760147094724e-05, 'time_sample_batch': 9.480667114257813e-05, 'time_algorithm_update': 0.0025772809982299804, 'temp_loss': 0.008332598941939068, 'temp': 0.02182553077675402, 'critic_loss': 2.393409481048584, 'actor_loss': -2.905662226200104, 'time_step': 0.0029823558330535887, 'rollout_return': 6.945584321526224, 'evaluation': 7.157594746328071} step=21000
# 2023-03-19 16:57.03 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_22000.pt
# 2023-03-19 16:57.03 [info     ] SAC_online_20230319165558: epoch=22 step=22000 epoch=22 metrics={'time_inference': 0.00025582194328308103, 'time_environment_step': 3.6167144775390625e-05, 'time_sample_batch': 9.517741203308105e-05, 'time_algorithm_update': 0.0025810589790344236, 'temp_loss': 0.008956152092199772, 'temp': 0.01836918376944959, 'critic_loss': 2.3946444318294526, 'actor_loss': -2.924429406642914, 'time_step': 0.002987446069717407, 'rollout_return': 6.24781292401288, 'evaluation': 6.2896170584064475} step=22000
# 2023-03-19 16:57.06 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_23000.pt
# 2023-03-19 16:57.06 [info     ] SAC_online_20230319165558: epoch=23 step=23000 epoch=23 metrics={'time_inference': 0.00025482797622680665, 'time_environment_step': 3.615856170654297e-05, 'time_sample_batch': 9.377169609069825e-05, 'time_algorithm_update': 0.002577519416809082, 'temp_loss': 0.002866486608196283, 'temp': 0.01597187584731728, 'critic_loss': 2.4437288966178894, 'actor_loss': -2.930617871046066, 'time_step': 0.002981348991394043, 'rollout_return': 6.712561156430914, 'evaluation': 7.4906950474997185} step=23000
# 2023-03-19 16:57.09 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_24000.pt
# 2023-03-19 16:57.09 [info     ] SAC_online_20230319165558: epoch=24 step=24000 epoch=24 metrics={'time_inference': 0.00025621771812438964, 'time_environment_step': 3.611254692077637e-05, 'time_sample_batch': 9.364962577819825e-05, 'time_algorithm_update': 0.0025830740928649903, 'temp_loss': -0.0007781930824421579, 'temp': 0.015343537790700794, 'critic_loss': 2.392824130535126, 'actor_loss': -2.9092020564079286, 'time_step': 0.002988147974014282, 'rollout_return': 7.051977940918038, 'evaluation': 7.367621148213686} step=24000
# 2023-03-19 16:57.12 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_25000.pt
# 2023-03-19 16:57.12 [info     ] SAC_online_20230319165558: epoch=25 step=25000 epoch=25 metrics={'time_inference': 0.000257859468460083, 'time_environment_step': 3.698611259460449e-05, 'time_sample_batch': 9.8480224609375e-05, 'time_algorithm_update': 0.0025950062274932863, 'temp_loss': -0.00060685808112612, 'temp': 0.016263816000893713, 'critic_loss': 2.305722843885422, 'actor_loss': -2.9023712642192843, 'time_step': 0.003007704973220825, 'rollout_return': 6.925830383928252, 'evaluation': 6.863947121715926} step=25000
# 2023-03-19 16:57.15 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_26000.pt
# 2023-03-19 16:57.15 [info     ] SAC_online_20230319165558: epoch=26 step=26000 epoch=26 metrics={'time_inference': 0.0002639420032501221, 'time_environment_step': 3.819751739501953e-05, 'time_sample_batch': 0.00010172152519226074, 'time_algorithm_update': 0.0026296322345733644, 'temp_loss': -0.0013053393909722218, 'temp': 0.01775094264186919, 'critic_loss': 2.306961511135101, 'actor_loss': -2.8849239921569825, 'time_step': 0.003053466081619263, 'rollout_return': 6.478273389647379, 'evaluation': 6.807798437732872} step=26000
# 2023-03-19 16:57.18 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_27000.pt
# 2023-03-19 16:57.18 [info     ] SAC_online_20230319165558: epoch=27 step=27000 epoch=27 metrics={'time_inference': 0.00026370644569396974, 'time_environment_step': 3.8740873336791995e-05, 'time_sample_batch': 0.00010141277313232422, 'time_algorithm_update': 0.002702911376953125, 'temp_loss': -0.000835021346792928, 'temp': 0.01880706581659615, 'critic_loss': 2.2459909772872924, 'actor_loss': -2.8504107341766356, 'time_step': 0.0031268141269683836, 'rollout_return': 6.85768838634688, 'evaluation': 7.269309773880176} step=27000
# 2023-03-19 16:57.21 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_28000.pt
# 2023-03-19 16:57.21 [info     ] SAC_online_20230319165558: epoch=28 step=28000 epoch=28 metrics={'time_inference': 0.00025783085823059083, 'time_environment_step': 3.667259216308594e-05, 'time_sample_batch': 9.646773338317871e-05, 'time_algorithm_update': 0.0026033406257629393, 'temp_loss': 4.57114513264969e-05, 'temp': 0.020608752988278866, 'critic_loss': 2.1818550485372543, 'actor_loss': -2.8243062415122986, 'time_step': 0.003013634443283081, 'rollout_return': 7.047092272304225, 'evaluation': 6.983783719756971} step=28000
# 2023-03-19 16:57.25 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_29000.pt
# 2023-03-19 16:57.25 [info     ] SAC_online_20230319165558: epoch=29 step=29000 epoch=29 metrics={'time_inference': 0.00025537872314453124, 'time_environment_step': 3.602838516235352e-05, 'time_sample_batch': 9.087324142456054e-05, 'time_algorithm_update': 0.002593080997467041, 'temp_loss': 0.0010048066634335555, 'temp': 0.018750639541074633, 'critic_loss': 2.1729290869235993, 'actor_loss': -2.8115654644966126, 'time_step': 0.0029942464828491212, 'rollout_return': 6.3595960020596625, 'evaluation': 6.981986445145614} step=29000
# 2023-03-19 16:57.28 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_30000.pt
# 2023-03-19 16:57.28 [info     ] SAC_online_20230319165558: epoch=30 step=30000 epoch=30 metrics={'time_inference': 0.00025947356224060057, 'time_environment_step': 3.7599563598632814e-05, 'time_sample_batch': 9.914660453796387e-05, 'time_algorithm_update': 0.002630302429199219, 'temp_loss': -0.0002889458228019066, 'temp': 0.018525137167423964, 'critic_loss': 2.121417141199112, 'actor_loss': -2.7916779358386994, 'time_step': 0.003046332120895386, 'rollout_return': 6.73113032536291, 'evaluation': 6.807047923002445} step=30000
# 2023-03-19 16:57.31 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_31000.pt
# 2023-03-19 16:57.31 [info     ] SAC_online_20230319165558: epoch=31 step=31000 epoch=31 metrics={'time_inference': 0.00025894498825073243, 'time_environment_step': 3.731536865234375e-05, 'time_sample_batch': 9.659051895141601e-05, 'time_algorithm_update': 0.002640791654586792, 'temp_loss': -0.00015988402759830933, 'temp': 0.018915607461705803, 'critic_loss': 2.1092814528942108, 'actor_loss': -2.7745202662944792, 'time_step': 0.0030531389713287353, 'rollout_return': 6.537285153156026, 'evaluation': 6.86717012652265} step=31000
# 2023-03-19 16:57.34 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_32000.pt
# 2023-03-19 16:57.34 [info     ] SAC_online_20230319165558: epoch=32 step=32000 epoch=32 metrics={'time_inference': 0.00025787615776062014, 'time_environment_step': 3.660869598388672e-05, 'time_sample_batch': 9.279155731201173e-05, 'time_algorithm_update': 0.002613468408584595, 'temp_loss': -0.000351869602498482, 'temp': 0.019715809000656007, 'critic_loss': 2.0338825129270552, 'actor_loss': -2.7401212146282194, 'time_step': 0.0030199458599090576, 'rollout_return': 6.572155947999578, 'evaluation': 6.899159397397608} step=32000
# 2023-03-19 16:57.37 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_33000.pt
# 2023-03-19 16:57.37 [info     ] SAC_online_20230319165558: epoch=33 step=33000 epoch=33 metrics={'time_inference': 0.0002601056098937988, 'time_environment_step': 3.692960739135742e-05, 'time_sample_batch': 9.27431583404541e-05, 'time_algorithm_update': 0.0026352908611297606, 'temp_loss': -0.0007207419663682231, 'temp': 0.02080599537678063, 'critic_loss': 1.9525435537099838, 'actor_loss': -2.7085901620388033, 'time_step': 0.003044503927230835, 'rollout_return': 6.689798500347666, 'evaluation': 6.837504009146883} step=33000
# 2023-03-19 16:57.40 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_34000.pt
# 2023-03-19 16:57.40 [info     ] SAC_online_20230319165558: epoch=34 step=34000 epoch=34 metrics={'time_inference': 0.00026218748092651366, 'time_environment_step': 3.7401676177978514e-05, 'time_sample_batch': 9.963631629943847e-05, 'time_algorithm_update': 0.0026342415809631346, 'temp_loss': 0.0007172963320335839, 'temp': 0.020910960964858533, 'critic_loss': 1.9345281194448471, 'actor_loss': -2.711369683265686, 'time_step': 0.0030533235073089597, 'rollout_return': 6.3779278303772955, 'evaluation': 6.128577834213127} step=34000
# 2023-03-19 16:57.43 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_35000.pt
# 2023-03-19 16:57.43 [info     ] SAC_online_20230319165558: epoch=35 step=35000 epoch=35 metrics={'time_inference': 0.0002590186595916748, 'time_environment_step': 3.691458702087402e-05, 'time_sample_batch': 9.634304046630859e-05, 'time_algorithm_update': 0.0026227564811706545, 'temp_loss': 0.0007980521770368796, 'temp': 0.019280006743967532, 'critic_loss': 1.978403842806816, 'actor_loss': -2.73146511888504, 'time_step': 0.0030345187187194823, 'rollout_return': 6.0797003688136, 'evaluation': 6.2669080594408335} step=35000
# 2023-03-19 16:57.46 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_36000.pt
# 2023-03-19 16:57.46 [info     ] SAC_online_20230319165558: epoch=36 step=36000 epoch=36 metrics={'time_inference': 0.0002624039649963379, 'time_environment_step': 3.725266456604004e-05, 'time_sample_batch': 9.845852851867675e-05, 'time_algorithm_update': 0.0026339468955993654, 'temp_loss': 0.00036997884878655897, 'temp': 0.018165396485477686, 'critic_loss': 1.933272238254547, 'actor_loss': -2.6885091013908387, 'time_step': 0.0030516273975372313, 'rollout_return': 6.061181235323164, 'evaluation': 6.795484373974816} step=36000
# 2023-03-19 16:57.49 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_37000.pt
# 2023-03-19 16:57.49 [info     ] SAC_online_20230319165558: epoch=37 step=37000 epoch=37 metrics={'time_inference': 0.00025805187225341796, 'time_environment_step': 3.659319877624512e-05, 'time_sample_batch': 9.419846534729003e-05, 'time_algorithm_update': 0.0026080195903778075, 'temp_loss': -0.0013572290141164558, 'temp': 0.019357101440429687, 'critic_loss': 1.8368072897195815, 'actor_loss': -2.650308954238892, 'time_step': 0.003016088008880615, 'rollout_return': 6.549112924812164, 'evaluation': 6.835767387223956} step=37000
# 2023-03-19 16:57.52 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_38000.pt
# 2023-03-19 16:57.52 [info     ] SAC_online_20230319165558: epoch=38 step=38000 epoch=38 metrics={'time_inference': 0.00025717997550964356, 'time_environment_step': 3.6114215850830076e-05, 'time_sample_batch': 9.239673614501954e-05, 'time_algorithm_update': 0.002600675106048584, 'temp_loss': -0.0009096269157889765, 'temp': 0.020895769979804753, 'critic_loss': 1.7879167127609252, 'actor_loss': -2.6156909894943237, 'time_step': 0.003005370616912842, 'rollout_return': 6.270557589736426, 'evaluation': 6.221552400107301} step=38000
# 2023-03-19 16:57.55 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_39000.pt
# 2023-03-19 16:57.55 [info     ] SAC_online_20230319165558: epoch=39 step=39000 epoch=39 metrics={'time_inference': 0.0002579782009124756, 'time_environment_step': 3.665423393249512e-05, 'time_sample_batch': 9.502792358398438e-05, 'time_algorithm_update': 0.0026063351631164552, 'temp_loss': -0.0006705932257464155, 'temp': 0.023502152072265744, 'critic_loss': 1.77778262925148, 'actor_loss': -2.5887933473587035, 'time_step': 0.003015247583389282, 'rollout_return': 6.016995822751275, 'evaluation': 6.17052853835477} step=39000
# 2023-03-19 16:57.58 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_40000.pt
# 2023-03-19 16:57.58 [info     ] SAC_online_20230319165558: epoch=40 step=40000 epoch=40 metrics={'time_inference': 0.00025600194931030273, 'time_environment_step': 3.604745864868164e-05, 'time_sample_batch': 9.053897857666015e-05, 'time_algorithm_update': 0.002597736358642578, 'temp_loss': 0.0004346390394784976, 'temp': 0.02322877411916852, 'critic_loss': 1.7045621913671494, 'actor_loss': -2.5358452270030973, 'time_step': 0.002999305486679077, 'rollout_return': 6.023519385824619, 'evaluation': 6.686308873414558} step=40000
# 2023-03-19 16:58.01 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_41000.pt
# 2023-03-19 16:58.01 [info     ] SAC_online_20230319165558: epoch=41 step=41000 epoch=41 metrics={'time_inference': 0.00025727510452270506, 'time_environment_step': 3.659248352050781e-05, 'time_sample_batch': 9.226703643798828e-05, 'time_algorithm_update': 0.0026173861026763915, 'temp_loss': -0.00024637607741169633, 'temp': 0.023264865623787045, 'critic_loss': 1.6375638885498047, 'actor_loss': -2.500835441350937, 'time_step': 0.0030230042934417723, 'rollout_return': 5.945251287657339, 'evaluation': 5.984217478958735} step=41000
# 2023-03-19 16:58.04 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_42000.pt
# 2023-03-19 16:58.04 [info     ] SAC_online_20230319165558: epoch=42 step=42000 epoch=42 metrics={'time_inference': 0.00025566625595092776, 'time_environment_step': 3.5778284072875976e-05, 'time_sample_batch': 8.910584449768067e-05, 'time_algorithm_update': 0.0025890257358551026, 'temp_loss': -0.00031471752151264806, 'temp': 0.024357924358919262, 'critic_loss': 1.5823870037794112, 'actor_loss': -2.477753056049347, 'time_step': 0.0029883856773376466, 'rollout_return': 5.811505569985679, 'evaluation': 5.775747535251385} step=42000
# 2023-03-19 16:58.08 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_43000.pt
# 2023-03-19 16:58.08 [info     ] SAC_online_20230319165558: epoch=43 step=43000 epoch=43 metrics={'time_inference': 0.00026114678382873534, 'time_environment_step': 3.741979598999023e-05, 'time_sample_batch': 9.92116928100586e-05, 'time_algorithm_update': 0.0026379554271698, 'temp_loss': -0.0003922340784702101, 'temp': 0.02415586749278009, 'critic_loss': 1.5678934587240219, 'actor_loss': -2.4671321699619293, 'time_step': 0.0030554170608520508, 'rollout_return': 5.623603719938372, 'evaluation': 6.439170677715282} step=43000
# 2023-03-19 16:58.11 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_44000.pt
# 2023-03-19 16:58.11 [info     ] SAC_online_20230319165558: epoch=44 step=44000 epoch=44 metrics={'time_inference': 0.0002591969966888428, 'time_environment_step': 3.6887645721435544e-05, 'time_sample_batch': 9.649610519409179e-05, 'time_algorithm_update': 0.0026146912574768065, 'temp_loss': 0.00019375615306489635, 'temp': 0.024535631300881506, 'critic_loss': 1.5074731158018113, 'actor_loss': -2.4174231424331665, 'time_step': 0.003026595115661621, 'rollout_return': 5.724161123030055, 'evaluation': 6.128795957754318} step=44000
# 2023-03-19 16:58.14 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_45000.pt
# 2023-03-19 16:58.14 [info     ] SAC_online_20230319165558: epoch=45 step=45000 epoch=45 metrics={'time_inference': 0.00025973844528198243, 'time_environment_step': 3.734040260314941e-05, 'time_sample_batch': 9.61141586303711e-05, 'time_algorithm_update': 0.002634486675262451, 'temp_loss': -0.0016806099176319548, 'temp': 0.026439223298802973, 'critic_loss': 1.4511775234937667, 'actor_loss': -2.3665245909690857, 'time_step': 0.0030471019744873046, 'rollout_return': 6.031303698642774, 'evaluation': 6.425001023101648} step=45000
# 2023-03-19 16:58.17 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_46000.pt
# 2023-03-19 16:58.17 [info     ] SAC_online_20230319165558: epoch=46 step=46000 epoch=46 metrics={'time_inference': 0.00025693821907043455, 'time_environment_step': 3.629851341247559e-05, 'time_sample_batch': 9.084177017211913e-05, 'time_algorithm_update': 0.002602827310562134, 'temp_loss': -0.0005659576677280711, 'temp': 0.02895657695643604, 'critic_loss': 1.4502300722599029, 'actor_loss': -2.368456937074661, 'time_step': 0.003006028413772583, 'rollout_return': 6.392778853524168, 'evaluation': 6.728927961595699} step=46000
# 2023-03-19 16:58.20 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_47000.pt
# 2023-03-19 16:58.20 [info     ] SAC_online_20230319165558: epoch=47 step=47000 epoch=47 metrics={'time_inference': 0.0002573270797729492, 'time_environment_step': 3.676486015319824e-05, 'time_sample_batch': 9.309673309326172e-05, 'time_algorithm_update': 0.00261173152923584, 'temp_loss': -0.00043806371417304035, 'temp': 0.0302953141964972, 'critic_loss': 1.4844411265850068, 'actor_loss': -2.3815913932323456, 'time_step': 0.0030180962085723877, 'rollout_return': 6.313810933067958, 'evaluation': 6.536877410130924} step=47000
# 2023-03-19 16:58.23 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_48000.pt
# 2023-03-19 16:58.23 [info     ] SAC_online_20230319165558: epoch=48 step=48000 epoch=48 metrics={'time_inference': 0.00025994324684143065, 'time_environment_step': 3.7331342697143557e-05, 'time_sample_batch': 9.540081024169922e-05, 'time_algorithm_update': 0.002622491121292114, 'temp_loss': -0.0007694054558960488, 'temp': 0.031180588686838748, 'critic_loss': 1.4910572390556336, 'actor_loss': -2.375573664188385, 'time_step': 0.0030345971584320067, 'rollout_return': 6.606187170722737, 'evaluation': 7.020225651055649} step=48000
# 2023-03-19 16:58.26 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_49000.pt
# 2023-03-19 16:58.26 [info     ] SAC_online_20230319165558: epoch=49 step=49000 epoch=49 metrics={'time_inference': 0.00026482415199279783, 'time_environment_step': 3.821897506713867e-05, 'time_sample_batch': 0.00010275602340698242, 'time_algorithm_update': 0.0026600358486175537, 'temp_loss': 0.00021517357157426885, 'temp': 0.03216965280100703, 'critic_loss': 1.4861696552038193, 'actor_loss': -2.3827988908290862, 'time_step': 0.0030858726501464843, 'rollout_return': 6.8793064472025165, 'evaluation': 7.090805359639144} step=49000
# 2023-03-19 16:58.29 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_50000.pt
# 2023-03-19 16:58.29 [info     ] SAC_online_20230319165558: epoch=50 step=50000 epoch=50 metrics={'time_inference': 0.0002660512924194336, 'time_environment_step': 3.832483291625977e-05, 'time_sample_batch': 0.00010079526901245118, 'time_algorithm_update': 0.002668248414993286, 'temp_loss': -0.00020320002830703744, 'temp': 0.03165503587387502, 'critic_loss': 1.5037513697743417, 'actor_loss': -2.4629250910282137, 'time_step': 0.0030936310291290285, 'rollout_return': 7.168766877640044, 'evaluation': 6.3883443857321485} step=50000
# 2023-03-19 16:58.33 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_51000.pt
# 2023-03-19 16:58.33 [info     ] SAC_online_20230319165558: epoch=51 step=51000 epoch=51 metrics={'time_inference': 0.00029826855659484863, 'time_environment_step': 5.218291282653809e-05, 'time_sample_batch': 0.00013170528411865235, 'time_algorithm_update': 0.0030123796463012694, 'temp_loss': 0.0007426039865531493, 'temp': 0.0312601271327585, 'critic_loss': 1.5931727303266525, 'actor_loss': -2.5919286665916443, 'time_step': 0.0035254948139190672, 'rollout_return': 6.633614339605656, 'evaluation': 6.354819517331846} step=51000
# 2023-03-19 16:58.36 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_52000.pt
# 2023-03-19 16:58.36 [info     ] SAC_online_20230319165558: epoch=52 step=52000 epoch=52 metrics={'time_inference': 0.0002663261890411377, 'time_environment_step': 3.9617300033569336e-05, 'time_sample_batch': 0.0001067502498626709, 'time_algorithm_update': 0.002746615171432495, 'temp_loss': -0.00118277142829902, 'temp': 0.03155614498257637, 'critic_loss': 1.740757707953453, 'actor_loss': -2.702348664999008, 'time_step': 0.003180384874343872, 'rollout_return': 5.934955889712399, 'evaluation': 6.6891150623113145} step=52000
# 2023-03-19 16:58.39 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_53000.pt
# 2023-03-19 16:58.39 [info     ] SAC_online_20230319165558: epoch=53 step=53000 epoch=53 metrics={'time_inference': 0.0002569892406463623, 'time_environment_step': 3.6267280578613285e-05, 'time_sample_batch': 9.187555313110351e-05, 'time_algorithm_update': 0.0025954933166503907, 'temp_loss': -0.0004897224544911296, 'temp': 0.03418572262302041, 'critic_loss': 1.609853067278862, 'actor_loss': -2.6090853414535524, 'time_step': 0.002999704360961914, 'rollout_return': 6.211110433191668, 'evaluation': 5.816147215002563} step=53000
# 2023-03-19 16:58.42 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_54000.pt
# 2023-03-19 16:58.42 [info     ] SAC_online_20230319165558: epoch=54 step=54000 epoch=54 metrics={'time_inference': 0.00025588297843933105, 'time_environment_step': 3.595066070556641e-05, 'time_sample_batch': 8.997058868408203e-05, 'time_algorithm_update': 0.0025843231678009033, 'temp_loss': 0.0008521383201587014, 'temp': 0.03347129603102803, 'critic_loss': 1.4819301924705506, 'actor_loss': -2.5436026046276092, 'time_step': 0.0029850914478302, 'rollout_return': 6.135006826661226, 'evaluation': 6.23752373618652} step=54000
# 2023-03-19 16:58.45 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_55000.pt
# 2023-03-19 16:58.45 [info     ] SAC_online_20230319165558: epoch=55 step=55000 epoch=55 metrics={'time_inference': 0.0002547290325164795, 'time_environment_step': 3.603076934814453e-05, 'time_sample_batch': 8.9247465133667e-05, 'time_algorithm_update': 0.0025782225131988526, 'temp_loss': 0.0009100754319661064, 'temp': 0.03186205858364701, 'critic_loss': 1.4121015346050263, 'actor_loss': -2.5075081095695495, 'time_step': 0.002977031946182251, 'rollout_return': 6.196177827590621, 'evaluation': 7.097929928864206} step=55000
# 2023-03-19 16:58.48 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_56000.pt
# 2023-03-19 16:58.48 [info     ] SAC_online_20230319165558: epoch=56 step=56000 epoch=56 metrics={'time_inference': 0.00025415372848510743, 'time_environment_step': 3.5974740982055666e-05, 'time_sample_batch': 8.901333808898926e-05, 'time_algorithm_update': 0.002569756269454956, 'temp_loss': 0.0008221213331562467, 'temp': 0.03080700137652457, 'critic_loss': 1.391805619060993, 'actor_loss': -2.490481840133667, 'time_step': 0.0029677364826202392, 'rollout_return': 6.538220152222108, 'evaluation': 6.6130875730754415} step=56000
# 2023-03-19 16:58.51 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_57000.pt
# 2023-03-19 16:58.51 [info     ] SAC_online_20230319165558: epoch=57 step=57000 epoch=57 metrics={'time_inference': 0.0002555491924285889, 'time_environment_step': 3.6228179931640625e-05, 'time_sample_batch': 9.150481224060058e-05, 'time_algorithm_update': 0.0025785002708435057, 'temp_loss': 0.0004132219402308692, 'temp': 0.029485543958842755, 'critic_loss': 1.3969721231460572, 'actor_loss': -2.5043081345558167, 'time_step': 0.0029807426929473876, 'rollout_return': 6.3656470040549, 'evaluation': 6.825732484706064} step=57000
# 2023-03-19 16:58.55 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_58000.pt
# 2023-03-19 16:58.55 [info     ] SAC_online_20230319165558: epoch=58 step=58000 epoch=58 metrics={'time_inference': 0.00027765679359436035, 'time_environment_step': 4.50129508972168e-05, 'time_sample_batch': 0.0001227421760559082, 'time_algorithm_update': 0.0028657119274139403, 'temp_loss': 0.0030685461839893833, 'temp': 0.027814938889816402, 'critic_loss': 1.4353747738599778, 'actor_loss': -2.541486694097519, 'time_step': 0.0033344852924346922, 'rollout_return': 6.0710930571352995, 'evaluation': 5.640916387476052} step=58000
# 2023-03-19 16:58.58 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_59000.pt
# 2023-03-19 16:58.58 [info     ] SAC_online_20230319165558: epoch=59 step=59000 epoch=59 metrics={'time_inference': 0.0002641284465789795, 'time_environment_step': 3.949141502380371e-05, 'time_sample_batch': 0.00010416746139526368, 'time_algorithm_update': 0.002668961763381958, 'temp_loss': 0.00034112817293498665, 'temp': 0.024100354466587304, 'critic_loss': 1.5571132390499114, 'actor_loss': -2.5831219193935393, 'time_step': 0.0030974607467651365, 'rollout_return': 5.223978592327858, 'evaluation': 6.211705227547943} step=59000
# 2023-03-19 16:59.01 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_60000.pt
# 2023-03-19 16:59.01 [info     ] SAC_online_20230319165558: epoch=60 step=60000 epoch=60 metrics={'time_inference': 0.0002557251453399658, 'time_environment_step': 3.6021709442138675e-05, 'time_sample_batch': 8.993220329284667e-05, 'time_algorithm_update': 0.0025872318744659425, 'temp_loss': 8.244252156873699e-05, 'temp': 0.02436462775617838, 'critic_loss': 1.4892178032398224, 'actor_loss': -2.4982668216228485, 'time_step': 0.002987986326217651, 'rollout_return': 5.994473651060888, 'evaluation': 6.466648321131087} step=60000
# 2023-03-19 16:59.04 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_61000.pt
# 2023-03-19 16:59.04 [info     ] SAC_online_20230319165558: epoch=61 step=61000 epoch=61 metrics={'time_inference': 0.0002657690048217773, 'time_environment_step': 4.097747802734375e-05, 'time_sample_batch': 0.0001013808250427246, 'time_algorithm_update': 0.0028246381282806396, 'temp_loss': -0.0005941339950659312, 'temp': 0.024566285816952586, 'critic_loss': 1.4635432544946672, 'actor_loss': -2.4683085758686065, 'time_step': 0.0032534706592559815, 'rollout_return': 5.399036769894458, 'evaluation': 5.443202255176111} step=61000
# 2023-03-19 16:59.07 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_62000.pt
# 2023-03-19 16:59.07 [info     ] SAC_online_20230319165558: epoch=62 step=62000 epoch=62 metrics={'time_inference': 0.0002560725212097168, 'time_environment_step': 3.617000579833984e-05, 'time_sample_batch': 9.014010429382324e-05, 'time_algorithm_update': 0.0025875105857849122, 'temp_loss': -0.00045386792041244916, 'temp': 0.02543904106505215, 'critic_loss': 1.441419674217701, 'actor_loss': -2.409057905912399, 'time_step': 0.0029889400005340574, 'rollout_return': 5.6167666195659285, 'evaluation': 6.110578495364321} step=62000
# 2023-03-19 16:59.10 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_63000.pt
# 2023-03-19 16:59.10 [info     ] SAC_online_20230319165558: epoch=63 step=63000 epoch=63 metrics={'time_inference': 0.0002570345401763916, 'time_environment_step': 3.6604642868041994e-05, 'time_sample_batch': 9.405732154846191e-05, 'time_algorithm_update': 0.0025992786884307863, 'temp_loss': 8.030908717773855e-05, 'temp': 0.02502526632323861, 'critic_loss': 1.4458061730861664, 'actor_loss': -2.3874034543037412, 'time_step': 0.00300619912147522, 'rollout_return': 5.676793773731966, 'evaluation': 5.779046568688493} step=63000
# 2023-03-19 16:59.13 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_64000.pt
# 2023-03-19 16:59.13 [info     ] SAC_online_20230319165558: epoch=64 step=64000 epoch=64 metrics={'time_inference': 0.00025681567192077637, 'time_environment_step': 3.639626502990723e-05, 'time_sample_batch': 9.392428398132324e-05, 'time_algorithm_update': 0.0025970222949981687, 'temp_loss': 6.251593108754605e-05, 'temp': 0.02634711889922619, 'critic_loss': 1.4567986352443696, 'actor_loss': -2.3664997501373293, 'time_step': 0.0030032837390899657, 'rollout_return': 5.824533146347494, 'evaluation': 5.9074073511668} step=64000
# 2023-03-19 16:59.16 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_65000.pt
# 2023-03-19 16:59.16 [info     ] SAC_online_20230319165558: epoch=65 step=65000 epoch=65 metrics={'time_inference': 0.0002571854591369629, 'time_environment_step': 3.675436973571777e-05, 'time_sample_batch': 9.421992301940918e-05, 'time_algorithm_update': 0.002593960762023926, 'temp_loss': 0.00044566233992372875, 'temp': 0.025203420447185636, 'critic_loss': 1.4741192866563797, 'actor_loss': -2.3533899948596955, 'time_step': 0.0030012900829315186, 'rollout_return': 5.775201699613318, 'evaluation': 5.944600281103637} step=65000
# 2023-03-19 16:59.19 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_66000.pt
# 2023-03-19 16:59.19 [info     ] SAC_online_20230319165558: epoch=66 step=66000 epoch=66 metrics={'time_inference': 0.0002589387893676758, 'time_environment_step': 3.747630119323731e-05, 'time_sample_batch': 9.884309768676757e-05, 'time_algorithm_update': 0.0026168930530548096, 'temp_loss': 0.00031788100689300337, 'temp': 0.024318350149318577, 'critic_loss': 1.5114619537591933, 'actor_loss': -2.372992446422577, 'time_step': 0.003031954050064087, 'rollout_return': 5.254950697371008, 'evaluation': 4.688804877466256} step=66000
# 2023-03-19 16:59.22 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_67000.pt
# 2023-03-19 16:59.22 [info     ] SAC_online_20230319165558: epoch=67 step=67000 epoch=67 metrics={'time_inference': 0.0002574293613433838, 'time_environment_step': 3.6475419998168946e-05, 'time_sample_batch': 9.369516372680664e-05, 'time_algorithm_update': 0.002592733383178711, 'temp_loss': 0.0006980764737381833, 'temp': 0.02296240979805589, 'critic_loss': 1.5288427735567094, 'actor_loss': -2.3456190497875213, 'time_step': 0.0029993860721588134, 'rollout_return': 5.464669523008735, 'evaluation': 5.67454957947721} step=67000
# 2023-03-19 16:59.25 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_68000.pt
# 2023-03-19 16:59.25 [info     ] SAC_online_20230319165558: epoch=68 step=68000 epoch=68 metrics={'time_inference': 0.00026146507263183593, 'time_environment_step': 3.8062810897827146e-05, 'time_sample_batch': 0.00010148048400878906, 'time_algorithm_update': 0.0026266515254974366, 'temp_loss': -0.0005367715327447513, 'temp': 0.023112725924700497, 'critic_loss': 1.4802994854450227, 'actor_loss': -2.30216814994812, 'time_step': 0.0030476152896881104, 'rollout_return': 5.857993721520538, 'evaluation': 5.90643925841683} step=68000
# 2023-03-19 16:59.29 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_69000.pt
# 2023-03-19 16:59.29 [info     ] SAC_online_20230319165558: epoch=69 step=69000 epoch=69 metrics={'time_inference': 0.00026073670387268065, 'time_environment_step': 3.7981748580932614e-05, 'time_sample_batch': 0.00010062980651855469, 'time_algorithm_update': 0.002620774269104004, 'temp_loss': -0.00041976159723708406, 'temp': 0.02414410245604813, 'critic_loss': 1.4656479498147965, 'actor_loss': -2.292129134654999, 'time_step': 0.0030399670600891114, 'rollout_return': 6.030021485089801, 'evaluation': 7.115473523652537} step=69000
# 2023-03-19 16:59.32 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_70000.pt
# 2023-03-19 16:59.32 [info     ] SAC_online_20230319165558: epoch=70 step=70000 epoch=70 metrics={'time_inference': 0.00026215004920959473, 'time_environment_step': 3.8580417633056643e-05, 'time_sample_batch': 0.00010396695137023926, 'time_algorithm_update': 0.002639082908630371, 'temp_loss': -0.0007754187364480458, 'temp': 0.025545155091211198, 'critic_loss': 1.4756642323732376, 'actor_loss': -2.3081210417747497, 'time_step': 0.003063973426818848, 'rollout_return': 6.2698854578299565, 'evaluation': 6.9317184983381965} step=70000
# 2023-03-19 16:59.35 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_71000.pt
# 2023-03-19 16:59.35 [info     ] SAC_online_20230319165558: epoch=71 step=71000 epoch=71 metrics={'time_inference': 0.0002617037296295166, 'time_environment_step': 3.812980651855469e-05, 'time_sample_batch': 0.00010168123245239258, 'time_algorithm_update': 0.0026477134227752687, 'temp_loss': -0.00018435565847175895, 'temp': 0.026190641021355987, 'critic_loss': 1.436512376308441, 'actor_loss': -2.292929900407791, 'time_step': 0.0030694093704223633, 'rollout_return': 5.993107543819315, 'evaluation': 6.0662627032755205} step=71000
# 2023-03-19 16:59.38 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_72000.pt
# 2023-03-19 16:59.38 [info     ] SAC_online_20230319165558: epoch=72 step=72000 epoch=72 metrics={'time_inference': 0.00025884437561035157, 'time_environment_step': 3.7591457366943356e-05, 'time_sample_batch': 9.659862518310547e-05, 'time_algorithm_update': 0.0026376378536224366, 'temp_loss': 0.0006480532069908804, 'temp': 0.026131379751488566, 'critic_loss': 1.4351989336013793, 'actor_loss': -2.29137534570694, 'time_step': 0.003050264835357666, 'rollout_return': 5.5077558127932615, 'evaluation': 5.748110615743296} step=72000
# 2023-03-19 16:59.41 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_73000.pt
# ...
# 2023-03-19 16:59.53 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_77000.pt
# 2023-03-19 16:59.53 [info     ] SAC_online_20230319165558: epoch=77 step=77000 epoch=77 metrics={'time_inference': 0.00025885653495788573, 'time_environment_step': 3.702998161315918e-05, 'time_sample_batch': 9.50329303741455e-05, 'time_algorithm_update': 0.002602285623550415, 'temp_loss': 0.0010180421822951757, 'temp': 0.023119753107428552, 'critic_loss': 1.444817393541336, 'actor_loss': -2.2649659821987154, 'time_step': 0.0030126242637634275, 'rollout_return': 5.961742301530956, 'evaluation': 5.61461188136933} step=77000
# 2023-03-19 16:59.56 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_78000.pt
# 2023-03-19 16:59.56 [info     ] SAC_online_20230319165558: epoch=78 step=78000 epoch=78 metrics={'time_inference': 0.00025758743286132815, 'time_environment_step': 3.696155548095703e-05, 'time_sample_batch': 9.462594985961914e-05, 'time_algorithm_update': 0.0026037642955780028, 'temp_loss': -0.0009440303309529554, 'temp': 0.02216820230334997, 'critic_loss': 1.4756168456077576, 'actor_loss': -2.284083383560181, 'time_step': 0.0030129363536834717, 'rollout_return': 6.073589141658171, 'evaluation': 6.890396342126207} step=78000
# 2023-03-19 16:59.59 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_79000.pt
# 2023-03-19 16:59.59 [info     ] SAC_online_20230319165558: epoch=79 step=79000 epoch=79 metrics={'time_inference': 0.00026933741569519043, 'time_environment_step': 3.903841972351074e-05, 'time_sample_batch': 9.797525405883789e-05, 'time_algorithm_update': 0.0026377551555633546, 'temp_loss': -0.0037556513405725125, 'temp': 0.028153059620410203, 'critic_loss': 1.5051524839401245, 'actor_loss': -2.3010411717891692, 'time_step': 0.003064054012298584, 'rollout_return': 6.32042813493263, 'evaluation': 6.467792660300094} step=79000
# 2023-03-19 17:00.03 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_80000.pt
# 2023-03-19 17:00.03 [info     ] SAC_online_20230319165558: epoch=80 step=80000 epoch=80 metrics={'time_inference': 0.00027352166175842284, 'time_environment_step': 4.205322265625e-05, 'time_sample_batch': 0.00011210370063781738, 'time_algorithm_update': 0.0028929734230041504, 'temp_loss': -0.000821251053319429, 'temp': 0.031513130528852344, 'critic_loss': 1.5071767513751984, 'actor_loss': -2.2936910214424135, 'time_step': 0.00334268856048584, 'rollout_return': 6.2405649048832625, 'evaluation': 6.684167098250173} step=80000
# 2023-03-19 17:00.06 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_81000.pt
# 2023-03-19 17:00.06 [info     ] SAC_online_20230319165558: epoch=81 step=81000 epoch=81 metrics={'time_inference': 0.0002732203006744385, 'time_environment_step': 4.2414188385009765e-05, 'time_sample_batch': 0.00011385583877563476, 'time_algorithm_update': 0.0027134573459625245, 'temp_loss': 0.00044025499816052613, 'temp': 0.03249554142728448, 'critic_loss': 1.5081754759550094, 'actor_loss': -2.2806680264472963, 'time_step': 0.0031646835803985597, 'rollout_return': 6.4250336559148105, 'evaluation': 6.5221841351274366} step=81000
# 2023-03-19 17:00.09 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_82000.pt
# 2023-03-19 17:00.09 [info     ] SAC_online_20230319165558: epoch=82 step=82000 epoch=82 metrics={'time_inference': 0.0002569928169250488, 'time_environment_step': 3.619837760925293e-05, 'time_sample_batch': 9.09719467163086e-05, 'time_algorithm_update': 0.0025880680084228516, 'temp_loss': 0.0005993782162258867, 'temp': 0.031284328538924454, 'critic_loss': 1.526164422273636, 'actor_loss': -2.3007614755630494, 'time_step': 0.0029913139343261718, 'rollout_return': 6.47797391687117, 'evaluation': 6.679426070303736} step=82000
# 2023-03-19 17:00.12 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_83000.pt
# 2023-03-19 17:00.12 [info     ] SAC_online_20230319165558: epoch=83 step=83000 epoch=83 metrics={'time_inference': 0.0002591543197631836, 'time_environment_step': 3.758549690246582e-05, 'time_sample_batch': 9.671139717102051e-05, 'time_algorithm_update': 0.0026157970428466798, 'temp_loss': 0.00014946526887069922, 'temp': 0.030316758923232556, 'critic_loss': 1.5660293364524842, 'actor_loss': -2.3476274502277374, 'time_step': 0.0030290901660919188, 'rollout_return': 6.3984864880688255, 'evaluation': 6.592303465718371} step=83000
# 2023-03-19 17:00.15 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_84000.pt
# 2023-03-19 17:00.15 [info     ] SAC_online_20230319165558: epoch=84 step=84000 epoch=84 metrics={'time_inference': 0.0002642796039581299, 'time_environment_step': 3.854250907897949e-05, 'time_sample_batch': 0.00010174059867858887, 'time_algorithm_update': 0.0026401777267456056, 'temp_loss': 0.0006089440359064611, 'temp': 0.0301520325448364, 'critic_loss': 1.6008217076063156, 'actor_loss': -2.373380434036255, 'time_step': 0.00306486439704895, 'rollout_return': 6.442334747193086, 'evaluation': 6.848908220594756} step=84000
# 2023-03-19 17:00.18 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_85000.pt
# 2023-03-19 17:00.18 [info     ] SAC_online_20230319165558: epoch=85 step=85000 epoch=85 metrics={'time_inference': 0.0002628145217895508, 'time_environment_step': 3.862142562866211e-05, 'time_sample_batch': 9.900569915771484e-05, 'time_algorithm_update': 0.0026883790493011477, 'temp_loss': 0.0003575679005589336, 'temp': 0.028254704302176834, 'critic_loss': 1.6486562126874924, 'actor_loss': -2.417417241334915, 'time_step': 0.0031090090274810793, 'rollout_return': 6.6418584353726065, 'evaluation': 7.288939202104311} step=85000
# 2023-03-19 17:00.21 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_86000.pt
# 2023-03-19 17:00.21 [info     ] SAC_online_20230319165558: epoch=86 step=86000 epoch=86 metrics={'time_inference': 0.0002558159828186035, 'time_environment_step': 3.60562801361084e-05, 'time_sample_batch': 8.85474681854248e-05, 'time_algorithm_update': 0.0025817534923553466, 'temp_loss': 0.002726916988111043, 'temp': 0.027188327139243483, 'critic_loss': 1.7093887467384339, 'actor_loss': -2.485947333574295, 'time_step': 0.002981095314025879, 'rollout_return': 6.7676711817541415, 'evaluation': 6.8597831371658815} step=86000
# 2023-03-19 17:00.24 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_87000.pt
# 2023-03-19 17:00.24 [info     ] SAC_online_20230319165558: epoch=87 step=87000 epoch=87 metrics={'time_inference': 0.0002560276985168457, 'time_environment_step': 3.600358963012695e-05, 'time_sample_batch': 8.892226219177246e-05, 'time_algorithm_update': 0.0025834794044494627, 'temp_loss': 0.003951090994865808, 'temp': 0.021147975290194153, 'critic_loss': 1.751199714064598, 'actor_loss': -2.551232498407364, 'time_step': 0.0029832782745361328, 'rollout_return': 5.950630635204189, 'evaluation': 5.775633847589797} step=87000
# 2023-03-19 17:00.27 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_88000.pt
# 2023-03-19 17:00.27 [info     ] SAC_online_20230319165558: epoch=88 step=88000 epoch=88 metrics={'time_inference': 0.00025428295135498046, 'time_environment_step': 3.5880327224731444e-05, 'time_sample_batch': 8.81493091583252e-05, 'time_algorithm_update': 0.0025786914825439455, 'temp_loss': -0.0011179620468174107, 'temp': 0.020229569083079695, 'critic_loss': 1.867544058561325, 'actor_loss': -2.6305703871250152, 'time_step': 0.0029759409427642823, 'rollout_return': 5.565372144068627, 'evaluation': 5.5485558983213545} step=88000
# 2023-03-19 17:00.30 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_89000.pt
# 2023-03-19 17:00.30 [info     ] SAC_online_20230319165558: epoch=89 step=89000 epoch=89 metrics={'time_inference': 0.00025500845909118654, 'time_environment_step': 3.5904645919799804e-05, 'time_sample_batch': 8.826923370361328e-05, 'time_algorithm_update': 0.002577772855758667, 'temp_loss': 0.000250273808487691, 'temp': 0.020512749534100296, 'critic_loss': 1.9461375007629393, 'actor_loss': -2.6227949690818786, 'time_step': 0.0029757905006408693, 'rollout_return': 5.59152639855338, 'evaluation': 6.4146074625346445} step=89000
# 2023-03-19 17:00.33 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_90000.pt
# 2023-03-19 17:00.33 [info     ] SAC_online_20230319165558: epoch=90 step=90000 epoch=90 metrics={'time_inference': 0.0002551438808441162, 'time_environment_step': 3.602957725524902e-05, 'time_sample_batch': 8.895039558410644e-05, 'time_algorithm_update': 0.002579385042190552, 'temp_loss': -0.0005773678804980591, 'temp': 0.020765541434288024, 'critic_loss': 1.8913706074953078, 'actor_loss': -2.588660864830017, 'time_step': 0.0029784672260284423, 'rollout_return': 5.969375250693169, 'evaluation': 6.130347728023525} step=90000
# 2023-03-19 17:00.36 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_91000.pt
# 2023-03-19 17:00.36 [info     ] SAC_online_20230319165558: epoch=91 step=91000 epoch=91 metrics={'time_inference': 0.0002547967433929443, 'time_environment_step': 3.5933971405029294e-05, 'time_sample_batch': 8.861327171325683e-05, 'time_algorithm_update': 0.0025779120922088624, 'temp_loss': -0.0013898642212006962, 'temp': 0.022696933317929505, 'critic_loss': 1.8493745242357253, 'actor_loss': -2.546496723175049, 'time_step': 0.0029762516021728516, 'rollout_return': 5.908037521346798, 'evaluation': 6.260548195132059} step=91000
# 2023-03-19 17:00.39 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_92000.pt
# 2023-03-19 17:00.39 [info     ] SAC_online_20230319165558: epoch=92 step=92000 epoch=92 metrics={'time_inference': 0.0002537250518798828, 'time_environment_step': 3.583669662475586e-05, 'time_sample_batch': 8.80131721496582e-05, 'time_algorithm_update': 0.0025757412910461424, 'temp_loss': -0.0026382482519547923, 'temp': 0.02711279154010117, 'critic_loss': 1.7874997568130493, 'actor_loss': -2.4985575573444367, 'time_step': 0.00297217059135437, 'rollout_return': 6.173374688753659, 'evaluation': 6.461555623319586} step=92000
# 2023-03-19 17:00.43 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_93000.pt
# 2023-03-19 17:00.43 [info     ] SAC_online_20230319165558: epoch=93 step=93000 epoch=93 metrics={'time_inference': 0.0002570939064025879, 'time_environment_step': 3.676152229309082e-05, 'time_sample_batch': 9.216856956481934e-05, 'time_algorithm_update': 0.002610515594482422, 'temp_loss': -0.0009770757232181494, 'temp': 0.030936012361198664, 'critic_loss': 1.714068871974945, 'actor_loss': -2.4464125640392305, 'time_step': 0.00301578426361084, 'rollout_return': 6.266056083109635, 'evaluation': 6.95424569143736} step=93000
# 2023-03-19 17:00.46 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_94000.pt
# 2023-03-19 17:00.46 [info     ] SAC_online_20230319165558: epoch=94 step=94000 epoch=94 metrics={'time_inference': 0.00025949788093566895, 'time_environment_step': 3.73528003692627e-05, 'time_sample_batch': 9.765887260437011e-05, 'time_algorithm_update': 0.0026045300960540773, 'temp_loss': 0.0006926529287011363, 'temp': 0.030792903032153845, 'critic_loss': 1.6762275593280793, 'actor_loss': -2.4251269137859346, 'time_step': 0.003018726348876953, 'rollout_return': 6.469395572600371, 'evaluation': 6.824948210525614} step=94000
# 2023-03-19 17:00.49 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_95000.pt
# 2023-03-19 17:00.49 [info     ] SAC_online_20230319165558: epoch=95 step=95000 epoch=95 metrics={'time_inference': 0.00026123714447021486, 'time_environment_step': 3.848123550415039e-05, 'time_sample_batch': 0.00010034775733947754, 'time_algorithm_update': 0.002658071517944336, 'temp_loss': -0.0012886205190152395, 'temp': 0.03211840385384858, 'critic_loss': 1.6393765758275987, 'actor_loss': -2.400720765590668, 'time_step': 0.003078418493270874, 'rollout_return': 6.4578008446767114, 'evaluation': 6.98559558248306} step=95000
# 2023-03-19 17:00.52 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_96000.pt
# 2023-03-19 17:00.52 [info     ] SAC_online_20230319165558: epoch=96 step=96000 epoch=96 metrics={'time_inference': 0.0002629930973052979, 'time_environment_step': 3.784990310668945e-05, 'time_sample_batch': 0.00010092186927795411, 'time_algorithm_update': 0.0026188085079193115, 'temp_loss': 0.00010062127023411449, 'temp': 0.0328064480163157, 'critic_loss': 1.6012874904870986, 'actor_loss': -2.3704399008750916, 'time_step': 0.003040311574935913, 'rollout_return': 6.546468544079852, 'evaluation': 7.070586527676814} step=96000
# 2023-03-19 17:00.55 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_97000.pt
# 2023-03-19 17:00.55 [info     ] SAC_online_20230319165558: epoch=97 step=97000 epoch=97 metrics={'time_inference': 0.00025913047790527345, 'time_environment_step': 3.696441650390625e-05, 'time_sample_batch': 9.662652015686035e-05, 'time_algorithm_update': 0.0026082494258880613, 'temp_loss': -0.0016280843879212625, 'temp': 0.034411625925451515, 'critic_loss': 1.5874007223844528, 'actor_loss': -2.3771509006023406, 'time_step': 0.003020394802093506, 'rollout_return': 6.783995990472285, 'evaluation': 7.381343805116304} step=97000
# 2023-03-19 17:00.58 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_98000.pt
# 2023-03-19 17:00.58 [info     ] SAC_online_20230319165558: epoch=98 step=98000 epoch=98 metrics={'time_inference': 0.0002577784061431885, 'time_environment_step': 3.687262535095215e-05, 'time_sample_batch': 9.395503997802735e-05, 'time_algorithm_update': 0.0026060695648193358, 'temp_loss': -0.002085391678730957, 'temp': 0.03862873950973153, 'critic_loss': 1.5739393768310548, 'actor_loss': -2.381696102142334, 'time_step': 0.0030140280723571777, 'rollout_return': 7.013888939701975, 'evaluation': 7.200117091898247} step=98000
# 2023-03-19 17:01.01 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_99000.pt
# 2023-03-19 17:01.01 [info     ] SAC_online_20230319165558: epoch=99 step=99000 epoch=99 metrics={'time_inference': 0.00027168893814086915, 'time_environment_step': 3.8246631622314455e-05, 'time_sample_batch': 0.0001018366813659668, 'time_algorithm_update': 0.0026358256340026855, 'temp_loss': 0.0008542191186861601, 'temp': 0.040524969588965176, 'critic_loss': 1.5390768492221831, 'actor_loss': -2.3902335369586947, 'time_step': 0.003067658424377441, 'rollout_return': 6.8447553285536085, 'evaluation': 6.942618858096123} step=99000
# 2023-03-19 17:01.04 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319165558/model_100000.pt
# 2023-03-19 17:01.04 [info     ] SAC_online_20230319165558: epoch=100 step=100000 epoch=100 metrics={'time_inference': 0.0002615413665771484, 'time_environment_step': 3.7937164306640626e-05, 'time_sample_batch': 0.00010093426704406738, 'time_algorithm_update': 0.002623650074005127, 'temp_loss': 0.0012977123664750252, 'temp': 0.03748245586454868, 'critic_loss': 1.5460257849693297, 'actor_loss': -2.43335772895813, 'time_step': 0.0030440430641174316, 'rollout_return': 6.604268089041953, 'evaluation': 7.155107780652516} step=100000

# %%
# save model
sac.save_model("d3rlpy_logs/sac.pt")

# %%
# reload model
sac.build_with_env(env)
sac.load_model("d3rlpy_logs/sac.pt")
# Out:
# 2023-03-19 17:01.04 [warning  ] Parameters will be reinitialized.

# %% [markdown]
# ### 2.1. Gaussian behavior policy
#
# Then, we convert a deterministic policy (i.e., greedy action choice of sac policy) into a stochastic policy.
#
# As the action space of `BasicEnv` is bounded, we use `ContinuousTruncatedGaussianHead`. \
# Given the deterministic action $\pi(s)$, this behavior policy samples actions from a truncated gaussian distribution as:
#
# $$a \sim Truncnorm(\pi(s), \sigma),$$
#
# where $\sigma$ indicates the noise level.
#
# Note that, when action space is not bounded, we can use `ContinuousGaussianHead` in a similar manner.

# %%
# convert base ddqn policy into a stochastic data collection policy
from ofrl.policy import ContinuousTruncatedGaussianHead

behavior_policy = ContinuousTruncatedGaussianHead(
    sac, 
    minimum=env.action_space.low,  # lower bound of the action space
    maximum=env.action_space.high,  # upper bound of the action space
    sigma=np.array([1.0]),  # noise level of a gaussian distribution
    name="sac_sigma_1.0",
    random_state=random_state,
)

# %%
# collect data
dataset = SyntheticDataset(
    env=env,
    max_episode_steps=env.step_per_episode,
)
logged_dataset = dataset.obtain_episodes(
    behavior_policies=behavior_policy,
    n_trajectories=10000, 
    obtain_info=False,
    random_state=random_state,
)
# Out:
# [obtain_trajectories]:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
logged_dataset
# Out:
# {'size': 100000,
#  'n_trajectories': 10000,
#  'step_per_trajectory': 10,
#  'action_type': 'continuous',
#  'n_actions': None,
#  'action_dim': 3,
#  'action_meaning': None,
#  'action_keys': None,
#  'state_dim': 5,
#  'state_keys': None,
#  'state': array([[ 0.46692103, -0.60091272,  0.12748286,  0.10612129,  0.62719618],
#         [ 0.23609089, -0.50355012,  0.42207593, -0.65038681,  0.2992445 ],
#         [ 0.0601901 ,  0.45938391,  0.7251643 ,  0.10180222,  0.49911584],
#         ...,
#         [-0.40770033, -0.17992142, -0.70017998, -0.00489399,  0.55779277],
#         [ 0.38460862,  0.36605222, -0.43847431,  0.30099484, -0.65971537],
#         [-0.34752225, -0.56691129, -0.63707318, -0.23699787, -0.30953134]]),
#  'action': array([[ 0.49497776, -0.80337565,  0.89943277],
#         [ 0.41315293,  0.1117985 , -0.44134898],
#         [ 0.68023601,  0.50271535, -0.10667011],
#         ...,
#         [-0.59465215,  0.92170738,  0.13497234],
#         [-0.28329238, -0.23372348,  0.59522857],
#         [-0.06848986,  0.78710364, -0.29546909]]),
#  'reward': array([ 0.53529708,  0.26419521,  0.51816541, ...,  0.0779796 ,
#         -0.34357986, -0.19074574]),
#  'done': array([0., 0., 0., ..., 0., 0., 1.]),
#  'terminal': array([0., 0., 0., ..., 0., 0., 1.]),
#  'info': {},
#  'pscore': array([[0.09885379, 0.09885379, 0.09885379],
#         [0.25108443, 0.25108443, 0.25108443],
#         [0.27544345, 0.27544345, 0.27544345],
#         ...,
#         [0.04859119, 0.04859119, 0.04859119],
#         [0.11385128, 0.11385128, 0.11385128],
#         [0.08344385, 0.08344385, 0.08344385]]),
#  'behavior_policy': 'sac_sigma_1.0',
#  'dataset_id': 0}

# %% [markdown]
# ## 3. Collecting Logged Datasets with Multiple Behavior Policies and Random Seeds
# Finally, we show how to collect logged data by several behavior policies and random seeds.
#
# We show the example in the discrete action case, but the continuous action case can also be handled in a simmilar manner.

# %%
# standardized environment for discrete action
env = gym.make("BasicEnv-discrete-v0")

# %%
# define several behavior policies
behavior_policy_01 = DiscreteEpsilonGreedyHead(
    ddqn, 
    n_actions=env.action_space.n,
    epsilon=0.1,  # probability of taking random action
    name="ddqn_eps_0.1",
    random_state=random_state,
)
behavior_policy_03 = DiscreteEpsilonGreedyHead(
    ddqn, 
    n_actions=env.action_space.n,
    epsilon=0.3,  # probability of taking random action
    name="ddqn_eps_0.3",
    random_state=random_state,
)
behavior_policy_05 = DiscreteEpsilonGreedyHead(
    ddqn, 
    n_actions=env.action_space.n,
    epsilon=0.5,  # probability of taking random action
    name="ddqn_eps_0.5",
    random_state=random_state,
)
behavior_policy_07 = DiscreteEpsilonGreedyHead(
    ddqn, 
    n_actions=env.action_space.n,
    epsilon=0.7,  # probability of taking random action
    name="ddqn_eps_0.7",
    random_state=random_state,
)
behavior_policies = [behavior_policy_01, behavior_policy_03, behavior_policy_05, behavior_policy_07]

# %%
# initialize the dataset class
dataset = SyntheticDataset(
    env=env,
    max_episode_steps=env.step_per_episode,
)

# %%
logged_datasets = dataset.obtain_episodes(
    behavior_policies=behavior_policies,
    n_datasets=2,  # number of random states
    n_trajectories=10000, 
    obtain_info=False,
    random_state=random_state,
)
# Out:
# [obtain_datasets: behavior_policy]:   0%|          | 0/4 [00:00<?, ?it/s]
# [obtain_datasets: dataset_id]:   0%|          | 0/2 [00:00<?, ?it/s]
# [obtain_trajectories]:   0%|          | 0/10000 [00:00<?, ?it/s]
# [obtain_trajectories]:   0%|          | 0/10000 [00:00<?, ?it/s]
# [obtain_datasets: dataset_id]:   0%|          | 0/2 [00:00<?, ?it/s]
# [obtain_trajectories]:   0%|          | 0/10000 [00:00<?, ?it/s]
# [obtain_trajectories]:   0%|          | 0/10000 [00:00<?, ?it/s]
# [obtain_datasets: dataset_id]:   0%|          | 0/2 [00:00<?, ?it/s]
# [obtain_trajectories]:   0%|          | 0/10000 [00:00<?, ?it/s]
# [obtain_trajectories]:   0%|          | 0/10000 [00:00<?, ?it/s]
# [obtain_datasets: dataset_id]:   0%|          | 0/2 [00:00<?, ?it/s]
# [obtain_trajectories]:   0%|          | 0/10000 [00:00<?, ?it/s]
# [obtain_trajectories]:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
logged_dataset = logged_datasets.get(behavior_policy_name=behavior_policies[0].name, dataset_id=0)
logged_dataset
# Out:
# {'size': 100000,
#  'n_trajectories': 10000,
#  'step_per_trajectory': 10,
#  'action_type': 'discrete',
#  'n_actions': 10,
#  'action_dim': None,
#  'action_meaning': None,
#  'action_keys': None,
#  'state_dim': 5,
#  'state_keys': None,
#  'state': array([[ 0.46692103, -0.60091272,  0.12748286,  0.10612129,  0.62719618],
#         [ 0.00305434,  0.25886564,  0.94683458, -0.18441597, -0.04974207],
#         [-0.13005656, -0.04117723,  0.18071338, -0.53347445,  0.81494626],
#         ...,
#         [-0.08940592, -0.45477914,  0.78416664, -0.39813098,  0.10842927],
#         [-0.00321797, -0.09604929,  0.03883138,  0.035452  ,  0.99398162],
#         [ 0.65571773,  0.04974576, -0.48633835, -0.55171117,  0.16324647]]),
#  'action': array([6, 6, 9, ..., 8, 9, 5]),
#  'reward': array([ 0.85571015,  0.80607969,  0.94343082, ..., -0.36078503,
#          1.00888756,  0.46196748]),
#  'done': array([0., 0., 0., ..., 0., 0., 1.]),
#  'terminal': array([0., 0., 0., ..., 0., 0., 1.]),
#  'info': {},
#  'pscore': array([0.91, 0.91, 0.91, ..., 0.01, 0.91, 0.91]),
#  'behavior_policy': 'ddqn_eps_0.1',
#  'dataset_id': 0}

# %% [markdown]
# For offline RL and OPE procedures, please refer to [examples/quickstart/basic/basic_synthetic_continuous_basic.ipynb](https://github.com/negocia-inc/ofrl/blob/ope/examples/quickstart/basic/basic_synthetic_continuous_basic.ipynb).
#
# For advanced topics regarding OPE and OPS, please refer to [examples/quickstart/basic/basic_synthetic_continuous_advanced.ipynb](https://github.com/negocia-inc/ofrl/blob/ope/examples/quickstart/basic/basic_synthetic_continuous_advanced.ipynb).

# %% [markdown]
# ## Reference
#
# - Yuta Saito, Shunsuke Aihara, Megumi Matsutani, and Yusuke Narita. \
# "Open Bandit Dataset and Pipeline: Towards Realistic and Reproducible Off-Policy Evaluation.", 2021.
#
# - Takuma Seno and Michita Imai. \
# "d3rlpy: An Offline Deep Reinforcement Library.", 2021.
#
# - Tuomas Haarnoja, Aurick Zhou, Pieter Abbeel, and Sergey Levine. \
# "Soft Actor-Critic: Off-Policy Maximum Entropy Deep Reinforcement Learning with a Stochastic Actor." 2018.
#
# - Di Wu, Xiujun Chen, Xun Yang, Hao Wang, Qing Tan, Xiaoxun Zhang, Jian Xu, and Kun Gai. \
# "Budget Constrained Bidding by Model-free Reinforcement Learning in Display Advertising.", 2018.
#
# - Jun Zhao, Guang Qiu, Ziyu Guan, Wei Zhao, and Xiaofei He. \
# "Deep Reinforcement Learning for Sponsored Search Real-time Bidding.", 2018.
#
# - Greg Brockman, Vicki Cheung, Ludwig Pettersson, Jonas Schneider, John Schulman, Jie Tang, and Wojciech Zaremba. \
# "OpenAI Gym.", 2016.
#
# - Hado van Hasselt, Arthur Guez, and David Silver. \
# "Deep Reinforcement Learning with Double Q-learning.", 2015.
