# %% [markdown]
# # Quickstart Example of Advanced Off-Policy Evaluation and Selection (Continuous)
# This notebook provides an example of conducting advanced **Off-policy Evaluation (OPE) and Off-Policy Selection OPS)** with a basic synthetic dataset.
#
# This example consists of the following 3 steps:
# 1. Setup, Synthetic Data Generation, and Offline Policy Learning
# 2. Various Off-Policy Evaluation (Policy Value Estimate, Cumulative Distribution Function Estimate)
# 3. Off-Policy Selection
#
# \* This library uses [d3rlpy](https://github.com/takuseno/d3rlpy)'s algorithm implementations of offline rl policies and model-based evaluation.
# \* Also, our implementations of OPE are highly inspired by [Open Bandit Pipeline](https://github.com/st-tech/zr-obp).

# %%
# delete later
# %load_ext autoreload
# %autoreload 2

# %%
# delete later
import warnings
warnings.simplefilter('ignore')

# %%
# delete later
import sys
sys.path.append('../../')
sys.path.append('../../../')

# %%
# import OFRL modules
import ofrl
from basicgym import BasicEnv
from ofrl.dataset import SyntheticDataset
from ofrl.policy import OnlineHead, ContinuousEvalHead
from ofrl.policy import ContinuousTruncatedGaussianHead as TruncatedGaussianHead
from ofrl.ope.online import (
    calc_on_policy_policy_value,
    visualize_on_policy_policy_value,
)
from ofrl.utils import MinMaxScaler, MinMaxActionScaler

# import d3rlpy algorithms
from d3rlpy.algos import RandomPolicy
# from d3rlpy.preprocessing import MinMaxScaler, MinMaxActionScaler
from ofrl.utils import MinMaxScaler, MinMaxActionScaler

# import from other libraries
import gym
import torch
from sklearn.model_selection import train_test_split

# %%
import pickle
from glob import glob
from tqdm import tqdm

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# version
print(ofrl.__version__)
# Out:
# 0.0.0

# %%
# set random state
random_state = 12345

# %%
# log directory
from pathlib import Path
Path("logs/").mkdir(exist_ok=True)

# %% [markdown]
# ## 1. Setup, Synthetic Data Generation, and Offline Policy Learning
# To begin with, we briefly describe the basic usage of the environment.
#
# #### RL setup for Basic Synthetic
# In Basic Synthetic, the objective of the RL agent is to maximize reward
#
# We often formulate this synthetic  problem as the following (Partially Observable) Markov Decision Process ((PO)MDP):
# - `state`: State observation, which may be noisy in POMDPs.
# - `action`:  Indicating the action to presented by the RL agent.
# - `reward`: Reward observation.
#
#
# For more about the environmental configuration and its customization, please refer to [examples/quickstart/basic_synthetic_customize_env.ipynb](https://github.com/negocia-inc/synthetic_reinforcement_learing/blob/ope/examples/quickstart/basic_synthetic_customize_env.ipynb).

# %%
# standardized environment for continuous action
env = gym.make("BasicEnv-continuous-v0")

# %%
# for api compatibility to d3rlpy
from ofrl.utils import OldGymAPIWrapper
env_ = OldGymAPIWrapper(env)

# %% [markdown]
# #### Synthetic Data Generation
# Next, we collect logged data with a behavior policy $\pi_0$:
#
# $$\mathcal{D}_0 := \{ \{ s_t, a_t, s_{t+1}, r_t \}_{t=1}^T \}_{i=1}^n \sim \prod_{i=1}^n d_{s_0}(s_0) \prod_{t=1}^T \pi_0(a_t | s_t) p(s_{t+1} | s_t, a_t) p(r_t | s_t, a_t),$$
#
# where $s_t \in \mathcal{S}$ is the state observed at timestep $t$, $a_t$ is the action chosen by the behavior policy $\pi_0$, and $r_t$ is the reward.
#
# `SyntheticDataset` has the following arguments:
# - `env`: Synthetic environment for RL defined in the previous section.
# - `max_episode_steps`: Maximum number of timesteps in an episode.
#
# For more about the data collection and visualization, please refer to [examples/quickstart/basic_synthetic_data_collection.ipynb](https://github.com/negocia-inc/synthetic_reinforcement_learing/blob/ope/examples/quickstart/basic_synthetic_data_collection.ipynb).

# %%
# behavior policy
from d3rlpy.algos import SAC
from d3rlpy.models.encoders import VectorEncoderFactory
from d3rlpy.models.q_functions import MeanQFunctionFactory
from d3rlpy.online.buffers import ReplayBuffer

# model
sac = SAC(
    actor_encoder_factory=VectorEncoderFactory(hidden_units=[30, 30]),
    critic_encoder_factory=VectorEncoderFactory(hidden_units=[30, 30]),
    q_func_factory=MeanQFunctionFactory(),
    use_gpu=torch.cuda.is_available(),
    action_scaler=MinMaxActionScaler(
        minimum=env_.action_space.low,   #
        maximum=env_.action_space.high,  #
    ),
)
# setup replay buffer
buffer = ReplayBuffer(
    maxlen=10000,
    env=env_,
)

# %%
# start training
# skip if there is a pre-trained model
sac.fit_online(
    env_,
    buffer,
    eval_env=env_,
    n_steps=100000,
    n_steps_per_epoch=1000,
    update_start_step=1000,
)
# Out:
# 2023-03-19 17:10.47 [info     ] Directory is created at d3rlpy_logs/SAC_online_20230319171047
# 2023-03-19 17:10.47 [debug    ] Fitting action scaler...       action_scler=min_max
# 2023-03-19 17:10.47 [debug    ] Building model...
# 2023-03-19 17:10.47 [debug    ] Model has been built.
# 2023-03-19 17:10.47 [info     ] Parameters are saved to d3rlpy_logs/SAC_online_20230319171047/params.json params={'action_scaler': {'type': 'min_max', 'params': {'minimum': array([-1., -1., -1.]), 'maximum': array([1., 1., 1.])}}, 'actor_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'actor_learning_rate': 0.0003, 'actor_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'batch_size': 256, 'critic_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'critic_learning_rate': 0.0003, 'critic_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'gamma': 0.99, 'generated_maxlen': 100000, 'initial_temperature': 1.0, 'n_critics': 2, 'n_frames': 1, 'n_steps': 1, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': None, 'tau': 0.005, 'temp_learning_rate': 0.0003, 'temp_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'use_gpu': None, 'algorithm': 'SAC', 'observation_shape': (5,), 'action_size': 3}
#   0%|          | 0/100000 [00:00<?, ?it/s]
# 2023-03-19 17:10.48 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319171047/model_1000.pt
# 2023-03-19 17:10.48 [info     ] SAC_online_20230319171047: epoch=1 step=1000 epoch=1 metrics={'time_inference': 0.00024523472785949706, 'time_environment_step': 2.9142141342163085e-05, 'time_step': 0.0002841112613677978, 'rollout_return': 0.6105160514390289, 'evaluation': 2.1826691602135435} step=1000
# 2023-03-19 17:10.51 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319171047/model_2000.pt
# 2023-03-19 17:10.51 [info     ] SAC_online_20230319171047: epoch=2 step=2000 epoch=2 metrics={'time_inference': 0.00026655006408691405, 'time_environment_step': 4.368066787719727e-05, 'time_sample_batch': 9.519982337951661e-05, 'time_algorithm_update': 0.002773146390914917, 'temp_loss': 4.336172228813171, 'temp': 0.8686343774795532, 'critic_loss': 4.027332042455673, 'actor_loss': -3.795684388279915, 'time_step': 0.003199281692504883, 'rollout_return': 0.6018283869566553, 'evaluation': 0.16806706524028853} step=2000
# 2023-03-19 17:10.54 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319171047/model_3000.pt
# 2023-03-19 17:10.54 [info     ] SAC_online_20230319171047: epoch=3 step=3000 epoch=3 metrics={'time_inference': 0.0002725815773010254, 'time_environment_step': 4.236459732055664e-05, 'time_sample_batch': 9.765315055847168e-05, 'time_algorithm_update': 0.002730508327484131, 'temp_loss': 3.2589492917060854, 'temp': 0.6657309778928757, 'critic_loss': 8.553955715179443, 'actor_loss': -5.527355741977692, 'time_step': 0.003163100004196167, 'rollout_return': 1.6385864800637944, 'evaluation': 1.8895468522818792} step=3000
# 2023-03-19 17:10.57 [info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319171047/model
[info     ] Model parameters are saved to d3rlpy_logs/SAC_online_20230319171047/model_100000.pt
# 2023-03-19 17:16.02 [info     ] SAC_online_20230319171047: epoch=100 step=100000 epoch=100 metrics={'time_inference': 0.00027390098571777345, 'time_environment_step': 4.240274429321289e-05, 'time_sample_batch': 0.0001081993579864502, 'time_algorithm_update': 0.0027536449432373046, 'temp_loss': 0.00018879775592358782, 'temp': 0.025262938171625136, 'critic_loss': 1.2895916572809218, 'actor_loss': -2.253437366247177, 'time_step': 0.0031997456550598145, 'rollout_return': 6.589826504473691, 'evaluation': 7.222427538798224} step=100000

# %%
# save model
sac.save_model("d3rlpy_logs/sac.pt")

# %%
# reload model
sac.build_with_env(env_)
sac.load_model("d3rlpy_logs/sac.pt")
# Out:
# 2023-03-19 17:16.02 [warning  ] Parameters will be reinitialized.

# %%
behavior_policy = TruncatedGaussianHead(
    sac, 
    minimum=env.action_space.low,
    maximum=env.action_space.high,
    sigma=np.array([1.0]),
    name="sac_sigma_1.0",
    random_state=random_state,
)

# %%
# initialize dataset class
dataset = SyntheticDataset(
    env=env,
    max_episode_steps=env.step_per_episode,
)

# %%
# collect logged data by a behavior policy
# skip if there is a preserved logged dataset
train_logged_dataset = dataset.obtain_episodes(
    behavior_policies=behavior_policy, 
    n_trajectories=10000, 
    obtain_info=False,
    random_state=random_state,
)
test_logged_dataset = dataset.obtain_episodes(
    behavior_policies=behavior_policy, 
    n_trajectories=10000, 
    obtain_info=False,
    random_state=random_state + 1,
)
# Out:
# [obtain_trajectories]:   0%|          | 0/10000 [00:00<?, ?it/s]
# [obtain_trajectories]:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
with open("logs/train_dataset_continuous_sac.pkl", "wb") as f:
    pickle.dump(train_logged_dataset, f)
with open("logs/test_dataset_continuous_sac.pkl", "wb") as f:
    pickle.dump(test_logged_dataset, f)

# %%
with open("logs/train_dataset_continuous_sac.pkl", "rb") as f:
    train_logged_dataset = pickle.load(f)
with open("logs/test_dataset_continuous_sac.pkl", "rb") as f:
    test_logged_dataset = pickle.load(f)

# %% [markdown]
# #### Offline Policy Learning
# Here, we learn several "candidate" policies to be evaluated and selected using [d3rlpy](https://github.com/takuseno/d3rlpy)'s algorithm implementation.
#
# For more about the offline RL procedure, please refer to [examples/quickstart/basic/basic_synthetic_discrete_basic.ipynb](https://github.com/negocia-inc/ofrl/blob/ope/examples/quickstart/basic/basic_synthetic_discrete_basic.ipynb).

# %%
# import modules from d3rlpy
from d3rlpy.dataset import MDPDataset
from d3rlpy.algos import CQL, TD3PlusBC, IQL
# transform offline dataset for d3rlpy
offlinerl_dataset = MDPDataset(
    observations=train_logged_dataset["state"],
    actions=train_logged_dataset["action"],
    rewards=train_logged_dataset["reward"],
    terminals=train_logged_dataset["done"],
    episode_terminals=train_logged_dataset["done"],
)
train_episodes, test_episodes = train_test_split(offlinerl_dataset, test_size=0.2, random_state=random_state)

# %%
# Use Conservative Q-Learning (CQL) policy
# base policy 1: hidden_units = [30, 30]
cql_b1 = CQL(
    actor_encoder_factory=VectorEncoderFactory(hidden_units=[30, 30]),
    critic_encoder_factory=VectorEncoderFactory(hidden_units=[30, 30]),
    q_func_factory=MeanQFunctionFactory(),
    use_gpu=torch.cuda.is_available(),
    action_scaler=MinMaxActionScaler(
        minimum=env_.action_space.low,  # minimum value that policy can take
        maximum=env_.action_space.high,  # maximum value that policy can take
    )
)

# %%
cql_b1.fit(
    train_episodes,
    eval_episodes=test_episodes,
    n_steps=10000,
    scorers={},
)
# Out:
# 2023-03-19 17:18.06 [debug    ] RandomIterator is selected.
# 2023-03-19 17:18.06 [info     ] Directory is created at d3rlpy_logs/CQL_20230319171806
# 2023-03-19 17:18.06 [debug    ] Fitting action scaler...       action_scaler=min_max
# 2023-03-19 17:18.06 [debug    ] Building models...
# 2023-03-19 17:18.06 [debug    ] Models have been built.
# 2023-03-19 17:18.06 [info     ] Parameters are saved to d3rlpy_logs/CQL_20230319171806/params.json params={'action_scaler': {'type': 'min_max', 'params': {'minimum': array([-1., -1., -1.]), 'maximum': array([1., 1., 1.])}}, 'actor_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'actor_learning_rate': 0.0001, 'actor_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'alpha_learning_rate': 0.0001, 'alpha_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'alpha_threshold': 10.0, 'batch_size': 256, 'conservative_weight': 5.0, 'critic_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'critic_learning_rate': 0.0003, 'critic_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'gamma': 0.99, 'generated_maxlen': 100000, 'initial_alpha': 1.0, 'initial_temperature': 1.0, 'n_action_samples': 10, 'n_critics': 2, 'n_frames': 1, 'n_steps': 1, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': None, 'soft_q_backup': False, 'tau': 0.005, 'temp_learning_rate': 0.0001, 'temp_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'use_gpu': None, 'algorithm': 'CQL', 'observation_shape': (5,), 'action_size': 3}
# Epoch 1/1:   0%|          | 0/10000 [00:00<?, ?it/s]
# 2023-03-19 17:20.19 [info     ] CQL_20230319171806: epoch=1 step=10000 epoch=1 metrics={'time_sample_batch': 0.0005124696969985962, 'time_algorithm_update': 0.012326540660858155, 'temp_loss': 3.1159336638331414, 'temp': 0.6510783038407564, 'alpha_loss': -29.533175661849974, 'alpha': 1.7942726212739943, 'critic_loss': 32.754433145141604, 'actor_loss': -4.746289656090736, 'time_step': 0.013200031185150146} step=10000
# 2023-03-19 17:20.19 [info     ] Model parameters are saved to d3rlpy_logs/CQL_20230319171806/model_10000.pt
# [(1,
#   {'time_sample_batch': 0.0005124696969985962,
#    'time_algorithm_update': 0.012326540660858155,
#    'temp_loss': 3.1159336638331414,
#    'temp': 0.6510783038407564,
#    'alpha_loss': -29.533175661849974,
#    'alpha': 1.7942726212739943,
#    'critic_loss': 32.754433145141604,
#    'actor_loss': -4.746289656090736,
#    'time_step': 0.013200031185150146})]

# %%
# save model
cql_b1.save_model("d3rlpy_logs/cql_continuous_b1.pt")

# %%
# reload model
cql_b1.build_with_env(env)
cql_b1.load_model("d3rlpy_logs/cql_continuous_b1.pt")
# Out:
# 2023-03-19 17:20.19 [warning  ] Parameters will be reinitialized.

# %%
# Use Conservative Q-Learning (CQL) policy
# base policy 2: hidden_units = [100]
cql_b2 = CQL(
    actor_encoder_factory=VectorEncoderFactory(hidden_units=[100]),
    critic_encoder_factory=VectorEncoderFactory(hidden_units=[100]),
    q_func_factory=MeanQFunctionFactory(),
    use_gpu=torch.cuda.is_available(),
    action_scaler=MinMaxActionScaler(
        minimum=env_.action_space.low,  # minimum value that policy can take
        maximum=env_.action_space.high,  # maximum value that policy can take
    )
)

# %%
cql_b2.fit(
    train_episodes,
    eval_episodes=test_episodes,
    n_steps=10000,
    scorers={},
)
# Out:
# 2023-03-19 17:20.19 [debug    ] RandomIterator is selected.
# 2023-03-19 17:20.19 [info     ] Directory is created at d3rlpy_logs/CQL_20230319172019
# 2023-03-19 17:20.19 [debug    ] Fitting action scaler...       action_scaler=min_max
# 2023-03-19 17:20.19 [debug    ] Building models...
# 2023-03-19 17:20.19 [debug    ] Models have been built.
# 2023-03-19 17:20.19 [info     ] Parameters are saved to d3rlpy_logs/CQL_20230319172019/params.json params={'action_scaler': {'type': 'min_max', 'params': {'minimum': array([-1., -1., -1.]), 'maximum': array([1., 1., 1.])}}, 'actor_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [100], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'actor_learning_rate': 0.0001, 'actor_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'alpha_learning_rate': 0.0001, 'alpha_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'alpha_threshold': 10.0, 'batch_size': 256, 'conservative_weight': 5.0, 'critic_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [100], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'critic_learning_rate': 0.0003, 'critic_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'gamma': 0.99, 'generated_maxlen': 100000, 'initial_alpha': 1.0, 'initial_temperature': 1.0, 'n_action_samples': 10, 'n_critics': 2, 'n_frames': 1, 'n_steps': 1, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': None, 'soft_q_backup': False, 'tau': 0.005, 'temp_learning_rate': 0.0001, 'temp_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'use_gpu': None, 'algorithm': 'CQL', 'observation_shape': (5,), 'action_size': 3}
# Epoch 1/1:   0%|          | 0/10000 [00:00<?, ?it/s]
# 2023-03-19 17:22.28 [info     ] CQL_20230319172019: epoch=1 step=10000 epoch=1 metrics={'time_sample_batch': 0.0005252432107925415, 'time_algorithm_update': 0.011867323136329651, 'temp_loss': 3.114458291578293, 'temp': 0.650917969289422, 'alpha_loss': -29.53718774547577, 'alpha': 1.7945163571596146, 'critic_loss': 32.84319613227844, 'actor_loss': -4.822826522779465, 'time_step': 0.012767564678192138} step=10000
# 2023-03-19 17:22.28 [info     ] Model parameters are saved to d3rlpy_logs/CQL_20230319172019/model_10000.pt
# [(1,
#   {'time_sample_batch': 0.0005252432107925415,
#    'time_algorithm_update': 0.011867323136329651,
#    'temp_loss': 3.114458291578293,
#    'temp': 0.650917969289422,
#    'alpha_loss': -29.53718774547577,
#    'alpha': 1.7945163571596146,
#    'critic_loss': 32.84319613227844,
#    'actor_loss': -4.822826522779465,
#    'time_step': 0.012767564678192138})]

# %%
# save model
cql_b2.save_model("d3rlpy_logs/cql_continuous_b2.pt")

# %%
# reload model
cql_b2.build_with_env(env)
cql_b2.load_model("d3rlpy_logs/cql_continuous_b2.pt")
# Out:
# 2023-03-19 17:22.28 [warning  ] Parameters will be reinitialized.

# %%
# Use Conservative Q-Learning (CQL) policy
# base policy 3: hidden_units = [50, 10]
cql_b3 = CQL(
    actor_encoder_factory=VectorEncoderFactory(hidden_units=[50, 10]),
    critic_encoder_factory=VectorEncoderFactory(hidden_units=[50, 10]),
    q_func_factory=MeanQFunctionFactory(),
    use_gpu=torch.cuda.is_available(),
    action_scaler=MinMaxActionScaler(
        minimum=env_.action_space.low,  # minimum value that policy can take
        maximum=env_.action_space.high,  # maximum value that policy can take
    )
)

# %%
cql_b3.fit(
    train_episodes,
    eval_episodes=test_episodes,
    n_steps=10000,
    scorers={},
)
# Out:
# 2023-03-19 17:22.28 [debug    ] RandomIterator is selected.
# 2023-03-19 17:22.28 [info     ] Directory is created at d3rlpy_logs/CQL_20230319172228
# 2023-03-19 17:22.28 [debug    ] Fitting action scaler...       action_scaler=min_max
# 2023-03-19 17:22.28 [debug    ] Building models...
# 2023-03-19 17:22.28 [debug    ] Models have been built.
# 2023-03-19 17:22.28 [info     ] Parameters are saved to d3rlpy_logs/CQL_20230319172228/params.json params={'action_scaler': {'type': 'min_max', 'params': {'minimum': array([-1., -1., -1.]), 'maximum': array([1., 1., 1.])}}, 'actor_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [50, 10], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'actor_learning_rate': 0.0001, 'actor_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'alpha_learning_rate': 0.0001, 'alpha_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'alpha_threshold': 10.0, 'batch_size': 256, 'conservative_weight': 5.0, 'critic_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [50, 10], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'critic_learning_rate': 0.0003, 'critic_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'gamma': 0.99, 'generated_maxlen': 100000, 'initial_alpha': 1.0, 'initial_temperature': 1.0, 'n_action_samples': 10, 'n_critics': 2, 'n_frames': 1, 'n_steps': 1, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': None, 'soft_q_backup': False, 'tau': 0.005, 'temp_learning_rate': 0.0001, 'temp_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'use_gpu': None, 'algorithm': 'CQL', 'observation_shape': (5,), 'action_size': 3}
# Epoch 1/1:   0%|          | 0/10000 [00:00<?, ?it/s]
# 2023-03-19 17:24.29 [info     ] CQL_20230319172228: epoch=1 step=10000 epoch=1 metrics={'time_sample_batch': 0.0005103677034378051, 'time_algorithm_update': 0.01116201651096344, 'temp_loss': 3.120572362613678, 'temp': 0.6512282829582691, 'alpha_loss': -29.525145965194703, 'alpha': 1.7938846231102943, 'critic_loss': 32.5520502954483, 'actor_loss': -4.583867635452747, 'time_step': 0.012033784866333008} step=10000
# 2023-03-19 17:24.29 [info     ] Model parameters are saved to d3rlpy_logs/CQL_20230319172228/model_10000.pt
# [(1,
#   {'time_sample_batch': 0.0005103677034378051,
#    'time_algorithm_update': 0.01116201651096344,
#    'temp_loss': 3.120572362613678,
#    'temp': 0.6512282829582691,
#    'alpha_loss': -29.525145965194703,
#    'alpha': 1.7938846231102943,
#    'critic_loss': 32.5520502954483,
#    'actor_loss': -4.583867635452747,
#    'time_step': 0.012033784866333008})]

# %%
# save model
cql_b3.save_model("d3rlpy_logs/cql_continuous_b3.pt")

# %%
# reload model
cql_b3.build_with_env(env)
cql_b3.load_model("d3rlpy_logs/cql_continuous_b3.pt")
# Out:
# 2023-03-19 17:27.55 [warning  ] Parameters will be reinitialized.

# %%
# Use TD3 + Behavior Cloning (TD3+BC) policy
# base policy 1: hidden_units = [30, 30]
td3bc_b1 = TD3PlusBC(
    actor_encoder_factory=VectorEncoderFactory(hidden_units=[30, 30]),
    critic_encoder_factory=VectorEncoderFactory(hidden_units=[30, 30]),
    q_func_factory=MeanQFunctionFactory(),
    use_gpu=torch.cuda.is_available(),
    action_scaler=MinMaxActionScaler(
        minimum=env_.action_space.low,  # minimum value that policy can take
        maximum=env_.action_space.high,  # maximum value that policy can take
    )
)

# %%
td3bc_b1.fit(
    train_episodes,
    eval_episodes=test_episodes,
    n_steps=10000,
    scorers={},
)
# Out:
# 2023-03-19 17:31.55 [debug    ] RandomIterator is selected.
# 2023-03-19 17:31.55 [info     ] Directory is created at d3rlpy_logs/TD3PlusBC_20230319173155
# 2023-03-19 17:31.55 [debug    ] Fitting scaler...              scaler=standard
# 2023-03-19 17:31.55 [debug    ] Fitting action scaler...       action_scaler=min_max
# 2023-03-19 17:31.55 [debug    ] Building models...
# 2023-03-19 17:31.55 [debug    ] Models have been built.
# 2023-03-19 17:31.56 [info     ] Parameters are saved to d3rlpy_logs/TD3PlusBC_20230319173155/params.json params={'action_scaler': {'type': 'min_max', 'params': {'minimum': array([-1., -1., -1.]), 'maximum': array([1., 1., 1.])}}, 'actor_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'actor_learning_rate': 0.0003, 'actor_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'alpha': 2.5, 'batch_size': 256, 'critic_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'critic_learning_rate': 0.0003, 'critic_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'gamma': 0.99, 'generated_maxlen': 100000, 'n_critics': 2, 'n_frames': 1, 'n_steps': 1, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': {'type': 'standard', 'params': {'mean': array([[ 0.03089025, -0.02355411, -0.01228593, -0.11395172,  0.03687143]]), 'std': array([[0.32946623, 0.38837454, 0.57328227, 0.40426394, 0.48221455]]), 'eps': 0.001}}, 'target_smoothing_clip': 0.5, 'target_smoothing_sigma': 0.2, 'tau': 0.005, 'update_actor_interval': 2, 'use_gpu': None, 'algorithm': 'TD3PlusBC', 'observation_shape': (5,), 'action_size': 3}
# Epoch 1/1:   0%|          | 0/10000 [00:00<?, ?it/s]
# 2023-03-19 17:32.15 [info     ] TD3PlusBC_20230319173155: epoch=1 step=10000 epoch=1 metrics={'time_sample_batch': 0.00045307953357696533, 'time_algorithm_update': 0.001384119939804077, 'critic_loss': 2.3149001921715215, 'actor_loss': -2.0426722652196885, 'time_step': 0.0019172434329986572} step=10000
# 2023-03-19 17:32.15 [info     ] Model parameters are saved to d3rlpy_logs/TD3PlusBC_20230319173155/model_10000.pt
# [(1,
#   {'time_sample_batch': 0.00045307953357696533,
#    'time_algorithm_update': 0.001384119939804077,
#    'critic_loss': 2.3149001921715215,
#    'actor_loss': -2.0426722652196885,
#    'time_step': 0.0019172434329986572})]

# %%
# save model
td3bc_b1.save_model("d3rlpy_logs/td3bc_continuous_b1.pt")

# %%
# reload model
td3bc_b1.build_with_env(env)
td3bc_b1.load_model("d3rlpy_logs/td3bc_continuous_b1.pt")
# Out:
# 2023-03-19 17:35.55 [warning  ] Parameters will be reinitialized.

# %%
# Use TD3 + Behavior Cloning (TD3+BC) policy
# base policy 2: hidden_units = [100]
td3bc_b2 = TD3PlusBC(
    actor_encoder_factory=VectorEncoderFactory(hidden_units=[100]),
    critic_encoder_factory=VectorEncoderFactory(hidden_units=[100]),
    q_func_factory=MeanQFunctionFactory(),
    use_gpu=torch.cuda.is_available(),
    action_scaler=MinMaxActionScaler(
        minimum=env_.action_space.low,  # minimum value that policy can take
        maximum=env_.action_space.high,  # maximum value that policy can take
    )
)

# %%
td3bc_b2.fit(
    train_episodes,
    eval_episodes=test_episodes,
    n_steps=10000,
    scorers={},
)
# Out:
# 2023-03-19 17:39.55 [debug    ] RandomIterator is selected.
# 2023-03-19 17:39.55 [info     ] Directory is created at d3rlpy_logs/TD3PlusBC_20230319173955
# 2023-03-19 17:39.55 [debug    ] Fitting scaler...              scaler=standard
# 2023-03-19 17:39.55 [debug    ] Fitting action scaler...       action_scaler=min_max
# 2023-03-19 17:39.55 [debug    ] Building models...
# 2023-03-19 17:39.55 [debug    ] Models have been built.
# 2023-03-19 17:39.55 [info     ] Parameters are saved to d3rlpy_logs/TD3PlusBC_20230319173955/params.json params={'action_scaler': {'type': 'min_max', 'params': {'minimum': array([-1., -1., -1.]), 'maximum': array([1., 1., 1.])}}, 'actor_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [100], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'actor_learning_rate': 0.0003, 'actor_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'alpha': 2.5, 'batch_size': 256, 'critic_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [100], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'critic_learning_rate': 0.0003, 'critic_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'gamma': 0.99, 'generated_maxlen': 100000, 'n_critics': 2, 'n_frames': 1, 'n_steps': 1, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': {'type': 'standard', 'params': {'mean': array([[ 0.03089025, -0.02355411, -0.01228593, -0.11395172,  0.03687143]]), 'std': array([[0.32946623, 0.38837454, 0.57328227, 0.40426394, 0.48221455]]), 'eps': 0.001}}, 'target_smoothing_clip': 0.5, 'target_smoothing_sigma': 0.2, 'tau': 0.005, 'update_actor_interval': 2, 'use_gpu': None, 'algorithm': 'TD3PlusBC', 'observation_shape': (5,), 'action_size': 3}
# Epoch 1/1:   0%|          | 0/10000 [00:00<?, ?it/s]
# 2023-03-19 17:40.13 [info     ] TD3PlusBC_20230319173955: epoch=1 step=10000 epoch=1 metrics={'time_sample_batch': 0.00045318653583526614, 'time_algorithm_update': 0.0012200720548629761, 'critic_loss': 2.420713173467107, 'actor_loss': -2.025154152750969, 'time_step': 0.0017521113634109498} step=10000
# 2023-03-19 17:40.13 [info     ] Model parameters are saved to d3rlpy_logs/TD3PlusBC_20230319173955/model_10000.pt
# [(1,
#   {'time_sample_batch': 0.00045318653583526614,
#    'time_algorithm_update': 0.0012200720548629761,
#    'critic_loss': 2.420713173467107,
#    'actor_loss': -2.025154152750969,
#    'time_step': 0.0017521113634109498})]

# %%
# save model
td3bc_b2.save_model("d3rlpy_logs/td3bc_continuous_b2.pt")

# %%
# reload model
td3bc_b2.build_with_env(env)
td3bc_b2.load_model("d3rlpy_logs/td3bc_continuous_b2.pt")
# Out:
# 2023-03-19 18:20.51 [warning  ] Parameters will be reinitialized.

# %%
# Use TD3 + Behavior Cloning (TD3+BC) policy
# base policy 3: hidden_units = [50, 10]
td3bc_b3 = TD3PlusBC(
    actor_encoder_factory=VectorEncoderFactory(hidden_units=[50, 10]),
    critic_encoder_factory=VectorEncoderFactory(hidden_units=[50, 10]),
    q_func_factory=MeanQFunctionFactory(),
    use_gpu=torch.cuda.is_available(),
    action_scaler=MinMaxActionScaler(
        minimum=env_.action_space.low,  # minimum value that policy can take
        maximum=env_.action_space.high,  # maximum value that policy can take
    )
)

# %%
td3bc_b3.fit(
    train_episodes,
    eval_episodes=test_episodes,
    n_steps=10000,
    scorers={},
)
# Out:
# 2023-03-19 18:20.51 [debug    ] RandomIterator is selected.
# 2023-03-19 18:20.51 [info     ] Directory is created at d3rlpy_logs/TD3PlusBC_20230319182051
# 2023-03-19 18:20.51 [debug    ] Fitting scaler...              scaler=standard
# 2023-03-19 18:20.51 [debug    ] Fitting action scaler...       action_scaler=min_max
# 2023-03-19 18:20.51 [debug    ] Building models...
# 2023-03-19 18:20.51 [debug    ] Models have been built.
# 2023-03-19 18:20.51 [info     ] Parameters are saved to d3rlpy_logs/TD3PlusBC_20230319182051/params.json params={'action_scaler': {'type': 'min_max', 'params': {'minimum': array([-1., -1., -1.]), 'maximum': array([1., 1., 1.])}}, 'actor_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [50, 10], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'actor_learning_rate': 0.0003, 'actor_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'alpha': 2.5, 'batch_size': 256, 'critic_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [50, 10], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'critic_learning_rate': 0.0003, 'critic_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'gamma': 0.99, 'generated_maxlen': 100000, 'n_critics': 2, 'n_frames': 1, 'n_steps': 1, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': {'type': 'standard', 'params': {'mean': array([[ 0.03089025, -0.02355411, -0.01228593, -0.11395172,  0.03687143]]), 'std': array([[0.32946623, 0.38837454, 0.57328227, 0.40426394, 0.48221455]]), 'eps': 0.001}}, 'target_smoothing_clip': 0.5, 'target_smoothing_sigma': 0.2, 'tau': 0.005, 'update_actor_interval': 2, 'use_gpu': None, 'algorithm': 'TD3PlusBC', 'observation_shape': (5,), 'action_size': 3}
# Epoch 1/1:   0%|          | 0/10000 [00:00<?, ?it/s]
# 2023-03-19 18:21.12 [info     ] TD3PlusBC_20230319182051: epoch=1 step=10000 epoch=1 metrics={'time_sample_batch': 0.00048610243797302246, 'time_algorithm_update': 0.001511806058883667, 'critic_loss': 2.2975495459244586, 'actor_loss': -1.9797124587893487, 'time_step': 0.0021011135339736938} step=10000
# 2023-03-19 18:21.12 [info     ] Model parameters are saved to d3rlpy_logs/TD3PlusBC_20230319182051/model_10000.pt
# [(1,
#   {'time_sample_batch': 0.00048610243797302246,
#    'time_algorithm_update': 0.001511806058883667,
#    'critic_loss': 2.2975495459244586,
#    'actor_loss': -1.9797124587893487,
#    'time_step': 0.0021011135339736938})]

# %%
# save model
td3bc_b3.save_model("d3rlpy_logs/td3bc_continuous_b3.pt")

# %%
# reload model
td3bc_b3.build_with_env(env)
td3bc_b3.load_model("d3rlpy_logs/td3bc_continuous_b3.pt")
# Out:
# 2023-03-19 18:21.12 [warning  ] Parameters will be reinitialized.

# %%
# Use Implicit Q-Learning (IQL) policy
# base policy 1: hidden_units = [30, 30]
iql_b1 = IQL(
    actor_encoder_factory=VectorEncoderFactory(hidden_units=[30, 30]),
    critic_encoder_factory=VectorEncoderFactory(hidden_units=[30, 30]),
    use_gpu=torch.cuda.is_available(),
    action_scaler=MinMaxActionScaler(
        minimum=env_.action_space.low,  # minimum value that policy can take
        maximum=env_.action_space.high,  # maximum value that policy can take
    )
)

# %%
iql_b1.fit(
    train_episodes,
    eval_episodes=test_episodes,
    n_steps=10000,
    scorers={},
)
# Out:
# 2023-03-19 18:21.13 [debug    ] RandomIterator is selected.
# 2023-03-19 18:21.13 [info     ] Directory is created at d3rlpy_logs/IQL_20230319182113
# 2023-03-19 18:21.13 [debug    ] Fitting action scaler...       action_scaler=min_max
# 2023-03-19 18:21.13 [debug    ] Building models...
# 2023-03-19 18:21.13 [debug    ] Models have been built.
# 2023-03-19 18:21.13 [info     ] Parameters are saved to d3rlpy_logs/IQL_20230319182113/params.json params={'action_scaler': {'type': 'min_max', 'params': {'minimum': array([-1., -1., -1.]), 'maximum': array([1., 1., 1.])}}, 'actor_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'actor_learning_rate': 0.0003, 'actor_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'batch_size': 256, 'critic_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'critic_learning_rate': 0.0003, 'critic_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'expectile': 0.7, 'gamma': 0.99, 'generated_maxlen': 100000, 'max_weight': 100.0, 'n_critics': 2, 'n_frames': 1, 'n_steps': 1, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': None, 'tau': 0.005, 'use_gpu': None, 'value_encoder_factory': {'type': 'default', 'params': {'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None}}, 'weight_temp': 3.0, 'algorithm': 'IQL', 'observation_shape': (5,), 'action_size': 3}
# Epoch 1/1:   0%|          | 0/10000 [00:00<?, ?it/s]
# 2023-03-19 18:21.48 [info     ] IQL_20230319182113: epoch=1 step=10000 epoch=1 metrics={'time_sample_batch': 0.0004789762258529663, 'time_algorithm_update': 0.0028279863595962523, 'critic_loss': 0.6659324524616823, 'value_loss': 0.041912429855433586, 'actor_loss': 2.3002481889009476, 'time_step': 0.0035077723264694215} step=10000
# 2023-03-19 18:21.48 [info     ] Model parameters are saved to d3rlpy_logs/IQL_20230319182113/model_10000.pt
# [(1,
#   {'time_sample_batch': 0.0004789762258529663,
#    'time_algorithm_update': 0.0028279863595962523,
#    'critic_loss': 0.6659324524616823,
#    'value_loss': 0.041912429855433586,
#    'actor_loss': 2.3002481889009476,
#    'time_step': 0.0035077723264694215})]

# %%
# save model
iql_b1.save_model("d3rlpy_logs/iql_continuous_b1.pt")

# %%
# reload model
iql_b1.build_with_env(env)
iql_b1.load_model("d3rlpy_logs/iql_continuous_b1.pt")
# Out:
# 2023-03-19 18:21.48 [warning  ] Parameters will be reinitialized.

# %%
# Use Implicit Q-Learning (IQL) policy
# base policy 2: hidden_units = [100]
iql_b2 = IQL(
    actor_encoder_factory=VectorEncoderFactory(hidden_units=[100]),
    critic_encoder_factory=VectorEncoderFactory(hidden_units=[100]),
    use_gpu=torch.cuda.is_available(),
    action_scaler=MinMaxActionScaler(
        minimum=env_.action_space.low,  # minimum value that policy can take
        maximum=env_.action_space.high,  # maximum value that policy can take
    )
)

# %%
iql_b2.fit(
    train_episodes,
    eval_episodes=test_episodes,
    n_steps=10000,
    scorers={},
)
# Out:
# 2023-03-19 18:21.48 [debug    ] RandomIterator is selected.
# 2023-03-19 18:21.48 [info     ] Directory is created at d3rlpy_logs/IQL_20230319182148
# 2023-03-19 18:21.48 [debug    ] Fitting action scaler...       action_scaler=min_max
# 2023-03-19 18:21.48 [debug    ] Building models...
# 2023-03-19 18:21.48 [debug    ] Models have been built.
# 2023-03-19 18:21.48 [info     ] Parameters are saved to d3rlpy_logs/IQL_20230319182148/params.json params={'action_scaler': {'type': 'min_max', 'params': {'minimum': array([-1., -1., -1.]), 'maximum': array([1., 1., 1.])}}, 'actor_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [100], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'actor_learning_rate': 0.0003, 'actor_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'batch_size': 256, 'critic_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [100], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'critic_learning_rate': 0.0003, 'critic_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'expectile': 0.7, 'gamma': 0.99, 'generated_maxlen': 100000, 'max_weight': 100.0, 'n_critics': 2, 'n_frames': 1, 'n_steps': 1, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': None, 'tau': 0.005, 'use_gpu': None, 'value_encoder_factory': {'type': 'default', 'params': {'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None}}, 'weight_temp': 3.0, 'algorithm': 'IQL', 'observation_shape': (5,), 'action_size': 3}
# Epoch 1/1:   0%|          | 0/10000 [00:00<?, ?it/s]
# 2023-03-19 18:22.21 [info     ] IQL_20230319182148: epoch=1 step=10000 epoch=1 metrics={'time_sample_batch': 0.00048161699771881103, 'time_algorithm_update': 0.002592041254043579, 'critic_loss': 0.6995276707963086, 'value_loss': 0.04170908443331718, 'actor_loss': 2.2745045607328414, 'time_step': 0.0032763550519943237} step=10000
# 2023-03-19 18:22.21 [info     ] Model parameters are saved to d3rlpy_logs/IQL_20230319182148/model_10000.pt
# [(1,
#   {'time_sample_batch': 0.00048161699771881103,
#    'time_algorithm_update': 0.002592041254043579,
#    'critic_loss': 0.6995276707963086,
#    'value_loss': 0.04170908443331718,
#    'actor_loss': 2.2745045607328414,
#    'time_step': 0.0032763550519943237})]

# %%
# save model
iql_b2.save_model("d3rlpy_logs/iql_continuous_b2.pt")

# %%
# reload model
iql_b2.build_with_env(env)
iql_b2.load_model("d3rlpy_logs/iql_continuous_b2.pt")
# Out:
# 2023-03-19 18:22.21 [warning  ] Parameters will be reinitialized.

# %%
# Use Implicit Q-Learning (IQL) policy
# base policy 3: hidden_units = [50, 10]
iql_b3 = IQL(
    actor_encoder_factory=VectorEncoderFactory(hidden_units=[50, 10]),
    critic_encoder_factory=VectorEncoderFactory(hidden_units=[50, 10]),
    use_gpu=torch.cuda.is_available(),
    action_scaler=MinMaxActionScaler(
        minimum=env_.action_space.low,  # minimum value that policy can take
        maximum=env_.action_space.high,  # maximum value that policy can take
    )
)

# %%
iql_b3.fit(
    train_episodes,
    eval_episodes=test_episodes,
    n_steps=10000,
    scorers={},
)
# Out:
# 2023-03-19 18:22.21 [debug    ] RandomIterator is selected.
# 2023-03-19 18:22.21 [info     ] Directory is created at d3rlpy_logs/IQL_20230319182221
# 2023-03-19 18:22.21 [debug    ] Fitting action scaler...       action_scaler=min_max
# 2023-03-19 18:22.21 [debug    ] Building models...
# 2023-03-19 18:22.21 [debug    ] Models have been built.
# 2023-03-19 18:22.21 [info     ] Parameters are saved to d3rlpy_logs/IQL_20230319182221/params.json params={'action_scaler': {'type': 'min_max', 'params': {'minimum': array([-1., -1., -1.]), 'maximum': array([1., 1., 1.])}}, 'actor_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [50, 10], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'actor_learning_rate': 0.0003, 'actor_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'batch_size': 256, 'critic_encoder_factory': {'type': 'vector', 'params': {'hidden_units': [50, 10], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'critic_learning_rate': 0.0003, 'critic_optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'expectile': 0.7, 'gamma': 0.99, 'generated_maxlen': 100000, 'max_weight': 100.0, 'n_critics': 2, 'n_frames': 1, 'n_steps': 1, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': None, 'tau': 0.005, 'use_gpu': None, 'value_encoder_factory': {'type': 'default', 'params': {'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None}}, 'weight_temp': 3.0, 'algorithm': 'IQL', 'observation_shape': (5,), 'action_size': 3}
# Epoch 1/1:   0%|          | 0/10000 [00:00<?, ?it/s]
# 2023-03-19 18:22.57 [info     ] IQL_20230319182221: epoch=1 step=10000 epoch=1 metrics={'time_sample_batch': 0.000489614462852478, 'time_algorithm_update': 0.0028807133674621584, 'critic_loss': 0.6785672980030067, 'value_loss': 0.041596146295678045, 'actor_loss': 2.349061738693714, 'time_step': 0.0035756824970245363} step=10000
# 2023-03-19 18:22.57 [info     ] Model parameters are saved to d3rlpy_logs/IQL_20230319182221/model_10000.pt
# [(1,
#   {'time_sample_batch': 0.000489614462852478,
#    'time_algorithm_update': 0.0028807133674621584,
#    'critic_loss': 0.6785672980030067,
#    'value_loss': 0.041596146295678045,
#    'actor_loss': 2.349061738693714,
#    'time_step': 0.0035756824970245363})]

# %%
# save model
iql_b3.save_model("d3rlpy_logs/iql_continuous_b3.pt")

# %%
# reload model
iql_b3.build_with_env(env)
iql_b3.load_model("d3rlpy_logs/iql_continuous_b3.pt")
# Out:
# 2023-03-19 18:22.57 [warning  ] Parameters will be reinitialized.

# %% [markdown]
# ## 2. Various Off-Policy Evaluation
# In this section, we aim at evaluating the various performance statistics of policies in an offline manner.
#
# #### Basic Estimation
#
# The most common approach in OPE is to estimate the estimators' average policy performance, the *policy value*.
#
# $$ V(\pi) := \mathbb{E}\left[\sum_{t=1}^T \gamma^{t-1} r_t \mid \pi \right] $$

# %%
# import ope modules from OFRL
from ofrl.ope import CreateOPEInput
from ofrl.ope import OffPolicyEvaluation as BasicOPE
from ofrl.ope import ContinuousDirectMethod as DM
from ofrl.ope import ContinuousTrajectoryWiseImportanceSampling as TIS
from ofrl.ope import ContinuousPerDecisionImportanceSampling as PDIS
from ofrl.ope import ContinuousDoublyRobust as DR
from ofrl.ope import ContinuousSelfNormalizedTrajectoryWiseImportanceSampling as SNTIS
from ofrl.ope import ContinuousSelfNormalizedPerDecisionImportanceSampling as SNPDIS
from ofrl.ope import ContinuousSelfNormalizedDoublyRobust as SNDR

# %%
# define evaluation policies (should be a deterministic policy)
cql_b1 = ContinuousEvalHead(base_policy=cql_b1, name="cql_b1")
cql_b2 = ContinuousEvalHead(base_policy=cql_b2, name="cql_b2")
cql_b3 = ContinuousEvalHead(base_policy=cql_b3, name="cql_b3")

td3bc_b1 = ContinuousEvalHead(base_policy=td3bc_b1, name="td3bc_b1")
td3bc_b2 = ContinuousEvalHead(base_policy=td3bc_b2, name="td3bc_b2")
td3bc_b3 = ContinuousEvalHead(base_policy=td3bc_b3, name="td3bc_b3")

iql_b1 = ContinuousEvalHead(base_policy=iql_b1, name="iql_b1")
iql_b2 = ContinuousEvalHead(base_policy=iql_b2, name="iql_b2")
iql_b3 = ContinuousEvalHead(base_policy=iql_b3, name="iql_b3")

evaluation_policies = [
    cql_b1, cql_b2, cql_b3,
    td3bc_b1, td3bc_b2, td3bc_b3,
    iql_b1, iql_b2, iql_b3,
]

# %%
# first, prepare OPE inputs
prep = CreateOPEInput(
    env=env,
    model_args={
        "fqe": {
            "encoder_factory": VectorEncoderFactory(hidden_units=[30, 30]),
            "q_func_factory": MeanQFunctionFactory(),
            "learning_rate": 1e-4,
            "use_gpu": torch.cuda.is_available(),
        },
    },
    state_scaler=MinMaxScaler(
        minimum=test_logged_dataset["state"].min(axis=0),
        maximum=test_logged_dataset["state"].max(axis=0),
    ),
    action_scaler=MinMaxActionScaler(
        minimum=env.action_space.low,  # minimum value that policy can take
        maximum=env.action_space.high,  # maximum value that policy can take
    ),
    sigma=0.1,
)

# %%
# takes time
input_dict = prep.obtain_whole_inputs(
    logged_dataset=test_logged_dataset,
    evaluation_policies=evaluation_policies,
    require_value_prediction=True,
    n_trajectories_on_policy_evaluation=100,
    random_state=random_state,
)
# Out:
# [fit FQE model]:   0%|          | 0/9 [00:00<?, ?it/s]
# 2023-03-19 18:22.58 [debug    ] RoundIterator is selected.
# 2023-03-19 18:22.58 [info     ] Directory is created at d3rlpy_logs/FQE_20230319182258
# 2023-03-19 18:22.58 [debug    ] Fitting scaler...              scaler=min_max
# 2023-03-19 18:22.58 [debug    ] Fitting action scaler...       action_scaler=min_max
# 2023-03-19 18:22.58 [debug    ] Building models...
# 2023-03-19 18:22.58 [debug    ] Models have been built.
# 2023-03-19 18:22.58 [info     ] Parameters are saved to d3rlpy_logs/FQE_20230319182258/params.json params={'action_scaler': {'type': 'min_max', 'params': {'minimum': array([-1., -1., -1.]), 'maximum': array([1., 1., 1.])}}, 'batch_size': 100, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 1.0, 'generated_maxlen': 100000, 'learning_rate': 0.0001, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': {'type': 'min_max', 'params': {'maximum': array([0.99322107, 0.98846274, 0.99919475, 0.9884822 , 0.99685334]), 'minimum': array([-0.97854354, -0.98118773, -0.99677948, -0.99357199, -0.99834301])}}, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'FQE', 'observation_shape': (5,), 'action_size': 3}
# Epoch 1/1:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2023-03-19 18:22.59 [info     ] FQE_20230319182258: epoch=1 step=1000 epoch=1 metrics={'time_sample_batch': 7.93290138244629e-05, 'time_algorithm_update': 0.0007894394397735595, 'loss': 0.12439672062918544, 'time_step': 0.0008924269676208496} step=1000
# 2023-03-19 18:22.59 [info     ] Model parameters are saved to d3rlpy_logs/FQE_20230319182258/model_1000.pt
# 2023-03-19 18:22.59 [debug    ] RoundIterator is selected.
# 2023-03-19 18:22.59 [info     ] Directory is created at d3rlpy_logs/FQE_20230319182259
# 2023-03-19 18:22.59 [debug    ] Fitting scaler...              scaler=min_max
# 2023-03-19 18:22.59 [debug    ] Fitting action scaler...       action_scaler=min_max
# 2023-03-19 18:22.59 [debug    ] Building models...
# 2023-03-19 18:22.59 [debug    ] Models have been built.
# 2023-03-19 18:22.59 [info     ] Parameters are saved to d3rlpy_logs/FQE_20230319182259/params.json params={'action_scaler': {'type': 'min_max', 'params': {'minimum': array([-1., -1., -1.]), 'maximum': array([1., 1., 1.])}}, 'batch_size': 100, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 1.0, 'generated_maxlen': 100000, 'learning_rate': 0.0001, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': {'type': 'min_max', 'params': {'maximum': array([0.99322107, 0.98846274, 0.99919475, 0.9884822 , 0.99685334]), 'minimum': array([-0.97854354, -0.98118773, -0.99677948, -0.99357199, -0.99834301])}}, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'FQE', 'observation_shape': (5,), 'action_size': 3}
# Epoch 1/1:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2023-03-19 18:23.00 [info     ] FQE_20230319182259: epoch=1 step=1000 epoch=1 metrics={'time_sample_batch': 7.94692039489746e-05, 'time_algorithm_update': 0.0007708594799041748, 'loss': 0.12233631908893586, 'time_step': 0.0008768563270568848} step=1000
# 2023-03-19 18:23.00 [info     ] Model parameters are saved to d3rlpy_logs/FQE_20230319182259/model_1000.pt
# 2023-03-19 18:23.00 [debug    ] RoundIterator is selected.
# 2023-03-19 18:23.00 [info     ] Directory is created at d3rlpy_logs/FQE_20230319182300
# 2023-03-19 18:23.00 [debug    ] Fitting scaler...              scaler=min_max
# 2023-03-19 18:23.00 [debug    ] Fitting action scaler...       action_scaler=min_max
# 2023-03-19 18:23.00 [debug    ] Building models...
# 2023-03-19 18:23.00 [debug    ] Models have been built.
# 2023-03-19 18:23.00 [info     ] Parameters are saved to d3rlpy_logs/FQE_20230319182300/params.json params={'action_scaler': {'type': 'min_max', 'params': {'minimum': array([-1., -1., -1.]), 'maximum': array([1., 1., 1.])}}, 'batch_size': 100, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 1.0, 'generated_maxlen': 100000, 'learning_rate': 0.0001, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': {'type': 'min_max', 'params': {'maximum': array([0.99322107, 0.98846274, 0.99919475, 0.9884822 , 0.99685334]), 'minimum': array([-0.97854354, -0.98118773, -0.99677948, -0.99357199, -0.99834301])}}, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'FQE', 'observation_shape': (5,), 'action_size': 3}
# Epoch 1/1:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2023-03-19 18:23.00 [info     ] FQE_20230319182300: epoch=1 step=1000 epoch=1 metrics={'time_sample_batch': 7.938742637634278e-05, 'time_algorithm_update': 0.0007910504341125488, 'loss': 0.10872944463416934, 'time_step': 0.0008984627723693847} step=1000
# 2023-03-19 18:23.00 [info     ] Model parameters are saved to d3rlpy_logs/FQE_20230319182300/model_1000.pt
# 2023-03-19 18:23.00 [debug    ] RoundIterator is selected.
# 2023-03-19 18:23.01 [info     ] Directory is created at d3rlpy_logs/FQE_20230319182301
# 2023-03-19 18:23.01 [debug    ] Fitting scaler...              scaler=min_max
# 2023-03-19 18:23.01 [debug    ] Fitting action scaler...       action_scaler=min_max
# 2023-03-19 18:23.01 [debug    ] Building models...
# 2023-03-19 18:23.01 [debug    ] Models have been built.
# 2023-03-19 18:23.01 [info     ] Parameters are saved to d3rlpy_logs/FQE_20230319182301/params.json params={'action_scaler': {'type': 'min_max', 'params': {'minimum': array([-1., -1., -1.]), 'maximum': array([1., 1., 1.])}}, 'batch_size': 100, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 1.0, 'generated_maxlen': 100000, 'learning_rate': 0.0001, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': {'type': 'min_max', 'params': {'maximum': array([0.99322107, 0.98846274, 0.99919475, 0.9884822 , 0.99685334]), 'minimum': array([-0.97854354, -0.98118773, -0.99677948, -0.99357199, -0.99834301])}}, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'FQE', 'observation_shape': (5,), 'action_size': 3}
# Epoch 1/1:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2023-03-19 18:23.02 [info     ] FQE_20230319182301: epoch=1 step=1000 epoch=1 metrics={'time_sample_batch': 8.124089241027833e-05, 'time_algorithm_update': 0.0007983107566833497, 'loss': 0.1535052463337779, 'time_step': 0.000907151460647583} step=1000
# 2023-03-19 18:23.02 [info     ] Model parameters are saved to d3rlpy_logs/FQE_20230319182301/model_1000.pt
# 2023-03-19 18:23.02 [debug    ] RoundIterator is selected.
# 2023-03-19 18:23.02 [info     ] Directory is created at d3rlpy_logs/FQE_20230319182302
# 2023-03-19 18:23.02 [debug    ] Fitting scaler...              scaler=min_max
# 2023-03-19 18:23.02 [debug    ] Fitting action scaler...       action_scaler=min_max
# 2023-03-19 18:23.02 [debug    ] Building models...
# 2023-03-19 18:23.02 [debug    ] Models have been built.
# 2023-03-19 18:23.02 [info     ] Parameters are saved to d3rlpy_logs/FQE_20230319182302/params.json params={'action_scaler': {'type': 'min_max', 'params': {'minimum': array([-1., -1., -1.]), 'maximum': array([1., 1., 1.])}}, 'batch_size': 100, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 1.0, 'generated_maxlen': 100000, 'learning_rate': 0.0001, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': {'type': 'min_max', 'params': {'maximum': array([0.99322107, 0.98846274, 0.99919475, 0.9884822 , 0.99685334]), 'minimum': array([-0.97854354, -0.98118773, -0.99677948, -0.99357199, -0.99834301])}}, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'FQE', 'observation_shape': (5,), 'action_size': 3}
# Epoch 1/1:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2023-03-19 18:23.03 [info     ] FQE_20230319182302: epoch=1 step=1000 epoch=1 metrics={'time_sample_batch': 7.717299461364746e-05, 'time_algorithm_update': 0.0007009992599487305, 'loss': 0.1573805605508387, 'time_step': 0.0008022925853729249} step=1000
# 2023-03-19 18:23.03 [info     ] Model parameters are saved to d3rlpy_logs/FQE_20230319182302/model_1000.pt
# 2023-03-19 18:23.03 [debug    ] RoundIterator is selected.
# 2023-03-19 18:23.03 [info     ] Directory is created at d3rlpy_logs/FQE_20230319182303
# 2023-03-19 18:23.03 [debug    ] Fitting scaler...              scaler=min_max
# 2023-03-19 18:23.03 [debug    ] Fitting action scaler...       action_scaler=min_max
# 2023-03-19 18:23.03 [debug    ] Building models...
# 2023-03-19 18:23.03 [debug    ] Models have been built.
# 2023-03-19 18:23.03 [info     ] Parameters are saved to d3rlpy_logs/FQE_20230319182303/params.json params={'action_scaler': {'type': 'min_max', 'params': {'minimum': array([-1., -1., -1.]), 'maximum': array([1., 1., 1.])}}, 'batch_size': 100, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 1.0, 'generated_maxlen': 100000, 'learning_rate': 0.0001, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': {'type': 'min_max', 'params': {'maximum': array([0.99322107, 0.98846274, 0.99919475, 0.9884822 , 0.99685334]), 'minimum': array([-0.97854354, -0.98118773, -0.99677948, -0.99357199, -0.99834301])}}, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'FQE', 'observation_shape': (5,), 'action_size': 3}
# Epoch 1/1:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2023-03-19 18:23.04 [info     ] FQE_20230319182303: epoch=1 step=1000 epoch=1 metrics={'time_sample_batch': 7.8566312789917e-05, 'time_algorithm_update': 0.0007320408821105957, 'loss': 0.1944688042886555, 'time_step': 0.0008403265476226807} step=1000
# 2023-03-19 18:23.04 [info     ] Model parameters are saved to d3rlpy_logs/FQE_20230319182303/model_1000.pt
# 2023-03-19 18:23.04 [debug    ] RoundIterator is selected.
# 2023-03-19 18:23.04 [info     ] Directory is created at d3rlpy_logs/FQE_20230319182304
# 2023-03-19 18:23.04 [debug    ] Fitting scaler...              scaler=min_max
# 2023-03-19 18:23.04 [debug    ] Fitting action scaler...       action_scaler=min_max
# 2023-03-19 18:23.04 [debug    ] Building models...
# 2023-03-19 18:23.04 [debug    ] Models have been built.
# 2023-03-19 18:23.04 [info     ] Parameters are saved to d3rlpy_logs/FQE_20230319182304/params.json params={'action_scaler': {'type': 'min_max', 'params': {'minimum': array([-1., -1., -1.]), 'maximum': array([1., 1., 1.])}}, 'batch_size': 100, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 1.0, 'generated_maxlen': 100000, 'learning_rate': 0.0001, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': {'type': 'min_max', 'params': {'maximum': array([0.99322107, 0.98846274, 0.99919475, 0.9884822 , 0.99685334]), 'minimum': array([-0.97854354, -0.98118773, -0.99677948, -0.99357199, -0.99834301])}}, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'FQE', 'observation_shape': (5,), 'action_size': 3}
# Epoch 1/1:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2023-03-19 18:23.05 [info     ] FQE_20230319182304: epoch=1 step=1000 epoch=1 metrics={'time_sample_batch': 7.742977142333985e-05, 'time_algorithm_update': 0.0007810025215148926, 'loss': 0.1575591699592769, 'time_step': 0.0008840844631195069} step=1000
# 2023-03-19 18:23.05 [info     ] Model parameters are saved to d3rlpy_logs/FQE_20230319182304/model_1000.pt
# 2023-03-19 18:23.05 [debug    ] RoundIterator is selected.
# 2023-03-19 18:23.05 [info     ] Directory is created at d3rlpy_logs/FQE_20230319182305
# 2023-03-19 18:23.05 [debug    ] Fitting scaler...              scaler=min_max
# 2023-03-19 18:23.05 [debug    ] Fitting action scaler...       action_scaler=min_max
# 2023-03-19 18:23.05 [debug    ] Building models...
# 2023-03-19 18:23.05 [debug    ] Models have been built.
# 2023-03-19 18:23.05 [info     ] Parameters are saved to d3rlpy_logs/FQE_20230319182305/params.json params={'action_scaler': {'type': 'min_max', 'params': {'minimum': array([-1., -1., -1.]), 'maximum': array([1., 1., 1.])}}, 'batch_size': 100, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 1.0, 'generated_maxlen': 100000, 'learning_rate': 0.0001, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': {'type': 'min_max', 'params': {'maximum': array([0.99322107, 0.98846274, 0.99919475, 0.9884822 , 0.99685334]), 'minimum': array([-0.97854354, -0.98118773, -0.99677948, -0.99357199, -0.99834301])}}, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'FQE', 'observation_shape': (5,), 'action_size': 3}
# Epoch 1/1:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2023-03-19 18:23.06 [info     ] FQE_20230319182305: epoch=1 step=1000 epoch=1 metrics={'time_sample_batch': 7.76832103729248e-05, 'time_algorithm_update': 0.0007607684135437011, 'loss': 0.15781316487863659, 'time_step': 0.0008653571605682373} step=1000
# 2023-03-19 18:23.06 [info     ] Model parameters are saved to d3rlpy_logs/FQE_20230319182305/model_1000.pt
# 2023-03-19 18:23.06 [debug    ] RoundIterator is selected.
# 2023-03-19 18:23.06 [info     ] Directory is created at d3rlpy_logs/FQE_20230319182306
# 2023-03-19 18:23.06 [debug    ] Fitting scaler...              scaler=min_max
# 2023-03-19 18:23.06 [debug    ] Fitting action scaler...       action_scaler=min_max
# 2023-03-19 18:23.06 [debug    ] Building models...
# 2023-03-19 18:23.06 [debug    ] Models have been built.
# 2023-03-19 18:23.06 [info     ] Parameters are saved to d3rlpy_logs/FQE_20230319182306/params.json params={'action_scaler': {'type': 'min_max', 'params': {'minimum': array([-1., -1., -1.]), 'maximum': array([1., 1., 1.])}}, 'batch_size': 100, 'encoder_factory': {'type': 'vector', 'params': {'hidden_units': [30, 30], 'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None, 'use_dense': False}}, 'gamma': 1.0, 'generated_maxlen': 100000, 'learning_rate': 0.0001, 'n_critics': 1, 'n_frames': 1, 'n_steps': 1, 'optim_factory': {'optim_cls': 'Adam', 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'real_ratio': 1.0, 'reward_scaler': None, 'scaler': {'type': 'min_max', 'params': {'maximum': array([0.99322107, 0.98846274, 0.99919475, 0.9884822 , 0.99685334]), 'minimum': array([-0.97854354, -0.98118773, -0.99677948, -0.99357199, -0.99834301])}}, 'target_update_interval': 100, 'use_gpu': None, 'algorithm': 'FQE', 'observation_shape': (5,), 'action_size': 3}
# Epoch 1/1:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2023-03-19 18:23.07 [info     ] FQE_20230319182306: epoch=1 step=1000 epoch=1 metrics={'time_sample_batch': 7.860469818115235e-05, 'time_algorithm_update': 0.0007793488502502441, 'loss': 0.1329747294895351, 'time_step': 0.0008844347000122071} step=1000
# 2023-03-19 18:23.07 [info     ] Model parameters are saved to d3rlpy_logs/FQE_20230319182306/model_1000.pt
# [collect input data: eval_policy]:   0%|          | 0/9 [00:00<?, ?it/s]
# [calculate on-policy policy value]:   0%|          | 0/100 [00:00<?, ?it/s]
# [calculate on-policy policy value]:   0%|          | 0/100 [00:00<?, ?it/s]
# [calculate on-policy policy value]:   0%|          | 0/100 [00:00<?, ?it/s]
# [calculate on-policy policy value]:   0%|          | 0/100 [00:00<?, ?it/s]
# [calculate on-policy policy value]:   0%|          | 0/100 [00:00<?, ?it/s]
# [calculate on-policy policy value]:   0%|          | 0/100 [00:00<?, ?it/s]
# [calculate on-policy policy value]:   0%|          | 0/100 [00:00<?, ?it/s]
# [calculate on-policy policy value]:   0%|          | 0/100 [00:00<?, ?it/s]
# [calculate on-policy policy value]:   0%|          | 0/100 [00:00<?, ?it/s]

# %%
with open("logs/ope_input_dict_continuous_advanced.pkl", "wb") as f:
    pickle.dump(input_dict, f)

# %%
with open("logs/ope_input_dict_continuous_advanced.pkl", "rb") as f:
    input_dict = pickle.load(f)

# %%
ope = BasicOPE(
    logged_dataset=test_logged_dataset,
    ope_estimators=[DM(), TIS(), PDIS(), DR(), SNTIS(), SNPDIS(), SNDR()],
    action_scaler=MinMaxActionScaler(
        minimum=env.action_space.low,  # minimum value that policy can take
        maximum=env.action_space.high,  # maximum value that policy can take
    ),
    sigma=0.1,
)

# %%
# policy value estimation by ope
policy_value_df_dict, policy_value_interval_df_dict = ope.summarize_off_policy_estimates(input_dict, random_state=random_state)
# dictionary of the estimation
policy_value_df_dict
# Out:
# {'cql_b1':            policy_value  relative_policy_value
#  on_policy  5.000090e+00           1.000000e+00
#  dm         1.584258e+00           3.168459e-01
#  tis        1.086642e-62           2.173245e-63
#  pdis      -5.396478e-06          -1.079276e-06
#  dr         1.584261e+00           3.168466e-01
#  sntis      1.086642e-52           2.173245e-53
#  snpdis    -6.010202e-01          -1.202019e-01
#  sndr       1.854274e+00           3.708482e-01,
#  'cql_b2':            policy_value  relative_policy_value
#  on_policy  4.975990e+00           1.000000e+00
#  dm         1.624804e+00           3.265288e-01
#  tis        5.122379e-57           1.029419e-57
#  pdis      -1.045761e-05          -2.101614e-06
#  dr         1.624812e+00           3.265304e-01
#  sntis      5.122379e-47           1.029419e-47
#  snpdis    -8.491356e-01          -1.706466e-01
#  sndr       2.049379e+00           4.118535e-01,
#  'cql_b3':            policy_value  relative_policy_value
#  on_policy  5.088382e+00           1.000000e+00
#  dm         1.483898e+00           2.916247e-01
#  tis       -7.260904e-65          -1.426957e-65
#  pdis      -6.554825e-06          -1.288195e-06
#  dr         1.483904e+00           2.916259e-01
#  sntis     -7.260904e-55          -1.426957e-55
#  snpdis    -5.019390e-01          -9.864414e-02
#  sndr       1.900030e+00           3.734056e-01,
#  'td3bc_b1':            policy_value  relative_policy_value
#  on_policy  6.227604e+00           1.000000e+00
#  dm         1.960783e+00           3.148536e-01
#  tis       -2.744683e-94          -4.407286e-95
#  pdis      -5.335025e-08          -8.566737e-09
#  dr         1.960783e+00           3.148536e-01
#  sntis     -2.744683e-84          -4.407286e-85
#  snpdis    -3.181905e-01          -5.109356e-02
#  sndr       2.291963e+00           3.680329e-01,
#  'td3bc_b2':            policy_value  relative_policy_value
#  on_policy  5.830659e+00           1.000000e+00
#  dm         1.943281e+00           3.332866e-01
#  tis       -7.371073e-98          -1.264192e-98
#  pdis      -2.052380e-06          -3.519980e-07
#  dr         1.943284e+00           3.332872e-01
#  sntis     -7.371073e-88          -1.264192e-88
#  snpdis    -2.044146e-01          -3.505858e-02
#  sndr       2.275629e+00           3.902867e-01,
#  'td3bc_b3':            policy_value  relative_policy_value
#  on_policy  5.738029e+00           1.000000e+00
#  dm         2.200718e+00           3.835320e-01
#  tis       -5.349022e-99         -9.322055e-100
#  pdis      -1.563773e-05          -2.725280e-06
#  dr         2.200736e+00           3.835351e-01
#  sntis     -5.349022e-89          -9.322055e-90
#  snpdis    -3.528218e-01          -6.148833e-02
#  sndr       2.605186e+00           4.540210e-01,
#  'iql_b1':            policy_value  relative_policy_value
#  on_policy  5.181983e+00           1.000000e+00
#  dm         1.882982e+00           3.633709e-01
#  tis       -5.570480e-57          -1.074971e-57
#  pdis      -2.346601e-05          -4.528385e-06
#  dr         1.883005e+00           3.633754e-01
#  sntis     -5.570480e-47          -1.074971e-47
#  snpdis    -3.718249e-01          -7.175341e-02
#  sndr       2.399573e+00           4.630608e-01,
#  'iql_b2':            policy_value  relative_policy_value
#  on_policy  5.162955e+00           1.000000e+00
#  dm         1.888874e+00           3.658514e-01
#  tis       -2.301244e-56          -4.457223e-57
#  pdis      -2.653935e-05          -5.140341e-06
#  dr         1.888901e+00           3.658565e-01
#  sntis     -2.301244e-46          -4.457223e-47
#  snpdis    -7.228588e-01          -1.400087e-01
#  sndr       2.376026e+00           4.602066e-01,
#  'iql_b3':            policy_value  relative_policy_value
#  on_policy  5.198168e+00           1.000000e+00
#  dm         1.624172e+00           3.124509e-01
#  tis       -1.762318e-59          -3.390268e-60
#  pdis      -1.135825e-05          -2.185048e-06
#  dr         1.624185e+00           3.124533e-01
#  sntis     -1.762318e-49          -3.390268e-50
#  snpdis    -4.587266e-01          -8.824775e-02
#  sndr       2.022141e+00           3.890103e-01}

# %%
# visualize and compare the result
ope.visualize_off_policy_estimates(
    input_dict, 
    compared_estimators=["dm", "sntis", "snpdis", "sndr"],
    random_state=random_state, 
    sharey=False,
)
# relative policy value to the behavior policy
# ope.visualize_off_policy_estimates(input_dict, random_state=random_state, is_relative=True, sharey=False)

# %%
# we can also compare the policy value of candidate OPE estimators estimated by a single OPE estimator
ope.visualize_off_policy_estimates(input_dict, random_state=random_state, hue="policy", sharey=False)
# relative policy value to the behavior policy
# ope.visualize_off_policy_estimates(input_dict, random_state=random_state, is_relative=True, hue="policy", sharey=False)

# %% [markdown]
# #### Cumulative Distribution Function Estimation
# We can also estimate various statistics regarding the policy performance based on the cumulative distribution function of the trajectory wise reward.
#
# $$ F(t, \pi) := \mathbb{E}\left[ \mathbb{I} \left \{ \sum_{t=1}^T \gamma^{t-1} r_t \leq t \right \} \mid \pi \right] $$
#
# Specifically, we can estimate the following performance metrics.
# - Cumulative Distribution Function
# - Mean of the return (i.e., policy value)
# - Variance of the return
# - Conditional Value at Risk
# - Interquartile Range

# %%
from ofrl.ope import CumulativeDistributionOffPolicyEvaluation as CumulativeDistributionOPE
from ofrl.ope import ContinuousCumulativeDistributionDirectMethod as CD_DM
from ofrl.ope import ContinuousCumulativeDistributionTrajectoryWiseImportanceSampling as CD_IS
from ofrl.ope import ContinuousCumulativeDistributionTrajectoryWiseDoublyRobust as CD_DR
from ofrl.ope import ContinuousCumulativeDistributionSelfNormalizedTrajectoryWiseImportanceSampling as CD_SNIS
from ofrl.ope import ContinuousCumulativeDistributionSelfNormalizedTrajectoryWiseDoublyRobust as CD_SNDR

# %%
cd_ope = CumulativeDistributionOPE(
    logged_dataset=test_logged_dataset,
    ope_estimators=[
        CD_DM(estimator_name="cdf_dm"), 
        CD_IS(estimator_name="cdf_is"), 
        CD_DR(estimator_name="cdf_dr"), 
        CD_SNIS(estimator_name="cdf_snis"), 
        CD_SNDR(estimator_name="cdf_sndr"),
    ],
    action_scaler=MinMaxActionScaler(
        minimum=env.action_space.low,  # minimum value that policy can take
        maximum=env.action_space.high,  # maximum value that policy can take
    ),
    sigma=0.1,
)

# %%
# cumulative distribution function
cd_ope.visualize_cumulative_distribution_function(input_dict, n_cols=4)

# %%
# cumulative distribution function comparison by each OPE estimator
# legend (evaluation policy name) is omitted here
cd_ope.visualize_cumulative_distribution_function(
    input_dict, 
    hue="policy",
    n_cols=4,
    legend=False,
)

# %%
# policy value calculated from cumulative distribution function
mean_dict = cd_ope.estimate_mean(input_dict)
variance_dict = cd_ope.estimate_variance(input_dict)

# visualize the policy value and its confidence intervals based on the mean and variance
# cd_ope.visualize_policy_value(input_dict, sharey=True)
# comparison among candidate policies by an OPE estimator
cd_ope.visualize_policy_value(input_dict, hue="policy", sharey=True)

# %%
# conditional value at risk
cvar_dict = cd_ope.estimate_conditional_value_at_risk(input_dict, alphas=0.3)
# visualize conditional value at risk
cd_ope.visualize_conditional_value_at_risk(input_dict, alphas=np.linspace(0, 1, 20), n_cols=3, sharey=True)
# comparison among candidate policies by an OPE estimator
# cd_ope.visualize_conditional_value_at_risk(input_dict, alphas=np.linspace(0, 1, 20), n_cols=4, sharey=True)

# %%
# interquartile range
interquartile_range_dict = cd_ope.estimate_interquartile_range(input_dict, alpha=0.10)
# visualize interquartile range
# cd_ope.visualize_interquartile_range(input_dict, alpha=0.10, sharey=True)
# comparison among candidate policies by an OPE estimator
cd_ope.visualize_interquartile_range(input_dict, alpha=0.10, hue="policy", sharey=True)

# %% [markdown]
# ## 3. Off-Policy Selection
#
# Off Policy Selection aims to select the ''best'' policy among several candidate policies based on some metrics.

# %%
from ofrl.ope import OffPolicySelection

# %%
ops = OffPolicySelection(
    ope=ope,
    cumulative_distribution_ope=cd_ope,
)

# %%
ops.obtain_true_selection_result(
    input_dict=input_dict,
    return_variance=True,
    return_lower_quartile=True,
    return_conditional_value_at_risk=True,
    return_by_dataframe=True,
)
# Out:
#     ranking  policy_value  relative_policy_value  variance  \
# 0  td3bc_b1      6.227604               3.855956  0.104378
# 1  td3bc_b2      5.830659               3.610179  0.092952
# 2  td3bc_b3      5.738029               3.552825  0.083925
# 3    iql_b3      5.198168               3.218559  0.137136
# 4    iql_b1      5.181983               3.208537  0.127922
# 5    iql_b2      5.162955               3.196756  0.137025
# 6    cql_b3      5.088382               3.150582  0.331830
# 7    cql_b1      5.000090               3.095914  0.319025
# 8    cql_b2      4.975990               3.080992  0.453919
#
#   ranking_by_lower_quartile  lower_quartile  \
# 0                    cql_b1        5.665670
# 1                    cql_b2        5.315328
# 2                    cql_b3        5.195939
# 3                  td3bc_b1        4.563112
# 4                  td3bc_b2        4.552542
# 5                  td3bc_b3        4.529569
# 6                    iql_b1        4.025096
# 7                    iql_b2        3.947437
# 8                    iql_b3        3.601258
#
#   ranking_by_conditional_value_at_risk  conditional_value_at_risk
# 0                             td3bc_b1                   5.604698
# 1                             td3bc_b2                   5.227729
# 2                             td3bc_b3                   5.129593
# 3                               iql_b3                   4.463522
# 4                               iql_b1                   4.456530
# 5                               iql_b2                   4.418131
# 6                               cql_b3                   3.710658
# 7                               cql_b1                   3.621723
# 8                               cql_b2                   3.282267

# %%
ranking_df, metric_df = ops.select_by_policy_value(
    input_dict=input_dict,
    return_true_values=True,
    return_metrics=True,
    return_by_dataframe=True,
)

# %%
ranking_df
# Out:
# {'dm':   estimated_ranking  estimated_policy_value  estimated_relative_policy_value  \
#  0          td3bc_b3                2.200718                         1.362622
#  1          td3bc_b1                1.960783                         1.214062
#   estimator  mean_squared_error  rank_correlation    pvalue  regret@1  \
# 0        dm           12.899684          0.733333  0.024554  0.489575
# 1       tis           29.098623         -0.233333  0.545699  1.251614
# 2      pdis           29.098741          0.266667  0.487922  0.000000
# 3        dr           12.899606          0.733333  0.024554  0.489575
# 4     sntis           29.098623         -0.233333  0.545699  1.251614
# 5    snpdis           34.490248          0.916667  0.000507  0.396945
# 6      sndr           10.240548          0.500000  0.170471  0.489575
#
#    type_i_error_rate  type_ii_error_rate
# 0           0.000000                 0.0
# 1           0.777778                 0.0
# 2           1.000000                 0.0
# 3           0.000000                 0.0
# 4           0.777778                 0.0
# 5           1.000000                 0.0
# 6           0.000000                 0.0

# %%
ranking_df, metric_df = ops.select_by_policy_value_via_cumulative_distribution_ope(
    input_dict=input_dict,
    return_metrics=True,
    return_by_dataframe=True,
)

# %%
metric_df
# Out:
#   estimator  mean_squared_error  rank_correlation    pvalue  regret@1  \
# 0    cdf_dm           12.897516          0.733333  0.024554  0.489575
# 1    cdf_is           29.098623         -0.233333  0.545699  1.251614
# 2    cdf_dr           12.897516          0.733333  0.024554  0.489575
# 3  cdf_snis           40.870220         -0.850000  0.003705  1.251614
# 4  cdf_sndr           41.254952         -0.850000  0.003705  1.251614
#
#    type_i_error_rate  type_ii_error_rate
# 0           0.000000                 0.0
# 1           0.777778                 0.0
# 2           0.000000                 0.0
# 3           0.777778                 0.0
# 4           0.777778                 0.0

# %%
ranking_df, metric_df = ops.select_by_policy_value_lower_bound(
    input_dict=input_dict,
    cis=["bootstrap", "bernstein", "hoeffding", "ttest"],
    return_metrics=True,
    return_by_dataframe=True,
    random_state=12345,
)

# %%
metric_df
# Out:
#            ci estimator  mean_squared_error  rank_correlation    pvalue  \
# 0   bootstrap        dm                 NaN          0.733333  0.024554
# 1   bootstrap       tis                 NaN          0.566667  0.111633
# 2   bootstrap      pdis                 NaN          0.266667  0.487922
# 3   bootstrap        dr                 NaN          0.733333  0.024554
# 4   bootstrap     sntis                 NaN          0.566667  0.111633
# 5   bootstrap    snpdis                 NaN          0.816667  0.007225
# 6   bootstrap      sndr                 NaN          0.666667  0.049867
# 7   bernstein        dm                 NaN          0.733333  0.024554
# 8   bernstein       tis                 NaN          0.633333  0.067086
# 9   bernstein      pdis                 NaN          0.250000  0.516490
# 10  bernstein        dr                 NaN          0.733333  0.024554
# 11  bernstein     sntis                 NaN          0.633333  0.067086
# 12  bernstein    snpdis                 NaN          0.750000  0.019942
# 13  bernstein      sndr                 NaN         -0.216667  0.575515
# 14  hoeffding        dm                 NaN         -0.766667  0.015944
# 15  hoeffding       tis                 NaN          0.683333  0.042442
# 16  hoeffding      pdis                 NaN         -0.050000  0.898353
# 17  hoeffding        dr                 NaN         -0.766667  0.015944
# 18  hoeffding     sntis                 NaN          0.683333  0.042442
# 19  hoeffding    snpdis                 NaN         -0.133333  0.732368
# 20  hoeffding      sndr                 NaN         -0.316667  0.406397
# 21      ttest        dm                 NaN          0.733333  0.024554
# 22      ttest       tis                 NaN          0.566667  0.111633
# 23      ttest      pdis                 NaN          0.266667  0.487922
# 24      ttest        dr                 NaN          0.733333  0.024554
# 25      ttest     sntis                 NaN          0.566667  0.111633
# 26      ttest    snpdis                 NaN          0.800000  0.009628
# 27      ttest      sndr                 NaN          0.633333  0.067086
#
#     regret@1  type_i_error_rate  type_ii_error_rate
# 0   0.489575           0.000000                 0.0
# 1   0.489575           1.000000                 0.0
# 2   0.000000           1.000000                 0.0
# 3   0.489575           0.000000                 0.0
# 4   0.489575           1.000000                 0.0
# 5   0.000000           1.000000                 0.0
# 6   0.489575           0.000000                 0.0
# 7   0.489575           0.000000                 0.0
# 8   0.489575           1.000000                 0.0
# 9   0.000000           1.000000                 0.0
# 10  0.489575           0.000000                 0.0
# 11  0.489575           1.000000                 0.0
# 12  0.396945           1.000000                 0.0
# 13  1.227514           0.666667                 0.0
# 14  1.227514           1.000000                 0.0
# 15  0.489575           1.000000                 0.0
# 16  0.000000           1.000000                 0.0
# 17  1.227514           1.000000                 0.0
# 18  0.489575           1.000000                 0.0
# 19  1.139222           1.000000                 0.0
# 20  1.227514           1.000000                 0.0
# 21  0.489575           0.000000                 0.0
# 22  0.489575           1.000000                 0.0
# 23  0.000000           1.000000                 0.0
# 24  0.489575           0.000000                 0.0
# 25  0.489575           1.000000                 0.0
# 26  0.396945           1.000000                 0.0
# 27  0.489575           0.000000                 0.0

# %%
ranking_df, metric_df = ops.select_by_lower_quartile(
    input_dict=input_dict,
    return_metrics=True,
    return_by_dataframe=True,
)

# %%
metric_df
# Out:
#   estimator  mean_squared_error  rank_correlation    pvalue  regret  \
# 0    cdf_dm           10.316567         -0.450000  0.224216     NaN
# 1    cdf_is            1.354968         -1.000000  0.000000     NaN
# 2    cdf_dr           10.316567         -0.450000  0.224216     NaN
# 3  cdf_snis           33.644625          0.383333  0.308495     NaN
# 4  cdf_sndr           33.979278          0.383333  0.308495     NaN
#
#    type_i_error_rate  type_ii_error_rate
# 0           0.000000                 0.0
# 1           0.000000                 0.0
# 2           0.000000                 0.0
# 3           0.888889                 0.0
# 4           0.888889                 0.0

# %%
ranking_df, metric_df = ops.select_by_conditional_value_at_risk(
    input_dict=input_dict,
    return_metrics=True,
    return_by_dataframe=True,
)

# %%
metric_df
# Out:
#   estimator  mean_squared_error  rank_correlation    pvalue  regret  \
# 0    cdf_dm           19.571823          0.716667  0.029818     NaN
# 1    cdf_is           20.224134         -0.233333  0.545699     NaN
# 2    cdf_dr           19.571823          0.716667  0.029818     NaN
# 3  cdf_snis           29.479105         -0.866667  0.002495     NaN
# 4  cdf_sndr           29.813830         -0.866667  0.002495     NaN
#
#    type_i_error_rate  type_ii_error_rate
# 0           0.000000                 0.0
# 1           0.777778                 0.0
# 2           0.000000                 0.0
# 3           0.888889                 0.0
# 4           0.888889                 0.0

# %%
topk_metric_df = ops.obtain_topk_policy_value_selected_by_standard_ope(
    input_dict=input_dict,
    compared_estimators=["dm", "tis", "pdis", "dr"],
    return_safety_violation_rate=True,
    relative_safety_criteria=1.0,
topk_metric_df = ops.obtain_topk_policy_value_selected_by_cumulative_distribution_ope(
    input_dict=input_dict,
    return_safety_violation_rate=True,
    relative_safety_criteria=1.0,
    return_by_dataframe=True,
)

# %%
topk_metric_df.head()
# Out:
#   estimator  topk      k-th      best     worst      mean       std  \
# 0    cdf_dm     0  5.738029  5.738029  5.738029  5.738029       NaN
# 1    cdf_dm     1  6.227604  6.227604  5.738029  5.982816  0.346182
# 2    cdf_dm     2  5.830659  6.227604  5.738029  5.932097  0.260074
# 3    cdf_dm     3  5.162955  6.227604  5.162955  5.739812  0.439303
# 4    cdf_dm     4  5.181983  6.227604  5.162955  5.628246  0.454945
#
#    safety_violation_rate  sharpe_ratio
# 0                    0.0           NaN
# 1                    0.0     13.324038
# 2                    0.0     17.735524
# 3                    0.0     10.499689
# 4                    0.0     10.138686

# %%
topk_metric_df = ops.obtain_topk_policy_value_selected_by_lower_bound(
    input_dict=input_dict,
    compared_estimators=["dm", "tis", "pdis", "dr"],
    return_safety_violation_rate=True,
    relative_safety_criteria=1.0,
    return_by_dataframe=True,
    random_state=random_state,
)

# %%
topk_metric_df.head()
# Out:
#           ci estimator  topk      k-th      best     worst      mean  \
# 0  bootstrap        dm     0  5.162955  5.162955  5.162955  5.162955
# 1  bootstrap        dm     1  5.198168  5.198168  5.162955  5.180561
# 2  bootstrap        dm     2  5.181983  5.198168  5.162955  5.181035
# 3  bootstrap        dm     3  5.000090  5.198168  5.000090  5.135799
# 4  bootstrap        dm     4  5.088382  5.198168  5.000090  5.126315
#
#         std  safety_violation_rate  sharpe_ratio
# 0       NaN                    0.0           NaN
# 1  0.024899                    0.0    143.906082
# 2  0.017625                    0.0    203.293239
# 3  0.091610                    0.0     39.112592
# 4  0.082122                    0.0     43.631638

# %%
topk_metric_df = ops.obtain_topk_conditional_value_at_risk_selected_by_standard_ope(
    input_dict=input_dict,
    compared_estimators=["dm", "tis", "pdis", "dr"],
    ope_alpha=0.1,
    return_safety_violation_rate=True,
    safety_threshold=7.0,
    return_by_dataframe=True,
)

# %%
topk_metric_df.head()
# Out:
#   estimator  topk      k-th      best     worst      mean       std  \
# 0        dm     0  5.176613  5.176613  5.176613  5.176613       NaN
# 1        dm     1  5.653599  5.653599  5.176613  5.415106  0.337280
# 2        dm     2  5.278079  5.653599  5.176613  5.369431  0.251272
# 3        dm     3  4.486747  5.653599  4.486747  5.148760  0.486697
# 4        dm     4  4.530405  5.653599  4.486747  5.025089  0.504111
#
#    safety_violation_rate  sharpe_ratio
# 0                    1.0           NaN
# 1                    1.0     11.973842
# 2                    1.0     16.072359
# 3                    1.0      8.297844
# 4                    1.0      8.011203

# %%
topk_metric_df = ops.obtain_topk_conditional_value_at_risk_selected_by_cumulative_distribution_ope(
    input_dict=input_dict,
    ope_alpha=0.1,
    return_safety_violation_rate=True,
    safety_threshold=7.0,
    return_by_dataframe=True,
)

# %%
topk_metric_df.head()
# Out:
#   estimator  topk      k-th      best     worst      mean       std  \
# 0    cdf_dm     0  5.176613  5.176613  5.176613  5.176613       NaN
# 1    cdf_dm     1  5.278079  5.278079  5.176613  5.227346  0.071747
# 2    cdf_dm     2  5.653599  5.653599  5.176613  5.369431  0.251272
# 3    cdf_dm     3  4.486747  5.653599  4.486747  5.148760  0.486697
# 4    cdf_dm     4  4.530405  5.653599  4.486747  5.025089  0.504111
#
#    safety_violation_rate  sharpe_ratio
# 0                    1.0           NaN
# 1                    1.0     51.054662
# 2                    1.0     16.072359
# 3                    1.0      8.297844
# 4                    1.0      8.011203

# %%
topk_metric_df = ops.obtain_topk_lower_quartile_selected_by_standard_ope(
    input_dict=input_dict,
    compared_estimators=["dm", "tis", "pdis", "dr"],
    ope_alpha=0.1,
    return_safety_violation_rate=True,
    safety_threshold=10.0,
    return_by_dataframe=True,
)

# %%
topk_metric_df.head()
# Out:
#   estimator  topk      k-th      best     worst      mean       std  \
# 0        dm     0  4.583987  4.583987  4.583987  4.583987       NaN
# 1        dm     1  4.660882  4.660882  4.583987  4.622435  0.054373
# 2        dm     2  4.659332  4.660882  4.583987  4.634734  0.043955
# 3        dm     3  4.286990  4.660882  4.286990  4.547798  0.177537
# 4        dm     4  4.348498  4.660882  4.286990  4.507938  0.177718
#
#    safety_violation_rate  sharpe_ratio
# 0                    1.0           NaN
# 1                    1.0     56.017388
# 2                    1.0     69.294836
# 3                    1.0     17.155958
# 4                    1.0     17.138508

# %%
topk_metric_df = ops.obtain_topk_lower_quartile_selected_by_cumulative_distribution_ope(
    input_dict=input_dict,
    ope_alpha=0.1,
    return_safety_violation_rate=True,
    safety_threshold=10.0,
    return_by_dataframe=True,
)

# %%
topk_metric_df.head()
# Out:
#   estimator  topk      k-th      best     worst      mean       std  \
# 0    cdf_dm     0  4.583987  4.583987  4.583987  4.583987       NaN
# 1    cdf_dm     1  4.659332  4.659332  4.583987  4.621660  0.053277
# 2    cdf_dm     2  4.660882  4.660882  4.583987  4.634734  0.043955
# 3    cdf_dm     3  4.286990  4.660882  4.286990  4.547798  0.177537
# 4    cdf_dm     4  4.348498  4.660882  4.286990  4.507938  0.177718
#
#    safety_violation_rate  sharpe_ratio
# 0                    1.0           NaN
# 1                    1.0     57.140841
# 2                    1.0     69.294836
# 3                    1.0     17.155958
# 4                    1.0     17.138508

# %%
ops.visualize_topk_policy_value_selected_by_standard_ope(
    input_dict=input_dict,
    compared_estimators=["dm", "tis", "pdis", "dr"],
    relative_safety_criteria=1.0,
    legend=True,
)

# %%
ops.visualize_topk_policy_value_selected_by_cumulative_distribution_ope(
    input_dict=input_dict,
    relative_safety_criteria=1.0,
    legend=True,
)

# %%
ops.visualize_topk_policy_value_selected_by_lower_bound(
    input_dict=input_dict,
    compared_estimators=["dm", "tis", "pdis", "dr"],
    ope_cis=["bootstrap", "bernstein", "hoeffding", "ttest"],
    relative_safety_criteria=1.0,
    legend=True,
    random_state=12345,
)

# %%
ops.visualize_topk_conditional_value_at_risk_selected_by_standard_ope(
    input_dict=input_dict,
    compared_estimators=["dm", "tis", "pdis", "dr"],
    ope_alpha=0.10,
    safety_threshold=8.0,
    legend=True,
)

# %%
ops.visualize_topk_conditional_value_at_risk_selected_by_cumulative_distribution_ope(
    input_dict=input_dict,
    ope_alpha=0.10,
    safety_threshold=8.0,
    legend=True,
)

# %%
ops.visualize_topk_lower_quartile_selected_by_standard_ope(
    input_dict=input_dict,
    compared_estimators=["dm", "tis", "pdis", "dr"],
    ope_alpha=0.10,
    safety_threshold=10.0,
    legend=True,
)

# %%
ops.visualize_topk_lower_quartile_selected_by_cumulative_distribution_ope(
    input_dict=input_dict,
    ope_alpha=0.10,
    safety_threshold=10.0,
    legend=True,
)

# %%
ops.visualize_policy_value_for_validation(
    input_dict=input_dict,
    n_cols=4,
    share_axes=True,
)

# %%
ops.visualize_policy_value_of_cumulative_distribution_ope_for_validation(
    input_dict=input_dict,
    share_axes=True,
)

# %%
ops.visualize_variance_for_validation(
    input_dict=input_dict,
    share_axes=True,
)

# %%
ops.visualize_lower_quartile_for_validation(
    input_dict=input_dict,
    share_axes=True,
)

# %%
ops.visualize_conditional_value_at_risk_for_validation(
    input_dict=input_dict,
    share_axes=True,
)

# %% [markdown]
# To see how to conduct OPE/OPS with multiple datasets, please refer to [examples/quickstart/basic/basic_synthetic_continuous_multiple_datasets.ipynb](https://github.com/negocia-inc/ofrl/blob/ope/examples/quickstart/basic/basic_synthetic_continuous_multiple_datasets.ipynb).
#
# For the examples in the discrete action space, please refer to [examples/quickstart/basic/basic_synthetic_discrete_advanced.ipynb](https://github.com/negocia-inc/ofrl/blob/ope/examples/quickstart/basic/basic_synthetic_discrete_advanced.ipynb).

# %% [markdown]
# ## Reference
#
# - Vladislav Kurenkov and Sergey Kolesnikov. \
# "Showing Your Offline Reinforcement Learning Work: Online Evaluation Budget Matters.", 2022.
#
# - Audrey Huang, Liu Leqi, Zachary C. Lipton, and Kamyar Azizzadenesheli. \
# "Off-Policy Risk Assessment for Markov Decision Processes.", 2022.
#
# - Haanvid Lee, Jongmin Lee, Yunseon Choi, Wonseok Jeon, Byung-Jun Lee, Yung-Kyun Noh, and Kee-Eung Kim. \
# "Local Metric Learning for Off-Policy Evaluation in Contextual Bandits with Continuous Actions.", 2022.
#
# - Ilya Kostrikov, Ashvin Nair, and Sergey Levine. \
# "Offline Reinforcement Learning with Implicit Q-Learning.", 2022.
#
# - Yuta Saito, Shunsuke Aihara, Megumi Matsutani, and Yusuke Narita. \
# "Open Bandit Dataset and Pipeline: Towards Realistic and Reproducible Off-Policy Evaluation.", 2021.
#
# - Takuma Seno and Michita Imai. \
# "d3rlpy: An Offline Deep Reinforcement Library.", 2021.
#
# - Shengpu Tang and Jenna Wiens. \
# "Model Selection for Offline Reinforcement Learning: Practical Considerations for Healthcare Settings.", 2021.
#
# - Justin Fu, Mohammad Norouzi, Ofir Nachum, George Tucker, Ziyu Wang, Alexander Novikov, Mengjiao Yang, Michael R. Zhang, Yutian Chen, Aviral Kumar, Cosmin Paduraru, Sergey Levine, and Tom Le Paine. \
# "Benchmarks for Deep Off-Policy Evaluation.", 2021.
#
# - Audrey Huang, Liu Leqi, Zachary C. Lipton, and Kamyar Azizzadenesheli. \
# "Off-Policy Risk Assessment in Contextual Bandits.", 2021.
#
# - Yash Chandak, Scott Niekum, Bruno Castro da Silva, Erik Learned-Miller, Emma Brunskill, and Philip S. Thomas. \
# "Universal Off-Policy Evaluation.", 2021.
#
# - Scott Fujimoto and Shixiang Shane Gu. \
# "A Minimalist Approach to Offline Reinforcement Learning.", 2021.
#
# - Sergey Levine, Aviral Kumar, George Tucker, and Justin Fu. \
# "Offline Reinforcement Learning: Tutorial, Review, and Perspectives on Open Problems." 2020.
#
# - Tom Le Paine, Cosmin Paduraru, Andrea Michi, Caglar Gulcehre, Konrad Zolna, Alexander Novikov, Ziyu Wang, and Nando de Freitas. \
# "Hyperparameter Selection for Offline Reinforcement Learning.", 2020.
#
# - Aviral Kumar, Aurick Zhou, George Tucker, and Sergey Levine. \
# "Conservative Q-Learning for Offline Reinforcement Learning.", 2020.
#
# - Nathan Kallus and Angela Zhou. \
# "Policy Evaluation and Optimization with Continuous Treatments.", 2019.
#
# - Nathan Kallus and Masatoshi Uehara. \
# "Intrinsically Efficient, Stable, and Bounded Off-Policy Evaluation for Reinforcement Learning.", 2019.
#
# - Hoang Le, Cameron Voloshin, and Yisong Yue. \
# "Batch Policy Learning under Constraints.", 2019.
#
# - Di Wu, Xiujun Chen, Xun Yang, Hao Wang, Qing Tan, Xiaoxun Zhang, Jian Xu, and Kun Gai. \
# "Budget Constrained Bidding by Model-free Reinforcement Learning in Display Advertising.", 2018.
#
# - Jun Zhao, Guang Qiu, Ziyu Guan, Wei Zhao, and Xiaofei He. \
# "Deep Reinforcement Learning for Sponsored Search Real-time Bidding.", 2018.
#
# - Josiah P. Hanna, Peter Stone, and Scott Niekum. \
# "Bootstrapping with Models: Confidence Intervals for Off-Policy Evaluation.", 2017.
#
# - Nan Jiang and Lihong Li. \
# "Doubly Robust Off-policy Value Evaluation for Reinforcement Learning.", 2016.
#
# - Philip S. Thomas and Emma Brunskill. \
# "Data-Efficient Off-Policy Policy Evaluation for Reinforcement Learning.", 2016.
#
# - Greg Brockman, Vicki Cheung, Ludwig Pettersson, Jonas Schneider, John Schulman, Jie Tang, and Wojciech Zaremba. \
# "OpenAI Gym.", 2016.
#
# - Philip S. Thomas, Georgios Theocharous, and Mohammad Ghavamzadeh. \
# "High Confidence Policy Improvement.", 2015.
#
# - Philip S. Thomas, Georgios Theocharous, and Mohammad Ghavamzadeh. \
# "High Confidence Off-Policy Evaluation.", 2015.
#
# - Adith Swaminathan and Thorsten Joachims. \
# "The Self-Normalized Estimator for Counterfactual Learning.", 2015.
#
# - Hado van Hasselt, Arthur Guez, and David Silver. \
# "Deep Reinforcement Learning with Double Q-learning.", 2015.
#
# - Miroslav Dudík, Dumitru Erhan, John Langford, and Lihong Li. \
# "Doubly Robust Policy Evaluation and Optimization.", 2014.
#
# - Alex Strehl, John Langford, Sham Kakade, and Lihong Li. \
# "Learning from Logged Implicit Exploration Data.", 2010.
#
# - Alina Beygelzimer and John Langford. \
# "The Offset Tree for Learning with Partial Labels.", 2009.
#
# - Doina Precup, Richard S. Sutton, and Satinder P. Singh. \
# "Eligibility Traces for Off-Policy Policy Evaluation.", 2000.
